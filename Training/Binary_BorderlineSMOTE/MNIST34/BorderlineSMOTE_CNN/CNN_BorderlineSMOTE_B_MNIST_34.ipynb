# %%
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
import torchvision
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
import numpy as np
import torch
import matplotlib.pyplot as plt
import sys
import os
sys.path.append(os.path.abspath("/Users/max/MasterThesis/Training/"))
from imblearn.over_sampling import BorderlineSMOTE

# %%
from Swim_Maha import SwimMaha
# frac  = [0.005, 0.01, 0.02, 0.05, 0.1, 0.2]
frac = 0.005
import torch
from torch.utils.data import DataLoader, Subset, ConcatDataset, TensorDataset
from torchvision import datasets, transforms
import numpy as np

# 数据预处理
mnist34_transforms = transforms.Compose([
    transforms.ToTensor(), 
    transforms.Normalize((0.1307,), (0.3081,))
])

# 加载 MNIST 数据集
full_train_datasets = datasets.MNIST(root="/Users/max/MasterThesisData/MNIST", train=True, transform=mnist34_transforms, download=True)
full_test_datasets = datasets.MNIST(root="/Users/max/MasterThesisData/MNIST", train=False, transform=mnist34_transforms, download=True)

# 选取标签为 3 和 4 的索引
indices3_train = [i for i in range(len(full_train_datasets)) if full_train_datasets.targets[i] == 3]
indices4_train = [i for i in range(len(full_train_datasets)) if full_train_datasets.targets[i] == 4]

indices3_test = [i for i in range(len(full_test_datasets)) if full_test_datasets.targets[i] == 3]
indices4_test = [i for i in range(len(full_test_datasets)) if full_test_datasets.targets[i] == 4]

# 获取训练集中标签为 3 和 4 的数据
mnist3_train_data = full_train_datasets.data[indices3_train]
mnist3_train_labels = torch.ones(len(indices3_train), dtype=torch.long)  # 标签 3 映射为 1 

mnist4_train_data = full_train_datasets.data[indices4_train]
mnist4_train_labels = torch.zeros(len(indices4_train), dtype=torch.long)  # 标签 4 映射为 0

# 获取测试集中标签为 3 和 4 的数据
mnist3_test_data = full_test_datasets.data[indices3_test]
mnist3_test_labels = torch.ones(len(indices3_test), dtype=torch.long)  # 标签 3 映射为 1 

mnist4_test_data = full_test_datasets.data[indices4_test]
mnist4_test_labels = torch.zeros(len(indices4_test), dtype=torch.long)  # 标签 4 映射为 0
# we can set the imbalanced ratio 0.005, 0.01, 0.02, 0.05, 0.1, 0.2
fraction = int(frac * len(mnist3_train_data))  ### control the fraction of the data to be used
selected_indices_4 = np.random.choice(len(mnist4_train_data), fraction, replace=False)
fraction_mnist4_train_data = mnist4_train_data[selected_indices_4]
fraction_mnist4_train_labels = mnist4_train_labels[selected_indices_4]


# 创建最终的训练和测试数据集
Final_train_data = torch.cat([mnist3_train_data, fraction_mnist4_train_data], dim=0)
Final_train_labels = torch.cat([mnist3_train_labels, fraction_mnist4_train_labels], dim=0)

Final_test_data = torch.cat([mnist3_test_data, mnist4_test_data], dim=0)
Final_test_labels = torch.cat([mnist3_test_labels, mnist4_test_labels], dim=0)

# 创建 TensorDataset
Final_train_datasets = TensorDataset(Final_train_data.unsqueeze(1).float() / 255, Final_train_labels)
Final_test_datasets = TensorDataset(Final_test_data.unsqueeze(1).float() / 255, Final_test_labels)

# 数据加载器
train_loader = DataLoader(Final_train_datasets, batch_size=64, shuffle=True)
test_loader = DataLoader(Final_test_datasets, batch_size=64, shuffle=False)

# 打印信息
print("Number of label 3 in the final training set: ", len(mnist3_train_data))
print("Number of label 4 in the final training set (after downsampling): ", len(fraction_mnist4_train_data))
print("Number of label 3 in the final test set: ", len(mnist3_test_data))
print("Number of label 4 in the final test set: ", len(mnist4_test_data))

print("Total samples in final training set: ", len(Final_train_datasets))
print("Total samples in final test set: ", len(Final_test_datasets))

print("Number of batches in training set: ", len(train_loader))
print("Number of batches in test set: ", len(test_loader))


# 获取一个 batch
images, labels = next(iter(train_loader))

# 查看 Tensor 形状
print(f"Images shape: {images.shape}")  # 形状为 (batch_size, channels, height, width)
print(f"Labels shape: {labels.shape}")  # 形状为 (batch_size,)

# 查看第一个样本的 Tensor 值
print(f"First image tensor:\n{images[0]}")  # 打印第一个样本的 Tensor 数据
print(f"First image label: {labels[0]}")  # 打印第一个样本的标签

# 如果需要转换回 NumPy 并可视化：
import matplotlib.pyplot as plt

# 转换为 NumPy 并显示
plt.imshow(images[0].squeeze().numpy(), cmap="gray")
plt.title(f"Label: {labels[0].item()}")
plt.show()


import numpy as np

# 指定图片大小，图像大小为20宽、5高的绘图(单位为英寸inch)
plt.figure(figsize=(20, 5)) 
for i, imgs in enumerate(images[:20]):
    # 维度缩减
    npimg = np.squeeze(imgs.numpy())
    # 将整个figure分成2行10列，绘制第i+1个子图。
    plt.subplot(2, 10, i+1)
    plt.imshow(npimg, cmap=plt.cm.binary)
    plt.axis('off')
# Out:
# Number of label 3 in the final training set:  6131
# Number of label 4 in the final training set (after downsampling):  30
# Number of label 3 in the final test set:  1010
# Number of label 4 in the final test set:  982
# Total samples in final training set:  6161
# Total samples in final test set:  1992
# Number of batches in training set:  97
# Number of batches in test set:  32
# Images shape: torch.Size([64, 1, 28, 28])
# Labels shape: torch.Size([64])
# First image tensor:
# tensor([[[0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.4275, 0.9216, 0.9961, 0.9961, 0.9961, 0.8784, 0.1373,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.3804, 0.9922, 0.9922, 0.9922, 0.9922, 0.9922, 0.9922, 0.9765,
#           0.2980, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0196, 0.2314, 0.9294, 0.9922, 0.2392, 0.0471, 0.1686, 0.8706,
#           0.9608, 0.3137, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0627, 0.4980, 0.1176, 0.0000, 0.0000, 0.7176,
#           0.9922, 0.8039, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.4078, 0.9647,
#           0.9922, 0.3804, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0941, 0.8314, 0.9922,
#           0.8353, 0.0431, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.4314, 0.9922, 0.9255,
#           0.2784, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.7686, 0.9922, 0.3686,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.7686, 0.9922, 0.4235,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.6353, 0.9922, 0.9451,
#           0.2353, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.2000, 0.9333, 0.9922,
#           0.4235, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.3765, 0.9922,
#           0.8510, 0.1765, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0706, 0.8000,
#           0.9922, 0.8667, 0.0667, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.3451,
#           0.9451, 0.9922, 0.4353, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.3647, 0.9922, 0.8627, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0275, 0.0824, 0.0235,
#           0.5255, 0.9922, 0.8118, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.5569, 0.8980, 0.4118,
#           0.9922, 0.9922, 0.3569, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.7686, 0.9922, 0.9922,
#           0.9922, 0.8784, 0.1569, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.7686, 0.9922, 0.9922,
#           0.8824, 0.1529, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.5020, 0.9922, 0.6235,
#           0.1490, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000]]])
# First image label: 1

# %%
X_train = []
y_train = []

for batch in train_loader:
    images, labels = batch  # images: (batch_size, 1, 28, 28), labels: (batch_size,)
    if hasattr(images, 'numpy'): # images is tensor
        images = images.numpy()
    # batch_size = 64
    for img, label in zip(images, labels):
        #print(f"Original shape: {img.shape}")  #  
        flattened_img = img.flatten()           
        #print(f"Flattened shape: {flattened_img.shape}")
        X_train.append(flattened_img) # 
        y_train.append(label)


X_test = [] # features
y_test = [] # labels
for batch in test_loader:
    images, labels = batch  # images: (batch_size, 1,28  ,28 ), labels: (batch_size,)
    if hasattr(images, 'numpy'): # images is tensor
        images = images.numpy()
    # batch_size = 64
    for img, label in zip(images, labels):
        flattened_img = img.flatten()           # flatten the image
        X_test.append(flattened_img)
        y_test.append(label)


X_train = np.array(X_train)
y_train = np.array(y_train)
X_test = np.array(X_test)
y_test = np.array(y_test)
print("X_train.shape:", X_train.shape)
print("y_train.shape:", y_train.shape)
print("X_test.shape:", X_test.shape)
print("y_test.shape:", y_test.shape)
# from Swim_Maha import SwimMaha
# sw = SwimMaha(sd=0.25,minClass=0)
# numsampels = len(mnist3_train_data) - len(fraction_mnist4_train_data)
# X_train_end, y_train_end = sw.mahaSampling(X_train,y_train,numsampels)
# print("X_train_end.shape:", X_train_end.shape)
# print("y_train_end.shape:", y_train_end.shape)
# X_train = np.concatenate((X_train, X_train_end), axis=0)
# y_train = np.concatenate((y_train, y_train_end), axis=0)
# print("SWIM_X_train.shape:", X_train.shape)
# print("SWIM_y_train.shape:", y_train.shape)
from imblearn.over_sampling import SMOTE
from collections import Counter
from imblearn.over_sampling import BorderlineSMOTE
sm = BorderlineSMOTE(random_state=42, kind='borderline-1')
X_train, y_train = sm.fit_resample(X_train, y_train)
print('Resampled dataset shape %s' % Counter(y_train))
print("##############################################")
print("SMOTE done!")
print("X_train.shape:", X_train.shape)
print("y_train.shape:", y_train.shape)
print("X_test.shape:", X_test.shape)
print("y_test.shape:", y_test.shape)
# Out:
# X_train.shape: (6161, 784)
# y_train.shape: (6161,)
# X_test.shape: (1992, 784)
# y_test.shape: (1992,)
# Resampled dataset shape Counter({np.int64(1): 6131, np.int64(0): 6131})
# ##############################################
# SMOTE done!
# X_train.shape: (12262, 784)
# y_train.shape: (12262,)
# X_test.shape: (1992, 784)
# y_test.shape: (1992,)
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(

# %%
import torch
from torch.utils.data import TensorDataset, DataLoader

# 假设 X_train 和 y_train 都是 numpy 数组
# 注意：如果你的像素值范围在 0~255，建议在转换为 tensor 时进行归一化
X_train_tensor= torch.tensor(X_train, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train, dtype=torch.long)
print("X_train_tensor.shape:", X_train_tensor.shape)
print("y_train_tensor.shape:", y_train_tensor.shape)

# 假设 X_train_tensor 的形状为 (N, 784)，每个样本是一个扁平化的 28x28 图像
reconstructed_images = []  # 用于保存恢复后的图像

for i in range(len(X_train_tensor)):
    flattened_img = X_train_tensor[i]        # 取出第 i 个样本，形状 (784,)
    original_img = flattened_img.view(28, 28)  # 恢复为 (28, 28) 图像
    reconstructed_images.append(original_img)  # 存入列表

print("总共恢复的图像数量：", len(reconstructed_images))

# 可视化恢复后的图像
plt.figure(figsize=(20, 5))
for i, img in enumerate(reconstructed_images[:20]):
    plt.subplot(2, 10, i+1)
    plt.imshow(img, cmap="gray")
    plt.axis('off')
plt.show()


# 创建 Dataset
reconstructed_images = torch.stack(reconstructed_images)  # 将列表转换为张量
print("reconstructed_images.shape:", reconstructed_images.shape)  # (N, 28, 28)
final_train_datasets = TensorDataset(reconstructed_images.unsqueeze(1).float(), y_train_tensor)

# 使用新的 Dataset 构建新的 DataLoader
new_train_loader = DataLoader(final_train_datasets, batch_size=64, shuffle=True)
print("Number of batches in new training set: ", len(new_train_loader))

# 获取一个 batch
images, labels = next(iter(new_train_loader))
print(f"Images shape: {images.shape}")  # 形状为 (batch_size, channels, height, width)
print(f"Labels shape: {labels.shape}")  # 形状为 (batch_size,)
# Out:
# X_train_tensor.shape: torch.Size([12262, 784])
# y_train_tensor.shape: torch.Size([12262])
# 总共恢复的图像数量： 12262
# reconstructed_images.shape: torch.Size([12262, 28, 28])
# Number of batches in new training set:  192
# Images shape: torch.Size([64, 1, 28, 28])
# Labels shape: torch.Size([64])

# %%
from torchinfo import summary
import torch
import torch.nn as nn
from CNN1 import BinaryCNN1
# 将模型转移到GPU中（我们模型运行均在GPU中进行）
model = BinaryCNN1().to(device)
summary(model)
# Out:
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# BinaryCNN1                               --
# ├─Conv2d: 1-1                            320
# ├─MaxPool2d: 1-2                         --
# ├─Conv2d: 1-3                            18,496
# ├─MaxPool2d: 1-4                         --
# ├─Linear: 1-5                            102,464
# ├─Linear: 1-6                            130
# =================================================================
# Total params: 121,410
# Trainable params: 121,410
# Non-trainable params: 0
# =================================================================

# %%
from torchinfo import summary
import torch
import torch.nn as nn
from CNN1 import BinaryCNN1
# 将模型转移到GPU中（我们模型运行均在GPU中进行）
model = BinaryCNN1().to(device)
summary(model)
# define the optimizer and loss function
import torch.optim as optimizer
from self_metrics import Binary_got_metrics
loss_function = nn.CrossEntropyLoss()
learning_rate = 0.001
optimizer = optimizer.Adam(model.parameters(), lr=learning_rate)

# model training
def train(dataloader, model, loss_function, optimizer):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    train_loss, train_accuracy = 0, 0
    for images, labels in dataloader:
        images, labels = images.to(device), labels.to(device)
        # Compute prediction error
        prediction = model(images)
        loss = loss_function(prediction, labels)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        train_loss += loss.item()
        train_accuracy += (prediction.argmax(1) == labels).type(torch.float).sum().item()

    train_loss /= num_batches
    train_accuracy /= size

    return train_loss, train_accuracy



# model evaluation
def test(dataloader, model, loss_function):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    test_loss, test_accuracy = 0, 0
    # 1(1) is positive, 0(7) is negative
    # TP: 1 classified as 1
    # TN: 0 classified as 0
    # FP: 0 classified as 1
    # FN: 1 classified as 0
    TP, TN, FP, FN = 0, 0, 0, 0
    with torch.no_grad():
        for images, labels in dataloader:
            images, labels = images.to(device), labels.to(device)
            prediction = model(images)
            test_loss += loss_function(prediction, labels).item()
            test_accuracy += (prediction.argmax(1) == labels).type(torch.float).sum().item()
            TP += ((prediction.argmax(1) == 1) & (labels == 1)).type(torch.float).sum().item()
            TN += ((prediction.argmax(1) == 0) & (labels == 0)).type(torch.float).sum().item()
            FP += ((prediction.argmax(1) == 1) & (labels == 0)).type(torch.float).sum().item()
            FN += ((prediction.argmax(1) == 0) & (labels == 1)).type(torch.float).sum().item()


    test_loss /= num_batches
    test_accuracy /= size
    return test_loss, test_accuracy, TP, TN, FP, FN

# training the model
epochs = 50
train_loss_list = []
train_accuracy_list = []
test_loss_list = []
test_accuracy_list = []

best_model_TP = 0
best_model_TN = 0
best_model_FP = 0
best_model_FN = 0
best_test_accuracy = 0.0 # for saving the best model
for epoch in range(epochs):
    model.train()
    train_loss, train_accuracy = train(new_train_loader, model, loss_function, optimizer)
    model.eval()
    test_loss, test_accuracy,TP, TN, FP, FN  = test(test_loader, model, loss_function)
    train_loss_list.append(train_loss)
    train_accuracy_list.append(train_accuracy)
    test_loss_list.append(test_loss)
    test_accuracy_list.append(test_accuracy)

    print(f"Epoch: {epoch+1}/{epochs}, Train Loss: {train_loss:.4f}, Train Accuracy: {train_accuracy:.4f}, Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.4f}") 

    if test_accuracy > best_test_accuracy:
        best_test_accuracy = test_accuracy
        best_model_TP = TP
        best_model_TN = TN
        best_model_FP = FP
        best_model_FN = FN
        save_path = f"BinaryMNIST34_{fraction}.pth"
        torch.save(model.state_dict(), save_path)
        print(f"==> New best model saved at epoch {epoch+1} with Test Accuracy: {test_accuracy:.4f}")
        #print(f"==> TP: {TP}, TN: {TN}, FP: {FP}, FN: {FN}")
        Accuracy, misclassification_rate, Sensitivity, Specificity, Precision, Negative_Predictive_Value, Gmean, Fmean, DPower, F2measure, InvF_05, AGFmeasure, Balanced_Accuracy, MCCmeasure, Kappa, Youden_Index, LR_pos, LR_neg = Binary_got_metrics(best_model_TP, best_model_FP, best_model_FN, best_model_TN)
        import json

        # 构造一个包含所有指标数据的字典
        metrics_dict = {
            "Number of label 3 in the final training set": len(mnist3_train_data),
            "Number of label 4 in the final training set (after downsampling)": len(fraction_mnist4_train_data),
            "Number of label 3 in the final test set": len(mnist3_test_data),
            "Number of label 4 in the final test set": len(mnist4_test_data),
            "Total samples in final training set": len(Final_train_datasets),
            "Total samples in final test set": len(Final_test_datasets),
            "Number of batches in training set": len(train_loader),
            "Number of batches in test set": len(test_loader),
            "TP": TP,
            "FP": FP,
            "FN": FN,
            "TN": TN,
            "Accuracy": round(Accuracy, 4),
            "Misclassification rate": round(misclassification_rate, 4),
            "Sensitivity (Recall)": round(Sensitivity, 4),
            "Specificity": round(Specificity, 4),
            "Precision": round(Precision, 4),
            "Negative Predictive Value": round(Negative_Predictive_Value, 4),
            "G-mean": round(Gmean, 4),
            "F-measure": round(Fmean, 4),
            "Discriminant Power (DP)": round(DPower, 4),
            "F2-measure": round(F2measure, 4),
            "InvF0.5-measure": round(InvF_05, 4),
            "AGF": round(AGFmeasure, 4),
            "Balanced Accuracy": round(Balanced_Accuracy, 4),
            "Matthew's Correlation Coefficient (MCC)": round(MCCmeasure, 4),
            "Cohen's Kappa": round(Kappa, 4),
            "Youden's Index": round(Youden_Index, 4),
            "Positive Likelihood Ratio (LR+)": round(LR_pos, 4),
            "Negative Likelihood Ratio (LR-)": round(LR_neg, 4)
        }

        # 指定 JSON 文件保存路径
        metrics_results_path = f"BorderlineSMOTE_CNNBinaryMNIST34_{fraction}_metrics_results.json"

        # 将字典保存为 JSON 文件
        with open(metrics_results_path, "w") as f:
            json.dump(metrics_dict, f, indent=4)
# Out:
# Epoch: 1/50, Train Loss: 0.0401, Train Accuracy: 0.9914, Test Loss: 0.0333, Test Accuracy: 0.9895
# ==> New best model saved at epoch 1 with Test Accuracy: 0.9895
# TP: 1008.0
# FP: 19.0
# FN: 2.0
# TN: 963.0
# Accuracy: 0.9895
# Misclassification rate: 0.0105
# Sensitivity (Recall): 0.9980
# Specificity: 0.9807
# Precision: 0.9815
# Negative Predictive Value: 0.9979
# G-mean: 0.9893
# F-measure: 0.9897
# Discriminant Power: 5.5950
# F2-measure: 0.9848
# InvF0.5-measure: 0.9947
# AGF: 0.9897
# Balanced Accuracy: 0.9893
# Matthew's Correlation Coefficient: 0.9790
# Cohen's Kappa: 0.9789
# Youden's Index: 0.9787
# Positive Likelihood Ratio: 51.5819
# Negative Likelihood Ratio: 0.0020
# Epoch: 2/50, Train Loss: 0.0012, Train Accuracy: 0.9997, Test Loss: 0.0498, Test Accuracy: 0.9864
# Epoch: 3/50, Train Loss: 0.0002, Train Accuracy: 0.9999, Test Loss: 0.1353, Test Accuracy: 0.9669
# Epoch: 4/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1104, Test Accuracy: 0.9779
# Epoch: 5/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1054, Test Accuracy: 0.9789
# Epoch: 6/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1036, Test Accuracy: 0.9789
# Epoch: 7/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1310, Test Accuracy: 0.9729
# Epoch: 8/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1153, Test Accuracy: 0.9789
# Epoch: 9/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1069, Test Accuracy: 0.9794
# Epoch: 10/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1202, Test Accuracy: 0.9779
# Epoch: 11/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1140, Test Accuracy: 0.9789
# Epoch: 12/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1223, Test Accuracy: 0.9779
# Epoch: 13/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1241, Test Accuracy: 0.9779
# Epoch: 14/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1184, Test Accuracy: 0.9794
# Epoch: 15/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1220, Test Accuracy: 0.9784
# Epoch: 16/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1212, Test Accuracy: 0.9794
# Epoch: 17/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1178, Test Accuracy: 0.9794
# Epoch: 18/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1327, Test Accuracy: 0.9779
# Epoch: 19/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1237, Test Accuracy: 0.9794
# Epoch: 20/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1198, Test Accuracy: 0.9799
# Epoch: 21/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1279, Test Accuracy: 0.9789
# Epoch: 22/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1269, Test Accuracy: 0.9789
# Epoch: 23/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1257, Test Accuracy: 0.9794
# Epoch: 24/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1314, Test Accuracy: 0.9784
# Epoch: 25/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1304, Test Accuracy: 0.9789
# Epoch: 26/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1309, Test Accuracy: 0.9789
# Epoch: 27/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1320, Test Accuracy: 0.9789
# Epoch: 28/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1283, Test Accuracy: 0.9799
# Epoch: 29/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1293, Test Accuracy: 0.9799
# Epoch: 30/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1325, Test Accuracy: 0.9794
# Epoch: 31/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1367, Test Accuracy: 0.9789
# Epoch: 32/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1327, Test Accuracy: 0.9794
# Epoch: 33/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1324, Test Accuracy: 0.9804
# Epoch: 34/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1291, Test Accuracy: 0.9809
# Epoch: 35/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1328, Test Accuracy: 0.9809
# Epoch: 36/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1299, Test Accuracy: 0.9809
# Epoch: 37/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1338, Test Accuracy: 0.9809
# Epoch: 38/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1436, Test Accuracy: 0.9779
# Epoch: 39/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1322, Test Accuracy: 0.9814
# Epoch: 40/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1365, Test Accuracy: 0.9804
# Epoch: 41/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1415, Test Accuracy: 0.9794
# Epoch: 42/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1342, Test Accuracy: 0.9809
# Epoch: 43/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1377, Test Accuracy: 0.9804
# Epoch: 44/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1376, Test Accuracy: 0.9809
# Epoch: 45/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1428, Test Accuracy: 0.9799
# Epoch: 46/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1391, Test Accuracy: 0.9809
# Epoch: 47/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1444, Test Accuracy: 0.9794
# Epoch: 48/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1372, Test Accuracy: 0.9809
# Epoch: 49/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1416, Test Accuracy: 0.9804
# Epoch: 50/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1450, Test Accuracy: 0.9799

# %%
fractions = [0.005, 0.01, 0.02, 0.05, 0.1, 0.2]
for frac in range(len(fractions)):
    import torch
    import torch.nn as nn
    import matplotlib.pyplot as plt
    import torchvision
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    import numpy as np
    import torch
    import matplotlib.pyplot as plt
    import sys
    import os
    sys.path.append(os.path.abspath("/Users/max/MasterThesis/Training/"))
    from imblearn.over_sampling import BorderlineSMOTE
    from Swim_Maha import SwimMaha
    # frac  = [0.005, 0.01, 0.02, 0.05, 0.1, 0.2]
    #frac = 0.005
    import torch
    from torch.utils.data import DataLoader, Subset, ConcatDataset, TensorDataset
    from torchvision import datasets, transforms
    import numpy as np

    # 数据预处理
    mnist34_transforms = transforms.Compose([
        transforms.ToTensor(), 
        transforms.Normalize((0.1307,), (0.3081,))
    ])

    # 加载 MNIST 数据集
    full_train_datasets = datasets.MNIST(root="/Users/max/MasterThesisData/MNIST", train=True, transform=mnist34_transforms, download=True)
    full_test_datasets = datasets.MNIST(root="/Users/max/MasterThesisData/MNIST", train=False, transform=mnist34_transforms, download=True)

    # 选取标签为 3 和 4 的索引
    indices3_train = [i for i in range(len(full_train_datasets)) if full_train_datasets.targets[i] == 3]
    indices4_train = [i for i in range(len(full_train_datasets)) if full_train_datasets.targets[i] == 4]

    indices3_test = [i for i in range(len(full_test_datasets)) if full_test_datasets.targets[i] == 3]
    indices4_test = [i for i in range(len(full_test_datasets)) if full_test_datasets.targets[i] == 4]

    # 获取训练集中标签为 3 和 4 的数据
    mnist3_train_data = full_train_datasets.data[indices3_train]
    mnist3_train_labels = torch.ones(len(indices3_train), dtype=torch.long)  # 标签 3 映射为 1 

    mnist4_train_data = full_train_datasets.data[indices4_train]
    mnist4_train_labels = torch.zeros(len(indices4_train), dtype=torch.long)  # 标签 4 映射为 0

    # 获取测试集中标签为 3 和 4 的数据
    mnist3_test_data = full_test_datasets.data[indices3_test]
    mnist3_test_labels = torch.ones(len(indices3_test), dtype=torch.long)  # 标签 3 映射为 1 

    mnist4_test_data = full_test_datasets.data[indices4_test]
    mnist4_test_labels = torch.zeros(len(indices4_test), dtype=torch.long)  # 标签 4 映射为 0
    # we can set the imbalanced ratio 0.005, 0.01, 0.02, 0.05, 0.1, 0.2
    fraction = int(fractions[frac] * len(mnist3_train_data))  ### control the fraction of the data to be used
    selected_indices_4 = np.random.choice(len(mnist4_train_data), fraction, replace=False)
    fraction_mnist4_train_data = mnist4_train_data[selected_indices_4]
    fraction_mnist4_train_labels = mnist4_train_labels[selected_indices_4]


    # 创建最终的训练和测试数据集
    Final_train_data = torch.cat([mnist3_train_data, fraction_mnist4_train_data], dim=0)
    Final_train_labels = torch.cat([mnist3_train_labels, fraction_mnist4_train_labels], dim=0)

    Final_test_data = torch.cat([mnist3_test_data, mnist4_test_data], dim=0)
    Final_test_labels = torch.cat([mnist3_test_labels, mnist4_test_labels], dim=0)

    # 创建 TensorDataset
    Final_train_datasets = TensorDataset(Final_train_data.unsqueeze(1).float() / 255, Final_train_labels)
    Final_test_datasets = TensorDataset(Final_test_data.unsqueeze(1).float() / 255, Final_test_labels)

    # 数据加载器
    train_loader = DataLoader(Final_train_datasets, batch_size=64, shuffle=True)
    test_loader = DataLoader(Final_test_datasets, batch_size=64, shuffle=False)

    # 打印信息
    print("Number of label 3 in the final training set: ", len(mnist3_train_data))
    print("Number of label 4 in the final training set (after downsampling): ", len(fraction_mnist4_train_data))
    print("Number of label 3 in the final test set: ", len(mnist3_test_data))
    print("Number of label 4 in the final test set: ", len(mnist4_test_data))

    print("Total samples in final training set: ", len(Final_train_datasets))
    print("Total samples in final test set: ", len(Final_test_datasets))

    print("Number of batches in training set: ", len(train_loader))
    print("Number of batches in test set: ", len(test_loader))


    # 获取一个 batch
    images, labels = next(iter(train_loader))

    # 查看 Tensor 形状
    print(f"Images shape: {images.shape}")  # 形状为 (batch_size, channels, height, width)
    print(f"Labels shape: {labels.shape}")  # 形状为 (batch_size,)

    # 查看第一个样本的 Tensor 值
    print(f"First image tensor:\n{images[0]}")  # 打印第一个样本的 Tensor 数据
    print(f"First image label: {labels[0]}")  # 打印第一个样本的标签

    # 如果需要转换回 NumPy 并可视化：
    import matplotlib.pyplot as plt

    # 转换为 NumPy 并显示
    plt.imshow(images[0].squeeze().numpy(), cmap="gray")
    plt.title(f"Label: {labels[0].item()}")
    plt.show()


    import numpy as np

    # 指定图片大小，图像大小为20宽、5高的绘图(单位为英寸inch)
    plt.figure(figsize=(20, 5)) 
    for i, imgs in enumerate(images[:20]):
        # 维度缩减
        npimg = np.squeeze(imgs.numpy())
        # 将整个figure分成2行10列，绘制第i+1个子图。
        plt.subplot(2, 10, i+1)
        plt.imshow(npimg, cmap=plt.cm.binary)
        plt.axis('off')
    
    X_train = []
    y_train = []

    for batch in train_loader:
        images, labels = batch  # images: (batch_size, 1, 28, 28), labels: (batch_size,)
        if hasattr(images, 'numpy'): # images is tensor
            images = images.numpy()
        # batch_size = 64
        for img, label in zip(images, labels):
            #print(f"Original shape: {img.shape}")  #  
            flattened_img = img.flatten()           
            #print(f"Flattened shape: {flattened_img.shape}")
            X_train.append(flattened_img) # 
            y_train.append(label)


    X_test = [] # features
    y_test = [] # labels
    for batch in test_loader:
        images, labels = batch  # images: (batch_size, 1,28  ,28 ), labels: (batch_size,)
        if hasattr(images, 'numpy'): # images is tensor
            images = images.numpy()
        # batch_size = 64
        for img, label in zip(images, labels):
            flattened_img = img.flatten()           # flatten the image
            X_test.append(flattened_img)
            y_test.append(label)


    X_train = np.array(X_train)
    y_train = np.array(y_train)
    X_test = np.array(X_test)
    y_test = np.array(y_test)
    print("X_train.shape:", X_train.shape)
    print("y_train.shape:", y_train.shape)
    print("X_test.shape:", X_test.shape)
    print("y_test.shape:", y_test.shape)
    # from Swim_Maha import SwimMaha
    # sw = SwimMaha(sd=0.25,minClass=0)
    # numsampels = len(mnist3_train_data) - len(fraction_mnist4_train_data)
    # X_train_end, y_train_end = sw.mahaSampling(X_train,y_train,numsampels)
    # print("X_train_end.shape:", X_train_end.shape)
    # print("y_train_end.shape:", y_train_end.shape)
    # X_train = np.concatenate((X_train, X_train_end), axis=0)
    # y_train = np.concatenate((y_train, y_train_end), axis=0)
    # print("SWIM_X_train.shape:", X_train.shape)
    # print("SWIM_y_train.shape:", y_train.shape)
    from imblearn.over_sampling import SMOTE
    from collections import Counter
    from imblearn.over_sampling import BorderlineSMOTE
    sm = BorderlineSMOTE(random_state=42, kind='borderline-1')
    X_train, y_train = sm.fit_resample(X_train, y_train)
    print('Resampled dataset shape %s' % Counter(y_train))
    print("##############################################")
    print("SMOTE done!")
    print("X_train.shape:", X_train.shape)
    print("y_train.shape:", y_train.shape)
    print("X_test.shape:", X_test.shape)
    print("y_test.shape:", y_test.shape)
    import torch
    from torch.utils.data import TensorDataset, DataLoader

    # 假设 X_train 和 y_train 都是 numpy 数组
    # 注意：如果你的像素值范围在 0~255，建议在转换为 tensor 时进行归一化
    X_train_tensor= torch.tensor(X_train, dtype=torch.float32)
    y_train_tensor = torch.tensor(y_train, dtype=torch.long)
    print("X_train_tensor.shape:", X_train_tensor.shape)
    print("y_train_tensor.shape:", y_train_tensor.shape)

    # 假设 X_train_tensor 的形状为 (N, 784)，每个样本是一个扁平化的 28x28 图像
    reconstructed_images = []  # 用于保存恢复后的图像

    for i in range(len(X_train_tensor)):
        flattened_img = X_train_tensor[i]        # 取出第 i 个样本，形状 (784,)
        original_img = flattened_img.view(28, 28)  # 恢复为 (28, 28) 图像
        reconstructed_images.append(original_img)  # 存入列表

    print("总共恢复的图像数量：", len(reconstructed_images))

    # 可视化恢复后的图像
    plt.figure(figsize=(20, 5))
    for i, img in enumerate(reconstructed_images[:20]):
        plt.subplot(2, 10, i+1)
        plt.imshow(img, cmap="gray")
        plt.axis('off')
    plt.show()


    # 创建 Dataset
    reconstructed_images = torch.stack(reconstructed_images)  # 将列表转换为张量
    print("reconstructed_images.shape:", reconstructed_images.shape)  # (N, 28, 28)
    final_train_datasets = TensorDataset(reconstructed_images.unsqueeze(1).float(), y_train_tensor)

    # 使用新的 Dataset 构建新的 DataLoader
    new_train_loader = DataLoader(final_train_datasets, batch_size=64, shuffle=True)
    print("Number of batches in new training set: ", len(new_train_loader))

    # 获取一个 batch
    images, labels = next(iter(new_train_loader))
    print(f"Images shape: {images.shape}")  # 形状为 (batch_size, channels, height, width)
    print(f"Labels shape: {labels.shape}")  # 形状为 (batch_size,)
    from torchinfo import summary
    import torch
    import torch.nn as nn
    from CNN1 import BinaryCNN1
    # 将模型转移到GPU中（我们模型运行均在GPU中进行）
    model = BinaryCNN1().to(device)
    summary(model)
    # define the optimizer and loss function
    import torch.optim as optimizer
    from self_metrics import Binary_got_metrics
    loss_function = nn.CrossEntropyLoss()
    learning_rate = 0.001
    optimizer = optimizer.Adam(model.parameters(), lr=learning_rate)

    # model training
    def train(dataloader, model, loss_function, optimizer):
        size = len(dataloader.dataset)
        num_batches = len(dataloader)
        train_loss, train_accuracy = 0, 0
        for images, labels in dataloader:
            images, labels = images.to(device), labels.to(device)
            # Compute prediction error
            prediction = model(images)
            loss = loss_function(prediction, labels)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            train_loss += loss.item()
            train_accuracy += (prediction.argmax(1) == labels).type(torch.float).sum().item()

        train_loss /= num_batches
        train_accuracy /= size

        return train_loss, train_accuracy



    # model evaluation
    def test(dataloader, model, loss_function):
        size = len(dataloader.dataset)
        num_batches = len(dataloader)
        test_loss, test_accuracy = 0, 0
        # 1(1) is positive, 0(7) is negative
        # TP: 1 classified as 1
        # TN: 0 classified as 0
        # FP: 0 classified as 1
        # FN: 1 classified as 0
        TP, TN, FP, FN = 0, 0, 0, 0
        with torch.no_grad():
            for images, labels in dataloader:
                images, labels = images.to(device), labels.to(device)
                prediction = model(images)
                test_loss += loss_function(prediction, labels).item()
                test_accuracy += (prediction.argmax(1) == labels).type(torch.float).sum().item()
                TP += ((prediction.argmax(1) == 1) & (labels == 1)).type(torch.float).sum().item()
                TN += ((prediction.argmax(1) == 0) & (labels == 0)).type(torch.float).sum().item()
                FP += ((prediction.argmax(1) == 1) & (labels == 0)).type(torch.float).sum().item()
                FN += ((prediction.argmax(1) == 0) & (labels == 1)).type(torch.float).sum().item()


        test_loss /= num_batches
        test_accuracy /= size
        return test_loss, test_accuracy, TP, TN, FP, FN

    # training the model
    epochs = 50
    train_loss_list = []
    train_accuracy_list = []
    test_loss_list = []
    test_accuracy_list = []

    best_model_TP = 0
    best_model_TN = 0
    best_model_FP = 0
    best_model_FN = 0
    best_test_accuracy = 0.0 # for saving the best model
    for epoch in range(epochs):
        model.train()
        train_loss, train_accuracy = train(new_train_loader, model, loss_function, optimizer)
        model.eval()
        test_loss, test_accuracy,TP, TN, FP, FN  = test(test_loader, model, loss_function)
        train_loss_list.append(train_loss)
        train_accuracy_list.append(train_accuracy)
        test_loss_list.append(test_loss)
        test_accuracy_list.append(test_accuracy)

        print(f"Epoch: {epoch+1}/{epochs}, Train Loss: {train_loss:.4f}, Train Accuracy: {train_accuracy:.4f}, Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.4f}") 

        if test_accuracy > best_test_accuracy:
            best_test_accuracy = test_accuracy
            best_model_TP = TP
            best_model_TN = TN
            best_model_FP = FP
            best_model_FN = FN
            save_path = f"BinaryMNIST34_{fraction}.pth"
            torch.save(model.state_dict(), save_path)
            print(f"==> New best model saved at epoch {epoch+1} with Test Accuracy: {test_accuracy:.4f}")
            #print(f"==> TP: {TP}, TN: {TN}, FP: {FP}, FN: {FN}")
            Accuracy, misclassification_rate, Sensitivity, Specificity, Precision, Negative_Predictive_Value, Gmean, Fmean, DPower, F2measure, InvF_05, AGFmeasure, Balanced_Accuracy, MCCmeasure, Kappa, Youden_Index, LR_pos, LR_neg = Binary_got_metrics(best_model_TP, best_model_FP, best_model_FN, best_model_TN)
            import json

            # 构造一个包含所有指标数据的字典
            metrics_dict = {
                "Number of label 3 in the final training set": len(mnist3_train_data),
                "Number of label 4 in the final training set (after downsampling)": len(fraction_mnist4_train_data),
                "Number of label 3 in the final test set": len(mnist3_test_data),
                "Number of label 4 in the final test set": len(mnist4_test_data),
                "Total samples in final training set": len(Final_train_datasets),
                "Total samples in final test set": len(Final_test_datasets),
                "Number of batches in training set": len(train_loader),
                "Number of batches in test set": len(test_loader),
                "TP": TP,
                "FP": FP,
                "FN": FN,
                "TN": TN,
                "Accuracy": round(Accuracy, 4),
                "Misclassification rate": round(misclassification_rate, 4),
                "Sensitivity (Recall)": round(Sensitivity, 4),
                "Specificity": round(Specificity, 4),
                "Precision": round(Precision, 4),
                "Negative Predictive Value": round(Negative_Predictive_Value, 4),
                "G-mean": round(Gmean, 4),
                "F-measure": round(Fmean, 4),
                "Discriminant Power (DP)": round(DPower, 4),
                "F2-measure": round(F2measure, 4),
                "InvF0.5-measure": round(InvF_05, 4),
                "AGF": round(AGFmeasure, 4),
                "Balanced Accuracy": round(Balanced_Accuracy, 4),
                "Matthew's Correlation Coefficient (MCC)": round(MCCmeasure, 4),
                "Cohen's Kappa": round(Kappa, 4),
                "Youden's Index": round(Youden_Index, 4),
                "Positive Likelihood Ratio (LR+)": round(LR_pos, 4),
                "Negative Likelihood Ratio (LR-)": round(LR_neg, 4)
            }

            # 指定 JSON 文件保存路径
            metrics_results_path = f"BorderlineSMOTE_CNNBinaryMNIST34_{fraction}_metrics_results.json"

            # 将字典保存为 JSON 文件
            with open(metrics_results_path, "w") as f:
                json.dump(metrics_dict, f, indent=4)
# Out:
# Number of label 3 in the final training set:  6131
# Number of label 4 in the final training set (after downsampling):  30
# Number of label 3 in the final test set:  1010
# Number of label 4 in the final test set:  982
# Total samples in final training set:  6161
# Total samples in final test set:  1992
# Number of batches in training set:  97
# Number of batches in test set:  32
# Images shape: torch.Size([64, 1, 28, 28])
# Labels shape: torch.Size([64])
# First image tensor:
# tensor([[[0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.1137, 0.4902, 0.8431,
#           0.9961, 0.9961, 0.9961, 0.6549, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.1333, 0.5922, 0.9765, 0.9922, 0.9922,
#           0.9922, 0.9922, 0.9922, 0.9922, 0.4235, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.3608, 0.8549, 0.9922, 0.9922, 0.9922, 0.9922,
#           0.9922, 0.9922, 0.9922, 0.9922, 0.9176, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.1725, 0.9098, 0.9922, 0.9922, 0.9922, 0.9098, 0.2314,
#           0.0745, 0.4588, 0.9922, 0.9922, 0.6784, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.3020, 0.9765, 0.9922, 0.8941, 0.4941, 0.0784, 0.0000,
#           0.3373, 0.9098, 0.9922, 0.9647, 0.3176, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.2157, 0.9294, 0.7059, 0.2078, 0.0000, 0.0000, 0.3451,
#           0.9529, 0.9922, 0.9922, 0.7294, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.1255, 0.0314, 0.0863, 0.3333, 0.4392, 0.9490,
#           0.9922, 0.9922, 0.7882, 0.2706, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.2471, 0.7490, 0.9922, 0.9922, 0.9922,
#           0.9922, 0.7294, 0.0667, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0980, 0.4431, 0.9529, 0.9922, 0.9922, 0.9922, 0.9922,
#           0.9922, 0.7961, 0.1098, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.6706, 0.8431, 0.9922, 0.9922, 0.9922, 0.9922, 0.9922, 0.9922,
#           0.9922, 0.9922, 0.7725, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.2902,
#           0.9608, 0.9922, 0.9922, 0.8078, 0.6314, 0.2549, 0.2549, 0.3451,
#           0.9176, 0.9922, 0.8902, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.1098,
#           0.8000, 0.9255, 0.3686, 0.0588, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.5608, 0.9922, 0.9098, 0.0863, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.1098, 0.2039, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.5098, 0.9922, 0.9922, 0.4078, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.6627, 0.9922, 0.9922, 0.4078, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0235,
#           0.7059, 0.9922, 0.9804, 0.3529, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.2353,
#           0.9922, 0.9922, 0.8902, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.1647, 0.8706,
#           0.9922, 0.9922, 0.5882, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.5373, 0.5608, 0.5608,
#           0.5608, 0.5608, 0.4078, 0.2000, 0.5608, 0.5608, 0.8745, 0.9922,
#           0.9922, 0.6314, 0.1647, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.9451, 0.9922, 0.9922,
#           0.9922, 0.9922, 0.9922, 0.9922, 0.9922, 0.9922, 0.9922, 0.9922,
#           0.8980, 0.1647, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.9451, 0.9922, 0.9922,
#           0.9922, 0.9922, 0.9922, 0.9922, 0.9922, 0.9922, 0.9922, 0.6353,
#           0.1608, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000]]])
# First image label: 1
# X_train.shape: (6161, 784)
# y_train.shape: (6161,)
# X_test.shape: (1992, 784)
# y_test.shape: (1992,)
# Resampled dataset shape Counter({np.int64(1): 6131, np.int64(0): 6131})
# ##############################################
# SMOTE done!
# X_train.shape: (12262, 784)
# y_train.shape: (12262,)
# X_test.shape: (1992, 784)
# y_test.shape: (1992,)
# X_train_tensor.shape: torch.Size([12262, 784])
# y_train_tensor.shape: torch.Size([12262])
# 总共恢复的图像数量： 12262
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# reconstructed_images.shape: torch.Size([12262, 28, 28])
# Number of batches in new training set:  192
# Images shape: torch.Size([64, 1, 28, 28])
# Labels shape: torch.Size([64])
# Epoch: 1/50, Train Loss: 0.0396, Train Accuracy: 0.9886, Test Loss: 0.7685, Test Accuracy: 0.8303
# ==> New best model saved at epoch 1 with Test Accuracy: 0.8303
# TP: 1010.0
# FP: 338.0
# FN: 0.0
# TN: 644.0
# Accuracy: 0.8303
# Misclassification rate: 0.1697
# Sensitivity (Recall): 1.0000
# Specificity: 0.6558
# Precision: 0.7493
# Negative Predictive Value: 1.0000
# G-mean: 0.8098
# F-measure: 0.8567
# Discriminant Power: Infinity
# F2-measure: 0.7888
# InvF0.5-measure: 0.9373
# AGF: 0.8598
# Balanced Accuracy: 0.8279
# Matthew's Correlation Coefficient: 0.7010
# Cohen's Kappa: 0.6589
# Youden's Index: 0.6558
# Positive Likelihood Ratio: 2.9053
# Negative Likelihood Ratio: 0.0000
# Epoch: 2/50, Train Loss: 0.0015, Train Accuracy: 0.9996, Test Loss: 0.1107, Test Accuracy: 0.9694
# ==> New best model saved at epoch 2 with Test Accuracy: 0.9694
# TP: 1009.0
# FP: 60.0
# FN: 1.0
# TN: 922.0
# Accuracy: 0.9694
# Misclassification rate: 0.0306
# Sensitivity (Recall): 0.9990
# Specificity: 0.9389
# Precision: 0.9439
# Negative Predictive Value: 0.9989
# G-mean: 0.9685
# F-measure: 0.9707
# Discriminant Power: 5.3197
# F2-measure: 0.9544
# InvF0.5-measure: 0.9875
# AGF: 0.9708
# Balanced Accuracy: 0.9690
# Matthew's Correlation Coefficient: 0.9403
# Cohen's Kappa: 0.9387
# Youden's Index: 0.9379
# Positive Likelihood Ratio: 16.3505
# Negative Likelihood Ratio: 0.0011
# Epoch: 3/50, Train Loss: 0.0003, Train Accuracy: 0.9999, Test Loss: 0.1247, Test Accuracy: 0.9659
# Epoch: 4/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1840, Test Accuracy: 0.9573
# Epoch: 5/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1664, Test Accuracy: 0.9613
# Epoch: 6/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2105, Test Accuracy: 0.9523
# Epoch: 7/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2308, Test Accuracy: 0.9488
# Epoch: 8/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2157, Test Accuracy: 0.9533
# Epoch: 9/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2214, Test Accuracy: 0.9528
# Epoch: 10/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2190, Test Accuracy: 0.9548
# Epoch: 11/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2219, Test Accuracy: 0.9543
# Epoch: 12/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2201, Test Accuracy: 0.9553
# Epoch: 13/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2301, Test Accuracy: 0.9543
# Epoch: 14/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2379, Test Accuracy: 0.9533
# Epoch: 15/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2336, Test Accuracy: 0.9543
# Epoch: 16/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2110, Test Accuracy: 0.9583
# Epoch: 17/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2378, Test Accuracy: 0.9548
# Epoch: 18/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2344, Test Accuracy: 0.9553
# Epoch: 19/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2423, Test Accuracy: 0.9553
# Epoch: 20/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2317, Test Accuracy: 0.9558
# Epoch: 21/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2343, Test Accuracy: 0.9553
# Epoch: 22/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2453, Test Accuracy: 0.9553
# Epoch: 23/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2377, Test Accuracy: 0.9553
# Epoch: 24/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2458, Test Accuracy: 0.9553
# Epoch: 25/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2531, Test Accuracy: 0.9548
# Epoch: 26/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2617, Test Accuracy: 0.9548
# Epoch: 27/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2558, Test Accuracy: 0.9548
# Epoch: 28/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2509, Test Accuracy: 0.9553
# Epoch: 29/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2552, Test Accuracy: 0.9548
# Epoch: 30/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2451, Test Accuracy: 0.9563
# Epoch: 31/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2688, Test Accuracy: 0.9548
# Epoch: 32/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2599, Test Accuracy: 0.9548
# Epoch: 33/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2593, Test Accuracy: 0.9553
# Epoch: 34/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2579, Test Accuracy: 0.9553
# Epoch: 35/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2701, Test Accuracy: 0.9548
# Epoch: 36/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2703, Test Accuracy: 0.9548
# Epoch: 37/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2668, Test Accuracy: 0.9553
# Epoch: 38/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2776, Test Accuracy: 0.9548
# Epoch: 39/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2790, Test Accuracy: 0.9548
# Epoch: 40/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2676, Test Accuracy: 0.9553
# Epoch: 41/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2724, Test Accuracy: 0.9553
# Epoch: 42/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2747, Test Accuracy: 0.9553
# Epoch: 43/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2753, Test Accuracy: 0.9553
# Epoch: 44/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2845, Test Accuracy: 0.9553
# Epoch: 45/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2582, Test Accuracy: 0.9583
# Epoch: 46/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2904, Test Accuracy: 0.9553
# Epoch: 47/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2766, Test Accuracy: 0.9563
# Epoch: 48/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2738, Test Accuracy: 0.9563
# Epoch: 49/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2992, Test Accuracy: 0.9548
# Epoch: 50/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2893, Test Accuracy: 0.9558
# Number of label 3 in the final training set:  6131
# Number of label 4 in the final training set (after downsampling):  61
# Number of label 3 in the final test set:  1010
# Number of label 4 in the final test set:  982
# Total samples in final training set:  6192
# Total samples in final test set:  1992
# Number of batches in training set:  97
# Number of batches in test set:  32
# Images shape: torch.Size([64, 1, 28, 28])
# Labels shape: torch.Size([64])
# First image tensor:
# tensor([[[0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.1059, 0.1529, 0.5647, 0.8863, 0.9961, 0.7569, 0.4549,
#           0.0824, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.1373,
#           0.5451, 0.9294, 0.9922, 0.9922, 0.9922, 0.9922, 1.0000, 0.9922,
#           0.8745, 0.3333, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.8824,
#           0.9922, 0.9922, 0.6353, 0.6039, 0.2824, 0.1725, 0.6549, 0.9922,
#           0.9922, 0.8314, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.4941,
#           0.8118, 0.3255, 0.0039, 0.0000, 0.0000, 0.0000, 0.0078, 0.4824,
#           0.9922, 0.9922, 0.3333, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0314, 0.4235,
#           0.9922, 0.9765, 0.2706, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0157, 0.3490, 0.6706, 0.7804, 0.8118, 0.9922,
#           0.9922, 0.5647, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0471, 0.9922, 0.9922, 0.9922, 0.9961, 0.9922,
#           0.9922, 0.9490, 0.5294, 0.0314, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0196, 0.6510, 0.6314, 0.8196, 0.5765, 0.6902,
#           0.8863, 0.9922, 0.9922, 0.8588, 0.1294, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.1020, 0.4863, 0.8902, 0.9922, 0.6471, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.4627, 0.9922, 0.9490, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.2784, 0.9961, 0.9529, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0235, 0.7412, 0.9922, 0.8353, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.4510, 0.9922, 0.9922, 0.1569, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.2431, 0.9569, 0.9922, 0.9647, 0.0784, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.1451, 0.2196, 0.3059, 0.0000, 0.0000, 0.0000, 0.0000, 0.0588,
#           0.8627, 0.9922, 0.9451, 0.3176, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.2235,
#           0.9216, 0.8706, 0.3373, 0.0000, 0.0000, 0.0000, 0.2549, 0.8353,
#           0.9922, 0.8118, 0.5059, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.9176,
#           0.9922, 0.4392, 0.0000, 0.0000, 0.0353, 0.2353, 0.9608, 0.9804,
#           0.7804, 0.2471, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.9529,
#           0.9922, 0.5373, 0.1765, 0.2510, 0.8941, 0.9922, 0.9765, 0.4196,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.6902,
#           0.9922, 0.9922, 0.9922, 0.9922, 0.9020, 0.6902, 0.2275, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0118,
#           0.4118, 0.7098, 0.9922, 0.9176, 0.2000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000]]])
# First image label: 1
# X_train.shape: (6192, 784)
# y_train.shape: (6192,)
# X_test.shape: (1992, 784)
# y_test.shape: (1992,)
# Resampled dataset shape Counter({np.int64(1): 6131, np.int64(0): 6131})
# ##############################################
# SMOTE done!
# X_train.shape: (12262, 784)
# y_train.shape: (12262,)
# X_test.shape: (1992, 784)
# y_test.shape: (1992,)
# X_train_tensor.shape: torch.Size([12262, 784])
# y_train_tensor.shape: torch.Size([12262])
# 总共恢复的图像数量： 12262
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# reconstructed_images.shape: torch.Size([12262, 28, 28])
# Number of batches in new training set:  192
# Images shape: torch.Size([64, 1, 28, 28])
# Labels shape: torch.Size([64])
# Epoch: 1/50, Train Loss: 0.0364, Train Accuracy: 0.9871, Test Loss: 0.1792, Test Accuracy: 0.9413
# ==> New best model saved at epoch 1 with Test Accuracy: 0.9413
# TP: 1009.0
# FP: 116.0
# FN: 1.0
# TN: 866.0
# Accuracy: 0.9413
# Misclassification rate: 0.0587
# Sensitivity (Recall): 0.9990
# Specificity: 0.8819
# Precision: 0.8969
# Negative Predictive Value: 0.9988
# G-mean: 0.9386
# F-measure: 0.9452
# Discriminant Power: 4.9217
# F2-measure: 0.9156
# InvF0.5-measure: 0.9768
# AGF: 0.9457
# Balanced Accuracy: 0.9404
# Matthew's Correlation Coefficient: 0.8883
# Cohen's Kappa: 0.8823
# Youden's Index: 0.8809
# Positive Likelihood Ratio: 8.4571
# Negative Likelihood Ratio: 0.0011
# Epoch: 2/50, Train Loss: 0.0015, Train Accuracy: 0.9997, Test Loss: 0.0537, Test Accuracy: 0.9834
# ==> New best model saved at epoch 2 with Test Accuracy: 0.9834
# TP: 1009.0
# FP: 32.0
# FN: 1.0
# TN: 950.0
# Accuracy: 0.9834
# Misclassification rate: 0.0166
# Sensitivity (Recall): 0.9990
# Specificity: 0.9674
# Precision: 0.9693
# Negative Predictive Value: 0.9989
# G-mean: 0.9831
# F-measure: 0.9839
# Discriminant Power: 5.6828
# F2-measure: 0.9751
# InvF0.5-measure: 0.9929
# AGF: 0.9840
# Balanced Accuracy: 0.9832
# Matthew's Correlation Coefficient: 0.9673
# Cohen's Kappa: 0.9668
# Youden's Index: 0.9664
# Positive Likelihood Ratio: 30.6571
# Negative Likelihood Ratio: 0.0010
# Epoch: 3/50, Train Loss: 0.0004, Train Accuracy: 0.9998, Test Loss: 0.0290, Test Accuracy: 0.9874
# ==> New best model saved at epoch 3 with Test Accuracy: 0.9874
# TP: 1009.0
# FP: 24.0
# FN: 1.0
# TN: 958.0
# Accuracy: 0.9874
# Misclassification rate: 0.0126
# Sensitivity (Recall): 0.9990
# Specificity: 0.9756
# Precision: 0.9768
# Negative Predictive Value: 0.9990
# G-mean: 0.9872
# F-measure: 0.9878
# Discriminant Power: 5.8460
# F2-measure: 0.9811
# InvF0.5-measure: 0.9945
# AGF: 0.9878
# Balanced Accuracy: 0.9873
# Matthew's Correlation Coefficient: 0.9751
# Cohen's Kappa: 0.9749
# Youden's Index: 0.9746
# Positive Likelihood Ratio: 40.8762
# Negative Likelihood Ratio: 0.0010
# Epoch: 4/50, Train Loss: 0.0011, Train Accuracy: 0.9996, Test Loss: 0.4247, Test Accuracy: 0.9076
# Epoch: 5/50, Train Loss: 0.0001, Train Accuracy: 1.0000, Test Loss: 0.0632, Test Accuracy: 0.9794
# Epoch: 6/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0656, Test Accuracy: 0.9799
# Epoch: 7/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0715, Test Accuracy: 0.9794
# Epoch: 8/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0787, Test Accuracy: 0.9774
# Epoch: 9/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0803, Test Accuracy: 0.9774
# Epoch: 10/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0799, Test Accuracy: 0.9784
# Epoch: 11/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0845, Test Accuracy: 0.9764
# Epoch: 12/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0806, Test Accuracy: 0.9794
# Epoch: 13/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0874, Test Accuracy: 0.9764
# Epoch: 14/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0827, Test Accuracy: 0.9789
# Epoch: 15/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0854, Test Accuracy: 0.9774
# Epoch: 16/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0845, Test Accuracy: 0.9779
# Epoch: 17/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0864, Test Accuracy: 0.9779
# Epoch: 18/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0879, Test Accuracy: 0.9779
# Epoch: 19/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0864, Test Accuracy: 0.9784
# Epoch: 20/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0859, Test Accuracy: 0.9789
# Epoch: 21/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0906, Test Accuracy: 0.9779
# Epoch: 22/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0939, Test Accuracy: 0.9774
# Epoch: 23/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0931, Test Accuracy: 0.9779
# Epoch: 24/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0944, Test Accuracy: 0.9774
# Epoch: 25/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0954, Test Accuracy: 0.9774
# Epoch: 26/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0943, Test Accuracy: 0.9774
# Epoch: 27/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0969, Test Accuracy: 0.9774
# Epoch: 28/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1006, Test Accuracy: 0.9774
# Epoch: 29/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0952, Test Accuracy: 0.9774
# Epoch: 30/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1057, Test Accuracy: 0.9754
# Epoch: 31/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0947, Test Accuracy: 0.9774
# Epoch: 32/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1037, Test Accuracy: 0.9769
# Epoch: 33/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1054, Test Accuracy: 0.9769
# Epoch: 34/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1038, Test Accuracy: 0.9774
# Epoch: 35/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1047, Test Accuracy: 0.9774
# Epoch: 36/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0978, Test Accuracy: 0.9779
# Epoch: 37/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1026, Test Accuracy: 0.9774
# Epoch: 38/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1042, Test Accuracy: 0.9774
# Epoch: 39/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1107, Test Accuracy: 0.9769
# Epoch: 40/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1093, Test Accuracy: 0.9774
# Epoch: 41/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1083, Test Accuracy: 0.9774
# Epoch: 42/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1084, Test Accuracy: 0.9774
# Epoch: 43/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1091, Test Accuracy: 0.9774
# Epoch: 44/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1051, Test Accuracy: 0.9779
# Epoch: 45/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1111, Test Accuracy: 0.9774
# Epoch: 46/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1064, Test Accuracy: 0.9779
# Epoch: 47/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1086, Test Accuracy: 0.9779
# Epoch: 48/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1102, Test Accuracy: 0.9779
# Epoch: 49/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1081, Test Accuracy: 0.9779
# Epoch: 50/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1140, Test Accuracy: 0.9784
# Number of label 3 in the final training set:  6131
# Number of label 4 in the final training set (after downsampling):  122
# Number of label 3 in the final test set:  1010
# Number of label 4 in the final test set:  982
# Total samples in final training set:  6253
# Total samples in final test set:  1992
# Number of batches in training set:  98
# Number of batches in test set:  32
# Images shape: torch.Size([64, 1, 28, 28])
# Labels shape: torch.Size([64])
# First image tensor:
# tensor([[[0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0706,
#           0.4157, 0.7137, 0.6000, 0.5647, 0.2431, 0.0745, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.8235,
#           0.9922, 0.9922, 0.9922, 0.9922, 0.9922, 0.8627, 0.2314, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.7843,
#           0.9922, 0.9922, 0.6510, 0.9922, 0.9922, 0.9922, 0.9765, 0.4235,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0588,
#           0.7765, 0.9922, 0.1255, 0.0392, 0.4980, 0.9451, 0.9961, 0.9843,
#           0.1647, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0784, 0.5333, 0.1804, 0.0000, 0.0000, 0.3412, 0.9961, 0.9922,
#           0.4549, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.9961, 0.9922,
#           0.6039, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.2118, 0.9961, 0.9922,
#           0.2078, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.1843, 0.6078, 0.7765, 0.9961, 0.9922,
#           0.1725, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.4784, 0.9922, 0.9922, 0.9961, 0.9922,
#           0.4235, 0.1451, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0235, 0.4510, 0.5608, 0.9961, 0.9922,
#           0.9922, 0.8902, 0.1529, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0588, 0.5451,
#           0.9765, 1.0000, 0.8078, 0.0314, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.4235, 0.9843, 0.9922, 0.6078, 0.0235, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.5922, 0.9922, 0.9922, 0.0863, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.1059, 0.9922, 0.9922, 0.1216, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0314, 0.7686, 0.9922, 0.5137, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.5608,
#           0.4235, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0706, 0.9216, 0.9922, 0.5137, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.9529,
#           0.9765, 0.4196, 0.0039, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0392, 0.6941, 0.9922, 0.9922, 0.3098, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.6118,
#           0.9922, 0.9922, 0.6196, 0.1765, 0.1765, 0.1765, 0.2353, 0.6078,
#           0.9294, 0.9922, 0.9922, 0.7059, 0.0353, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0235,
#           0.5412, 0.9294, 0.9922, 0.9922, 0.9922, 0.9922, 0.9961, 0.9922,
#           0.9922, 0.9686, 0.5961, 0.0549, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.2549, 0.7686, 0.9922, 0.9922, 0.9922, 0.9961, 0.9922,
#           0.6314, 0.3255, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000]]])
# First image label: 1
# X_train.shape: (6253, 784)
# y_train.shape: (6253,)
# X_test.shape: (1992, 784)
# y_test.shape: (1992,)
# Resampled dataset shape Counter({np.int64(1): 6131, np.int64(0): 6131})
# ##############################################
# SMOTE done!
# X_train.shape: (12262, 784)
# y_train.shape: (12262,)
# X_test.shape: (1992, 784)
# y_test.shape: (1992,)
# X_train_tensor.shape: torch.Size([12262, 784])
# y_train_tensor.shape: torch.Size([12262])
# 总共恢复的图像数量： 12262
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# reconstructed_images.shape: torch.Size([12262, 28, 28])
# Number of batches in new training set:  192
# Images shape: torch.Size([64, 1, 28, 28])
# Labels shape: torch.Size([64])
# Epoch: 1/50, Train Loss: 0.0436, Train Accuracy: 0.9911, Test Loss: 0.0104, Test Accuracy: 0.9965
# ==> New best model saved at epoch 1 with Test Accuracy: 0.9965
# TP: 1007.0
# FP: 4.0
# FN: 3.0
# TN: 978.0
# Accuracy: 0.9965
# Misclassification rate: 0.0035
# Sensitivity (Recall): 0.9970
# Specificity: 0.9959
# Precision: 0.9960
# Negative Predictive Value: 0.9969
# G-mean: 0.9965
# F-measure: 0.9965
# Discriminant Power: 6.2385
# F2-measure: 0.9962
# InvF0.5-measure: 0.9968
# AGF: 0.9965
# Balanced Accuracy: 0.9965
# Matthew's Correlation Coefficient: 0.9930
# Cohen's Kappa: 0.9930
# Youden's Index: 0.9930
# Positive Likelihood Ratio: 244.7708
# Negative Likelihood Ratio: 0.0030
# Epoch: 2/50, Train Loss: 0.0029, Train Accuracy: 0.9994, Test Loss: 0.0087, Test Accuracy: 0.9975
# ==> New best model saved at epoch 2 with Test Accuracy: 0.9975
# TP: 1007.0
# FP: 2.0
# FN: 3.0
# TN: 980.0
# Accuracy: 0.9975
# Misclassification rate: 0.0025
# Sensitivity (Recall): 0.9970
# Specificity: 0.9980
# Precision: 0.9980
# Negative Predictive Value: 0.9969
# G-mean: 0.9975
# F-measure: 0.9975
# Discriminant Power: 6.6217
# F2-measure: 0.9978
# InvF0.5-measure: 0.9972
# AGF: 0.9975
# Balanced Accuracy: 0.9975
# Matthew's Correlation Coefficient: 0.9950
# Cohen's Kappa: 0.9950
# Youden's Index: 0.9950
# Positive Likelihood Ratio: 489.5416
# Negative Likelihood Ratio: 0.0030
# Epoch: 3/50, Train Loss: 0.0014, Train Accuracy: 0.9998, Test Loss: 0.0134, Test Accuracy: 0.9965
# Epoch: 4/50, Train Loss: 0.0010, Train Accuracy: 0.9998, Test Loss: 0.0146, Test Accuracy: 0.9955
# Epoch: 5/50, Train Loss: 0.0008, Train Accuracy: 0.9998, Test Loss: 0.0139, Test Accuracy: 0.9965
# Epoch: 6/50, Train Loss: 0.0004, Train Accuracy: 0.9999, Test Loss: 0.0211, Test Accuracy: 0.9955
# Epoch: 7/50, Train Loss: 0.0003, Train Accuracy: 0.9999, Test Loss: 0.0188, Test Accuracy: 0.9960
# Epoch: 8/50, Train Loss: 0.0003, Train Accuracy: 0.9998, Test Loss: 0.0169, Test Accuracy: 0.9965
# Epoch: 9/50, Train Loss: 0.0002, Train Accuracy: 0.9999, Test Loss: 0.0149, Test Accuracy: 0.9975
# Epoch: 10/50, Train Loss: 0.0001, Train Accuracy: 0.9999, Test Loss: 0.0184, Test Accuracy: 0.9950
# Epoch: 11/50, Train Loss: 0.0166, Train Accuracy: 0.9952, Test Loss: 0.0299, Test Accuracy: 0.9864
# Epoch: 12/50, Train Loss: 0.0013, Train Accuracy: 0.9997, Test Loss: 0.0120, Test Accuracy: 0.9960
# Epoch: 13/50, Train Loss: 0.0003, Train Accuracy: 0.9998, Test Loss: 0.0166, Test Accuracy: 0.9960
# Epoch: 14/50, Train Loss: 0.0002, Train Accuracy: 0.9999, Test Loss: 0.0148, Test Accuracy: 0.9960
# Epoch: 15/50, Train Loss: 0.0001, Train Accuracy: 0.9999, Test Loss: 0.0129, Test Accuracy: 0.9965
# Epoch: 16/50, Train Loss: 0.0001, Train Accuracy: 0.9999, Test Loss: 0.0112, Test Accuracy: 0.9970
# Epoch: 17/50, Train Loss: 0.0001, Train Accuracy: 1.0000, Test Loss: 0.0143, Test Accuracy: 0.9960
# Epoch: 18/50, Train Loss: 0.0001, Train Accuracy: 1.0000, Test Loss: 0.0136, Test Accuracy: 0.9965
# Epoch: 19/50, Train Loss: 0.0001, Train Accuracy: 1.0000, Test Loss: 0.0155, Test Accuracy: 0.9960
# Epoch: 20/50, Train Loss: 0.0001, Train Accuracy: 1.0000, Test Loss: 0.0130, Test Accuracy: 0.9970
# Epoch: 21/50, Train Loss: 0.0001, Train Accuracy: 1.0000, Test Loss: 0.0173, Test Accuracy: 0.9960
# Epoch: 22/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0173, Test Accuracy: 0.9960
# Epoch: 23/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0125, Test Accuracy: 0.9970
# Epoch: 24/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0182, Test Accuracy: 0.9960
# Epoch: 25/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0155, Test Accuracy: 0.9960
# Epoch: 26/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0180, Test Accuracy: 0.9960
# Epoch: 27/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0200, Test Accuracy: 0.9960
# Epoch: 28/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0158, Test Accuracy: 0.9960
# Epoch: 29/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0221, Test Accuracy: 0.9960
# Epoch: 30/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0192, Test Accuracy: 0.9960
# Epoch: 31/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0214, Test Accuracy: 0.9960
# Epoch: 32/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0196, Test Accuracy: 0.9960
# Epoch: 33/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0219, Test Accuracy: 0.9960
# Epoch: 34/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0219, Test Accuracy: 0.9960
# Epoch: 35/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0223, Test Accuracy: 0.9960
# Epoch: 36/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0222, Test Accuracy: 0.9960
# Epoch: 37/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0235, Test Accuracy: 0.9960
# Epoch: 38/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0231, Test Accuracy: 0.9960
# Epoch: 39/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0223, Test Accuracy: 0.9960
# Epoch: 40/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0245, Test Accuracy: 0.9960
# Epoch: 41/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0228, Test Accuracy: 0.9960
# Epoch: 42/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0249, Test Accuracy: 0.9960
# Epoch: 43/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0242, Test Accuracy: 0.9960
# Epoch: 44/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0236, Test Accuracy: 0.9960
# Epoch: 45/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0247, Test Accuracy: 0.9960
# Epoch: 46/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0253, Test Accuracy: 0.9960
# Epoch: 47/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0242, Test Accuracy: 0.9960
# Epoch: 48/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0266, Test Accuracy: 0.9960
# Epoch: 49/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0267, Test Accuracy: 0.9960
# Epoch: 50/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0271, Test Accuracy: 0.9960
# Number of label 3 in the final training set:  6131
# Number of label 4 in the final training set (after downsampling):  306
# Number of label 3 in the final test set:  1010
# Number of label 4 in the final test set:  982
# Total samples in final training set:  6437
# Total samples in final test set:  1992
# Number of batches in training set:  101
# Number of batches in test set:  32
# Images shape: torch.Size([64, 1, 28, 28])
# Labels shape: torch.Size([64])
# First image tensor:
# tensor([[[0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.1451, 0.2627, 0.6118, 0.6118, 0.7608, 1.0000, 0.8157, 0.6118,
#           0.4078, 0.0549, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0157, 0.5176,
#           0.9373, 0.9922, 0.9922, 0.9804, 0.9137, 0.9176, 0.9216, 0.9922,
#           0.9922, 0.7255, 0.0627, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0980, 0.7059, 0.9922,
#           0.9961, 0.8471, 0.4196, 0.2588, 0.0000, 0.0000, 0.0235, 0.3059,
#           0.8196, 0.9922, 0.7647, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0157, 0.7059, 0.9686, 0.6902,
#           0.2235, 0.0392, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.1020, 0.8667, 0.7647, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
# ...
# Number of label 3 in the final training set:  6131
# Number of label 4 in the final training set (after downsampling):  1226
# Number of label 3 in the final test set:  1010
# Number of label 4 in the final test set:  982
# Total samples in final training set:  7357
# Total samples in final test set:  1992
# Number of batches in training set:  115
# Number of batches in test set:  32
# Images shape: torch.Size([64, 1, 28, 28])
# Labels shape: torch.Size([64])
# First image tensor:
# tensor([[[0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.1216, 0.1333, 0.1333, 0.3216, 0.5647, 0.5647,
#           0.5647, 0.5647, 0.4706, 0.0314, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.2902,
#           0.6941, 0.6941, 0.9686, 0.9922, 0.9922, 0.9922, 0.9961, 0.9922,
#           0.9922, 0.9922, 0.9922, 0.7569, 0.1725, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.3882, 0.8235, 0.9882,
#           0.9922, 0.9922, 0.9922, 0.9922, 0.9922, 0.9922, 0.9961, 0.9922,
#           0.8392, 0.9765, 0.9922, 0.9922, 0.5137, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.6549, 0.9608, 0.9529,
#           0.8784, 0.4745, 0.0784, 0.0392, 0.0392, 0.0392, 0.0431, 0.0392,
#           0.0588, 0.3922, 0.9922, 0.9922, 0.5137, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0902, 0.2118, 0.1804,
#           0.4588, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0314, 0.5176,
#           0.7843, 0.9922, 0.9922, 0.9176, 0.2157, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.1098, 0.3490, 0.8118, 0.9922,
#           0.9922, 0.9922, 0.9176, 0.2353, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0314, 0.0471, 0.4431, 0.7412, 0.9373, 0.9922, 0.9961, 0.9804,
#           0.7804, 0.4824, 0.0667, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0706, 0.5882,
#           0.8588, 0.9922, 0.9922, 0.9922, 0.9922, 0.9922, 0.9961, 0.8941,
#           0.4392, 0.1608, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.3922, 0.9922,
#           0.9922, 0.9922, 0.9922, 0.9922, 0.9922, 0.9922, 0.9961, 0.9922,
#           0.9922, 0.9725, 0.7373, 0.7373, 0.5294, 0.1216, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0510, 0.7333,
#           0.5608, 0.5608, 0.5608, 0.5608, 0.5608, 0.5608, 0.5608, 0.8627,
#           0.9922, 0.9922, 0.9922, 0.9922, 0.9922, 0.8392, 0.3020, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0392, 0.5294, 0.9137, 0.9961, 0.9961, 0.9961, 0.4314,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.1059, 0.6314, 0.9922, 0.9922, 0.9922,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.1176, 0.9922, 0.9922, 0.9922,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.3098, 0.9922, 0.9922, 0.9176,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.1804, 0.6510, 0.4824, 0.0118,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.7216, 0.9922, 0.9922, 0.3176,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.9059, 0.9922, 0.6863, 0.0118,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0784, 0.5020, 0.9765, 0.9922, 0.9922, 0.1294,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.9804, 0.9922, 0.9608, 0.6824,
#           0.4784, 0.1373, 0.0471, 0.0471, 0.0471, 0.0471, 0.0471, 0.0471,
#           0.2157, 0.7059, 0.9294, 0.9922, 0.9922, 0.9098, 0.3882, 0.0118,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.2784, 0.8667, 0.9922, 0.9922,
#           0.9922, 0.9922, 0.9922, 0.9922, 0.9922, 0.9922, 1.0000, 0.9922,
#           0.9922, 0.9922, 0.9922, 0.9922, 0.9098, 0.4902, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0706, 0.4275, 0.8471,
#           0.9922, 0.9922, 0.9922, 0.9922, 0.9922, 0.9922, 0.9961, 0.9922,
#           0.9922, 0.9686, 0.6902, 0.6902, 0.1725, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0667,
#           0.1294, 0.1294, 0.5216, 0.5608, 0.5608, 0.5608, 0.5608, 0.5608,
#           0.3922, 0.1176, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000]]])
# First image label: 1
# X_train.shape: (7357, 784)
# y_train.shape: (7357,)
# X_test.shape: (1992, 784)
# y_test.shape: (1992,)
# Resampled dataset shape Counter({np.int64(1): 6131, np.int64(0): 6131})
# ##############################################
# SMOTE done!
# X_train.shape: (12262, 784)
# y_train.shape: (12262,)
# X_test.shape: (1992, 784)
# y_test.shape: (1992,)
# X_train_tensor.shape: torch.Size([12262, 784])
# y_train_tensor.shape: torch.Size([12262])
# 总共恢复的图像数量： 12262
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# reconstructed_images.shape: torch.Size([12262, 28, 28])
# Number of batches in new training set:  192
# Images shape: torch.Size([64, 1, 28, 28])
# Labels shape: torch.Size([64])
# Epoch: 1/50, Train Loss: 0.0617, Train Accuracy: 0.9794, Test Loss: 0.0101, Test Accuracy: 0.9970
# ==> New best model saved at epoch 1 with Test Accuracy: 0.9970
# TP: 1007.0
# FP: 3.0
# FN: 3.0
# TN: 979.0
# Accuracy: 0.9970
# Misclassification rate: 0.0030
# Sensitivity (Recall): 0.9970
# Specificity: 0.9969
# Precision: 0.9970
# Negative Predictive Value: 0.9969
# G-mean: 0.9970
# F-measure: 0.9970
# Discriminant Power: 6.3976
# F2-measure: 0.9970
# InvF0.5-measure: 0.9970
# AGF: 0.9970
# Balanced Accuracy: 0.9970
# Matthew's Correlation Coefficient: 0.9940
# Cohen's Kappa: 0.9940
# Youden's Index: 0.9940
# Positive Likelihood Ratio: 326.3611
# Negative Likelihood Ratio: 0.0030
# Epoch: 2/50, Train Loss: 0.0088, Train Accuracy: 0.9981, Test Loss: 0.0055, Test Accuracy: 0.9985
# ==> New best model saved at epoch 2 with Test Accuracy: 0.9985
# TP: 1010.0
# FP: 3.0
# FN: 0.0
# TN: 979.0
# Accuracy: 0.9985
# Misclassification rate: 0.0015
# Sensitivity (Recall): 1.0000
# Specificity: 0.9969
# Precision: 0.9970
# Negative Predictive Value: 1.0000
# G-mean: 0.9985
# F-measure: 0.9985
# Discriminant Power: Infinity
# F2-measure: 0.9976
# InvF0.5-measure: 0.9994
# AGF: 0.9985
# Balanced Accuracy: 0.9985
# Matthew's Correlation Coefficient: 0.9970
# Cohen's Kappa: 0.9970
# Youden's Index: 0.9969
# Positive Likelihood Ratio: 327.3333
# Negative Likelihood Ratio: 0.0000
# Epoch: 3/50, Train Loss: 0.0051, Train Accuracy: 0.9984, Test Loss: 0.0043, Test Accuracy: 0.9975
# Epoch: 4/50, Train Loss: 0.0035, Train Accuracy: 0.9990, Test Loss: 0.0042, Test Accuracy: 0.9985
# Epoch: 5/50, Train Loss: 0.0020, Train Accuracy: 0.9996, Test Loss: 0.0078, Test Accuracy: 0.9975
# Epoch: 6/50, Train Loss: 0.0013, Train Accuracy: 0.9998, Test Loss: 0.0038, Test Accuracy: 0.9990
# ==> New best model saved at epoch 6 with Test Accuracy: 0.9990
# TP: 1008.0
# FP: 0.0
# FN: 2.0
# TN: 982.0
# Accuracy: 0.9990
# Misclassification rate: 0.0010
# Sensitivity (Recall): 0.9980
# Specificity: 1.0000
# Precision: 1.0000
# Negative Predictive Value: 0.9980
# G-mean: 0.9990
# F-measure: 0.9990
# Discriminant Power: Infinity
# F2-measure: 0.9996
# InvF0.5-measure: 0.9984
# AGF: 0.9990
# Balanced Accuracy: 0.9990
# Matthew's Correlation Coefficient: 0.9980
# Cohen's Kappa: 0.9980
# Youden's Index: 0.9980
# Positive Likelihood Ratio: -99999999.0000
# Negative Likelihood Ratio: 0.0020
# Epoch: 7/50, Train Loss: 0.0012, Train Accuracy: 0.9998, Test Loss: 0.0015, Test Accuracy: 0.9995
# ==> New best model saved at epoch 7 with Test Accuracy: 0.9995
# TP: 1009.0
# FP: 0.0
# FN: 1.0
# TN: 982.0
# Accuracy: 0.9995
# Misclassification rate: 0.0005
# Sensitivity (Recall): 0.9990
# Specificity: 1.0000
# Precision: 1.0000
# Negative Predictive Value: 0.9990
# G-mean: 0.9995
# F-measure: 0.9995
# Discriminant Power: Infinity
# F2-measure: 0.9998
# InvF0.5-measure: 0.9992
# AGF: 0.9995
# Balanced Accuracy: 0.9995
# Matthew's Correlation Coefficient: 0.9990
# Cohen's Kappa: 0.9990
# Youden's Index: 0.9990
# Positive Likelihood Ratio: -99999999.0000
# Negative Likelihood Ratio: 0.0010
# Epoch: 8/50, Train Loss: 0.0011, Train Accuracy: 0.9998, Test Loss: 0.0018, Test Accuracy: 0.9995
# Epoch: 9/50, Train Loss: 0.0002, Train Accuracy: 0.9999, Test Loss: 0.0012, Test Accuracy: 0.9995
# Epoch: 10/50, Train Loss: 0.0005, Train Accuracy: 0.9998, Test Loss: 0.0015, Test Accuracy: 0.9995
# Epoch: 11/50, Train Loss: 0.0002, Train Accuracy: 1.0000, Test Loss: 0.0027, Test Accuracy: 0.9995
# Epoch: 12/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0022, Test Accuracy: 0.9995
# Epoch: 13/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0025, Test Accuracy: 0.9995
# Epoch: 14/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0025, Test Accuracy: 0.9995
# Epoch: 15/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0025, Test Accuracy: 0.9995
# Epoch: 16/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0025, Test Accuracy: 0.9995
# Epoch: 17/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0025, Test Accuracy: 0.9995
# Epoch: 18/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0023, Test Accuracy: 0.9995
# Epoch: 19/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0025, Test Accuracy: 0.9995
# Epoch: 20/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0025, Test Accuracy: 0.9995
# Epoch: 21/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0022, Test Accuracy: 0.9995
# Epoch: 22/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0022, Test Accuracy: 0.9995
# Epoch: 23/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0023, Test Accuracy: 0.9995
# Epoch: 24/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0024, Test Accuracy: 0.9995
# Epoch: 25/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0023, Test Accuracy: 0.9995
# Epoch: 26/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0025, Test Accuracy: 0.9995
# Epoch: 27/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0025, Test Accuracy: 0.9995
# Epoch: 28/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0024, Test Accuracy: 0.9995
# Epoch: 29/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0024, Test Accuracy: 0.9995
# Epoch: 30/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0024, Test Accuracy: 0.9995
# Epoch: 31/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0024, Test Accuracy: 0.9995
# Epoch: 32/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0024, Test Accuracy: 0.9995
# Epoch: 33/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0022, Test Accuracy: 0.9995
# Epoch: 34/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0025, Test Accuracy: 0.9995
# Epoch: 35/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0024, Test Accuracy: 0.9995
# Epoch: 36/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0026, Test Accuracy: 0.9995
# Epoch: 37/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0024, Test Accuracy: 0.9995
# Epoch: 38/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0027, Test Accuracy: 0.9995
# Epoch: 39/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0024, Test Accuracy: 0.9995
# Epoch: 40/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0024, Test Accuracy: 0.9995
# Epoch: 41/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0025, Test Accuracy: 0.9995
# Epoch: 42/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0024, Test Accuracy: 0.9995
# Epoch: 43/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0022, Test Accuracy: 0.9995
# Epoch: 44/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0024, Test Accuracy: 0.9995
# Epoch: 45/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0024, Test Accuracy: 0.9995
# Epoch: 46/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0025, Test Accuracy: 0.9995
# Epoch: 47/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0024, Test Accuracy: 0.9995
# Epoch: 48/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0024, Test Accuracy: 0.9995
# Epoch: 49/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0027, Test Accuracy: 0.9995
# Epoch: 50/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0026, Test Accuracy: 0.9995
