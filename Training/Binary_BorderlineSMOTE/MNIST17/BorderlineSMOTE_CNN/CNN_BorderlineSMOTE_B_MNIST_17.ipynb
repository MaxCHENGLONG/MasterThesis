# %%
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
import torchvision
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
import numpy as np
import torch
import matplotlib.pyplot as plt
import sys
import os
from imblearn.over_sampling import BorderlineSMOTE
sys.path.append(os.path.abspath("/Users/max/MasterThesis/Training/"))

# %%
fractions = [0.005, 0.01, 0.02, 0.05, 0.1, 0.2]
for frac in range(len(fractions)):
    import torch
    from torch.utils.data import DataLoader, Subset, ConcatDataset, TensorDataset
    from torchvision import datasets, transforms
    import numpy as np

    # 数据预处理
    mnist17_transforms = transforms.Compose([
        transforms.ToTensor(), 
        transforms.Normalize((0.1307,), (0.3081,))
    ])

    # 加载 MNIST 数据集
    full_train_datasets = datasets.MNIST(root="/Users/max/MasterThesisData/MNIST", train=True, transform=mnist17_transforms, download=True)
    full_test_datasets = datasets.MNIST(root="/Users/max/MasterThesisData/MNIST", train=False, transform=mnist17_transforms, download=True)

    # 选取标签为 1 和 7 的索引
    indices1_train = [i for i in range(len(full_train_datasets)) if full_train_datasets.targets[i] == 1]
    indices7_train = [i for i in range(len(full_train_datasets)) if full_train_datasets.targets[i] == 7]

    indices1_test = [i for i in range(len(full_test_datasets)) if full_test_datasets.targets[i] == 1]
    indices7_test = [i for i in range(len(full_test_datasets)) if full_test_datasets.targets[i] == 7]

    # 获取训练集中标签为 1 和 7 的数据
    mnist1_train_data = full_train_datasets.data[indices1_train]
    mnist1_train_labels = torch.ones(len(indices1_train), dtype=torch.long)  # 标签 1 保持不变

    mnist7_train_data = full_train_datasets.data[indices7_train]
    mnist7_train_labels = torch.zeros(len(indices7_train), dtype=torch.long)  # 标签 7 映射为 0

    # 获取测试集中标签为 1 和 7 的数据
    mnist1_test_data = full_test_datasets.data[indices1_test]
    mnist1_test_labels = torch.ones(len(indices1_test), dtype=torch.long)  # 标签 1 保持不变

    mnist7_test_data = full_test_datasets.data[indices7_test]
    mnist7_test_labels = torch.zeros(len(indices7_test), dtype=torch.long)  # 标签 7 映射为 0

    # we can set the imbalanced ratio 0.005, 0.01, 0.02, 0.05, 0.1, 0.2
    fraction = int(fractions[frac] * len(mnist1_train_data))  ### control the fraction of the data to be used
    selected_indices_7 = np.random.choice(len(mnist7_train_data), fraction, replace=False)

    fraction_mnist7_train_data = mnist7_train_data[selected_indices_7]
    fraction_mnist7_train_labels = mnist7_train_labels[selected_indices_7]

    # 创建最终的训练和测试数据集
    Final_train_data = torch.cat([mnist1_train_data, fraction_mnist7_train_data], dim=0)
    Final_train_labels = torch.cat([mnist1_train_labels, fraction_mnist7_train_labels], dim=0)

    Final_test_data = torch.cat([mnist1_test_data, mnist7_test_data], dim=0)
    Final_test_labels = torch.cat([mnist1_test_labels, mnist7_test_labels], dim=0)

    # 创建 TensorDataset
    Final_train_datasets = TensorDataset(Final_train_data.unsqueeze(1).float() / 255, Final_train_labels)
    Final_test_datasets = TensorDataset(Final_test_data.unsqueeze(1).float() / 255, Final_test_labels)

    # 数据加载器
    train_loader = DataLoader(Final_train_datasets, batch_size=64, shuffle=True)
    test_loader = DataLoader(Final_test_datasets, batch_size=64, shuffle=False)

    # 打印信息
    print("Number of label 1 in the final training set: ", len(mnist1_train_data))
    print("Number of label 7 in the final training set (after downsampling): ", len(fraction_mnist7_train_data))
    print("Number of label 1 in the final test set: ", len(mnist1_test_data))
    print("Number of label 7 in the final test set: ", len(mnist7_test_data))

    print("Total samples in final training set: ", len(Final_train_datasets))
    print("Total samples in final test set: ", len(Final_test_datasets))

    print("Number of batches in training set: ", len(train_loader))
    print("Number of batches in test set: ", len(test_loader))



    # 获取一个 batch
    images, labels = next(iter(train_loader))

    # 查看 Tensor 形状
    print(f"Images shape: {images.shape}")  # 形状为 (batch_size, channels, height, width)
    print(f"Labels shape: {labels.shape}")  # 形状为 (batch_size,)

    # 查看第一个样本的 Tensor 值
    print(f"First image tensor:\n{images[0]}")  # 打印第一个样本的 Tensor 数据
    print(f"First image label: {labels[0]}")  # 打印第一个样本的标签

    # 如果需要转换回 NumPy 并可视化：
    import matplotlib.pyplot as plt

    # 转换为 NumPy 并显示
    plt.imshow(images[0].squeeze().numpy(), cmap="gray")
    plt.title(f"Label: {labels[0].item()}")
    plt.show()

    import numpy as np

    # 指定图片大小，图像大小为20宽、5高的绘图(单位为英寸inch)
    plt.figure(figsize=(20, 5)) 
    for i, imgs in enumerate(images[:20]):
        # 维度缩减
        npimg = np.squeeze(imgs.numpy())
        # 将整个figure分成2行10列，绘制第i+1个子图。
        plt.subplot(2, 10, i+1)
        plt.imshow(npimg, cmap=plt.cm.binary)
        plt.axis('off')


    X_train = []
    y_train = []

    for batch in train_loader:
        images, labels = batch  # images: (batch_size, 1, 28, 28), labels: (batch_size,)
        if hasattr(images, 'numpy'): # images is tensor
            images = images.numpy()
        # batch_size = 64
        for img, label in zip(images, labels):
            #print(f"Original shape: {img.shape}")  #  
            flattened_img = img.flatten()           
            #print(f"Flattened shape: {flattened_img.shape}")
            X_train.append(flattened_img) # 
            y_train.append(label)


    X_test = [] # features
    y_test = [] # labels
    for batch in test_loader:
        images, labels = batch  # images: (batch_size, 1,28  ,28 ), labels: (batch_size,)
        if hasattr(images, 'numpy'): # images is tensor
            images = images.numpy()
        # batch_size = 64
        for img, label in zip(images, labels):
            flattened_img = img.flatten()           # flatten the image
            X_test.append(flattened_img)
            y_test.append(label)


    X_train = np.array(X_train)
    y_train = np.array(y_train)
    X_test = np.array(X_test)
    y_test = np.array(y_test)
    print("X_train.shape:", X_train.shape)
    print("y_train.shape:", y_train.shape)
    print("X_test.shape:", X_test.shape)
    print("y_test.shape:", y_test.shape)



    from imblearn.over_sampling import SMOTE
    from collections import Counter

    sm = BorderlineSMOTE(random_state=42)
    X_train, y_train = sm.fit_resample(X_train, y_train)
    print('Resampled dataset shape %s' % Counter(y_train))
    print("##############################################")
    print("SMOTE done!")
    print("X_train.shape:", X_train.shape)
    print("y_train.shape:", y_train.shape)
    print("X_test.shape:", X_test.shape)
    print("y_test.shape:", y_test.shape)
    import torch
    from torch.utils.data import TensorDataset, DataLoader

    # 假设 X_train 和 y_train 都是 numpy 数组
    # 注意：如果你的像素值范围在 0~255，建议在转换为 tensor 时进行归一化
    X_train_tensor= torch.tensor(X_train, dtype=torch.float32)
    y_train_tensor = torch.tensor(y_train, dtype=torch.long)
    print("X_train_tensor.shape:", X_train_tensor.shape)
    print("y_train_tensor.shape:", y_train_tensor.shape)

    # 假设 X_train_tensor 的形状为 (N, 784)，每个样本是一个扁平化的 28x28 图像
    reconstructed_images = []  # 用于保存恢复后的图像

    for i in range(len(X_train_tensor)):
        flattened_img = X_train_tensor[i]        # 取出第 i 个样本，形状 (784,)
        original_img = flattened_img.view(28, 28)  # 恢复为 (28, 28) 图像
        reconstructed_images.append(original_img)  # 存入列表

    print("总共恢复的图像数量：", len(reconstructed_images))

    # 可视化恢复后的图像
    plt.figure(figsize=(20, 5))
    for i, img in enumerate(reconstructed_images[:20]):
        plt.subplot(2, 10, i+1)
        plt.imshow(img, cmap="gray")
        plt.axis('off')
    plt.show()


    # 创建 Dataset
    reconstructed_images = torch.stack(reconstructed_images)  # 将列表转换为张量
    print("reconstructed_images.shape:", reconstructed_images.shape)  # (N, 28, 28)
    final_train_datasets = TensorDataset(reconstructed_images.unsqueeze(1).float(), y_train_tensor)

    # 使用新的 Dataset 构建新的 DataLoader
    new_train_loader = DataLoader(final_train_datasets, batch_size=64, shuffle=True)
    print("Number of batches in new training set: ", len(new_train_loader))

    # 获取一个 batch
    images, labels = next(iter(new_train_loader))
    print(f"Images shape: {images.shape}")  # 形状为 (batch_size, channels, height, width)
    print(f"Labels shape: {labels.shape}")  # 形状为 (batch_size,)
    from torchinfo import summary
    import torch
    import torch.nn as nn
    from CNN1 import BinaryCNN1
    # 将模型转移到GPU中（我们模型运行均在GPU中进行）
    model = BinaryCNN1().to(device)
    summary(model)
    # define the optimizer and loss function
    import torch.optim as optimizer
    from self_metrics import Binary_got_metrics
    loss_function = nn.CrossEntropyLoss()
    learning_rate = 0.001
    optimizer = optimizer.Adam(model.parameters(), lr=learning_rate)

    # model training
    def train(dataloader, model, loss_function, optimizer):
        size = len(dataloader.dataset)
        num_batches = len(dataloader)
        train_loss, train_accuracy = 0, 0
        for images, labels in dataloader:
            images, labels = images.to(device), labels.to(device)
            # Compute prediction error
            prediction = model(images)
            loss = loss_function(prediction, labels)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            train_loss += loss.item()
            train_accuracy += (prediction.argmax(1) == labels).type(torch.float).sum().item()

        train_loss /= num_batches
        train_accuracy /= size

        return train_loss, train_accuracy



    # model evaluation
    def test(dataloader, model, loss_function):
        size = len(dataloader.dataset)
        num_batches = len(dataloader)
        test_loss, test_accuracy = 0, 0
        # 1(1) is positive, 0(7) is negative
        # TP: 1 classified as 1
        # TN: 0 classified as 0
        # FP: 0 classified as 1
        # FN: 1 classified as 0
        TP, TN, FP, FN = 0, 0, 0, 0
        with torch.no_grad():
            for images, labels in dataloader:
                images, labels = images.to(device), labels.to(device)
                prediction = model(images)
                test_loss += loss_function(prediction, labels).item()
                test_accuracy += (prediction.argmax(1) == labels).type(torch.float).sum().item()
                TP += ((prediction.argmax(1) == 1) & (labels == 1)).type(torch.float).sum().item()
                TN += ((prediction.argmax(1) == 0) & (labels == 0)).type(torch.float).sum().item()
                FP += ((prediction.argmax(1) == 1) & (labels == 0)).type(torch.float).sum().item()
                FN += ((prediction.argmax(1) == 0) & (labels == 1)).type(torch.float).sum().item()


        test_loss /= num_batches
        test_accuracy /= size
        return test_loss, test_accuracy, TP, TN, FP, FN

    # training the model
    epochs = 50
    train_loss_list = []
    train_accuracy_list = []
    test_loss_list = []
    test_accuracy_list = []

    best_model_TP = 0
    best_model_TN = 0
    best_model_FP = 0
    best_model_FN = 0
    best_test_accuracy = 0.0 # for saving the best model
    for epoch in range(epochs):
        model.train()
        train_loss, train_accuracy = train(new_train_loader, model, loss_function, optimizer)
        model.eval()
        test_loss, test_accuracy,TP, TN, FP, FN  = test(test_loader, model, loss_function)
        train_loss_list.append(train_loss)
        train_accuracy_list.append(train_accuracy)
        test_loss_list.append(test_loss)
        test_accuracy_list.append(test_accuracy)

        print(f"Epoch: {epoch+1}/{epochs}, Train Loss: {train_loss:.4f}, Train Accuracy: {train_accuracy:.4f}, Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.4f}") 

        if test_accuracy > best_test_accuracy:
            best_test_accuracy = test_accuracy
            best_model_TP = TP
            best_model_TN = TN
            best_model_FP = FP
            best_model_FN = FN
            save_path = f"BinaryMNIST17_{fraction}.pth"
            torch.save(model.state_dict(), save_path)
            print(f"==> New best model saved at epoch {epoch+1} with Test Accuracy: {test_accuracy:.4f}")
            #print(f"==> TP: {TP}, TN: {TN}, FP: {FP}, FN: {FN}")
            Accuracy, misclassification_rate, Sensitivity, Specificity, Precision, Negative_Predictive_Value, Gmean, Fmean, DPower, F2measure, InvF_05, AGFmeasure, Balanced_Accuracy, MCCmeasure, Kappa, Youden_Index, LR_pos, LR_neg = Binary_got_metrics(best_model_TP, best_model_FP, best_model_FN, best_model_TN)
            import json

            # 构造一个包含所有指标数据的字典
            metrics_dict = {
                "Number of label 3 in the final training set": len(mnist1_train_data),
                "Number of label 4 in the final training set (after downsampling)": len(fraction_mnist7_train_data),
                "Number of label 3 in the final test set": len(mnist1_test_data),
                "Number of label 4 in the final test set": len(mnist7_test_data),
                "Total samples in final training set": len(Final_train_datasets),
                "Total samples in final test set": len(Final_test_datasets),
                "Number of batches in training set": len(train_loader),
                "Number of batches in test set": len(test_loader),
                "TP": TP,
                "FP": FP,
                "FN": FN,
                "TN": TN,
                "Accuracy": round(Accuracy, 4),
                "Misclassification rate": round(misclassification_rate, 4),
                "Sensitivity (Recall)": round(Sensitivity, 4),
                "Specificity": round(Specificity, 4),
                "Precision": round(Precision, 4),
                "Negative Predictive Value": round(Negative_Predictive_Value, 4),
                "G-mean": round(Gmean, 4),
                "F-measure": round(Fmean, 4),
                "Discriminant Power (DP)": round(DPower, 4),
                "F2-measure": round(F2measure, 4),
                "InvF0.5-measure": round(InvF_05, 4),
                "AGF": round(AGFmeasure, 4),
                "Balanced Accuracy": round(Balanced_Accuracy, 4),
                "Matthew's Correlation Coefficient (MCC)": round(MCCmeasure, 4),
                "Cohen's Kappa": round(Kappa, 4),
                "Youden's Index": round(Youden_Index, 4),
                "Positive Likelihood Ratio (LR+)": round(LR_pos, 4),
                "Negative Likelihood Ratio (LR-)": round(LR_neg, 4)
            }

            # 指定 JSON 文件保存路径
            metrics_results_path = f"BorderlineSMOTE_CNNBinaryMNIST17_{fraction}_metrics_results.json"

            # 将字典保存为 JSON 文件
            with open(metrics_results_path, "w") as f:
                json.dump(metrics_dict, f, indent=4)
# Out:
# Number of label 1 in the final training set:  6742
# Number of label 7 in the final training set (after downsampling):  33
# Number of label 1 in the final test set:  1135
# Number of label 7 in the final test set:  1028
# Total samples in final training set:  6775
# Total samples in final test set:  2163
# Number of batches in training set:  106
# Number of batches in test set:  34
# Images shape: torch.Size([64, 1, 28, 28])
# Labels shape: torch.Size([64])
# First image tensor:
# tensor([[[0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.1647, 1.0000, 0.6941, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.1647, 0.9922, 0.8745, 0.1647,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.1294, 0.9294, 0.9922, 0.6196,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.6941, 0.9922, 0.8980,
#           0.0667, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.6941, 0.9922, 0.9922,
#           0.0902, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.6941, 0.9922, 0.9922,
#           0.0902, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.6941, 0.9922, 0.9922,
#           0.0902, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.4392, 0.9922, 0.9922,
#           0.0902, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.3098, 0.9922, 0.9922,
#           0.0902, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.6941, 0.9922, 0.9922,
#           0.0902, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.6941, 0.9922, 0.9922,
#           0.0902, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.6941, 0.9922, 0.9922,
#           0.0902, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.6941, 0.9922, 0.9922,
#           0.0902, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.6941, 0.9922, 0.9922,
#           0.0902, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0980, 0.8706, 0.9922, 0.9922,
#           0.0902, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.2510, 0.9922, 0.9922, 0.9255,
#           0.0745, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0275, 0.7216, 0.9922, 0.9922, 0.5020,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0941, 0.9922, 0.9922, 0.8941, 0.1098,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0941, 0.9922, 0.9922, 0.6902, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0510, 0.8235, 0.9922, 0.6902, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000]]])
# First image label: 1
# X_train.shape: (6775, 784)
# y_train.shape: (6775,)
# X_test.shape: (2163, 784)
# y_test.shape: (2163,)
# Resampled dataset shape Counter({np.int64(1): 6742, np.int64(0): 6742})
# ##############################################
# SMOTE done!
# X_train.shape: (13484, 784)
# y_train.shape: (13484,)
# X_test.shape: (2163, 784)
# y_test.shape: (2163,)
# X_train_tensor.shape: torch.Size([13484, 784])
# y_train_tensor.shape: torch.Size([13484])
# 总共恢复的图像数量： 13484
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# reconstructed_images.shape: torch.Size([13484, 28, 28])
# Number of batches in new training set:  211
# Images shape: torch.Size([64, 1, 28, 28])
# Labels shape: torch.Size([64])
# Epoch: 1/50, Train Loss: 0.0419, Train Accuracy: 0.9895, Test Loss: 0.1747, Test Accuracy: 0.9626
# ==> New best model saved at epoch 1 with Test Accuracy: 0.9626
# TP: 1135.0
# FP: 81.0
# FN: 0.0
# TN: 947.0
# Accuracy: 0.9626
# Misclassification rate: 0.0374
# Sensitivity (Recall): 1.0000
# Specificity: 0.9212
# Precision: 0.9334
# Negative Predictive Value: 1.0000
# G-mean: 0.9598
# F-measure: 0.9655
# Discriminant Power: Infinity
# F2-measure: 0.9460
# InvF0.5-measure: 0.9859
# AGF: 0.9658
# Balanced Accuracy: 0.9606
# Matthew's Correlation Coefficient: 0.9273
# Cohen's Kappa: 0.9246
# Youden's Index: 0.9212
# Positive Likelihood Ratio: 12.6914
# Negative Likelihood Ratio: 0.0000
# Epoch: 2/50, Train Loss: 0.0012, Train Accuracy: 0.9998, Test Loss: 0.1855, Test Accuracy: 0.9630
# ==> New best model saved at epoch 2 with Test Accuracy: 0.9630
# TP: 1135.0
# FP: 80.0
# FN: 0.0
# TN: 948.0
# Accuracy: 0.9630
# Misclassification rate: 0.0370
# Sensitivity (Recall): 1.0000
# Specificity: 0.9222
# Precision: 0.9342
# Negative Predictive Value: 1.0000
# G-mean: 0.9603
# F-measure: 0.9660
# Discriminant Power: Infinity
# F2-measure: 0.9466
# InvF0.5-measure: 0.9861
# AGF: 0.9662
# Balanced Accuracy: 0.9611
# Matthew's Correlation Coefficient: 0.9281
# Cohen's Kappa: 0.9256
# Youden's Index: 0.9222
# Positive Likelihood Ratio: 12.8500
# Negative Likelihood Ratio: 0.0000
# Epoch: 3/50, Train Loss: 0.0003, Train Accuracy: 0.9999, Test Loss: 0.2225, Test Accuracy: 0.9635
# ==> New best model saved at epoch 3 with Test Accuracy: 0.9635
# TP: 1135.0
# FP: 79.0
# FN: 0.0
# TN: 949.0
# Accuracy: 0.9635
# Misclassification rate: 0.0365
# Sensitivity (Recall): 1.0000
# Specificity: 0.9232
# Precision: 0.9349
# Negative Predictive Value: 1.0000
# G-mean: 0.9608
# F-measure: 0.9664
# Discriminant Power: Infinity
# F2-measure: 0.9473
# InvF0.5-measure: 0.9863
# AGF: 0.9666
# Balanced Accuracy: 0.9616
# Matthew's Correlation Coefficient: 0.9290
# Cohen's Kappa: 0.9265
# Youden's Index: 0.9232
# Positive Likelihood Ratio: 13.0127
# Negative Likelihood Ratio: 0.0000
# Epoch: 4/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2360, Test Accuracy: 0.9626
# Epoch: 5/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2645, Test Accuracy: 0.9612
# Epoch: 6/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2389, Test Accuracy: 0.9644
# ==> New best model saved at epoch 6 with Test Accuracy: 0.9644
# TP: 1135.0
# FP: 77.0
# FN: 0.0
# TN: 951.0
# Accuracy: 0.9644
# Misclassification rate: 0.0356
# Sensitivity (Recall): 1.0000
# Specificity: 0.9251
# Precision: 0.9365
# Negative Predictive Value: 1.0000
# G-mean: 0.9618
# F-measure: 0.9672
# Discriminant Power: Infinity
# F2-measure: 0.9485
# InvF0.5-measure: 0.9866
# AGF: 0.9674
# Balanced Accuracy: 0.9625
# Matthew's Correlation Coefficient: 0.9308
# Cohen's Kappa: 0.9284
# Youden's Index: 0.9251
# Positive Likelihood Ratio: 13.3506
# Negative Likelihood Ratio: 0.0000
# Epoch: 7/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2945, Test Accuracy: 0.9607
# Epoch: 8/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2919, Test Accuracy: 0.9612
# Epoch: 9/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2963, Test Accuracy: 0.9612
# Epoch: 10/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.3088, Test Accuracy: 0.9612
# Epoch: 11/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2913, Test Accuracy: 0.9630
# Epoch: 12/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.3334, Test Accuracy: 0.9593
# Epoch: 13/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.3124, Test Accuracy: 0.9616
# Epoch: 14/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.3515, Test Accuracy: 0.9589
# Epoch: 15/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.3337, Test Accuracy: 0.9607
# Epoch: 16/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.3586, Test Accuracy: 0.9593
# Epoch: 17/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.3492, Test Accuracy: 0.9602
# Epoch: 18/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.3567, Test Accuracy: 0.9598
# Epoch: 19/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.3557, Test Accuracy: 0.9602
# Epoch: 20/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.3678, Test Accuracy: 0.9598
# Epoch: 21/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.3621, Test Accuracy: 0.9612
# Epoch: 22/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.3771, Test Accuracy: 0.9598
# Epoch: 23/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.3855, Test Accuracy: 0.9602
# Epoch: 24/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.3709, Test Accuracy: 0.9616
# Epoch: 25/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.3963, Test Accuracy: 0.9602
# Epoch: 26/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.3927, Test Accuracy: 0.9602
# Epoch: 27/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.3921, Test Accuracy: 0.9602
# Epoch: 28/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.4063, Test Accuracy: 0.9602
# Epoch: 29/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.4058, Test Accuracy: 0.9602
# Epoch: 30/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.4235, Test Accuracy: 0.9593
# Epoch: 31/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.4248, Test Accuracy: 0.9593
# Epoch: 32/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.4256, Test Accuracy: 0.9598
# Epoch: 33/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.4345, Test Accuracy: 0.9593
# Epoch: 34/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.4554, Test Accuracy: 0.9575
# Epoch: 35/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.4482, Test Accuracy: 0.9579
# Epoch: 36/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.4427, Test Accuracy: 0.9598
# Epoch: 37/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.4435, Test Accuracy: 0.9598
# Epoch: 38/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.4622, Test Accuracy: 0.9579
# Epoch: 39/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.4614, Test Accuracy: 0.9579
# Epoch: 40/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.4602, Test Accuracy: 0.9598
# Epoch: 41/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.4920, Test Accuracy: 0.9565
# Epoch: 42/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.4891, Test Accuracy: 0.9565
# Epoch: 43/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.4716, Test Accuracy: 0.9598
# Epoch: 44/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.4789, Test Accuracy: 0.9589
# Epoch: 45/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.4767, Test Accuracy: 0.9602
# Epoch: 46/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.4931, Test Accuracy: 0.9575
# Epoch: 47/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.4905, Test Accuracy: 0.9589
# Epoch: 48/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.5101, Test Accuracy: 0.9565
# Epoch: 49/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.5179, Test Accuracy: 0.9565
# Epoch: 50/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.5063, Test Accuracy: 0.9575
# Number of label 1 in the final training set:  6742
# Number of label 7 in the final training set (after downsampling):  67
# Number of label 1 in the final test set:  1135
# Number of label 7 in the final test set:  1028
# Total samples in final training set:  6809
# Total samples in final test set:  2163
# Number of batches in training set:  107
# Number of batches in test set:  34
# Images shape: torch.Size([64, 1, 28, 28])
# Labels shape: torch.Size([64])
# First image tensor:
# tensor([[[0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.2275, 0.9686,
#           0.8000, 0.0745, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.4745, 0.9882,
#           0.9882, 0.1529, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.4745, 0.9882,
#           0.9882, 0.3490, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.4745, 0.9882,
#           0.9882, 0.6745, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.4745, 0.9882,
#           0.9882, 0.5333, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.8588, 0.9882,
#           0.9882, 0.1529, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0863, 0.9922, 0.9882,
#           0.6510, 0.0510, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0353, 0.8157, 0.9922, 0.9882,
#           0.1020, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0549, 0.9882, 0.9922, 0.9882,
#           0.1020, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0549, 0.9882, 0.9922, 0.9882,
#           0.1020, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.5765, 0.9922, 1.0000, 0.5725,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.5725, 0.9882, 0.9922, 0.5686,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0980, 0.9451, 0.9882, 0.9922, 0.3804,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.5451, 0.9882, 0.9882, 0.5922, 0.0078,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.6275, 0.9882, 0.9882, 0.5216, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0353, 0.7020, 0.9882, 0.9882, 0.4157, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.2431, 0.9882, 0.9882, 0.9882, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0235, 0.7098, 0.9882, 0.9882, 0.9333, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.2000, 0.9725, 0.9882, 0.9569, 0.1961, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.4039, 0.9882, 0.6588, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000]]])
# First image label: 1
# X_train.shape: (6809, 784)
# y_train.shape: (6809,)
# X_test.shape: (2163, 784)
# y_test.shape: (2163,)
# Resampled dataset shape Counter({np.int64(0): 6742, np.int64(1): 6742})
# ##############################################
# SMOTE done!
# X_train.shape: (13484, 784)
# y_train.shape: (13484,)
# X_test.shape: (2163, 784)
# y_test.shape: (2163,)
# X_train_tensor.shape: torch.Size([13484, 784])
# y_train_tensor.shape: torch.Size([13484])
# 总共恢复的图像数量： 13484
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# reconstructed_images.shape: torch.Size([13484, 28, 28])
# Number of batches in new training set:  211
# Images shape: torch.Size([64, 1, 28, 28])
# Labels shape: torch.Size([64])
# Epoch: 1/50, Train Loss: 0.0355, Train Accuracy: 0.9889, Test Loss: 0.0850, Test Accuracy: 0.9810
# ==> New best model saved at epoch 1 with Test Accuracy: 0.9810
# TP: 1135.0
# FP: 41.0
# FN: 0.0
# TN: 987.0
# Accuracy: 0.9810
# Misclassification rate: 0.0190
# Sensitivity (Recall): 1.0000
# Specificity: 0.9601
# Precision: 0.9651
# Negative Predictive Value: 1.0000
# G-mean: 0.9799
# F-measure: 0.9823
# Discriminant Power: Infinity
# F2-measure: 0.9719
# InvF0.5-measure: 0.9928
# AGF: 0.9823
# Balanced Accuracy: 0.9801
# Matthew's Correlation Coefficient: 0.9626
# Cohen's Kappa: 0.9619
# Youden's Index: 0.9601
# Positive Likelihood Ratio: 25.0732
# Negative Likelihood Ratio: 0.0000
# Epoch: 2/50, Train Loss: 0.0023, Train Accuracy: 0.9993, Test Loss: 0.2174, Test Accuracy: 0.9663
# Epoch: 3/50, Train Loss: 0.0016, Train Accuracy: 0.9997, Test Loss: 0.1629, Test Accuracy: 0.9690
# Epoch: 4/50, Train Loss: 0.0003, Train Accuracy: 0.9999, Test Loss: 0.1684, Test Accuracy: 0.9732
# Epoch: 5/50, Train Loss: 0.0002, Train Accuracy: 0.9999, Test Loss: 0.1453, Test Accuracy: 0.9741
# Epoch: 6/50, Train Loss: 0.0003, Train Accuracy: 0.9999, Test Loss: 0.2657, Test Accuracy: 0.9602
# Epoch: 7/50, Train Loss: 0.0008, Train Accuracy: 0.9998, Test Loss: 0.1205, Test Accuracy: 0.9792
# Epoch: 8/50, Train Loss: 0.0007, Train Accuracy: 0.9998, Test Loss: 0.0933, Test Accuracy: 0.9847
# ==> New best model saved at epoch 8 with Test Accuracy: 0.9847
# TP: 1135.0
# FP: 33.0
# FN: 0.0
# TN: 995.0
# Accuracy: 0.9847
# Misclassification rate: 0.0153
# Sensitivity (Recall): 1.0000
# Specificity: 0.9679
# Precision: 0.9717
# Negative Predictive Value: 1.0000
# G-mean: 0.9838
# F-measure: 0.9857
# Discriminant Power: Infinity
# F2-measure: 0.9773
# InvF0.5-measure: 0.9942
# AGF: 0.9857
# Balanced Accuracy: 0.9839
# Matthew's Correlation Coefficient: 0.9698
# Cohen's Kappa: 0.9694
# Youden's Index: 0.9679
# Positive Likelihood Ratio: 31.1515
# Negative Likelihood Ratio: 0.0000
# Epoch: 9/50, Train Loss: 0.0012, Train Accuracy: 0.9998, Test Loss: 0.1246, Test Accuracy: 0.9783
# Epoch: 10/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0872, Test Accuracy: 0.9857
# ==> New best model saved at epoch 10 with Test Accuracy: 0.9857
# TP: 1135.0
# FP: 31.0
# FN: 0.0
# TN: 997.0
# Accuracy: 0.9857
# Misclassification rate: 0.0143
# Sensitivity (Recall): 1.0000
# Specificity: 0.9698
# Precision: 0.9734
# Negative Predictive Value: 1.0000
# G-mean: 0.9848
# F-measure: 0.9865
# Discriminant Power: Infinity
# F2-measure: 0.9786
# InvF0.5-measure: 0.9946
# AGF: 0.9866
# Balanced Accuracy: 0.9849
# Matthew's Correlation Coefficient: 0.9716
# Cohen's Kappa: 0.9712
# Youden's Index: 0.9698
# Positive Likelihood Ratio: 33.1613
# Negative Likelihood Ratio: 0.0000
# Epoch: 11/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1162, Test Accuracy: 0.9820
# Epoch: 12/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1196, Test Accuracy: 0.9820
# Epoch: 13/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1258, Test Accuracy: 0.9820
# Epoch: 14/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1272, Test Accuracy: 0.9820
# Epoch: 15/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1304, Test Accuracy: 0.9820
# Epoch: 16/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1340, Test Accuracy: 0.9815
# Epoch: 17/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1379, Test Accuracy: 0.9810
# Epoch: 18/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1405, Test Accuracy: 0.9810
# Epoch: 19/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1417, Test Accuracy: 0.9810
# Epoch: 20/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1441, Test Accuracy: 0.9810
# Epoch: 21/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1475, Test Accuracy: 0.9806
# Epoch: 22/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1491, Test Accuracy: 0.9806
# Epoch: 23/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1520, Test Accuracy: 0.9797
# Epoch: 24/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1544, Test Accuracy: 0.9797
# Epoch: 25/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1578, Test Accuracy: 0.9792
# Epoch: 26/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1592, Test Accuracy: 0.9792
# Epoch: 27/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1624, Test Accuracy: 0.9792
# Epoch: 28/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1631, Test Accuracy: 0.9792
# Epoch: 29/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1653, Test Accuracy: 0.9792
# Epoch: 30/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1672, Test Accuracy: 0.9792
# Epoch: 31/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1708, Test Accuracy: 0.9792
# Epoch: 32/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1717, Test Accuracy: 0.9792
# Epoch: 33/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1755, Test Accuracy: 0.9792
# Epoch: 34/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1765, Test Accuracy: 0.9792
# Epoch: 35/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1785, Test Accuracy: 0.9792
# Epoch: 36/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1812, Test Accuracy: 0.9792
# Epoch: 37/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1837, Test Accuracy: 0.9792
# Epoch: 38/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1861, Test Accuracy: 0.9792
# Epoch: 39/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1873, Test Accuracy: 0.9792
# Epoch: 40/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1892, Test Accuracy: 0.9792
# Epoch: 41/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1921, Test Accuracy: 0.9787
# Epoch: 42/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1956, Test Accuracy: 0.9787
# Epoch: 43/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1973, Test Accuracy: 0.9783
# Epoch: 44/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2006, Test Accuracy: 0.9783
# Epoch: 45/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2017, Test Accuracy: 0.9783
# Epoch: 46/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2034, Test Accuracy: 0.9783
# Epoch: 47/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2048, Test Accuracy: 0.9783
# Epoch: 48/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2085, Test Accuracy: 0.9783
# Epoch: 49/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2095, Test Accuracy: 0.9783
# Epoch: 50/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2126, Test Accuracy: 0.9783
# Number of label 1 in the final training set:  6742
# Number of label 7 in the final training set (after downsampling):  134
# Number of label 1 in the final test set:  1135
# Number of label 7 in the final test set:  1028
# Total samples in final training set:  6876
# Total samples in final test set:  2163
# Number of batches in training set:  108
# Number of batches in test set:  34
# Images shape: torch.Size([64, 1, 28, 28])
# Labels shape: torch.Size([64])
# First image tensor:
# tensor([[[0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.2235, 0.6667, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.8863, 0.4471, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.6667, 1.0000, 0.2235, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.6667, 1.0000, 0.3373, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.4471, 1.0000, 0.3373, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.1137, 1.0000, 0.3373, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0000, 0.3373, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0000, 0.4471, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0000, 0.7765, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.8863, 1.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.6667, 1.0000, 0.2235,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.6667, 1.0000, 0.3373,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.6667, 1.0000, 0.3373,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.6667, 1.0000, 0.3373,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.6667, 1.0000, 0.3373,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.4471, 1.0000, 0.6667,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.2235, 1.0000, 0.8863,
#           0.1137, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.8863, 1.0000,
#           0.3373, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.6667, 1.0000,
#           0.2235, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.4471, 0.5529,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000]]])
# First image label: 1
# X_train.shape: (6876, 784)
# y_train.shape: (6876,)
# X_test.shape: (2163, 784)
# y_test.shape: (2163,)
# Resampled dataset shape Counter({np.int64(1): 6742, np.int64(0): 6742})
# ##############################################
# SMOTE done!
# X_train.shape: (13484, 784)
# y_train.shape: (13484,)
# X_test.shape: (2163, 784)
# y_test.shape: (2163,)
# X_train_tensor.shape: torch.Size([13484, 784])
# y_train_tensor.shape: torch.Size([13484])
# 总共恢复的图像数量： 13484
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# reconstructed_images.shape: torch.Size([13484, 28, 28])
# Number of batches in new training set:  211
# Images shape: torch.Size([64, 1, 28, 28])
# Labels shape: torch.Size([64])
# Epoch: 1/50, Train Loss: 0.0497, Train Accuracy: 0.9907, Test Loss: 0.0870, Test Accuracy: 0.9801
# ==> New best model saved at epoch 1 with Test Accuracy: 0.9801
# TP: 1135.0
# FP: 43.0
# FN: 0.0
# TN: 985.0
# Accuracy: 0.9801
# Misclassification rate: 0.0199
# Sensitivity (Recall): 1.0000
# Specificity: 0.9582
# Precision: 0.9635
# Negative Predictive Value: 1.0000
# G-mean: 0.9789
# F-measure: 0.9814
# Discriminant Power: Infinity
# F2-measure: 0.9706
# InvF0.5-measure: 0.9925
# AGF: 0.9815
# Balanced Accuracy: 0.9791
# Matthew's Correlation Coefficient: 0.9608
# Cohen's Kappa: 0.9601
# Youden's Index: 0.9582
# Positive Likelihood Ratio: 23.9070
# Negative Likelihood Ratio: 0.0000
# Epoch: 2/50, Train Loss: 0.0023, Train Accuracy: 0.9993, Test Loss: 0.1502, Test Accuracy: 0.9787
# Epoch: 3/50, Train Loss: 0.0025, Train Accuracy: 0.9994, Test Loss: 0.0317, Test Accuracy: 0.9949
# ==> New best model saved at epoch 3 with Test Accuracy: 0.9949
# TP: 1134.0
# FP: 10.0
# FN: 1.0
# TN: 1018.0
# Accuracy: 0.9949
# Misclassification rate: 0.0051
# Sensitivity (Recall): 0.9991
# Specificity: 0.9903
# Precision: 0.9913
# Negative Predictive Value: 0.9990
# G-mean: 0.9947
# F-measure: 0.9952
# Discriminant Power: 6.4266
# F2-measure: 0.9928
# InvF0.5-measure: 0.9975
# AGF: 0.9952
# Balanced Accuracy: 0.9947
# Matthew's Correlation Coefficient: 0.9898
# Cohen's Kappa: 0.9898
# Youden's Index: 0.9894
# Positive Likelihood Ratio: 102.7094
# Negative Likelihood Ratio: 0.0009
# Epoch: 4/50, Train Loss: 0.0014, Train Accuracy: 0.9997, Test Loss: 0.1370, Test Accuracy: 0.9815
# Epoch: 5/50, Train Loss: 0.0004, Train Accuracy: 0.9999, Test Loss: 0.0697, Test Accuracy: 0.9889
# Epoch: 6/50, Train Loss: 0.0020, Train Accuracy: 0.9994, Test Loss: 0.0487, Test Accuracy: 0.9917
# Epoch: 7/50, Train Loss: 0.0002, Train Accuracy: 1.0000, Test Loss: 0.1558, Test Accuracy: 0.9792
# Epoch: 8/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1529, Test Accuracy: 0.9792
# Epoch: 9/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1522, Test Accuracy: 0.9806
# Epoch: 10/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1545, Test Accuracy: 0.9806
# Epoch: 11/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1554, Test Accuracy: 0.9806
# Epoch: 12/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1560, Test Accuracy: 0.9810
# Epoch: 13/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1599, Test Accuracy: 0.9810
# Epoch: 14/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1602, Test Accuracy: 0.9810
# Epoch: 15/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1650, Test Accuracy: 0.9810
# Epoch: 16/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1625, Test Accuracy: 0.9810
# Epoch: 17/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1632, Test Accuracy: 0.9810
# Epoch: 18/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1651, Test Accuracy: 0.9810
# Epoch: 19/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1681, Test Accuracy: 0.9810
# Epoch: 20/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1695, Test Accuracy: 0.9810
# Epoch: 21/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1714, Test Accuracy: 0.9815
# Epoch: 22/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1733, Test Accuracy: 0.9815
# Epoch: 23/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1746, Test Accuracy: 0.9810
# Epoch: 24/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1787, Test Accuracy: 0.9810
# Epoch: 25/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1787, Test Accuracy: 0.9810
# Epoch: 26/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1797, Test Accuracy: 0.9810
# Epoch: 27/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1866, Test Accuracy: 0.9810
# Epoch: 28/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1883, Test Accuracy: 0.9810
# Epoch: 29/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1867, Test Accuracy: 0.9810
# Epoch: 30/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1853, Test Accuracy: 0.9815
# Epoch: 31/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1858, Test Accuracy: 0.9815
# Epoch: 32/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1920, Test Accuracy: 0.9810
# Epoch: 33/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1920, Test Accuracy: 0.9810
# Epoch: 34/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1949, Test Accuracy: 0.9810
# Epoch: 35/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1914, Test Accuracy: 0.9815
# Epoch: 36/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1931, Test Accuracy: 0.9815
# Epoch: 37/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1920, Test Accuracy: 0.9820
# Epoch: 38/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1965, Test Accuracy: 0.9815
# Epoch: 39/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1993, Test Accuracy: 0.9815
# Epoch: 40/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2047, Test Accuracy: 0.9810
# Epoch: 41/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2073, Test Accuracy: 0.9810
# Epoch: 42/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2079, Test Accuracy: 0.9810
# Epoch: 43/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2032, Test Accuracy: 0.9815
# Epoch: 44/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2069, Test Accuracy: 0.9815
# Epoch: 45/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2073, Test Accuracy: 0.9815
# Epoch: 46/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2091, Test Accuracy: 0.9815
# Epoch: 47/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2063, Test Accuracy: 0.9820
# Epoch: 48/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2118, Test Accuracy: 0.9815
# Epoch: 49/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2143, Test Accuracy: 0.9815
# Epoch: 50/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2182, Test Accuracy: 0.9815
# Number of label 1 in the final training set:  6742
# Number of label 7 in the final training set (after downsampling):  337
# Number of label 1 in the final test set:  1135
# Number of label 7 in the final test set:  1028
# Total samples in final training set:  7079
# Total samples in final test set:  2163
# Number of batches in training set:  111
# Number of batches in test set:  34
# Images shape: torch.Size([64, 1, 28, 28])
# Labels shape: torch.Size([64])
# First image tensor:
# tensor([[[0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
# ...
# Epoch: 46/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0998, Test Accuracy: 0.9912
# Epoch: 47/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1005, Test Accuracy: 0.9912
# Epoch: 48/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0974, Test Accuracy: 0.9912
# Epoch: 49/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1018, Test Accuracy: 0.9912
# Epoch: 50/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0982, Test Accuracy: 0.9912
# Number of label 1 in the final training set:  6742
# Number of label 7 in the final training set (after downsampling):  1348
# Number of label 1 in the final test set:  1135
# Number of label 7 in the final test set:  1028
# Total samples in final training set:  8090
# Total samples in final test set:  2163
# Number of batches in training set:  127
# Number of batches in test set:  34
# Images shape: torch.Size([64, 1, 28, 28])
# Labels shape: torch.Size([64])
# First image tensor:
# tensor([[[0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0314, 0.2980, 0.5725, 0.6627, 1.0000, 0.9961, 1.0000,
#           1.0000, 0.9961, 0.7059, 0.1608, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.3608,
#           0.7216, 0.7725, 0.9922, 0.9922, 0.9922, 0.9922, 0.7137, 0.6941,
#           0.6941, 0.7294, 0.9922, 0.8824, 0.0157, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0392, 0.8706, 0.9451,
#           0.9725, 0.9725, 0.6471, 0.5451, 0.4588, 0.1255, 0.0078, 0.0000,
#           0.0000, 0.0157, 0.7176, 0.9922, 0.3922, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.3608, 0.7490, 0.1020,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.6784, 0.9922, 0.4431, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0353, 0.7804, 0.9922, 0.4431, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.1098, 0.9922, 0.9922, 0.0627, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.1882, 0.9922, 0.6627, 0.0078, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.6745, 0.9922, 0.1686, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.3529, 0.9922, 0.7333, 0.0157, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0510,
#           0.6941, 0.9725, 0.2510, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.3922,
#           0.9922, 0.8863, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0078, 0.6863,
#           0.9922, 0.2745, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.1882, 0.9922,
#           0.7412, 0.0157, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.8549, 0.9922,
#           0.2706, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.1137, 0.6863, 0.9922, 0.5412,
#           0.0078, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.3255, 0.9922, 0.8275, 0.1098,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.2275, 0.9333, 0.9922, 0.3137, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.4902, 0.9922, 0.9490, 0.0549, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.4902, 0.9922, 0.5137, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.4902, 0.9020, 0.1216, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000]]])
# First image label: 0
# X_train.shape: (8090, 784)
# y_train.shape: (8090,)
# X_test.shape: (2163, 784)
# y_test.shape: (2163,)
# Resampled dataset shape Counter({np.int64(1): 6742, np.int64(0): 6742})
# ##############################################
# SMOTE done!
# X_train.shape: (13484, 784)
# y_train.shape: (13484,)
# X_test.shape: (2163, 784)
# y_test.shape: (2163,)
# X_train_tensor.shape: torch.Size([13484, 784])
# y_train_tensor.shape: torch.Size([13484])
# 总共恢复的图像数量： 13484
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# reconstructed_images.shape: torch.Size([13484, 28, 28])
# Number of batches in new training set:  211
# Images shape: torch.Size([64, 1, 28, 28])
# Labels shape: torch.Size([64])
# Epoch: 1/50, Train Loss: 0.0670, Train Accuracy: 0.9823, Test Loss: 0.0146, Test Accuracy: 0.9954
# ==> New best model saved at epoch 1 with Test Accuracy: 0.9954
# TP: 1135.0
# FP: 10.0
# FN: 0.0
# TN: 1018.0
# Accuracy: 0.9954
# Misclassification rate: 0.0046
# Sensitivity (Recall): 1.0000
# Specificity: 0.9903
# Precision: 0.9913
# Negative Predictive Value: 1.0000
# G-mean: 0.9951
# F-measure: 0.9956
# Discriminant Power: Infinity
# F2-measure: 0.9930
# InvF0.5-measure: 0.9982
# AGF: 0.9956
# Balanced Accuracy: 0.9951
# Matthew's Correlation Coefficient: 0.9908
# Cohen's Kappa: 0.9907
# Youden's Index: 0.9903
# Positive Likelihood Ratio: 102.8000
# Negative Likelihood Ratio: 0.0000
# Epoch: 2/50, Train Loss: 0.0087, Train Accuracy: 0.9978, Test Loss: 0.0119, Test Accuracy: 0.9958
# ==> New best model saved at epoch 2 with Test Accuracy: 0.9958
# TP: 1134.0
# FP: 8.0
# FN: 1.0
# TN: 1020.0
# Accuracy: 0.9958
# Misclassification rate: 0.0042
# Sensitivity (Recall): 0.9991
# Specificity: 0.9922
# Precision: 0.9930
# Negative Predictive Value: 0.9990
# G-mean: 0.9957
# F-measure: 0.9960
# Discriminant Power: 6.5507
# F2-measure: 0.9942
# InvF0.5-measure: 0.9979
# AGF: 0.9960
# Balanced Accuracy: 0.9957
# Matthew's Correlation Coefficient: 0.9917
# Cohen's Kappa: 0.9917
# Youden's Index: 0.9913
# Positive Likelihood Ratio: 128.3868
# Negative Likelihood Ratio: 0.0009
# Epoch: 3/50, Train Loss: 0.0051, Train Accuracy: 0.9987, Test Loss: 0.0272, Test Accuracy: 0.9917
# Epoch: 4/50, Train Loss: 0.0020, Train Accuracy: 0.9996, Test Loss: 0.0165, Test Accuracy: 0.9958
# Epoch: 5/50, Train Loss: 0.0023, Train Accuracy: 0.9992, Test Loss: 0.0314, Test Accuracy: 0.9921
# Epoch: 6/50, Train Loss: 0.0017, Train Accuracy: 0.9996, Test Loss: 0.0241, Test Accuracy: 0.9949
# Epoch: 7/50, Train Loss: 0.0008, Train Accuracy: 0.9998, Test Loss: 0.0126, Test Accuracy: 0.9968
# ==> New best model saved at epoch 7 with Test Accuracy: 0.9968
# TP: 1135.0
# FP: 7.0
# FN: 0.0
# TN: 1021.0
# Accuracy: 0.9968
# Misclassification rate: 0.0032
# Sensitivity (Recall): 1.0000
# Specificity: 0.9932
# Precision: 0.9939
# Negative Predictive Value: 1.0000
# G-mean: 0.9966
# F-measure: 0.9969
# Discriminant Power: Infinity
# F2-measure: 0.9951
# InvF0.5-measure: 0.9988
# AGF: 0.9969
# Balanced Accuracy: 0.9966
# Matthew's Correlation Coefficient: 0.9935
# Cohen's Kappa: 0.9935
# Youden's Index: 0.9932
# Positive Likelihood Ratio: 146.8571
# Negative Likelihood Ratio: 0.0000
# Epoch: 8/50, Train Loss: 0.0004, Train Accuracy: 0.9999, Test Loss: 0.0314, Test Accuracy: 0.9935
# Epoch: 9/50, Train Loss: 0.0001, Train Accuracy: 1.0000, Test Loss: 0.0153, Test Accuracy: 0.9958
# Epoch: 10/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0250, Test Accuracy: 0.9949
# Epoch: 11/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0277, Test Accuracy: 0.9949
# Epoch: 12/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0266, Test Accuracy: 0.9949
# Epoch: 13/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0279, Test Accuracy: 0.9940
# Epoch: 14/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0297, Test Accuracy: 0.9940
# Epoch: 15/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0269, Test Accuracy: 0.9949
# Epoch: 16/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0286, Test Accuracy: 0.9940
# Epoch: 17/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0301, Test Accuracy: 0.9940
# Epoch: 18/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0296, Test Accuracy: 0.9940
# Epoch: 19/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0295, Test Accuracy: 0.9940
# Epoch: 20/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0316, Test Accuracy: 0.9940
# Epoch: 21/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0328, Test Accuracy: 0.9940
# Epoch: 22/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0322, Test Accuracy: 0.9940
# Epoch: 23/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0313, Test Accuracy: 0.9940
# Epoch: 24/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0339, Test Accuracy: 0.9940
# Epoch: 25/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0328, Test Accuracy: 0.9940
# Epoch: 26/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0346, Test Accuracy: 0.9940
# Epoch: 27/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0344, Test Accuracy: 0.9940
# Epoch: 28/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0363, Test Accuracy: 0.9940
# Epoch: 29/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0339, Test Accuracy: 0.9940
# Epoch: 30/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0374, Test Accuracy: 0.9940
# Epoch: 31/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0358, Test Accuracy: 0.9940
# Epoch: 32/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0363, Test Accuracy: 0.9940
# Epoch: 33/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0368, Test Accuracy: 0.9940
# Epoch: 34/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0373, Test Accuracy: 0.9940
# Epoch: 35/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0392, Test Accuracy: 0.9940
# Epoch: 36/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0378, Test Accuracy: 0.9940
# Epoch: 37/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0386, Test Accuracy: 0.9940
# Epoch: 38/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0417, Test Accuracy: 0.9940
# Epoch: 39/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0391, Test Accuracy: 0.9940
# Epoch: 40/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0408, Test Accuracy: 0.9940
# Epoch: 41/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0394, Test Accuracy: 0.9940
# Epoch: 42/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0400, Test Accuracy: 0.9940
# Epoch: 43/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0416, Test Accuracy: 0.9940
# Epoch: 44/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0425, Test Accuracy: 0.9940
# Epoch: 45/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0410, Test Accuracy: 0.9940
# Epoch: 46/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0432, Test Accuracy: 0.9940
# Epoch: 47/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0433, Test Accuracy: 0.9940
# Epoch: 48/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0471, Test Accuracy: 0.9940
# Epoch: 49/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0453, Test Accuracy: 0.9940
# Epoch: 50/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0427, Test Accuracy: 0.9940
