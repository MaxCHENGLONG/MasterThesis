# %%
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
import torchvision
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
import numpy as np
import torch
import matplotlib.pyplot as plt
import sys
import os
sys.path.append(os.path.abspath("/Users/max/MasterThesis/Training/"))
from imblearn.over_sampling import BorderlineSMOTE

# %%
from Swim_Maha import SwimMaha
fractions = [0.005, 0.01, 0.02, 0.05, 0.1, 0.2]
for frac in range(len(fractions)):
    import torch
    from torch.utils.data import DataLoader, Subset, ConcatDataset, TensorDataset
    from torchvision import datasets, transforms
    import numpy as np

    # CIFAR10 数据归一化参数
    # 数据预处理
    cifar10_transforms = transforms.Compose([
        transforms.ToTensor(), 
        transforms.Normalize((0.4914, 0.4822, 0.4465), (0.247, 0.243, 0.261))
    ])
    # 加载 CIFAR10 数据集
    full_train_dataset = datasets.CIFAR10(
        root="/Users/max/MasterThesisData/CIFAR10", train=True, transform=cifar10_transforms, download=True)
    full_test_dataset = datasets.CIFAR10(
        root="/Users/max/MasterThesisData/CIFAR10", train=False, transform=cifar10_transforms, download=True)

    # 筛选训练集中的标签 3 和 4，并映射标签（标签 3 -> 1，标签 4 -> 0）
    indices3_train = [i for i in range(len(full_train_dataset)) if full_train_dataset.targets[i] == 3]
    indices4_train = [i for i in range(len(full_train_dataset)) if full_train_dataset.targets[i] == 4]

    # 筛选测试集中的标签 3 和 4，并映射标签
    indices3_test = [i for i in range(len(full_test_dataset)) if full_test_dataset.targets[i] == 3]
    indices4_test = [i for i in range(len(full_test_dataset)) if full_test_dataset.targets[i] == 4]

    # 训练集：获取标签为 3 的数据（映射为 1）
    cifar3_train_data = full_train_dataset.data[indices3_train]  # numpy 数组，形状 (n, 32, 32, 3)
    cifar3_train_labels = torch.ones(len(indices3_train), dtype=torch.long)

    # 训练集：获取标签为 4 的数据（映射为 0）
    cifar4_train_data = full_train_dataset.data[indices4_train]
    cifar4_train_labels = torch.zeros(len(indices4_train), dtype=torch.long)

    # 测试集：获取标签为 3 的数据（映射为 1）
    cifar3_test_data = full_test_dataset.data[indices3_test]
    cifar3_test_labels = torch.ones(len(indices3_test), dtype=torch.long)

    # 测试集：获取标签为 4 的数据（映射为 0）
    cifar4_test_data = full_test_dataset.data[indices4_test]
    cifar4_test_labels = torch.zeros(len(indices4_test), dtype=torch.long)

    # 控制不平衡比例，比如这里设定为 0.005（即只选取标签 4 数据中的一小部分）
    fraction = int(fractions[frac] * len(cifar3_train_data))
    selected_indices_4 = np.random.choice(len(cifar4_train_data), fraction, replace=False)
    fraction_cifar4_train_data = cifar4_train_data[selected_indices_4]
    fraction_cifar4_train_labels = cifar4_train_labels[selected_indices_4]

    # 拼接最终的训练和测试数据集
    Final_train_data = np.concatenate([cifar3_train_data, fraction_cifar4_train_data], axis=0)
    Final_train_labels = torch.cat([cifar3_train_labels, fraction_cifar4_train_labels], dim=0)

    Final_test_data = np.concatenate([cifar3_test_data, cifar4_test_data], axis=0)
    Final_test_labels = torch.cat([cifar3_test_labels, cifar4_test_labels], dim=0)

    # 将 numpy 数组转换为 tensor，并调整维度为 (N, C, H, W)
    Final_train_data = torch.from_numpy(Final_train_data).permute(0, 3, 1, 2).float()
    Final_test_data = torch.from_numpy(Final_test_data).permute(0, 3, 1, 2).float()

    # 归一化图像数据：先除以 255，再进行标准化
    # # 创建 TensorDataset
    # Final_train_datasets = TensorDataset(Final_train_data.unsqueeze(3).float() / 255, Final_train_labels)
    # Final_test_datasets = TensorDataset(Final_test_data.unsqueeze(3).float() / 255, Final_test_labels)

    # 创建 TensorDataset
    Final_train_dataset = TensorDataset(Final_train_data.float() / 255, Final_train_labels)
    Final_test_dataset = TensorDataset(Final_test_data.float() / 255, Final_test_labels)

    # 数据加载器
    train_loader = DataLoader(Final_train_dataset, batch_size=64, shuffle=True)
    test_loader = DataLoader(Final_test_dataset, batch_size=64, shuffle=False)

    # 打印数据信息
    print("Number of label 1 in the final training set: ", len(cifar3_train_data))
    print("Number of label 0 in the final training set (after downsampling): ", len(fraction_cifar4_train_data))
    print("Number of label 1 in the final test set: ", len(cifar3_test_data))
    print("Number of label 0 in the final test set: ", len(cifar4_test_data))

    print("Total samples in final training set: ", len(Final_train_dataset))
    print("Total samples in final test set: ", len(Final_test_dataset))

    print("Number of batches in training set: ", len(train_loader))
    print("Number of batches in test set: ", len(test_loader))


    
    ## 获取一个 batch
    images, labels = next(iter(train_loader))

    # 打印张量信息
    print(f"Images shape: {images.shape}")  # (batch_size, 3, 32, 32)
    print(f"Labels shape: {labels.shape}")

    # 将第一张图像的维度转换为 (H, W, C) 并显示
    img = images[0].permute(1, 2, 0).numpy()  # (32, 32, 3)
    plt.imshow(img)  # 对于彩色图像，无需指定 cmap
    plt.title(f"Label: {labels[0].item()}")
    plt.show()

    plt.figure(figsize=(20, 5))
    for i, img_tensor in enumerate(images[:20]):
        # 将每张图像转换为 (H, W, C)
        npimg = img_tensor.permute(1, 2, 0).numpy()
        plt.subplot(2, 10, i+1)
        plt.imshow(npimg)  # 彩色图像，不指定 cmap
        plt.axis('off')
    plt.show()


    X_train = []
    y_train = []

    for batch in train_loader:
        images, labels = batch  # images: (batch_size, 1, 28, 28), labels: (batch_size,)
        if hasattr(images, 'numpy'): # images is tensor
            images = images.numpy()
        # batch_size = 64
        for img, label in zip(images, labels):
            #print(f"Original shape: {img.shape}")  #  
            flattened_img = img.flatten()           
            #print(f"Flattened shape: {flattened_img.shape}")
            X_train.append(flattened_img) # 
            y_train.append(label)


    X_test = [] # features
    y_test = [] # labels
    for batch in test_loader:
        images, labels = batch  # images: (batch_size, 1,28  ,28 ), labels: (batch_size,)
        if hasattr(images, 'numpy'): # images is tensor
            images = images.numpy()
        # batch_size = 64
        for img, label in zip(images, labels):
            flattened_img = img.flatten()           # flatten the image
            X_test.append(flattened_img)
            y_test.append(label)


    X_train = np.array(X_train)
    y_train = np.array(y_train)
    X_test = np.array(X_test)
    y_test = np.array(y_test)
    print("X_train.shape:", X_train.shape)
    print("y_train.shape:", y_train.shape)
    print("X_test.shape:", X_test.shape)
    print("y_test.shape:", y_test.shape)
    ### SMOTE

    from imblearn.over_sampling import SMOTE
    from collections import Counter

    sm = BorderlineSMOTE(random_state=42, kind='borderline-1')
    X_train, y_train = sm.fit_resample(X_train, y_train)
    print('Resampled dataset shape %s' % Counter(y_train))
    print("##############################################")
    print("SMOTE done!")
    print("X_train.shape:", X_train.shape)
    print("y_train.shape:", y_train.shape)
    print("X_test.shape:", X_test.shape)
    print("y_test.shape:", y_test.shape)
    # training model

    from sklearn import svm
    from sklearn.preprocessing import StandardScaler

    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_test = scaler.transform(X_test)

    clf = svm.SVC(kernel='linear', C=1.0)
    clf.fit(X_train, y_train)
    y_pred = clf.predict(X_test)
    print("y_pred.shape:", y_pred.shape)

    from self_metrics import Binary_got_metrics
    from self_metrics import Binary_got_cofusion_matrix
    from self_metrics import Binary_got_metrics
    TP, FP, FN, TN = Binary_got_cofusion_matrix(y_test, y_pred, labels = [1,0])


    Accuracy, misclassification_rate, Sensitivity, Specificity, Precision, Negative_Predictive_Value, Gmean, Fmean, DPower, F2measure, InvF_05, AGFmeasure, Balanced_Accuracy, MCCmeasure, Kappa, Youden_Index, LR_pos, LR_neg = Binary_got_metrics(TP, FP, FN, TN)
    import json

            # 构造一个包含所有指标数据的字典
    metrics_dict = {
                "Number of label 3 in the final training set": len(cifar3_train_data),
                "Number of label 4 in the final training set (after downsampling)": len(fraction_cifar4_train_data),
                "Number of label 3 in the final test set": len(cifar3_test_data),
                "Number of label 4 in the final test set": len(cifar4_test_data),
                "Total samples in final training set": len(Final_train_dataset),
                "Total samples in final test set": len(Final_test_dataset),
                "Number of batches in training set": len(train_loader),
                "Number of batches in test set": len(test_loader),
                "TP": TP,
                "FP": FP,
                "FN": FN,
                "TN": TN,
                "Accuracy": round(Accuracy, 4),
                "Misclassification rate": round(misclassification_rate, 4),
                "Sensitivity (Recall)": round(Sensitivity, 4),
                "Specificity": round(Specificity, 4),
                "Precision": round(Precision, 4),
                "Negative Predictive Value": round(Negative_Predictive_Value, 4),
                "G-mean": round(Gmean, 4),
                "F-measure": round(Fmean, 4),
                "Discriminant Power (DP)": round(DPower, 4),
                "F2-measure": round(F2measure, 4),
                "InvF0.5-measure": round(InvF_05, 4),
                "AGF": round(AGFmeasure, 4),
                "Balanced Accuracy": round(Balanced_Accuracy, 4),
                "Matthew's Correlation Coefficient (MCC)": round(MCCmeasure, 4),
                "Cohen's Kappa": round(Kappa, 4),
                "Youden's Index": round(Youden_Index, 4),
                "Positive Likelihood Ratio (LR+)": round(LR_pos, 4),
                "Negative Likelihood Ratio (LR-)": round(LR_neg, 4)
            }

            # 指定 JSON 文件保存路径
    metrics_results_path = f"BorderlineSMOTE_SVMBinaryCIFAR1034_{fraction}_metrics_results.json"
    # 将字典保存为 JSON 文件
    with open(metrics_results_path, "w") as f:
        json.dump(metrics_dict, f, indent=4)
# Out:
# Number of label 1 in the final training set:  5000
# Number of label 0 in the final training set (after downsampling):  25
# Number of label 1 in the final test set:  1000
# Number of label 0 in the final test set:  1000
# Total samples in final training set:  5025
# Total samples in final test set:  2000
# Number of batches in training set:  79
# Number of batches in test set:  32
# Images shape: torch.Size([64, 3, 32, 32])
# Labels shape: torch.Size([64])
# X_train.shape: (5025, 3072)
# y_train.shape: (5025,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# Resampled dataset shape Counter({np.int64(1): 5000, np.int64(0): 5000})
# ##############################################
# SMOTE done!
# X_train.shape: (10000, 3072)
# y_train.shape: (10000,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# y_pred.shape: (2000,)
# TP: 993
# FP: 973
# FN: 7
# TN: 27
# Accuracy: 0.5100
# Misclassification rate: 0.4900
# Sensitivity (Recall): 0.9930
# Specificity: 0.0270
# Precision: 0.5051
# Negative Predictive Value: 0.7941
# G-mean: 0.1637
# F-measure: 0.6696
# Discriminant Power: 0.7555
# F2-measure: 0.5601
# InvF0.5-measure: 0.8322
# AGF: 0.6828
# Balanced Accuracy: 0.5100
# Matthew's Correlation Coefficient: 0.0774
# Cohen's Kappa: 0.0200
# Youden's Index: 0.0200
# Positive Likelihood Ratio: 1.0206
# Negative Likelihood Ratio: 0.2593
# Number of label 1 in the final training set:  5000
# Number of label 0 in the final training set (after downsampling):  50
# Number of label 1 in the final test set:  1000
# Number of label 0 in the final test set:  1000
# Total samples in final training set:  5050
# Total samples in final test set:  2000
# Number of batches in training set:  79
# Number of batches in test set:  32
# Images shape: torch.Size([64, 3, 32, 32])
# Labels shape: torch.Size([64])
# X_train.shape: (5050, 3072)
# y_train.shape: (5050,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# Resampled dataset shape Counter({np.int64(1): 5000, np.int64(0): 5000})
# ##############################################
# SMOTE done!
# X_train.shape: (10000, 3072)
# y_train.shape: (10000,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# y_pred.shape: (2000,)
# TP: 984
# FP: 950
# FN: 16
# TN: 50
# Accuracy: 0.5170
# Misclassification rate: 0.4830
# Sensitivity (Recall): 0.9840
# Specificity: 0.0500
# Precision: 0.5088
# Negative Predictive Value: 0.7576
# G-mean: 0.2218
# F-measure: 0.6708
# Discriminant Power: 0.6476
# F2-measure: 0.5632
# InvF0.5-measure: 0.8291
# AGF: 0.6833
# Balanced Accuracy: 0.5170
# Matthew's Correlation Coefficient: 0.0952
# Cohen's Kappa: 0.0340
# Youden's Index: 0.0340
# Positive Likelihood Ratio: 1.0358
# Negative Likelihood Ratio: 0.3200
# Number of label 1 in the final training set:  5000
# Number of label 0 in the final training set (after downsampling):  100
# Number of label 1 in the final test set:  1000
# Number of label 0 in the final test set:  1000
# Total samples in final training set:  5100
# Total samples in final test set:  2000
# Number of batches in training set:  80
# Number of batches in test set:  32
# Images shape: torch.Size([64, 3, 32, 32])
# Labels shape: torch.Size([64])
# X_train.shape: (5100, 3072)
# y_train.shape: (5100,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# Resampled dataset shape Counter({np.int64(1): 5000, np.int64(0): 5000})
# ##############################################
# SMOTE done!
# X_train.shape: (10000, 3072)
# y_train.shape: (10000,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# y_pred.shape: (2000,)
# TP: 962
# FP: 913
# FN: 38
# TN: 87
# Accuracy: 0.5245
# Misclassification rate: 0.4755
# Sensitivity (Recall): 0.9620
# Specificity: 0.0870
# Precision: 0.5131
# Negative Predictive Value: 0.6960
# G-mean: 0.2893
# F-measure: 0.6692
# Discriminant Power: 0.4855
# F2-measure: 0.5659
# InvF0.5-measure: 0.8187
# AGF: 0.6807
# Balanced Accuracy: 0.5245
# Matthew's Correlation Coefficient: 0.1012
# Cohen's Kappa: 0.0490
# Youden's Index: 0.0490
# Positive Likelihood Ratio: 1.0537
# Negative Likelihood Ratio: 0.4368
# Number of label 1 in the final training set:  5000
# Number of label 0 in the final training set (after downsampling):  250
# Number of label 1 in the final test set:  1000
# Number of label 0 in the final test set:  1000
# Total samples in final training set:  5250
# Total samples in final test set:  2000
# Number of batches in training set:  83
# Number of batches in test set:  32
# Images shape: torch.Size([64, 3, 32, 32])
# Labels shape: torch.Size([64])
# X_train.shape: (5250, 3072)
# y_train.shape: (5250,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# Resampled dataset shape Counter({np.int64(1): 5000, np.int64(0): 5000})
# ##############################################
# SMOTE done!
# X_train.shape: (10000, 3072)
# y_train.shape: (10000,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# y_pred.shape: (2000,)
# TP: 917
# FP: 802
# FN: 83
# TN: 198
# Accuracy: 0.5575
# Misclassification rate: 0.4425
# Sensitivity (Recall): 0.9170
# Specificity: 0.1980
# Precision: 0.5334
# Negative Predictive Value: 0.7046
# G-mean: 0.4261
# F-measure: 0.6745
# Discriminant Power: 0.5532
# F2-measure: 0.5821
# InvF0.5-measure: 0.8017
# AGF: 0.6832
# Balanced Accuracy: 0.5575
# Matthew's Correlation Coefficient: 0.1655
# Cohen's Kappa: 0.1150
# Youden's Index: 0.1150
# Positive Likelihood Ratio: 1.1434
# Negative Likelihood Ratio: 0.4192
# Number of label 1 in the final training set:  5000
# Number of label 0 in the final training set (after downsampling):  500
# Number of label 1 in the final test set:  1000
# Number of label 0 in the final test set:  1000
# Total samples in final training set:  5500
# Total samples in final test set:  2000
# Number of batches in training set:  86
# Number of batches in test set:  32
# Images shape: torch.Size([64, 3, 32, 32])
# Labels shape: torch.Size([64])
# X_train.shape: (5500, 3072)
# y_train.shape: (5500,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# Resampled dataset shape Counter({np.int64(1): 5000, np.int64(0): 5000})
# ##############################################
# SMOTE done!
# X_train.shape: (10000, 3072)
# y_train.shape: (10000,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# y_pred.shape: (2000,)
# TP: 849
# FP: 673
# FN: 151
# TN: 327
# Accuracy: 0.5880
# Misclassification rate: 0.4120
# Sensitivity (Recall): 0.8490
# Specificity: 0.3270
# Precision: 0.5578
# Negative Predictive Value: 0.6841
# G-mean: 0.5269
# F-measure: 0.6733
# Discriminant Power: 0.5541
# F2-measure: 0.5989
# InvF0.5-measure: 0.7687
# AGF: 0.6785
# Balanced Accuracy: 0.5880
# Matthew's Correlation Coefficient: 0.2063
# Cohen's Kappa: 0.1760
# Youden's Index: 0.1760
# Positive Likelihood Ratio: 1.2615
# Negative Likelihood Ratio: 0.4618
# Number of label 1 in the final training set:  5000
# Number of label 0 in the final training set (after downsampling):  1000
# Number of label 1 in the final test set:  1000
# Number of label 0 in the final test set:  1000
# Total samples in final training set:  6000
# Total samples in final test set:  2000
# Number of batches in training set:  94
# Number of batches in test set:  32
# Images shape: torch.Size([64, 3, 32, 32])
# Labels shape: torch.Size([64])
# X_train.shape: (6000, 3072)
# y_train.shape: (6000,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# Resampled dataset shape Counter({np.int64(1): 5000, np.int64(0): 5000})
# ##############################################
# SMOTE done!
# X_train.shape: (10000, 3072)
# y_train.shape: (10000,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# y_pred.shape: (2000,)
# TP: 800
# FP: 576
# FN: 200
# TN: 424
# Accuracy: 0.6120
# Misclassification rate: 0.3880
# Sensitivity (Recall): 0.8000
# Specificity: 0.4240
# Precision: 0.5814
# Negative Predictive Value: 0.6795
# G-mean: 0.5824
# F-measure: 0.6734
# Discriminant Power: 0.5954
# F2-measure: 0.6150
# InvF0.5-measure: 0.7440
# AGF: 0.6765
# Balanced Accuracy: 0.6120
# Matthew's Correlation Coefficient: 0.2417
# Cohen's Kappa: 0.2240
# Youden's Index: 0.2240
# Positive Likelihood Ratio: 1.3889
# Negative Likelihood Ratio: 0.4717

# %%
from Swim_Maha import SwimMaha
fractions = [0.005, 0.01, 0.02, 0.05, 0.1, 0.2]
for frac in range(len(fractions)):
    import torch
    from torch.utils.data import DataLoader, Subset, ConcatDataset, TensorDataset
    from torchvision import datasets, transforms
    import numpy as np

    # CIFAR10 数据归一化参数
    # 数据预处理
    cifar10_transforms = transforms.Compose([
        transforms.ToTensor(), 
        transforms.Normalize((0.4914, 0.4822, 0.4465), (0.247, 0.243, 0.261))
    ])
    # 加载 CIFAR10 数据集
    full_train_dataset = datasets.CIFAR10(
        root="/Users/max/MasterThesisData/CIFAR10", train=True, transform=cifar10_transforms, download=True)
    full_test_dataset = datasets.CIFAR10(
        root="/Users/max/MasterThesisData/CIFAR10", train=False, transform=cifar10_transforms, download=True)

    # 筛选训练集中的标签 3 和 4，并映射标签（标签 3 -> 1，标签 4 -> 0）
    indices3_train = [i for i in range(len(full_train_dataset)) if full_train_dataset.targets[i] == 3]
    indices4_train = [i for i in range(len(full_train_dataset)) if full_train_dataset.targets[i] == 4]

    # 筛选测试集中的标签 3 和 4，并映射标签
    indices3_test = [i for i in range(len(full_test_dataset)) if full_test_dataset.targets[i] == 3]
    indices4_test = [i for i in range(len(full_test_dataset)) if full_test_dataset.targets[i] == 4]

    # 训练集：获取标签为 3 的数据（映射为 1）
    cifar3_train_data = full_train_dataset.data[indices3_train]  # numpy 数组，形状 (n, 32, 32, 3)
    cifar3_train_labels = torch.ones(len(indices3_train), dtype=torch.long)

    # 训练集：获取标签为 4 的数据（映射为 0）
    cifar4_train_data = full_train_dataset.data[indices4_train]
    cifar4_train_labels = torch.zeros(len(indices4_train), dtype=torch.long)

    # 测试集：获取标签为 3 的数据（映射为 1）
    cifar3_test_data = full_test_dataset.data[indices3_test]
    cifar3_test_labels = torch.ones(len(indices3_test), dtype=torch.long)

    # 测试集：获取标签为 4 的数据（映射为 0）
    cifar4_test_data = full_test_dataset.data[indices4_test]
    cifar4_test_labels = torch.zeros(len(indices4_test), dtype=torch.long)

    # 控制不平衡比例，比如这里设定为 0.005（即只选取标签 4 数据中的一小部分）
    fraction = int(fractions[frac] * len(cifar3_train_data))
    selected_indices_4 = np.random.choice(len(cifar4_train_data), fraction, replace=False)
    fraction_cifar4_train_data = cifar4_train_data[selected_indices_4]
    fraction_cifar4_train_labels = cifar4_train_labels[selected_indices_4]

    # 拼接最终的训练和测试数据集
    Final_train_data = np.concatenate([cifar3_train_data, fraction_cifar4_train_data], axis=0)
    Final_train_labels = torch.cat([cifar3_train_labels, fraction_cifar4_train_labels], dim=0)

    Final_test_data = np.concatenate([cifar3_test_data, cifar4_test_data], axis=0)
    Final_test_labels = torch.cat([cifar3_test_labels, cifar4_test_labels], dim=0)

    # 将 numpy 数组转换为 tensor，并调整维度为 (N, C, H, W)
    Final_train_data = torch.from_numpy(Final_train_data).permute(0, 3, 1, 2).float()
    Final_test_data = torch.from_numpy(Final_test_data).permute(0, 3, 1, 2).float()

    # 归一化图像数据：先除以 255，再进行标准化
    # # 创建 TensorDataset
    # Final_train_datasets = TensorDataset(Final_train_data.unsqueeze(3).float() / 255, Final_train_labels)
    # Final_test_datasets = TensorDataset(Final_test_data.unsqueeze(3).float() / 255, Final_test_labels)

    # 创建 TensorDataset
    Final_train_dataset = TensorDataset(Final_train_data.float() / 255, Final_train_labels)
    Final_test_dataset = TensorDataset(Final_test_data.float() / 255, Final_test_labels)

    # 数据加载器
    train_loader = DataLoader(Final_train_dataset, batch_size=64, shuffle=True)
    test_loader = DataLoader(Final_test_dataset, batch_size=64, shuffle=False)

    # 打印数据信息
    print("Number of label 1 in the final training set: ", len(cifar3_train_data))
    print("Number of label 0 in the final training set (after downsampling): ", len(fraction_cifar4_train_data))
    print("Number of label 1 in the final test set: ", len(cifar3_test_data))
    print("Number of label 0 in the final test set: ", len(cifar4_test_data))

    print("Total samples in final training set: ", len(Final_train_dataset))
    print("Total samples in final test set: ", len(Final_test_dataset))

    print("Number of batches in training set: ", len(train_loader))
    print("Number of batches in test set: ", len(test_loader))


    
    ## 获取一个 batch
    images, labels = next(iter(train_loader))

    # 打印张量信息
    print(f"Images shape: {images.shape}")  # (batch_size, 3, 32, 32)
    print(f"Labels shape: {labels.shape}")

    # 将第一张图像的维度转换为 (H, W, C) 并显示
    img = images[0].permute(1, 2, 0).numpy()  # (32, 32, 3)
    plt.imshow(img)  # 对于彩色图像，无需指定 cmap
    plt.title(f"Label: {labels[0].item()}")
    plt.show()

    plt.figure(figsize=(20, 5))
    for i, img_tensor in enumerate(images[:20]):
        # 将每张图像转换为 (H, W, C)
        npimg = img_tensor.permute(1, 2, 0).numpy()
        plt.subplot(2, 10, i+1)
        plt.imshow(npimg)  # 彩色图像，不指定 cmap
        plt.axis('off')
    plt.show()


    X_train = []
    y_train = []

    for batch in train_loader:
        images, labels = batch  # images: (batch_size, 1, 28, 28), labels: (batch_size,)
        if hasattr(images, 'numpy'): # images is tensor
            images = images.numpy()
        # batch_size = 64
        for img, label in zip(images, labels):
            #print(f"Original shape: {img.shape}")  #  
            flattened_img = img.flatten()           
            #print(f"Flattened shape: {flattened_img.shape}")
            X_train.append(flattened_img) # 
            y_train.append(label)


    X_test = [] # features
    y_test = [] # labels
    for batch in test_loader:
        images, labels = batch  # images: (batch_size, 1,28  ,28 ), labels: (batch_size,)
        if hasattr(images, 'numpy'): # images is tensor
            images = images.numpy()
        # batch_size = 64
        for img, label in zip(images, labels):
            flattened_img = img.flatten()           # flatten the image
            X_test.append(flattened_img)
            y_test.append(label)


    X_train = np.array(X_train)
    y_train = np.array(y_train)
    X_test = np.array(X_test)
    y_test = np.array(y_test)
    print("X_train.shape:", X_train.shape)
    print("y_train.shape:", y_train.shape)
    print("X_test.shape:", X_test.shape)
    print("y_test.shape:", y_test.shape)
    ### SMOTE

    from imblearn.over_sampling import SMOTE
    from collections import Counter

    sm = BorderlineSMOTE(random_state=42, kind='borderline-1')
    X_train, y_train = sm.fit_resample(X_train, y_train)
    print('Resampled dataset shape %s' % Counter(y_train))
    print("##############################################")
    print("SMOTE done!")
    print("X_train.shape:", X_train.shape)
    print("y_train.shape:", y_train.shape)
    print("X_test.shape:", X_test.shape)
    print("y_test.shape:", y_test.shape)
    # training model
    from sklearn import svm
    from sklearn.preprocessing import StandardScaler
    from sklearn.neighbors import KNeighborsClassifier

    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_test = scaler.transform(X_test)
    from sklearn.naive_bayes import GaussianNB

    # 创建一个Gaussian Naive Bayes分类器
    nb = GaussianNB()
    nb.fit(X_train, y_train)
    y_pred = nb.predict(X_test)
    print("y_pred.shape:", y_pred.shape)


    from self_metrics import Binary_got_metrics
    from self_metrics import Binary_got_cofusion_matrix
    from self_metrics import Binary_got_metrics
    TP, FP, FN, TN = Binary_got_cofusion_matrix(y_test, y_pred, labels = [1,0])


    Accuracy, misclassification_rate, Sensitivity, Specificity, Precision, Negative_Predictive_Value, Gmean, Fmean, DPower, F2measure, InvF_05, AGFmeasure, Balanced_Accuracy, MCCmeasure, Kappa, Youden_Index, LR_pos, LR_neg = Binary_got_metrics(TP, FP, FN, TN)
    import json

            # 构造一个包含所有指标数据的字典
    metrics_dict = {
                "Number of label 3 in the final training set": len(cifar3_train_data),
                "Number of label 4 in the final training set (after downsampling)": len(fraction_cifar4_train_data),
                "Number of label 3 in the final test set": len(cifar3_test_data),
                "Number of label 4 in the final test set": len(cifar4_test_data),
                "Total samples in final training set": len(Final_train_dataset),
                "Total samples in final test set": len(Final_test_dataset),
                "Number of batches in training set": len(train_loader),
                "Number of batches in test set": len(test_loader),
                "TP": TP,
                "FP": FP,
                "FN": FN,
                "TN": TN,
                "Accuracy": round(Accuracy, 4),
                "Misclassification rate": round(misclassification_rate, 4),
                "Sensitivity (Recall)": round(Sensitivity, 4),
                "Specificity": round(Specificity, 4),
                "Precision": round(Precision, 4),
                "Negative Predictive Value": round(Negative_Predictive_Value, 4),
                "G-mean": round(Gmean, 4),
                "F-measure": round(Fmean, 4),
                "Discriminant Power (DP)": round(DPower, 4),
                "F2-measure": round(F2measure, 4),
                "InvF0.5-measure": round(InvF_05, 4),
                "AGF": round(AGFmeasure, 4),
                "Balanced Accuracy": round(Balanced_Accuracy, 4),
                "Matthew's Correlation Coefficient (MCC)": round(MCCmeasure, 4),
                "Cohen's Kappa": round(Kappa, 4),
                "Youden's Index": round(Youden_Index, 4),
                "Positive Likelihood Ratio (LR+)": round(LR_pos, 4),
                "Negative Likelihood Ratio (LR-)": round(LR_neg, 4)
            }

            # 指定 JSON 文件保存路径
    metrics_results_path = f"BorderlineSMOTE_NavieBayesBinaryCIFAR1034_{fraction}_metrics_results.json"
    # 将字典保存为 JSON 文件
    with open(metrics_results_path, "w") as f:
        json.dump(metrics_dict, f, indent=4)
# Out:
# Number of label 1 in the final training set:  5000
# Number of label 0 in the final training set (after downsampling):  25
# Number of label 1 in the final test set:  1000
# Number of label 0 in the final test set:  1000
# Total samples in final training set:  5025
# Total samples in final test set:  2000
# Number of batches in training set:  79
# Number of batches in test set:  32
# Images shape: torch.Size([64, 3, 32, 32])
# Labels shape: torch.Size([64])
# X_train.shape: (5025, 3072)
# y_train.shape: (5025,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# Resampled dataset shape Counter({np.int64(1): 5000, np.int64(0): 5000})
# ##############################################
# SMOTE done!
# X_train.shape: (10000, 3072)
# y_train.shape: (10000,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# y_pred.shape: (2000,)
# TP: 941
# FP: 774
# FN: 59
# TN: 226
# Accuracy: 0.5835
# Misclassification rate: 0.4165
# Sensitivity (Recall): 0.9410
# Specificity: 0.2260
# Precision: 0.5487
# Negative Predictive Value: 0.7930
# G-mean: 0.4612
# F-measure: 0.6932
# Discriminant Power: 0.8481
# F2-measure: 0.5986
# InvF0.5-measure: 0.8233
# AGF: 0.7020
# Balanced Accuracy: 0.5835
# Matthew's Correlation Coefficient: 0.2389
# Cohen's Kappa: 0.1670
# Youden's Index: 0.1670
# Positive Likelihood Ratio: 1.2158
# Negative Likelihood Ratio: 0.2611
# Number of label 1 in the final training set:  5000
# Number of label 0 in the final training set (after downsampling):  50
# Number of label 1 in the final test set:  1000
# Number of label 0 in the final test set:  1000
# Total samples in final training set:  5050
# Total samples in final test set:  2000
# Number of batches in training set:  79
# Number of batches in test set:  32
# Images shape: torch.Size([64, 3, 32, 32])
# Labels shape: torch.Size([64])
# X_train.shape: (5050, 3072)
# y_train.shape: (5050,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# Resampled dataset shape Counter({np.int64(1): 5000, np.int64(0): 5000})
# ##############################################
# SMOTE done!
# X_train.shape: (10000, 3072)
# y_train.shape: (10000,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# y_pred.shape: (2000,)
# TP: 917
# FP: 653
# FN: 83
# TN: 347
# Accuracy: 0.6320
# Misclassification rate: 0.3680
# Sensitivity (Recall): 0.9170
# Specificity: 0.3470
# Precision: 0.5841
# Negative Predictive Value: 0.8070
# G-mean: 0.5641
# F-measure: 0.7136
# Discriminant Power: 0.9759
# F2-measure: 0.6298
# InvF0.5-measure: 0.8232
# AGF: 0.7200
# Balanced Accuracy: 0.6320
# Matthew's Correlation Coefficient: 0.3213
# Cohen's Kappa: 0.2640
# Youden's Index: 0.2640
# Positive Likelihood Ratio: 1.4043
# Negative Likelihood Ratio: 0.2392
# Number of label 1 in the final training set:  5000
# Number of label 0 in the final training set (after downsampling):  100
# Number of label 1 in the final test set:  1000
# Number of label 0 in the final test set:  1000
# Total samples in final training set:  5100
# Total samples in final test set:  2000
# Number of batches in training set:  80
# Number of batches in test set:  32
# Images shape: torch.Size([64, 3, 32, 32])
# Labels shape: torch.Size([64])
# X_train.shape: (5100, 3072)
# y_train.shape: (5100,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# Resampled dataset shape Counter({np.int64(1): 5000, np.int64(0): 5000})
# ##############################################
# SMOTE done!
# X_train.shape: (10000, 3072)
# y_train.shape: (10000,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# y_pred.shape: (2000,)
# TP: 813
# FP: 463
# FN: 187
# TN: 537
# Accuracy: 0.6750
# Misclassification rate: 0.3250
# Sensitivity (Recall): 0.8130
# Specificity: 0.5370
# Precision: 0.6371
# Negative Predictive Value: 0.7417
# G-mean: 0.6607
# F-measure: 0.7144
# Discriminant Power: 0.8920
# F2-measure: 0.6660
# InvF0.5-measure: 0.7705
# AGF: 0.7163
# Balanced Accuracy: 0.6750
# Matthew's Correlation Coefficient: 0.3641
# Cohen's Kappa: 0.3500
# Youden's Index: 0.3500
# Positive Likelihood Ratio: 1.7559
# Negative Likelihood Ratio: 0.3482
# Number of label 1 in the final training set:  5000
# Number of label 0 in the final training set (after downsampling):  250
# Number of label 1 in the final test set:  1000
# Number of label 0 in the final test set:  1000
# Total samples in final training set:  5250
# Total samples in final test set:  2000
# Number of batches in training set:  83
# Number of batches in test set:  32
# Images shape: torch.Size([64, 3, 32, 32])
# Labels shape: torch.Size([64])
# X_train.shape: (5250, 3072)
# y_train.shape: (5250,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# Resampled dataset shape Counter({np.int64(1): 5000, np.int64(0): 5000})
# ##############################################
# SMOTE done!
# X_train.shape: (10000, 3072)
# y_train.shape: (10000,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# y_pred.shape: (2000,)
# TP: 714
# FP: 356
# FN: 286
# TN: 644
# Accuracy: 0.6790
# Misclassification rate: 0.3210
# Sensitivity (Recall): 0.7140
# Specificity: 0.6440
# Precision: 0.6673
# Negative Predictive Value: 0.6925
# G-mean: 0.6781
# F-measure: 0.6899
# Discriminant Power: 0.8312
# F2-measure: 0.6761
# InvF0.5-measure: 0.7041
# AGF: 0.6900
# Balanced Accuracy: 0.6790
# Matthew's Correlation Coefficient: 0.3589
# Cohen's Kappa: 0.3580
# Youden's Index: 0.3580
# Positive Likelihood Ratio: 2.0056
# Negative Likelihood Ratio: 0.4441
# Number of label 1 in the final training set:  5000
# Number of label 0 in the final training set (after downsampling):  500
# Number of label 1 in the final test set:  1000
# Number of label 0 in the final test set:  1000
# Total samples in final training set:  5500
# Total samples in final test set:  2000
# Number of batches in training set:  86
# Number of batches in test set:  32
# Images shape: torch.Size([64, 3, 32, 32])
# Labels shape: torch.Size([64])
# X_train.shape: (5500, 3072)
# y_train.shape: (5500,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# Resampled dataset shape Counter({np.int64(1): 5000, np.int64(0): 5000})
# ##############################################
# SMOTE done!
# X_train.shape: (10000, 3072)
# y_train.shape: (10000,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# y_pred.shape: (2000,)
# TP: 694
# FP: 332
# FN: 306
# TN: 668
# Accuracy: 0.6810
# Misclassification rate: 0.3190
# Sensitivity (Recall): 0.6940
# Specificity: 0.6680
# Precision: 0.6764
# Negative Predictive Value: 0.6858
# G-mean: 0.6809
# F-measure: 0.6851
# Discriminant Power: 0.8369
# F2-measure: 0.6799
# InvF0.5-measure: 0.6904
# AGF: 0.6851
# Balanced Accuracy: 0.6810
# Matthew's Correlation Coefficient: 0.3621
# Cohen's Kappa: 0.3620
# Youden's Index: 0.3620
# Positive Likelihood Ratio: 2.0904
# Negative Likelihood Ratio: 0.4581
# Number of label 1 in the final training set:  5000
# Number of label 0 in the final training set (after downsampling):  1000
# Number of label 1 in the final test set:  1000
# Number of label 0 in the final test set:  1000
# Total samples in final training set:  6000
# Total samples in final test set:  2000
# Number of batches in training set:  94
# Number of batches in test set:  32
# Images shape: torch.Size([64, 3, 32, 32])
# Labels shape: torch.Size([64])
# X_train.shape: (6000, 3072)
# y_train.shape: (6000,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# Resampled dataset shape Counter({np.int64(1): 5000, np.int64(0): 5000})
# ##############################################
# SMOTE done!
# X_train.shape: (10000, 3072)
# y_train.shape: (10000,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# y_pred.shape: (2000,)
# TP: 613
# FP: 271
# FN: 387
# TN: 729
# Accuracy: 0.6710
# Misclassification rate: 0.3290
# Sensitivity (Recall): 0.6130
# Specificity: 0.7290
# Precision: 0.6934
# Negative Predictive Value: 0.6532
# G-mean: 0.6685
# F-measure: 0.6507
# Discriminant Power: 0.7991
# F2-measure: 0.6757
# InvF0.5-measure: 0.6276
# AGF: 0.6512
# Balanced Accuracy: 0.6710
# Matthew's Correlation Coefficient: 0.3443
# Cohen's Kappa: 0.3420
# Youden's Index: 0.3420
# Positive Likelihood Ratio: 2.2620
# Negative Likelihood Ratio: 0.5309

# %%
from Swim_Maha import SwimMaha
fractions = [0.005, 0.01, 0.02, 0.05, 0.1, 0.2]
for frac in range(len(fractions)):
    import torch
    from torch.utils.data import DataLoader, Subset, ConcatDataset, TensorDataset
    from torchvision import datasets, transforms
    import numpy as np

    # CIFAR10 数据归一化参数
    # 数据预处理
    cifar10_transforms = transforms.Compose([
        transforms.ToTensor(), 
        transforms.Normalize((0.4914, 0.4822, 0.4465), (0.247, 0.243, 0.261))
    ])
    # 加载 CIFAR10 数据集
    full_train_dataset = datasets.CIFAR10(
        root="/Users/max/MasterThesisData/CIFAR10", train=True, transform=cifar10_transforms, download=True)
    full_test_dataset = datasets.CIFAR10(
        root="/Users/max/MasterThesisData/CIFAR10", train=False, transform=cifar10_transforms, download=True)

    # 筛选训练集中的标签 3 和 4，并映射标签（标签 3 -> 1，标签 4 -> 0）
    indices3_train = [i for i in range(len(full_train_dataset)) if full_train_dataset.targets[i] == 3]
    indices4_train = [i for i in range(len(full_train_dataset)) if full_train_dataset.targets[i] == 4]

    # 筛选测试集中的标签 3 和 4，并映射标签
    indices3_test = [i for i in range(len(full_test_dataset)) if full_test_dataset.targets[i] == 3]
    indices4_test = [i for i in range(len(full_test_dataset)) if full_test_dataset.targets[i] == 4]

    # 训练集：获取标签为 3 的数据（映射为 1）
    cifar3_train_data = full_train_dataset.data[indices3_train]  # numpy 数组，形状 (n, 32, 32, 3)
    cifar3_train_labels = torch.ones(len(indices3_train), dtype=torch.long)

    # 训练集：获取标签为 4 的数据（映射为 0）
    cifar4_train_data = full_train_dataset.data[indices4_train]
    cifar4_train_labels = torch.zeros(len(indices4_train), dtype=torch.long)

    # 测试集：获取标签为 3 的数据（映射为 1）
    cifar3_test_data = full_test_dataset.data[indices3_test]
    cifar3_test_labels = torch.ones(len(indices3_test), dtype=torch.long)

    # 测试集：获取标签为 4 的数据（映射为 0）
    cifar4_test_data = full_test_dataset.data[indices4_test]
    cifar4_test_labels = torch.zeros(len(indices4_test), dtype=torch.long)

    # 控制不平衡比例，比如这里设定为 0.005（即只选取标签 4 数据中的一小部分）
    fraction = int(fractions[frac] * len(cifar3_train_data))
    selected_indices_4 = np.random.choice(len(cifar4_train_data), fraction, replace=False)
    fraction_cifar4_train_data = cifar4_train_data[selected_indices_4]
    fraction_cifar4_train_labels = cifar4_train_labels[selected_indices_4]

    # 拼接最终的训练和测试数据集
    Final_train_data = np.concatenate([cifar3_train_data, fraction_cifar4_train_data], axis=0)
    Final_train_labels = torch.cat([cifar3_train_labels, fraction_cifar4_train_labels], dim=0)

    Final_test_data = np.concatenate([cifar3_test_data, cifar4_test_data], axis=0)
    Final_test_labels = torch.cat([cifar3_test_labels, cifar4_test_labels], dim=0)

    # 将 numpy 数组转换为 tensor，并调整维度为 (N, C, H, W)
    Final_train_data = torch.from_numpy(Final_train_data).permute(0, 3, 1, 2).float()
    Final_test_data = torch.from_numpy(Final_test_data).permute(0, 3, 1, 2).float()

    # 归一化图像数据：先除以 255，再进行标准化
    # # 创建 TensorDataset
    # Final_train_datasets = TensorDataset(Final_train_data.unsqueeze(3).float() / 255, Final_train_labels)
    # Final_test_datasets = TensorDataset(Final_test_data.unsqueeze(3).float() / 255, Final_test_labels)

    # 创建 TensorDataset
    Final_train_dataset = TensorDataset(Final_train_data.float() / 255, Final_train_labels)
    Final_test_dataset = TensorDataset(Final_test_data.float() / 255, Final_test_labels)

    # 数据加载器
    train_loader = DataLoader(Final_train_dataset, batch_size=64, shuffle=True)
    test_loader = DataLoader(Final_test_dataset, batch_size=64, shuffle=False)

    # 打印数据信息
    print("Number of label 1 in the final training set: ", len(cifar3_train_data))
    print("Number of label 0 in the final training set (after downsampling): ", len(fraction_cifar4_train_data))
    print("Number of label 1 in the final test set: ", len(cifar3_test_data))
    print("Number of label 0 in the final test set: ", len(cifar4_test_data))

    print("Total samples in final training set: ", len(Final_train_dataset))
    print("Total samples in final test set: ", len(Final_test_dataset))

    print("Number of batches in training set: ", len(train_loader))
    print("Number of batches in test set: ", len(test_loader))


    
    ## 获取一个 batch
    images, labels = next(iter(train_loader))

    # 打印张量信息
    print(f"Images shape: {images.shape}")  # (batch_size, 3, 32, 32)
    print(f"Labels shape: {labels.shape}")

    # 将第一张图像的维度转换为 (H, W, C) 并显示
    img = images[0].permute(1, 2, 0).numpy()  # (32, 32, 3)
    plt.imshow(img)  # 对于彩色图像，无需指定 cmap
    plt.title(f"Label: {labels[0].item()}")
    plt.show()

    plt.figure(figsize=(20, 5))
    for i, img_tensor in enumerate(images[:20]):
        # 将每张图像转换为 (H, W, C)
        npimg = img_tensor.permute(1, 2, 0).numpy()
        plt.subplot(2, 10, i+1)
        plt.imshow(npimg)  # 彩色图像，不指定 cmap
        plt.axis('off')
    plt.show()


    X_train = []
    y_train = []

    for batch in train_loader:
        images, labels = batch  # images: (batch_size, 1, 28, 28), labels: (batch_size,)
        if hasattr(images, 'numpy'): # images is tensor
            images = images.numpy()
        # batch_size = 64
        for img, label in zip(images, labels):
            #print(f"Original shape: {img.shape}")  #  
            flattened_img = img.flatten()           
            #print(f"Flattened shape: {flattened_img.shape}")
            X_train.append(flattened_img) # 
            y_train.append(label)


    X_test = [] # features
    y_test = [] # labels
    for batch in test_loader:
        images, labels = batch  # images: (batch_size, 1,28  ,28 ), labels: (batch_size,)
        if hasattr(images, 'numpy'): # images is tensor
            images = images.numpy()
        # batch_size = 64
        for img, label in zip(images, labels):
            flattened_img = img.flatten()           # flatten the image
            X_test.append(flattened_img)
            y_test.append(label)


    X_train = np.array(X_train)
    y_train = np.array(y_train)
    X_test = np.array(X_test)
    y_test = np.array(y_test)
    print("X_train.shape:", X_train.shape)
    print("y_train.shape:", y_train.shape)
    print("X_test.shape:", X_test.shape)
    print("y_test.shape:", y_test.shape)
    ### SMOTE

    from imblearn.over_sampling import SMOTE
    from collections import Counter

    sm = BorderlineSMOTE(random_state=42, kind='borderline-1')
    X_train, y_train = sm.fit_resample(X_train, y_train)
    print('Resampled dataset shape %s' % Counter(y_train))
    print("##############################################")
    print("SMOTE done!")
    print("X_train.shape:", X_train.shape)
    print("y_train.shape:", y_train.shape)
    print("X_test.shape:", X_test.shape)
    print("y_test.shape:", y_test.shape)
    # training model
    from sklearn import svm
    from sklearn.preprocessing import StandardScaler
    from sklearn.neighbors import KNeighborsClassifier

    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_test = scaler.transform(X_test)
    # 创建一个KNN分类器，设定邻居数为5（你可以根据需要调整n_neighbors的值）
    knn = KNeighborsClassifier(n_neighbors=5)
    knn.fit(X_train, y_train)
    y_pred = knn.predict(X_test)
    print("y_pred.shape:", y_pred.shape)



    from self_metrics import Binary_got_metrics
    from self_metrics import Binary_got_cofusion_matrix
    from self_metrics import Binary_got_metrics
    TP, FP, FN, TN = Binary_got_cofusion_matrix(y_test, y_pred, labels = [1,0])


    Accuracy, misclassification_rate, Sensitivity, Specificity, Precision, Negative_Predictive_Value, Gmean, Fmean, DPower, F2measure, InvF_05, AGFmeasure, Balanced_Accuracy, MCCmeasure, Kappa, Youden_Index, LR_pos, LR_neg = Binary_got_metrics(TP, FP, FN, TN)
    import json

            # 构造一个包含所有指标数据的字典
    metrics_dict = {
                "Number of label 3 in the final training set": len(cifar3_train_data),
                "Number of label 4 in the final training set (after downsampling)": len(fraction_cifar4_train_data),
                "Number of label 3 in the final test set": len(cifar3_test_data),
                "Number of label 4 in the final test set": len(cifar4_test_data),
                "Total samples in final training set": len(Final_train_dataset),
                "Total samples in final test set": len(Final_test_dataset),
                "Number of batches in training set": len(train_loader),
                "Number of batches in test set": len(test_loader),
                "TP": TP,
                "FP": FP,
                "FN": FN,
                "TN": TN,
                "Accuracy": round(Accuracy, 4),
                "Misclassification rate": round(misclassification_rate, 4),
                "Sensitivity (Recall)": round(Sensitivity, 4),
                "Specificity": round(Specificity, 4),
                "Precision": round(Precision, 4),
                "Negative Predictive Value": round(Negative_Predictive_Value, 4),
                "G-mean": round(Gmean, 4),
                "F-measure": round(Fmean, 4),
                "Discriminant Power (DP)": round(DPower, 4),
                "F2-measure": round(F2measure, 4),
                "InvF0.5-measure": round(InvF_05, 4),
                "AGF": round(AGFmeasure, 4),
                "Balanced Accuracy": round(Balanced_Accuracy, 4),
                "Matthew's Correlation Coefficient (MCC)": round(MCCmeasure, 4),
                "Cohen's Kappa": round(Kappa, 4),
                "Youden's Index": round(Youden_Index, 4),
                "Positive Likelihood Ratio (LR+)": round(LR_pos, 4),
                "Negative Likelihood Ratio (LR-)": round(LR_neg, 4)
            }

            # 指定 JSON 文件保存路径
    metrics_results_path = f"BorderlineSMOTE_KNNBinaryCIFAR1034_{fraction}_metrics_results.json"
    # 将字典保存为 JSON 文件
    with open(metrics_results_path, "w") as f:
        json.dump(metrics_dict, f, indent=4)
# Out:
# Number of label 1 in the final training set:  5000
# Number of label 0 in the final training set (after downsampling):  25
# Number of label 1 in the final test set:  1000
# Number of label 0 in the final test set:  1000
# Total samples in final training set:  5025
# Total samples in final test set:  2000
# Number of batches in training set:  79
# Number of batches in test set:  32
# Images shape: torch.Size([64, 3, 32, 32])
# Labels shape: torch.Size([64])
# X_train.shape: (5025, 3072)
# y_train.shape: (5025,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# Resampled dataset shape Counter({np.int64(1): 5000, np.int64(0): 5000})
# ##############################################
# SMOTE done!
# X_train.shape: (10000, 3072)
# y_train.shape: (10000,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# y_pred.shape: (2000,)
# TP: 888
# FP: 674
# FN: 112
# TN: 326
# Accuracy: 0.6070
# Misclassification rate: 0.3930
# Sensitivity (Recall): 0.8880
# Specificity: 0.3260
# Precision: 0.5685
# Negative Predictive Value: 0.7443
# G-mean: 0.5380
# F-measure: 0.6932
# Discriminant Power: 0.7411
# F2-measure: 0.6126
# InvF0.5-measure: 0.7983
# AGF: 0.6993
# Balanced Accuracy: 0.6070
# Matthew's Correlation Coefficient: 0.2587
# Cohen's Kappa: 0.2140
# Youden's Index: 0.2140
# Positive Likelihood Ratio: 1.3175
# Negative Likelihood Ratio: 0.3436
# Number of label 1 in the final training set:  5000
# Number of label 0 in the final training set (after downsampling):  50
# Number of label 1 in the final test set:  1000
# Number of label 0 in the final test set:  1000
# Total samples in final training set:  5050
# Total samples in final test set:  2000
# Number of batches in training set:  79
# Number of batches in test set:  32
# Images shape: torch.Size([64, 3, 32, 32])
# Labels shape: torch.Size([64])
# X_train.shape: (5050, 3072)
# y_train.shape: (5050,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# Resampled dataset shape Counter({np.int64(1): 5000, np.int64(0): 5000})
# ##############################################
# SMOTE done!
# X_train.shape: (10000, 3072)
# y_train.shape: (10000,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# y_pred.shape: (2000,)
# TP: 740
# FP: 462
# FN: 260
# TN: 538
# Accuracy: 0.6390
# Misclassification rate: 0.3610
# Sensitivity (Recall): 0.7400
# Specificity: 0.5380
# Precision: 0.6156
# Negative Predictive Value: 0.6742
# G-mean: 0.6310
# F-measure: 0.6721
# Discriminant Power: 0.6606
# F2-measure: 0.6371
# InvF0.5-measure: 0.7113
# AGF: 0.6731
# Balanced Accuracy: 0.6390
# Matthew's Correlation Coefficient: 0.2839
# Cohen's Kappa: 0.2780
# Youden's Index: 0.2780
# Positive Likelihood Ratio: 1.6017
# Negative Likelihood Ratio: 0.4833
# Number of label 1 in the final training set:  5000
# Number of label 0 in the final training set (after downsampling):  100
# Number of label 1 in the final test set:  1000
# Number of label 0 in the final test set:  1000
# Total samples in final training set:  5100
# Total samples in final test set:  2000
# Number of batches in training set:  80
# Number of batches in test set:  32
# Images shape: torch.Size([64, 3, 32, 32])
# Labels shape: torch.Size([64])
# X_train.shape: (5100, 3072)
# y_train.shape: (5100,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# Resampled dataset shape Counter({np.int64(1): 5000, np.int64(0): 5000})
# ##############################################
# SMOTE done!
# X_train.shape: (10000, 3072)
# y_train.shape: (10000,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# y_pred.shape: (2000,)
# TP: 608
# FP: 229
# FN: 392
# TN: 771
# Accuracy: 0.6895
# Misclassification rate: 0.3105
# Sensitivity (Recall): 0.6080
# Specificity: 0.7710
# Precision: 0.7264
# Negative Predictive Value: 0.6629
# G-mean: 0.6847
# F-measure: 0.6619
# Discriminant Power: 0.9113
# F2-measure: 0.6992
# InvF0.5-measure: 0.6285
# AGF: 0.6629
# Balanced Accuracy: 0.6895
# Matthew's Correlation Coefficient: 0.3841
# Cohen's Kappa: 0.3790
# Youden's Index: 0.3790
# Positive Likelihood Ratio: 2.6550
# Negative Likelihood Ratio: 0.5084
# Number of label 1 in the final training set:  5000
# Number of label 0 in the final training set (after downsampling):  250
# Number of label 1 in the final test set:  1000
# Number of label 0 in the final test set:  1000
# Total samples in final training set:  5250
# Total samples in final test set:  2000
# Number of batches in training set:  83
# Number of batches in test set:  32
# Images shape: torch.Size([64, 3, 32, 32])
# Labels shape: torch.Size([64])
# X_train.shape: (5250, 3072)
# y_train.shape: (5250,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# Resampled dataset shape Counter({np.int64(1): 5000, np.int64(0): 5000})
# ##############################################
# SMOTE done!
# X_train.shape: (10000, 3072)
# y_train.shape: (10000,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# y_pred.shape: (2000,)
# TP: 418
# FP: 90
# FN: 582
# TN: 910
# Accuracy: 0.6640
# Misclassification rate: 0.3360
# Sensitivity (Recall): 0.4180
# Specificity: 0.9100
# Precision: 0.8228
# Negative Predictive Value: 0.6099
# G-mean: 0.6167
# F-measure: 0.5544
# Discriminant Power: 1.0931
# F2-measure: 0.6893
# InvF0.5-measure: 0.4636
# AGF: 0.5653
# Balanced Accuracy: 0.6640
# Matthew's Correlation Coefficient: 0.3768
# Cohen's Kappa: 0.3280
# Youden's Index: 0.3280
# Positive Likelihood Ratio: 4.6444
# Negative Likelihood Ratio: 0.6396
# Number of label 1 in the final training set:  5000
# Number of label 0 in the final training set (after downsampling):  500
# Number of label 1 in the final test set:  1000
# Number of label 0 in the final test set:  1000
# Total samples in final training set:  5500
# Total samples in final test set:  2000
# Number of batches in training set:  86
# Number of batches in test set:  32
# Images shape: torch.Size([64, 3, 32, 32])
# Labels shape: torch.Size([64])
# X_train.shape: (5500, 3072)
# y_train.shape: (5500,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# Resampled dataset shape Counter({np.int64(1): 5000, np.int64(0): 5000})
# ##############################################
# SMOTE done!
# X_train.shape: (10000, 3072)
# y_train.shape: (10000,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# y_pred.shape: (2000,)
# TP: 392
# FP: 83
# FN: 608
# TN: 917
# Accuracy: 0.6545
# Misclassification rate: 0.3455
# Sensitivity (Recall): 0.3920
# Specificity: 0.9170
# Precision: 0.8253
# Negative Predictive Value: 0.6013
# G-mean: 0.5996
# F-measure: 0.5315
# Discriminant Power: 1.0825
# F2-measure: 0.6759
# InvF0.5-measure: 0.4380
# AGF: 0.5441
# Balanced Accuracy: 0.6545
# Matthew's Correlation Coefficient: 0.3631
# Cohen's Kappa: 0.3090
# Youden's Index: 0.3090
# Positive Likelihood Ratio: 4.7229
# Negative Likelihood Ratio: 0.6630
# Number of label 1 in the final training set:  5000
# Number of label 0 in the final training set (after downsampling):  1000
# Number of label 1 in the final test set:  1000
# Number of label 0 in the final test set:  1000
# Total samples in final training set:  6000
# Total samples in final test set:  2000
# Number of batches in training set:  94
# Number of batches in test set:  32
# Images shape: torch.Size([64, 3, 32, 32])
# Labels shape: torch.Size([64])
# X_train.shape: (6000, 3072)
# y_train.shape: (6000,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# Resampled dataset shape Counter({np.int64(1): 5000, np.int64(0): 5000})
# ##############################################
# SMOTE done!
# X_train.shape: (10000, 3072)
# y_train.shape: (10000,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# y_pred.shape: (2000,)
# TP: 320
# FP: 41
# FN: 680
# TN: 959
# Accuracy: 0.6395
# Misclassification rate: 0.3605
# Sensitivity (Recall): 0.3200
# Specificity: 0.9590
# Precision: 0.8864
# Negative Predictive Value: 0.5851
# G-mean: 0.5540
# F-measure: 0.4702
# Discriminant Power: 1.3224
# F2-measure: 0.6547
# InvF0.5-measure: 0.3669
# AGF: 0.4901
# Balanced Accuracy: 0.6395
# Matthew's Correlation Coefficient: 0.3627
# Cohen's Kappa: 0.2790
# Youden's Index: 0.2790
# Positive Likelihood Ratio: 7.8049
# Negative Likelihood Ratio: 0.7091
