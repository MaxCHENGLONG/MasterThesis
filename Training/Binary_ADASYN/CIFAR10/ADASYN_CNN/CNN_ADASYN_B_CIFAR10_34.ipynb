# %%
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
import torchvision
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
import numpy as np
import torch
import matplotlib.pyplot as plt
import sys
import os
sys.path.append(os.path.abspath("/Users/max/MasterThesis/Training/"))
from imblearn.over_sampling import BorderlineSMOTE

# %%
from Swim_Maha import SwimMaha
fractions  = [0.005, 0.01, 0.02, 0.05, 0.1, 0.2]
for frac in range(len(fractions)):
    import torch
    from torch.utils.data import DataLoader, Subset, ConcatDataset, TensorDataset
    from torchvision import datasets, transforms
    import numpy as np

    # CIFAR10 数据归一化参数
    # 数据预处理
    cifar10_transforms = transforms.Compose([
        transforms.ToTensor(), 
        transforms.Normalize((0.4914, 0.4822, 0.4465), (0.247, 0.243, 0.261))
    ])
    # 加载 CIFAR10 数据集
    full_train_dataset = datasets.CIFAR10(
        root="/Users/max/MasterThesisData/CIFAR10", train=True, transform=cifar10_transforms, download=True)
    full_test_dataset = datasets.CIFAR10(
        root="/Users/max/MasterThesisData/CIFAR10", train=False, transform=cifar10_transforms, download=True)

    # 筛选训练集中的标签 3 和 4，并映射标签（标签 3 -> 1，标签 4 -> 0）
    indices3_train = [i for i in range(len(full_train_dataset)) if full_train_dataset.targets[i] == 3]
    indices4_train = [i for i in range(len(full_train_dataset)) if full_train_dataset.targets[i] == 4]

    # 筛选测试集中的标签 3 和 4，并映射标签
    indices3_test = [i for i in range(len(full_test_dataset)) if full_test_dataset.targets[i] == 3]
    indices4_test = [i for i in range(len(full_test_dataset)) if full_test_dataset.targets[i] == 4]

    # 训练集：获取标签为 3 的数据（映射为 1）
    cifar3_train_data = full_train_dataset.data[indices3_train]  # numpy 数组，形状 (n, 32, 32, 3)
    cifar3_train_labels = torch.ones(len(indices3_train), dtype=torch.long)

    # 训练集：获取标签为 4 的数据（映射为 0）
    cifar4_train_data = full_train_dataset.data[indices4_train]
    cifar4_train_labels = torch.zeros(len(indices4_train), dtype=torch.long)

    # 测试集：获取标签为 3 的数据（映射为 1）
    cifar3_test_data = full_test_dataset.data[indices3_test]
    cifar3_test_labels = torch.ones(len(indices3_test), dtype=torch.long)

    # 测试集：获取标签为 4 的数据（映射为 0）
    cifar4_test_data = full_test_dataset.data[indices4_test]
    cifar4_test_labels = torch.zeros(len(indices4_test), dtype=torch.long)

    # 控制不平衡比例，比如这里设定为 0.005（即只选取标签 4 数据中的一小部分）
    fraction = int(fractions[frac] * len(cifar3_train_data))
    selected_indices_4 = np.random.choice(len(cifar4_train_data), fraction, replace=False)
    fraction_cifar4_train_data = cifar4_train_data[selected_indices_4]
    fraction_cifar4_train_labels = cifar4_train_labels[selected_indices_4]

    # 拼接最终的训练和测试数据集
    Final_train_data = np.concatenate([cifar3_train_data, fraction_cifar4_train_data], axis=0)
    Final_train_labels = torch.cat([cifar3_train_labels, fraction_cifar4_train_labels], dim=0)

    Final_test_data = np.concatenate([cifar3_test_data, cifar4_test_data], axis=0)
    Final_test_labels = torch.cat([cifar3_test_labels, cifar4_test_labels], dim=0)

    # 将 numpy 数组转换为 tensor，并调整维度为 (N, C, H, W)
    Final_train_data = torch.from_numpy(Final_train_data).permute(0, 3, 1, 2).float()
    Final_test_data = torch.from_numpy(Final_test_data).permute(0, 3, 1, 2).float()

    # 归一化图像数据：先除以 255，再进行标准化
    # # 创建 TensorDataset
    # Final_train_datasets = TensorDataset(Final_train_data.unsqueeze(3).float() / 255, Final_train_labels)
    # Final_test_datasets = TensorDataset(Final_test_data.unsqueeze(3).float() / 255, Final_test_labels)

    # 创建 TensorDataset
    Final_train_dataset = TensorDataset(Final_train_data.float() / 255, Final_train_labels)
    Final_test_dataset = TensorDataset(Final_test_data.float() / 255, Final_test_labels)

    # 数据加载器
    train_loader = DataLoader(Final_train_dataset, batch_size=64, shuffle=True)
    test_loader = DataLoader(Final_test_dataset, batch_size=64, shuffle=False)

    # 打印数据信息
    print("Number of label 1 in the final training set: ", len(cifar3_train_data))
    print("Number of label 0 in the final training set (after downsampling): ", len(fraction_cifar4_train_data))
    print("Number of label 1 in the final test set: ", len(cifar3_test_data))
    print("Number of label 0 in the final test set: ", len(cifar4_test_data))

    print("Total samples in final training set: ", len(Final_train_dataset))
    print("Total samples in final test set: ", len(Final_test_dataset))

    print("Number of batches in training set: ", len(train_loader))
    print("Number of batches in test set: ", len(test_loader))



    ## 获取一个 batch
    images, labels = next(iter(train_loader))

    # 打印张量信息
    print(f"Images shape: {images.shape}")  # (batch_size, 3, 32, 32)
    print(f"Labels shape: {labels.shape}")

    # 将第一张图像的维度转换为 (H, W, C) 并显示
    img = images[0].permute(1, 2, 0).numpy()  # (32, 32, 3)
    plt.imshow(img)  # 对于彩色图像，无需指定 cmap
    plt.title(f"Label: {labels[0].item()}")
    plt.show()

    plt.figure(figsize=(20, 5))
    for i, img_tensor in enumerate(images[:20]):
        # 将每张图像转换为 (H, W, C)
        npimg = img_tensor.permute(1, 2, 0).numpy()
        plt.subplot(2, 10, i+1)
        plt.imshow(npimg)  # 彩色图像，不指定 cmap
        plt.axis('off')
    plt.show()


    X_train = []
    y_train = []

    for batch in train_loader:
        images, labels = batch  # images: (batch_size, 1, 28, 28), labels: (batch_size,)
        if hasattr(images, 'numpy'): # images is tensor
            images = images.numpy()
        # batch_size = 64
        for img, label in zip(images, labels):
            #print(f"Original shape: {img.shape}")  #  
            flattened_img = img.flatten()           
            #print(f"Flattened shape: {flattened_img.shape}")
            X_train.append(flattened_img) # 
            y_train.append(label)


    X_test = [] # features
    y_test = [] # labels
    for batch in test_loader:
        images, labels = batch  # images: (batch_size, 1,28  ,28 ), labels: (batch_size,)
        if hasattr(images, 'numpy'): # images is tensor
            images = images.numpy()
        # batch_size = 64
        for img, label in zip(images, labels):
            flattened_img = img.flatten()           # flatten the image
            X_test.append(flattened_img)
            y_test.append(label)


    X_train = np.array(X_train)
    y_train = np.array(y_train)
    X_test = np.array(X_test)
    y_test = np.array(y_test)
    print("X_train.shape:", X_train.shape)
    print("y_train.shape:", y_train.shape)
    print("X_test.shape:", X_test.shape)
    print("y_test.shape:", y_test.shape)
    ### SMOTE

    from imblearn.over_sampling import SMOTE
    from collections import Counter

    sm = BorderlineSMOTE(random_state=42, kind='borderline-1')
    X_train, y_train = sm.fit_resample(X_train, y_train)
    print('Resampled dataset shape %s' % Counter(y_train))
    print("##############################################")
    print("SMOTE done!")
    print("X_train.shape:", X_train.shape)
    print("y_train.shape:", y_train.shape)
    print("X_test.shape:", X_test.shape)
    print("y_test.shape:", y_test.shape)
    import torch
    from torch.utils.data import TensorDataset, DataLoader

    # 假设 X_train 和 y_train 都是 numpy 数组
    # 注意：如果你的像素值范围在 0~255，建议在转换为 tensor 时进行归一化
    X_train_tensor= torch.tensor(X_train, dtype=torch.float32)
    y_train_tensor = torch.tensor(y_train, dtype=torch.long)
    print("X_train_tensor.shape:", X_train_tensor.shape)
    print("y_train_tensor.shape:", y_train_tensor.shape)

    # 假设 X_train_tensor 的形状为 (N, 32*32)，每个样本是一个扁平化的 32x32 图像
    reconstructed_images = []  # 用于保存恢复后的图像

    for i in range(len(X_train_tensor)):
        flattened_img = X_train_tensor[i]        # 取出第 i 个样本，形状 (32 32,)
        original_img = flattened_img.view(3,32, 32)  # 恢复为 (28, 28) 图像
        reconstructed_images.append(original_img)  # 存入列表

    print("总共恢复的图像数量：", len(reconstructed_images))

    # 可视化恢复后的图像
    plt.figure(figsize=(20, 5))
    for i, img in enumerate(reconstructed_images[:20]):
        plt.subplot(2, 10, i+1)
        # 将图像从 (3,32,32) 转换为 (32,32,3) 以供 plt.imshow 显示
        img_np = img.permute(1, 2, 0).numpy()
        plt.imshow(img_np)  # 对于彩色图像，不需要指定 cmap 参数
        plt.axis('off')
    plt.show()


    # 创建 Dataset
    reconstructed_images = torch.stack(reconstructed_images)  # 将列表转换为张量
    print("reconstructed_images.shape:", reconstructed_images.shape)  # (N, 32, 32)
    final_train_datasets = TensorDataset(reconstructed_images.float(), y_train_tensor)

    # 使用新的 Dataset 构建新的 DataLoader
    new_train_loader = DataLoader(final_train_datasets, batch_size=64, shuffle=True)
    print("Number of batches in new training set: ", len(new_train_loader))

    # 获取一个 batch
    images, labels = next(iter(new_train_loader))
    print(f"Images shape: {images.shape}")  # 形状为 (batch_size, channels, height, width)
    print(f"Labels shape: {labels.shape}")  # 形状为 (batch_size,)
    from torchinfo import summary
    import torch
    import torch.nn as nn
    from CNN1 import BinaryCNN3
    # 将模型转移到GPU中（我们模型运行均在GPU中进行）
    model = BinaryCNN3().to(device)
    summary(model)
    # define the optimizer and loss function
    import torch.optim as optimizer
    from self_metrics import Binary_got_metrics
    loss_function = nn.CrossEntropyLoss()
    learning_rate = 0.001
    optimizer = optimizer.Adam(model.parameters(), lr=learning_rate)

    # model training
    def train(dataloader, model, loss_function, optimizer):
        size = len(dataloader.dataset)
        num_batches = len(dataloader)
        train_loss, train_accuracy = 0, 0
        for images, labels in dataloader:
            images, labels = images.to(device), labels.to(device)
            # Compute prediction error
            prediction = model(images)
            loss = loss_function(prediction, labels)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            train_loss += loss.item()
            train_accuracy += (prediction.argmax(1) == labels).type(torch.float).sum().item()

        train_loss /= num_batches
        train_accuracy /= size

        return train_loss, train_accuracy



    # model evaluation
    def test(dataloader, model, loss_function):
        size = len(dataloader.dataset)
        num_batches = len(dataloader)
        test_loss, test_accuracy = 0, 0
        # 1(1) is positive, 0(7) is negative
        # TP: 1 classified as 1
        # TN: 0 classified as 0
        # FP: 0 classified as 1
        # FN: 1 classified as 0
        TP, TN, FP, FN = 0, 0, 0, 0
        with torch.no_grad():
            for images, labels in dataloader:
                images, labels = images.to(device), labels.to(device)
                prediction = model(images)
                test_loss += loss_function(prediction, labels).item()
                test_accuracy += (prediction.argmax(1) == labels).type(torch.float).sum().item()
                TP += ((prediction.argmax(1) == 1) & (labels == 1)).type(torch.float).sum().item()
                TN += ((prediction.argmax(1) == 0) & (labels == 0)).type(torch.float).sum().item()
                FP += ((prediction.argmax(1) == 1) & (labels == 0)).type(torch.float).sum().item()
                FN += ((prediction.argmax(1) == 0) & (labels == 1)).type(torch.float).sum().item()


        test_loss /= num_batches
        test_accuracy /= size
        return test_loss, test_accuracy, TP, TN, FP, FN

    # training the model
    epochs = 50
    train_loss_list = []
    train_accuracy_list = []
    test_loss_list = []
    test_accuracy_list = []

    best_model_TP = 0
    best_model_TN = 0
    best_model_FP = 0
    best_model_FN = 0
    best_test_accuracy = 0.0 # for saving the best model
    for epoch in range(epochs):
        model.train()
        train_loss, train_accuracy = train(new_train_loader, model, loss_function, optimizer)
        model.eval()
        test_loss, test_accuracy,TP, TN, FP, FN  = test(test_loader, model, loss_function)
        train_loss_list.append(train_loss)
        train_accuracy_list.append(train_accuracy)
        test_loss_list.append(test_loss)
        test_accuracy_list.append(test_accuracy)

        print(f"Epoch: {epoch+1}/{epochs}, Train Loss: {train_loss:.4f}, Train Accuracy: {train_accuracy:.4f}, Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.4f}") 

        if test_accuracy > best_test_accuracy:
            best_test_accuracy = test_accuracy
            best_model_TP = TP
            best_model_TN = TN
            best_model_FP = FP
            best_model_FN = FN
            save_path = f"BinaryCIFAR1034_{fraction}.pth"
            torch.save(model.state_dict(), save_path)
            print(f"==> New best model saved at epoch {epoch+1} with Test Accuracy: {test_accuracy:.4f}")
            #print(f"==> TP: {TP}, TN: {TN}, FP: {FP}, FN: {FN}")
            Accuracy, misclassification_rate, Sensitivity, Specificity, Precision, Negative_Predictive_Value, Gmean, Fmean, DPower, F2measure, InvF_05, AGFmeasure, Balanced_Accuracy, MCCmeasure, Kappa, Youden_Index, LR_pos, LR_neg = Binary_got_metrics(best_model_TP, best_model_FP, best_model_FN, best_model_TN)
            import json

            # 构造一个包含所有指标数据的字典
            metrics_dict = {
                "Number of label 3 in the final training set": len(cifar3_train_data),
                "Number of label 4 in the final training set (after downsampling)": len(fraction_cifar4_train_data),
                "Number of label 3 in the final test set": len(cifar3_test_data),
                "Number of label 4 in the final test set": len(cifar4_test_data),
                "Total samples in final training set": len(Final_train_dataset),
                "Total samples in final test set": len(Final_test_dataset),
                "Number of batches in training set": len(train_loader),
                "Number of batches in test set": len(test_loader),
                "TP": TP,
                "FP": FP,
                "FN": FN,
                "TN": TN,
                "Accuracy": round(Accuracy, 4),
                "Misclassification rate": round(misclassification_rate, 4),
                "Sensitivity (Recall)": round(Sensitivity, 4),
                "Specificity": round(Specificity, 4),
                "Precision": round(Precision, 4),
                "Negative Predictive Value": round(Negative_Predictive_Value, 4),
                "G-mean": round(Gmean, 4),
                "F-measure": round(Fmean, 4),
                "Discriminant Power (DP)": round(DPower, 4),
                "F2-measure": round(F2measure, 4),
                "InvF0.5-measure": round(InvF_05, 4),
                "AGF": round(AGFmeasure, 4),
                "Balanced Accuracy": round(Balanced_Accuracy, 4),
                "Matthew's Correlation Coefficient (MCC)": round(MCCmeasure, 4),
                "Cohen's Kappa": round(Kappa, 4),
                "Youden's Index": round(Youden_Index, 4),
                "Positive Likelihood Ratio (LR+)": round(LR_pos, 4),
                "Negative Likelihood Ratio (LR-)": round(LR_neg, 4)
            }

            # 指定 JSON 文件保存路径
            metrics_results_path = f"BorderlineSMOTE_CNNBinaryCIFAR1034_{fraction}_metrics_results.json"

            # 将字典保存为 JSON 文件
            with open(metrics_results_path, "w") as f:
                json.dump(metrics_dict, f, indent=4)
# Out:
# Number of label 1 in the final training set:  5000
# Number of label 0 in the final training set (after downsampling):  25
# Number of label 1 in the final test set:  1000
# Number of label 0 in the final test set:  1000
# Total samples in final training set:  5025
# Total samples in final test set:  2000
# Number of batches in training set:  79
# Number of batches in test set:  32
# Images shape: torch.Size([64, 3, 32, 32])
# Labels shape: torch.Size([64])
# X_train.shape: (5025, 3072)
# y_train.shape: (5025,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# Resampled dataset shape Counter({np.int64(1): 5000, np.int64(0): 5000})
# ##############################################
# SMOTE done!
# X_train.shape: (10000, 3072)
# y_train.shape: (10000,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# X_train_tensor.shape: torch.Size([10000, 3072])
# y_train_tensor.shape: torch.Size([10000])
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# 总共恢复的图像数量： 10000
# reconstructed_images.shape: torch.Size([10000, 3, 32, 32])
# Number of batches in new training set:  157
# Images shape: torch.Size([64, 3, 32, 32])
# Labels shape: torch.Size([64])
# Epoch: 1/50, Train Loss: 0.2374, Train Accuracy: 0.9001, Test Loss: 1.8900, Test Accuracy: 0.6260
# ==> New best model saved at epoch 1 with Test Accuracy: 0.6260
# TP: 949.0
# FP: 697.0
# FN: 51.0
# TN: 303.0
# Accuracy: 0.6260
# Misclassification rate: 0.3740
# Sensitivity (Recall): 0.9490
# Specificity: 0.3030
# Precision: 0.5765
# Negative Predictive Value: 0.8559
# G-mean: 0.5362
# F-measure: 0.7173
# Discriminant Power: 1.1526
# F2-measure: 0.6257
# InvF0.5-measure: 0.8404
# AGF: 0.7251
# Balanced Accuracy: 0.6260
# Matthew's Correlation Coefficient: 0.3301
# Cohen's Kappa: 0.2520
# Youden's Index: 0.2520
# Positive Likelihood Ratio: 1.3615
# Negative Likelihood Ratio: 0.1683
# Epoch: 2/50, Train Loss: 0.0592, Train Accuracy: 0.9837, Test Loss: 3.2945, Test Accuracy: 0.5890
# Epoch: 3/50, Train Loss: 0.0325, Train Accuracy: 0.9919, Test Loss: 3.7875, Test Accuracy: 0.5795
# Epoch: 4/50, Train Loss: 0.0285, Train Accuracy: 0.9942, Test Loss: 5.4012, Test Accuracy: 0.5375
# Epoch: 5/50, Train Loss: 0.0233, Train Accuracy: 0.9959, Test Loss: 4.1282, Test Accuracy: 0.5760
# Epoch: 6/50, Train Loss: 0.0181, Train Accuracy: 0.9962, Test Loss: 5.2461, Test Accuracy: 0.5335
# Epoch: 7/50, Train Loss: 0.0185, Train Accuracy: 0.9964, Test Loss: 4.7559, Test Accuracy: 0.5530
# Epoch: 8/50, Train Loss: 0.0116, Train Accuracy: 0.9979, Test Loss: 4.9194, Test Accuracy: 0.5520
# Epoch: 9/50, Train Loss: 0.0109, Train Accuracy: 0.9976, Test Loss: 5.3665, Test Accuracy: 0.5380
# Epoch: 10/50, Train Loss: 0.0088, Train Accuracy: 0.9982, Test Loss: 6.3303, Test Accuracy: 0.5260
# Epoch: 11/50, Train Loss: 0.0058, Train Accuracy: 0.9992, Test Loss: 5.4770, Test Accuracy: 0.5405
50, Train Loss: 0.0005, Train Accuracy: 1.0000, Test Loss: 6.1922, Test Accuracy: 0.5465
# Epoch: 18/50, Train Loss: 0.0004, Train Accuracy: 1.0000, Test Loss: 5.8979, Test Accuracy: 0.5565
# Epoch: 19/50, Train Loss: 0.0002, Train Accuracy: 1.0000, Test Loss: 6.1985, Test Accuracy: 0.5570
# Epoch: 20/50, Train Loss: 0.0001, Train Accuracy: 1.0000, Test Loss: 6.6514, Test Accuracy: 0.5495
# Epoch: 21/50, Train Loss: 0.0001, Train Accuracy: 1.0000, Test Loss: 6.6071, Test Accuracy: 0.5550
# Epoch: 22/50, Train Loss: 0.0001, Train Accuracy: 1.0000, Test Loss: 6.6319, Test Accuracy: 0.5545
# Epoch: 23/50, Train Loss: 0.0001, Train Accuracy: 1.0000, Test Loss: 6.7059, Test Accuracy: 0.5555
# Epoch: 24/50, Train Loss: 0.0001, Train Accuracy: 1.0000, Test Loss: 6.8680, Test Accuracy: 0.5550
# Epoch: 25/50, Train Loss: 0.0001, Train Accuracy: 1.0000, Test Loss: 7.2155, Test Accuracy: 0.5505
# Epoch: 26/50, Train Loss: 0.0001, Train Accuracy: 1.0000, Test Loss: 6.8497, Test Accuracy: 0.5585
# Epoch: 27/50, Train Loss: 0.0001, Train Accuracy: 1.0000, Test Loss: 7.1385, Test Accuracy: 0.5530
# Epoch: 28/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 7.3469, Test Accuracy: 0.5525
# Epoch: 29/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 7.3960, Test Accuracy: 0.5550
# Epoch: 30/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 7.1135, Test Accuracy: 0.5600
# Epoch: 31/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 7.4304, Test Accuracy: 0.5560
# Epoch: 32/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 7.7046, Test Accuracy: 0.5515
# Epoch: 33/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 7.6749, Test Accuracy: 0.5540
# Epoch: 34/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 7.6975, Test Accuracy: 0.5555
# Epoch: 35/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 7.9068, Test Accuracy: 0.5515
# Epoch: 36/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 8.0177, Test Accuracy: 0.5520
# Epoch: 37/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 8.0079, Test Accuracy: 0.5530
# Epoch: 38/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 7.9106, Test Accuracy: 0.5560
# Epoch: 39/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 8.0016, Test Accuracy: 0.5560
# Epoch: 40/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 8.0809, Test Accuracy: 0.5560
# Epoch: 41/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 8.2711, Test Accuracy: 0.5540
# Epoch: 42/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 8.5600, Test Accuracy: 0.5480
# Epoch: 43/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 8.5063, Test Accuracy: 0.5510
# Epoch: 44/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 8.4662, Test Accuracy: 0.5530
# Epoch: 45/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 8.5193, Test Accuracy: 0.5520
# Epoch: 46/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 8.6900, Test Accuracy: 0.5495
# Epoch: 47/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 8.5251, Test Accuracy: 0.5560
# Epoch: 48/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 8.7131, Test Accuracy: 0.5540
# Epoch: 49/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 8.5440, Test Accuracy: 0.5580
# Epoch: 50/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 9.0247, Test Accuracy: 0.5485
# Number of label 1 in the final training set:  5000
# Number of label 0 in the final training set (after downsampling):  100
# Number of label 1 in the final test set:  1000
# Number of label 0 in the final test set:  1000
# Total samples in final training set:  5100
# Total samples in final test set:  2000
# Number of batches in training set:  80
# Number of batches in test set:  32
# Images shape: torch.Size([64, 3, 32, 32])
# Labels shape: torch.Size([64])
# X_train.shape: (5100, 3072)
# y_train.shape: (5100,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# Resampled dataset shape Counter({np.int64(0): 5000, np.int64(1): 5000})
# ##############################################
# SMOTE done!
# X_train.shape: (10000, 3072)
# y_train.shape: (10000,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# X_train_tensor.shape: torch.Size([10000, 3072])
# y_train_tensor.shape: torch.Size([10000])
# 总共恢复的图像数量： 10000
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# reconstructed_images.shape: torch.Size([10000, 3, 32, 32])
# Number of batches in new training set:  157
# Images shape: torch.Size([64, 3, 32, 32])
# Labels shape: torch.Size([64])
# Epoch: 1/50, Train Loss: 0.4005, Train Accuracy: 0.8221, Test Loss: 0.7753, Test Accuracy: 0.6880
# ==> New best model saved at epoch 1 with Test Accuracy: 0.6880
# TP: 898.0
# FP: 522.0
# FN: 102.0
# TN: 478.0
# Accuracy: 0.6880
# Misclassification rate: 0.3120
# Sensitivity (Recall): 0.8980
# Specificity: 0.4780
# Precision: 0.6324
# Negative Predictive Value: 0.8241
# G-mean: 0.6552
# F-measure: 0.7421
# Discriminant Power: 1.1507
# F2-measure: 0.6722
# InvF0.5-measure: 0.8284
# AGF: 0.7462
# Balanced Accuracy: 0.6880
# Matthew's Correlation Coefficient: 0.4143
# Cohen's Kappa: 0.3760
# Youden's Index: 0.3760
# Positive Likelihood Ratio: 1.7203
# Negative Likelihood Ratio: 0.2134
# Epoch: 2/50, Train Loss: 0.2472, Train Accuracy: 0.8983, Test Loss: 0.8861, Test Accuracy: 0.6830
# Epoch: 3/50, Train Loss: 0.1722, Train Accuracy: 0.9363, Test Loss: 0.9100, Test Accuracy: 0.7145
# ==> New best model saved at epoch 3 with Test Accuracy: 0.7145
50, Train Loss: 0.0009, Train Accuracy: 1.0000, Test Loss: 5.7243, Test Accuracy: 0.5725
# Epoch: 24/50, Train Loss: 0.0005, Train Accuracy: 1.0000, Test Loss: 5.4240, Test Accuracy: 0.5835
# Epoch: 25/50, Train Loss: 0.0003, Train Accuracy: 1.0000, Test Loss: 6.2016, Test Accuracy: 0.5705
# Epoch: 26/50, Train Loss: 0.0003, Train Accuracy: 1.0000, Test Loss: 5.3504, Test Accuracy: 0.5935
# Epoch: 27/50, Train Loss: 0.0002, Train Accuracy: 1.0000, Test Loss: 5.6694, Test Accuracy: 0.5895
# Epoch: 28/50, Train Loss: 0.0002, Train Accuracy: 1.0000, Test Loss: 5.8405, Test Accuracy: 0.5845
# Epoch: 29/50, Train Loss: 0.0002, Train Accuracy: 1.0000, Test Loss: 5.9302, Test Accuracy: 0.5840
# Epoch: 30/50, Train Loss: 0.0001, Train Accuracy: 1.0000, Test Loss: 6.3402, Test Accuracy: 0.5765
# Epoch: 31/50, Train Loss: 0.0001, Train Accuracy: 1.0000, Test Loss: 6.1596, Test Accuracy: 0.5825
# Epoch: 32/50, Train Loss: 0.0001, Train Accuracy: 1.0000, Test Loss: 6.2244, Test Accuracy: 0.5840
# Epoch: 33/50, Train Loss: 0.0001, Train Accuracy: 1.0000, Test Loss: 6.5448, Test Accuracy: 0.5755
# Epoch: 34/50, Train Loss: 0.0001, Train Accuracy: 1.0000, Test Loss: 6.5272, Test Accuracy: 0.5780
# Epoch: 35/50, Train Loss: 0.0001, Train Accuracy: 1.0000, Test Loss: 6.4562, Test Accuracy: 0.5780
# Epoch: 36/50, Train Loss: 0.0001, Train Accuracy: 1.0000, Test Loss: 6.5723, Test Accuracy: 0.5805
# Epoch: 37/50, Train Loss: 0.0001, Train Accuracy: 1.0000, Test Loss: 6.6901, Test Accuracy: 0.5800
# Epoch: 38/50, Train Loss: 0.0001, Train Accuracy: 1.0000, Test Loss: 6.8975, Test Accuracy: 0.5780
# Epoch: 39/50, Train Loss: 0.0001, Train Accuracy: 1.0000, Test Loss: 6.7565, Test Accuracy: 0.5815
# Epoch: 40/50, Train Loss: 0.0001, Train Accuracy: 1.0000, Test Loss: 6.8691, Test Accuracy: 0.5815
# Epoch: 41/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 7.0654, Test Accuracy: 0.5780
# Epoch: 42/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 6.8924, Test Accuracy: 0.5825
# Epoch: 43/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 7.0536, Test Accuracy: 0.5815
# Epoch: 44/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 7.1980, Test Accuracy: 0.5810
# Epoch: 45/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 7.4670, Test Accuracy: 0.5750
# Epoch: 46/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 7.4042, Test Accuracy: 0.5785
# Epoch: 47/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 7.2458, Test Accuracy: 0.5840
# Epoch: 48/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 7.4205, Test Accuracy: 0.5805
# Epoch: 49/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 7.4239, Test Accuracy: 0.5825
# Epoch: 50/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 7.4401, Test Accuracy: 0.5835
# Number of label 1 in the final training set:  5000
# Number of label 0 in the final training set (after downsampling):  250
# Number of label 1 in the final test set:  1000
# Number of label 0 in the final test set:  1000
# Total samples in final training set:  5250
# Total samples in final test set:  2000
# Number of batches in training set:  83
# Number of batches in test set:  32
# Images shape: torch.Size([64, 3, 32, 32])
# Labels shape: torch.Size([64])
# X_train.shape: (5250, 3072)
# y_train.shape: (5250,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# Resampled dataset shape Counter({np.int64(1): 5000, np.int64(0): 5000})
# ##############################################
# SMOTE done!
# X_train.shape: (10000, 3072)
# y_train.shape: (10000,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# X_train_tensor.shape: torch.Size([10000, 3072])
# y_train_tensor.shape: torch.Size([10000])
# 总共恢复的图像数量： 10000
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# reconstructed_images.shape: torch.Size([10000, 3, 32, 32])
# Number of batches in new training set:  157
# Images shape: torch.Size([64, 3, 32, 32])
# Labels shape: torch.Size([64])
# Epoch: 1/50, Train Loss: 0.3668, Train Accuracy: 0.8326, Test Loss: 0.8495, Test Accuracy: 0.7095
# ==> New best model saved at epoch 1 with Test Accuracy: 0.7095
# TP: 914.0
# FP: 495.0
# FN: 86.0
# TN: 505.0
# Accuracy: 0.7095
# Misclassification rate: 0.2905
# Sensitivity (Recall): 0.9140
# Specificity: 0.5050
# Precision: 0.6487
# Negative Predictive Value: 0.8545
# G-mean: 0.6794
# F-measure: 0.7588
# Discriminant Power: 1.3141
# F2-measure: 0.6887
# InvF0.5-measure: 0.8449
# AGF: 0.7628
# Balanced Accuracy: 0.7095
# Matthew's Correlation Coefficient: 0.4592
# Cohen's Kappa: 0.4190
# Youden's Index: 0.4190
# Positive Likelihood Ratio: 1.8465
# Negative Likelihood Ratio: 0.1703
# Epoch: 2/50, Train Loss: 0.2338, Train Accuracy: 0.9091, Test Loss: 0.9102, Test Accuracy: 0.7175
# ==> New best model saved at epoch 2 with Test Accuracy: 0.7175
# TP: 930.0
# FP: 495.0
# FN: 70.0
# TN: 505.0
# Accuracy: 0.7175
# Misclassification rate: 0.2825
# Sensitivity (Recall): 0.9300
# Specificity: 0.5050
# Precision: 0.6526
# Negative Predictive Value: 0.8783
# G-mean: 0.6853
# F-measure: 0.7670
# Discriminant Power: 1.4371
# F2-measure: 0.6940
# InvF0.5-measure: 0.8571
# AGF: 0.7713
# Balanced Accuracy: 0.7175
50, Train Loss: 0.0008, Train Accuracy: 1.0000, Test Loss: 3.5135, Test Accuracy: 0.6500
# Epoch: 21/50, Train Loss: 0.0005, Train Accuracy: 1.0000, Test Loss: 3.5275, Test Accuracy: 0.6665
# Epoch: 22/50, Train Loss: 0.0003, Train Accuracy: 1.0000, Test Loss: 3.8738, Test Accuracy: 0.6555
# Epoch: 23/50, Train Loss: 0.0003, Train Accuracy: 1.0000, Test Loss: 3.6896, Test Accuracy: 0.6575
# Epoch: 24/50, Train Loss: 0.0002, Train Accuracy: 1.0000, Test Loss: 3.8018, Test Accuracy: 0.6590
# Epoch: 25/50, Train Loss: 0.0002, Train Accuracy: 1.0000, Test Loss: 3.8697, Test Accuracy: 0.6620
# Epoch: 26/50, Train Loss: 0.0002, Train Accuracy: 1.0000, Test Loss: 3.9617, Test Accuracy: 0.6580
# Epoch: 27/50, Train Loss: 0.0002, Train Accuracy: 1.0000, Test Loss: 4.1300, Test Accuracy: 0.6525
# Epoch: 28/50, Train Loss: 0.0001, Train Accuracy: 1.0000, Test Loss: 3.9323, Test Accuracy: 0.6630
# Epoch: 29/50, Train Loss: 0.0001, Train Accuracy: 1.0000, Test Loss: 4.0700, Test Accuracy: 0.6585
# Epoch: 30/50, Train Loss: 0.0001, Train Accuracy: 1.0000, Test Loss: 4.0784, Test Accuracy: 0.6565
# Epoch: 31/50, Train Loss: 0.0001, Train Accuracy: 1.0000, Test Loss: 4.2329, Test Accuracy: 0.6570
# Epoch: 32/50, Train Loss: 0.0001, Train Accuracy: 1.0000, Test Loss: 4.3400, Test Accuracy: 0.6490
# Epoch: 33/50, Train Loss: 0.0001, Train Accuracy: 1.0000, Test Loss: 4.1651, Test Accuracy: 0.6600
# Epoch: 34/50, Train Loss: 0.0001, Train Accuracy: 1.0000, Test Loss: 4.2647, Test Accuracy: 0.6590
# Epoch: 35/50, Train Loss: 0.0001, Train Accuracy: 1.0000, Test Loss: 4.3412, Test Accuracy: 0.6590
# Epoch: 36/50, Train Loss: 0.0001, Train Accuracy: 1.0000, Test Loss: 4.4637, Test Accuracy: 0.6570
# Epoch: 37/50, Train Loss: 0.0001, Train Accuracy: 1.0000, Test Loss: 4.4879, Test Accuracy: 0.6605
# Epoch: 38/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 4.4752, Test Accuracy: 0.6585
# Epoch: 39/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 4.6203, Test Accuracy: 0.6590
# Epoch: 40/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 4.5451, Test Accuracy: 0.6575
# Epoch: 41/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 4.6856, Test Accuracy: 0.6570
# Epoch: 42/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 4.6370, Test Accuracy: 0.6610
# Epoch: 43/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 4.7893, Test Accuracy: 0.6560
# Epoch: 44/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 4.8565, Test Accuracy: 0.6555
# Epoch: 45/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 4.7892, Test Accuracy: 0.6585
# Epoch: 46/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 4.7488, Test Accuracy: 0.6635
# Epoch: 47/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 4.8388, Test Accuracy: 0.6595
# Epoch: 48/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 4.9253, Test Accuracy: 0.6590
# Epoch: 49/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 4.8394, Test Accuracy: 0.6635
# Epoch: 50/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 4.9598, Test Accuracy: 0.6590
# Number of label 1 in the final training set:  5000
# Number of label 0 in the final training set (after downsampling):  500
# Number of label 1 in the final test set:  1000
# Number of label 0 in the final test set:  1000
# Total samples in final training set:  5500
# Total samples in final test set:  2000
# Number of batches in training set:  86
# Number of batches in test set:  32
# Images shape: torch.Size([64, 3, 32, 32])
# Labels shape: torch.Size([64])
# X_train.shape: (5500, 3072)
# y_train.shape: (5500,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# Resampled dataset shape Counter({np.int64(1): 5000, np.int64(0): 5000})
# ##############################################
# SMOTE done!
# X_train.shape: (10000, 3072)
# y_train.shape: (10000,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# X_train_tensor.shape: torch.Size([10000, 3072])
# y_train_tensor.shape: torch.Size([10000])
# 总共恢复的图像数量： 10000
# reconstructed_images.shape: torch.Size([10000, 3, 32, 32])
# Number of batches in new training set:  157
# Images shape: torch.Size([64, 3, 32, 32])
# Labels shape: torch.Size([64])
# Epoch: 1/50, Train Loss: 0.4671, Train Accuracy: 0.7713, Test Loss: 0.6591, Test Accuracy: 0.7270
# ==> New best model saved at epoch 1 with Test Accuracy: 0.7270
# TP: 856.0
# FP: 402.0
# FN: 144.0
# TN: 598.0
# Accuracy: 0.7270
# Misclassification rate: 0.2730
# Sensitivity (Recall): 0.8560
# Specificity: 0.5980
# Precision: 0.6804
# Negative Predictive Value: 0.8059
# G-mean: 0.7155
# F-measure: 0.7582
# Discriminant Power: 1.2017
# F2-measure: 0.7095
# InvF0.5-measure: 0.8140
# AGF: 0.7600
# Balanced Accuracy: 0.7270
# Matthew's Correlation Coefficient: 0.4699
# Cohen's Kappa: 0.4540
# Youden's Index: 0.4540
# Positive Likelihood Ratio: 2.1294
# Negative Likelihood Ratio: 0.2408
# Epoch: 2/50, Train Loss: 0.3320, Train Accuracy: 0.8596, Test Loss: 0.6240, Test Accuracy: 0.7500
# ==> New best model saved at epoch 2 with Test Accuracy: 0.7500
# TP: 817.0
# FP: 317.0
# FN: 183.0
# TN: 683.0
# Accuracy: 0.7500
# Misclassification rate: 0.2500
# Sensitivity (Recall): 0.8170
# Specificity: 0.6830
# Precision: 0.7205
# Negative Predictive Value: 0.7887
# G-mean: 0.7470
# F-measure: 0.7657
# Discriminant Power: 1.2481
# F2-measure: 0.7379
# InvF0.5-measure: 0.7957
# AGF: 0.7662
# Balanced Accuracy: 0.7500
# Matthew's Correlation Coefficient: 0.5046
# Cohen's Kappa: 0.5000
# Youden's Index: 0.5000
# Positive Likelihood Ratio: 2.5773
# Negative Likelihood Ratio: 0.2679
# Epoch: 3/50, Train Loss: 0.2803, Train Accuracy: 0.8859, Test Loss: 0.7077, Test Accuracy: 0.7495
# Epoch: 4/50, Train Loss: 0.2453, Train Accuracy: 0.9027, Test Loss: 0.5765, Test Accuracy: 0.7710
# ==> New best model saved at epoch 4 with Test Accuracy: 0.7710
# TP: 800.0
# FP: 258.0
# FN: 200.0
# TN: 742.0
# Accuracy: 0.7710
# Misclassification rate: 0.2290
# Sensitivity (Recall): 0.8000
# Specificity: 0.7420
# Precision: 0.7561
# Negative Predictive Value: 0.7877
# G-mean: 0.7705
# F-measure: 0.7775
# Discriminant Power: 1.3467
# F2-measure: 0.7645
# InvF0.5-measure: 0.7908
# AGF: 0.7776
# Balanced Accuracy: 0.7710
# Matthew's Correlation Coefficient: 0.5429
# Cohen's Kappa: 0.5420
# Youden's Index: 0.5420
# Positive Likelihood Ratio: 3.1008
# Negative Likelihood Ratio: 0.2695
# Epoch: 5/50, Train Loss: 0.2036, Train Accuracy: 0.9202, Test Loss: 0.9307, Test Accuracy: 0.7170
# Epoch: 6/50, Train Loss: 0.1775, Train Accuracy: 0.9347, Test Loss: 0.6759, Test Accuracy: 0.7790
# ==> New best model saved at epoch 6 with Test Accuracy: 0.7790
# TP: 882.0
# FP: 324.0
# FN: 118.0
# TN: 676.0
# Accuracy: 0.7790
# Misclassification rate: 0.2210
# Sensitivity (Recall): 0.8820
# Specificity: 0.6760
# Precision: 0.7313
# Negative Predictive Value: 0.8514
# G-mean: 0.7722
# F-measure: 0.7996
# Discriminant Power: 1.5145
# F2-measure: 0.7572
# InvF0.5-measure: 0.8471
# AGF: 0.8009
# Balanced Accuracy: 0.7790
# Matthew's Correlation Coefficient: 0.5702
# Cohen's Kappa: 0.5580
# Youden's Index: 0.5580
# Positive Likelihood Ratio: 2.7222
# Negative Likelihood Ratio: 0.1746
# Epoch: 7/50, Train Loss: 0.1515, Train Accuracy: 0.9439, Test Loss: 0.9253, Test Accuracy: 0.7410
# Epoch: 8/50, Train Loss: 0.1320, Train Accuracy: 0.9521, Test Loss: 1.1380, Test Accuracy: 0.7240
# Epoch: 9/50, Train Loss: 0.1083, Train Accuracy: 0.9610, Test Loss: 0.7249, Test Accuracy: 0.7825
# ==> New best model saved at epoch 9 with Test Accuracy: 0.7825
# TP: 858.0
# FP: 293.0
# FN: 142.0
# TN: 707.0
# Accuracy: 0.7825
# Misclassification rate: 0.2175
# Sensitivity (Recall): 0.8580
# Specificity: 0.7070
# Precision: 0.7454
# Negative Predictive Value: 0.8327
# G-mean: 0.7788
# F-measure: 0.7978
# Discriminant Power: 1.4774
# F2-measure: 0.7655
# InvF0.5-measure: 0.8328
50, Train Loss: 0.0002, Train Accuracy: 1.0000, Test Loss: 3.3041, Test Accuracy: 0.7310
# Epoch: 38/50, Train Loss: 0.0001, Train Accuracy: 1.0000, Test Loss: 3.3652, Test Accuracy: 0.7315
# Epoch: 39/50, Train Loss: 0.0001, Train Accuracy: 1.0000, Test Loss: 3.4418, Test Accuracy: 0.7300
# Epoch: 40/50, Train Loss: 0.0001, Train Accuracy: 1.0000, Test Loss: 3.4570, Test Accuracy: 0.7305
# Epoch: 41/50, Train Loss: 0.0001, Train Accuracy: 1.0000, Test Loss: 3.5067, Test Accuracy: 0.7300
# Epoch: 42/50, Train Loss: 0.0001, Train Accuracy: 1.0000, Test Loss: 3.6215, Test Accuracy: 0.7290
# Epoch: 43/50, Train Loss: 0.0001, Train Accuracy: 1.0000, Test Loss: 3.5379, Test Accuracy: 0.7315
# Epoch: 44/50, Train Loss: 0.0001, Train Accuracy: 1.0000, Test Loss: 3.6114, Test Accuracy: 0.7305
# Epoch: 45/50, Train Loss: 0.0001, Train Accuracy: 1.0000, Test Loss: 3.6191, Test Accuracy: 0.7315
# Epoch: 46/50, Train Loss: 0.0001, Train Accuracy: 1.0000, Test Loss: 3.6748, Test Accuracy: 0.7325
# Epoch: 47/50, Train Loss: 0.0001, Train Accuracy: 1.0000, Test Loss: 3.7026, Test Accuracy: 0.7330
# Epoch: 48/50, Train Loss: 0.0001, Train Accuracy: 1.0000, Test Loss: 3.6737, Test Accuracy: 0.7360
# Epoch: 49/50, Train Loss: 0.0001, Train Accuracy: 1.0000, Test Loss: 3.8705, Test Accuracy: 0.7280
# Epoch: 50/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 3.7600, Test Accuracy: 0.7345
# Number of label 1 in the final training set:  5000
# Number of label 0 in the final training set (after downsampling):  1000
# Number of label 1 in the final test set:  1000
# Number of label 0 in the final test set:  1000
# Total samples in final training set:  6000
# Total samples in final test set:  2000
# Number of batches in training set:  94
# Number of batches in test set:  32
# Images shape: torch.Size([64, 3, 32, 32])
# Labels shape: torch.Size([64])
# X_train.shape: (6000, 3072)
# y_train.shape: (6000,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# Resampled dataset shape Counter({np.int64(1): 5000, np.int64(0): 5000})
# ##############################################
# SMOTE done!
# X_train.shape: (10000, 3072)
# y_train.shape: (10000,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# X_train_tensor.shape: torch.Size([10000, 3072])
# y_train_tensor.shape: torch.Size([10000])
# 总共恢复的图像数量： 10000
# reconstructed_images.shape: torch.Size([10000, 3, 32, 32])
# Number of batches in new training set:  157
# Images shape: torch.Size([64, 3, 32, 32])
# Labels shape: torch.Size([64])
# Epoch: 1/50, Train Loss: 0.4913, Train Accuracy: 0.7647, Test Loss: 0.5986, Test Accuracy: 0.7450
# ==> New best model saved at epoch 1 with Test Accuracy: 0.7450
# TP: 868.0
# FP: 378.0
# FN: 132.0
# TN: 622.0
# Accuracy: 0.7450
# Misclassification rate: 0.2550
# Sensitivity (Recall): 0.8680
# Specificity: 0.6220
# Precision: 0.6966
# Negative Predictive Value: 0.8249
# G-mean: 0.7348
# F-measure: 0.7729
# Discriminant Power: 1.3130
# F2-measure: 0.7253
# InvF0.5-measure: 0.8273
# AGF: 0.7746
# Balanced Accuracy: 0.7450
# Matthew's Correlation Coefficient: 0.5055
# Cohen's Kappa: 0.4900
# Youden's Index: 0.4900
# Positive Likelihood Ratio: 2.2963
# Negative Likelihood Ratio: 0.2122
# Epoch: 2/50, Train Loss: 0.3775, Train Accuracy: 0.8388, Test Loss: 0.5419, Test Accuracy: 0.7730
# ==> New best model saved at epoch 2 with Test Accuracy: 0.7730
# TP: 847.0
# FP: 301.0
# FN: 153.0
# TN: 699.0
# Accuracy: 0.7730
# Misclassification rate: 0.2270
# Sensitivity (Recall): 0.8470
# Specificity: 0.6990
# Precision: 0.7378
# Negative Predictive Value: 0.8204
# G-mean: 0.7694
# F-measure: 0.7886
# Discriminant Power: 1.4080
# F2-measure: 0.7573
# InvF0.5-measure: 0.8226
# AGF: 0.7893
# Balanced Accuracy: 0.7730
# Matthew's Correlation Coefficient: 0.5521
# Cohen's Kappa: 0.5460
# Youden's Index: 0.5460
# Positive Likelihood Ratio: 2.8140
# Negative Likelihood Ratio: 0.2189
# Epoch: 3/50, Train Loss: 0.3175, Train Accuracy: 0.8658, Test Loss: 0.5704, Test Accuracy: 0.7635
# Epoch: 4/50, Train Loss: 0.2814, Train Accuracy: 0.8868, Test Loss: 0.5057, Test Accuracy: 0.7910
# ==> New best model saved at epoch 4 with Test Accuracy: 0.7910
# TP: 850.0
# FP: 268.0
# FN: 150.0
# TN: 732.0
# Accuracy: 0.7910
# Misclassification rate: 0.2090
# Sensitivity (Recall): 0.8500
# Specificity: 0.7320
# Precision: 0.7603
# Negative Predictive Value: 0.8299
# G-mean: 0.7888
# F-measure: 0.8026
# Discriminant Power: 1.5103
# F2-measure: 0.7767
# InvF0.5-measure: 0.8304
# AGF: 0.8031
# Balanced Accuracy: 0.7910
# Matthew's Correlation Coefficient: 0.5861
# Cohen's Kappa: 0.5820
# Youden's Index: 0.5820
# Positive Likelihood Ratio: 3.1716
# Negative Likelihood Ratio: 0.2049
# Epoch: 5/50, Train Loss: 0.2477, Train Accuracy: 0.8986, Test Loss: 0.6545, Test Accuracy: 0.7575
# Epoch: 6/50, Train Loss: 0.2049, Train Accuracy: 0.9205, Test Loss: 0.4936, Test Accuracy: 0.8050
# ==> New best model saved at epoch 6 with Test Accuracy: 0.8050
# TP: 856.0
# FP: 246.0
# FN: 144.0
# TN: 754.0
# Accuracy: 0.8050
# Misclassification rate: 0.1950
# Sensitivity (Recall): 0.8560
# Specificity: 0.7540
# Precision: 0.7768
# Negative Predictive Value: 0.8396
# G-mean: 0.8034
# F-measure: 0.8145
# Discriminant Power: 1.6002
# F2-measure: 0.7914
# InvF0.5-measure: 0.8389
# AGF: 0.8148
# Balanced Accuracy: 0.8050
# Matthew's Correlation Coefficient: 0.6132
# Cohen's Kappa: 0.6100
# Youden's Index: 0.6100
# Positive Likelihood Ratio: 3.4797
# Negative Likelihood Ratio: 0.1910
# Epoch: 7/50, Train Loss: 0.1767, Train Accuracy: 0.9331, Test Loss: 0.6737, Test Accuracy: 0.7730
# Epoch: 8/50, Train Loss: 0.1506, Train Accuracy: 0.9471, Test Loss: 0.8235, Test Accuracy: 0.7700
# Epoch: 9/50, Train Loss: 0.1277, Train Accuracy: 0.9563, Test Loss: 0.6065, Test Accuracy: 0.7975
# Epoch: 10/50, Train Loss: 0.1046, Train Accuracy: 0.9638, Test Loss: 0.7974, Test Accuracy: 0.7800
# Epoch: 11/50, Train Loss: 0.0908, Train Accuracy: 0.9693, Test Loss: 0.7008, Test Accuracy: 0.8135
# ==> New best model saved at epoch 11 with Test Accuracy: 0.8135
# TP: 886.0
# FP: 259.0
# FN: 114.0
# TN: 741.0
# Accuracy: 0.8135
# Misclassification rate: 0.1865
# Sensitivity (Recall): 0.8860
# Specificity: 0.7410
# Precision: 0.7738
# Negative Predictive Value: 0.8667
# G-mean: 0.8103
# F-measure: 0.8261
# Discriminant Power: 1.7101
# F2-measure: 0.7939
# InvF0.5-measure: 0.8610
# AGF: 0.8268
# Balanced Accuracy: 0.8135
# Matthew's Correlation Coefficient: 0.6337
# Cohen's Kappa: 0.6270
# Youden's Index: 0.6270
# Positive Likelihood Ratio: 3.4208
# Negative Likelihood Ratio: 0.1538
# Epoch: 12/50, Train Loss: 0.0910, Train Accuracy: 0.9679, Test Loss: 0.7053, Test Accuracy: 0.8025
# Epoch: 13/50, Train Loss: 0.0667, Train Accuracy: 0.9781, Test Loss: 0.7887, Test Accuracy: 0.8130
