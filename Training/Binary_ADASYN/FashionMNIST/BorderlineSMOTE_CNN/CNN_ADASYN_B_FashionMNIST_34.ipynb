# %%
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
import torchvision
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
import numpy as np
import torch
import matplotlib.pyplot as plt
import sys
import os
sys.path.append(os.path.abspath("/Users/max/MasterThesis/Training/"))
from imblearn.over_sampling import BorderlineSMOTE
from imblearn.over_sampling import ADASYN

# %%
from Swim_Maha import SwimMaha
fractions  = [0.005, 0.01, 0.02, 0.05, 0.1, 0.2]
for frac in range(len(fractions)):
    import torch
    from torch.utils.data import DataLoader, Subset, ConcatDataset, TensorDataset
    from torchvision import datasets, transforms
    import numpy as np

    # 数据预处理
    mnist34_transforms = transforms.Compose([
        transforms.ToTensor(), 
        transforms.Normalize((0.1307,), (0.3081,))
    ])

    # 加载 MNIST 数据集
    full_train_datasets = datasets.FashionMNIST(root="/Users/max/MasterThesisData/FashionMNIST", train=True, transform=mnist34_transforms, download=True)
    full_test_datasets = datasets.FashionMNIST(root="/Users/max/MasterThesisData/FashionMNIST", train=False, transform=mnist34_transforms, download=True)

    # 选取标签为 3 和 4 的索引
    indices3_train = [i for i in range(len(full_train_datasets)) if full_train_datasets.targets[i] == 3]
    indices4_train = [i for i in range(len(full_train_datasets)) if full_train_datasets.targets[i] == 4]

    indices3_test = [i for i in range(len(full_test_datasets)) if full_test_datasets.targets[i] == 3]
    indices4_test = [i for i in range(len(full_test_datasets)) if full_test_datasets.targets[i] == 4]

    # 获取训练集中标签为 3 和 4 的数据
    mnist3_train_data = full_train_datasets.data[indices3_train]
    mnist3_train_labels = torch.ones(len(indices3_train), dtype=torch.long)  # 标签 3 映射为 1 

    mnist4_train_data = full_train_datasets.data[indices4_train]
    mnist4_train_labels = torch.zeros(len(indices4_train), dtype=torch.long)  # 标签 4 映射为 0

    # 获取测试集中标签为 3 和 4 的数据
    mnist3_test_data = full_test_datasets.data[indices3_test]
    mnist3_test_labels = torch.ones(len(indices3_test), dtype=torch.long)  # 标签 3 映射为 1 

    mnist4_test_data = full_test_datasets.data[indices4_test]
    mnist4_test_labels = torch.zeros(len(indices4_test), dtype=torch.long)  # 标签 4 映射为 0
    # we can set the imbalanced ratio 0.005, 0.01, 0.02, 0.05, 0.1, 0.2
    fraction = int(fractions[frac] * len(mnist3_train_data))  ### control the fraction of the data to be used
    selected_indices_4 = np.random.choice(len(mnist4_train_data), fraction, replace=False)
    fraction_mnist4_train_data = mnist4_train_data[selected_indices_4]
    fraction_mnist4_train_labels = mnist4_train_labels[selected_indices_4]


    # 创建最终的训练和测试数据集
    Final_train_data = torch.cat([mnist3_train_data, fraction_mnist4_train_data], dim=0)
    Final_train_labels = torch.cat([mnist3_train_labels, fraction_mnist4_train_labels], dim=0)

    Final_test_data = torch.cat([mnist3_test_data, mnist4_test_data], dim=0)
    Final_test_labels = torch.cat([mnist3_test_labels, mnist4_test_labels], dim=0)

    # 创建 TensorDataset
    Final_train_datasets = TensorDataset(Final_train_data.unsqueeze(1).float() / 255, Final_train_labels)
    Final_test_datasets = TensorDataset(Final_test_data.unsqueeze(1).float() / 255, Final_test_labels)

    # 数据加载器
    train_loader = DataLoader(Final_train_datasets, batch_size=64, shuffle=True)
    test_loader = DataLoader(Final_test_datasets, batch_size=64, shuffle=False)

    # 打印信息
    print("Number of label 3 in the final training set: ", len(mnist3_train_data))
    print("Number of label 4 in the final training set (after downsampling): ", len(fraction_mnist4_train_data))
    print("Number of label 3 in the final test set: ", len(mnist3_test_data))
    print("Number of label 4 in the final test set: ", len(mnist4_test_data))

    print("Total samples in final training set: ", len(Final_train_datasets))
    print("Total samples in final test set: ", len(Final_test_datasets))

    print("Number of batches in training set: ", len(train_loader))
    print("Number of batches in test set: ", len(test_loader))


    # 获取一个 batch
    images, labels = next(iter(train_loader))

    # 查看 Tensor 形状
    print(f"Images shape: {images.shape}")  # 形状为 (batch_size, channels, height, width)
    print(f"Labels shape: {labels.shape}")  # 形状为 (batch_size,)

    # 查看第一个样本的 Tensor 值
    print(f"First image tensor:\n{images[0]}")  # 打印第一个样本的 Tensor 数据
    print(f"First image label: {labels[0]}")  # 打印第一个样本的标签

    # 如果需要转换回 NumPy 并可视化：
    import matplotlib.pyplot as plt

    # 转换为 NumPy 并显示
    plt.imshow(images[0].squeeze().numpy(), cmap="gray")
    plt.title(f"Label: {labels[0].item()}")
    plt.show()


    import numpy as np

    # 指定图片大小，图像大小为20宽、5高的绘图(单位为英寸inch)
    plt.figure(figsize=(20, 5)) 
    for i, imgs in enumerate(images[:20]):
        # 维度缩减
        npimg = np.squeeze(imgs.numpy())
        # 将整个figure分成2行10列，绘制第i+1个子图。
        plt.subplot(2, 10, i+1)
        plt.imshow(npimg, cmap=plt.cm.binary)
        plt.axis('off')

    X_train = []
    y_train = []

    for batch in train_loader:
        images, labels = batch  # images: (batch_size, 1, 28, 28), labels: (batch_size,)
        if hasattr(images, 'numpy'): # images is tensor
            images = images.numpy()
        # batch_size = 64
        for img, label in zip(images, labels):
            #print(f"Original shape: {img.shape}")  #  
            flattened_img = img.flatten()           
            #print(f"Flattened shape: {flattened_img.shape}")
            X_train.append(flattened_img) # 
            y_train.append(label)


    X_test = [] # features
    y_test = [] # labels
    for batch in test_loader:
        images, labels = batch  # images: (batch_size, 1,28  ,28 ), labels: (batch_size,)
        if hasattr(images, 'numpy'): # images is tensor
            images = images.numpy()
        # batch_size = 64
        for img, label in zip(images, labels):
            flattened_img = img.flatten()           # flatten the image
            X_test.append(flattened_img)
            y_test.append(label)


    X_train = np.array(X_train)
    y_train = np.array(y_train)
    X_test = np.array(X_test)
    y_test = np.array(y_test)
    print("X_train.shape:", X_train.shape)
    print("y_train.shape:", y_train.shape)
    print("X_test.shape:", X_test.shape)
    print("y_test.shape:", y_test.shape)
    ### SMOTE

    from imblearn.over_sampling import SMOTE
    from collections import Counter

    sm = ADASYN(random_state=42)
    print("##############################################")
    print("SMOTE started!")
    X_train, y_train = sm.fit_resample(X_train, y_train)
    print('Resampled dataset shape %s' % Counter(y_train))
    print("##############################################")
    print("SMOTE done!")
    print("X_train.shape:", X_train.shape)
    print("y_train.shape:", y_train.shape)
    print("X_test.shape:", X_test.shape)
    print("y_test.shape:", y_test.shape)
    import torch
    from torch.utils.data import TensorDataset, DataLoader

    # 假设 X_train 和 y_train 都是 numpy 数组
    # 注意：如果你的像素值范围在 0~255，建议在转换为 tensor 时进行归一化
    X_train_tensor= torch.tensor(X_train, dtype=torch.float32)
    y_train_tensor = torch.tensor(y_train, dtype=torch.long)
    print("X_train_tensor.shape:", X_train_tensor.shape)
    print("y_train_tensor.shape:", y_train_tensor.shape)

    # 假设 X_train_tensor 的形状为 (N, 784)，每个样本是一个扁平化的 28x28 图像
    reconstructed_images = []  # 用于保存恢复后的图像

    for i in range(len(X_train_tensor)):
        flattened_img = X_train_tensor[i]        # 取出第 i 个样本，形状 (784,)
        original_img = flattened_img.view(28, 28)  # 恢复为 (28, 28) 图像
        reconstructed_images.append(original_img)  # 存入列表

    print("总共恢复的图像数量：", len(reconstructed_images))

    # 可视化恢复后的图像
    plt.figure(figsize=(20, 5))
    for i, img in enumerate(reconstructed_images[:20]):
        plt.subplot(2, 10, i+1)
        plt.imshow(img, cmap="gray")
        plt.axis('off')
    plt.show()


    # 创建 Dataset
    reconstructed_images = torch.stack(reconstructed_images)  # 将列表转换为张量
    print("reconstructed_images.shape:", reconstructed_images.shape)  # (N, 28, 28)
    final_train_datasets = TensorDataset(reconstructed_images.unsqueeze(1).float(), y_train_tensor)

    # 使用新的 Dataset 构建新的 DataLoader
    new_train_loader = DataLoader(final_train_datasets, batch_size=64, shuffle=True)
    print("Number of batches in new training set: ", len(new_train_loader))

    # 获取一个 batch
    images, labels = next(iter(new_train_loader))
    print(f"Images shape: {images.shape}")  # 形状为 (batch_size, channels, height, width)
    print(f"Labels shape: {labels.shape}")  # 形状为 (batch_size,)
    from torchinfo import summary
    import torch
    import torch.nn as nn
    from CNN1 import BinaryCNN1
    # 将模型转移到GPU中（我们模型运行均在GPU中进行）
    model = BinaryCNN1().to(device)
    summary(model)
    # define the optimizer and loss function
    import torch.optim as optimizer
    from self_metrics import Binary_got_metrics
    loss_function = nn.CrossEntropyLoss()
    learning_rate = 0.001
    optimizer = optimizer.Adam(model.parameters(), lr=learning_rate)

    # model training
    def train(dataloader, model, loss_function, optimizer):
        size = len(dataloader.dataset)
        num_batches = len(dataloader)
        train_loss, train_accuracy = 0, 0
        for images, labels in dataloader:
            images, labels = images.to(device), labels.to(device)
            # Compute prediction error
            prediction = model(images)
            loss = loss_function(prediction, labels)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            train_loss += loss.item()
            train_accuracy += (prediction.argmax(1) == labels).type(torch.float).sum().item()

        train_loss /= num_batches
        train_accuracy /= size

        return train_loss, train_accuracy



    # model evaluation
    def test(dataloader, model, loss_function):
        size = len(dataloader.dataset)
        num_batches = len(dataloader)
        test_loss, test_accuracy = 0, 0
        # 1(1) is positive, 0(7) is negative
        # TP: 1 classified as 1
        # TN: 0 classified as 0
        # FP: 0 classified as 1
        # FN: 1 classified as 0
        TP, TN, FP, FN = 0, 0, 0, 0
        with torch.no_grad():
            for images, labels in dataloader:
                images, labels = images.to(device), labels.to(device)
                prediction = model(images)
                test_loss += loss_function(prediction, labels).item()
                test_accuracy += (prediction.argmax(1) == labels).type(torch.float).sum().item()
                TP += ((prediction.argmax(1) == 1) & (labels == 1)).type(torch.float).sum().item()
                TN += ((prediction.argmax(1) == 0) & (labels == 0)).type(torch.float).sum().item()
                FP += ((prediction.argmax(1) == 1) & (labels == 0)).type(torch.float).sum().item()
                FN += ((prediction.argmax(1) == 0) & (labels == 1)).type(torch.float).sum().item()


        test_loss /= num_batches
        test_accuracy /= size
        return test_loss, test_accuracy, TP, TN, FP, FN

    # training the model
    epochs = 50
    train_loss_list = []
    train_accuracy_list = []
    test_loss_list = []
    test_accuracy_list = []

    best_model_TP = 0
    best_model_TN = 0
    best_model_FP = 0
    best_model_FN = 0
    best_test_accuracy = 0.0 # for saving the best model
    for epoch in range(epochs):
        model.train()
        train_loss, train_accuracy = train(new_train_loader, model, loss_function, optimizer)
        model.eval()
        test_loss, test_accuracy,TP, TN, FP, FN  = test(test_loader, model, loss_function)
        train_loss_list.append(train_loss)
        train_accuracy_list.append(train_accuracy)
        test_loss_list.append(test_loss)
        test_accuracy_list.append(test_accuracy)

        print(f"Epoch: {epoch+1}/{epochs}, Train Loss: {train_loss:.4f}, Train Accuracy: {train_accuracy:.4f}, Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.4f}") 

        if test_accuracy > best_test_accuracy:
            best_test_accuracy = test_accuracy
            best_model_TP = TP
            best_model_TN = TN
            best_model_FP = FP
            best_model_FN = FN
            save_path = f"BinaryMNIST34_{fraction}.pth"
            torch.save(model.state_dict(), save_path)
            print(f"==> New best model saved at epoch {epoch+1} with Test Accuracy: {test_accuracy:.4f}")
            #print(f"==> TP: {TP}, TN: {TN}, FP: {FP}, FN: {FN}")
            Accuracy, misclassification_rate, Sensitivity, Specificity, Precision, Negative_Predictive_Value, Gmean, Fmean, DPower, F2measure, InvF_05, AGFmeasure, Balanced_Accuracy, MCCmeasure, Kappa, Youden_Index, LR_pos, LR_neg = Binary_got_metrics(best_model_TP, best_model_FP, best_model_FN, best_model_TN)
            import json

            # 构造一个包含所有指标数据的字典
            metrics_dict = {
                "Number of label 3 in the final training set": len(mnist3_train_data),
                "Number of label 4 in the final training set (after downsampling)": len(fraction_mnist4_train_data),
                "Number of label 3 in the final test set": len(mnist3_test_data),
                "Number of label 4 in the final test set": len(mnist4_test_data),
                "Total samples in final training set": len(Final_train_datasets),
                "Total samples in final test set": len(Final_test_datasets),
                "Number of batches in training set": len(train_loader),
                "Number of batches in test set": len(test_loader),
                "TP": TP,
                "FP": FP,
                "FN": FN,
                "TN": TN,
                "Accuracy": round(Accuracy, 4),
                "Misclassification rate": round(misclassification_rate, 4),
                "Sensitivity (Recall)": round(Sensitivity, 4),
                "Specificity": round(Specificity, 4),
                "Precision": round(Precision, 4),
                "Negative Predictive Value": round(Negative_Predictive_Value, 4),
                "G-mean": round(Gmean, 4),
                "F-measure": round(Fmean, 4),
                "Discriminant Power (DP)": round(DPower, 4),
                "F2-measure": round(F2measure, 4),
                "InvF0.5-measure": round(InvF_05, 4),
                "AGF": round(AGFmeasure, 4),
                "Balanced Accuracy": round(Balanced_Accuracy, 4),
                "Matthew's Correlation Coefficient (MCC)": round(MCCmeasure, 4),
                "Cohen's Kappa": round(Kappa, 4),
                "Youden's Index": round(Youden_Index, 4),
                "Positive Likelihood Ratio (LR+)": round(LR_pos, 4),
                "Negative Likelihood Ratio (LR-)": round(LR_neg, 4)
            }

            # 指定 JSON 文件保存路径
            metrics_results_path = f"ADASYN_CNNBinaryFashionMNIST34_{fraction}_metrics_results.json"

            # 将字典保存为 JSON 文件
            with open(metrics_results_path, "w") as f:
                json.dump(metrics_dict, f, indent=4)
# Out:
# Number of label 3 in the final training set:  6000
# Number of label 4 in the final training set (after downsampling):  30
# Number of label 3 in the final test set:  1000
# Number of label 4 in the final test set:  1000
# Total samples in final training set:  
 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.5882, 0.8392,
#           0.5843, 0.7451, 0.7647, 0.6314, 0.9137, 0.7686, 0.6824, 0.6784,
#           0.8588, 0.7216, 0.5686, 0.8667, 0.7412, 0.6235, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.6157, 0.8235,
#           0.5373, 0.8078, 0.6980, 0.6510, 0.9020, 0.7765, 0.6706, 0.6745,
#           0.8392, 0.7176, 0.5647, 0.8039, 0.6824, 0.5804, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.6510, 0.7686,
#           0.2824, 0.8980, 0.6745, 0.6706, 0.9059, 0.7569, 0.6549, 0.6784,
#           0.8235, 0.7373, 0.5843, 0.7216, 0.7373, 0.6549, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.4667, 0.6745,
#           0.0784, 0.9294, 0.6549, 0.6824, 0.9020, 0.7569, 0.6706, 0.6941,
#           0.8078, 0.7294, 0.6078, 0.5137, 0.6745, 0.4431, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.1725, 0.9333, 0.6706, 0.7059, 0.8980, 0.7647, 0.6824, 0.6824,
#           0.7725, 0.7137, 0.6314, 0.3843, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0039, 0.0000,
#           0.1686, 0.7843, 0.6784, 0.7294, 0.8863, 0.7647, 0.6902, 0.6824,
#           0.7255, 0.6980, 0.6353, 0.5216, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0078, 0.0000,
#           0.1765, 0.7882, 0.6824, 0.7333, 0.8863, 0.7647, 0.6863, 0.6824,
#           0.6902, 0.6941, 0.6706, 0.5608, 0.0000, 0.0039, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0235, 0.0000,
#           0.2039, 0.7922, 0.6824, 0.6980, 0.8824, 0.7843, 0.6980, 0.6902,
#           0.6706, 0.6863, 0.7294, 0.5255, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0196, 0.0000,
#           0.1176, 0.7765, 0.6941, 0.6980, 0.8549, 0.7843, 0.6980, 0.6824,
#           0.6706, 0.7137, 0.7373, 0.4039, 0.0000, 0.0039, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0118, 0.0000,
#           0.0627, 0.8196, 0.7451, 0.7412, 0.9255, 0.9176, 0.7294, 0.7765,
#           0.6863, 0.6745, 0.7843, 0.5373, 0.0000, 0.0078, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.3647, 0.6039, 0.4667, 0.4627, 0.4549, 0.5686, 0.6549,
#           0.6745, 0.5647, 0.4588, 0.0667, 0.0000, 0.0118, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000]]])
# First image label: 1
# X_train.shape: (6030, 784)
# y_train.shape: (6030,)
# X_test.shape: (2000, 784)
# y_test.shape: (2000,)
# ##############################################
# SMOTE started!
# Resampled dataset shape Counter({np.int64(1): 6000, np.int64(0): 6000})
# ##############################################
# SMOTE done!
# X_train.shape: (12000, 784)
# y_train.shape: (12000,)
# X_test.shape: (2000, 784)
# y_test.shape: (2000,)
# X_train_tensor.shape: torch.Size([12000, 784])
# y_train_tensor.shape: torch.Size([12000])
# 总共恢复的图像数量： 12000
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# reconstructed_images.shape: torch.Size([12000, 28, 28])
# Number of batches in new training set:  188
# Images shape: torch.Size([64, 1, 28, 28])
# Labels shape: torch.Size([64])
# Epoch: 1/50, Train Loss: 0.1058, Train Accuracy: 0.9596, Test Loss: 0.3016, Test Accuracy: 0.9220
# ==> New best model saved at epoch 1 with Test Accuracy: 0.9220
# TP: 977.0
# FP: 133.0
# FN: 23.0
# TN: 867.0
# Accuracy: 0.9220
# Misclassification rate: 0.0780
# Sensitivity (Recall): 0.9770
# Specificity: 0.8670
# Precision: 0.8802
# Negative Predictive Value: 0.9742
# G-mean: 0.9204
# F-measure: 0.9261
# Discriminant Power: 3.1005
# F2-measure: 0.8980
# InvF0.5-measure: 0.9560
# AGF: 0.9265
# Balanced Accuracy: 0.9220
# Matthew's Correlation Coefficient: 0.8492
# Cohen's Kappa: 0.8440
# Youden's Index: 0.8440
# Positive Likelihood Ratio: 7.3459
# Negative Likelihood Ratio: 0.0265
# Epoch: 2/50, Train Loss: 0.0111, Train Accuracy: 0.9970, Test Loss: 0.8112, Test Accuracy: 0.8495
# Epoch: 3/50, Train Loss: 0.0072, Train Accuracy: 0.9982, Test Loss: 0.8881, Test Accuracy: 0.8550

#           0.0000, 0.0000, 0.0000, 0.0000]]])
# First image label: 1
# X_train.shape: (6120, 784)
# y_train.shape: (6120,)
# X_test.shape: (2000, 784)
# y_test.shape: (2000,)
# ##############################################
# SMOTE started!
# Resampled dataset shape Counter({np.int64(1): 6000, np.int64(0): 6000})
# ##############################################
# SMOTE done!
# X_train.shape: (12000, 784)
# y_train.shape: (12000,)
# X_test.shape: (2000, 784)
# y_test.shape: (2000,)
# X_train_tensor.shape: torch.Size([12000, 784])
# y_train_tensor.shape: torch.Size([12000])
# 总共恢复的图像数量： 12000
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# reconstructed_images.shape: torch.Size([12000, 28, 28])
# Number of batches in new training set:  188
# Images shape: torch.Size([64, 1, 28, 28])
# Labels shape: torch.Size([64])
# Epoch: 1/50, Train Loss: 0.1629, Train Accuracy: 0.9406, Test Loss: 0.2199, Test Accuracy: 0.9390
# ==> New best model saved at epoch 1 with Test Accuracy: 0.9390
# TP: 969.0
# FP: 91.0
# FN: 31.0
# TN: 909.0
# Accuracy: 0.9390
# Misclassification rate: 0.0610
# Sensitivity (Recall): 0.9690
# Specificity: 0.9090
# Precision: 0.9142
# Negative Predictive Value: 0.9670
# G-mean: 0.9385
# F-measure: 0.9408
# Discriminant Power: 3.1667
# F2-measure: 0.9246
# InvF0.5-measure: 0.9575
# AGF: 0.9409
# Balanced Accuracy: 0.9390
# Matthew's Correlation Coefficient: 0.8796
# Cohen's Kappa: 0.8780
# Youden's Index: 0.8780
# Positive Likelihood Ratio: 10.6484
# Negative Likelihood Ratio: 0.0341
# Epoch: 2/50, Train Loss: 0.0379, Train Accuracy: 0.9904, Test Loss: 0.3597, Test Accuracy: 0.9225
# Epoch: 3/50, Train Loss: 0.0225, Train Accuracy: 0.9943, Test Loss: 0.2434, Test Accuracy: 0.9375
# Epoch: 4/50, Train Loss: 0.0156, Train Accuracy: 0.9965, Test Loss: 0.2730, Test Accuracy: 0.9390
# Epoch: 5/50, Train Loss: 0.0137, Train Accuracy: 0.9964, Test Loss: 0.6935, Test Accuracy: 0.8725
# Epoch: 6/50, Train Loss: 0.0118, Train Accuracy: 0.9978, Test Loss: 0.2213, Test Accuracy: 0.9370
# Epoch: 7/50, Train Loss: 0.0087, Train Accuracy: 0.9983, Test Loss: 0.2907, Test Accuracy: 0.9305
# Epoch: 8/50, Train Loss: 0.0073, Train Accuracy: 0.9984, Test Loss: 0.5215, Test Accuracy: 0.9125
# Epoch: 9/50, Train Loss: 0.0049, Train Accuracy: 0.9992, Test Loss: 0.5217, Test Accuracy: 0.9130
# Epoch: 10/50, Train Loss: 0.0036, Train Accuracy: 0.9992, Test Loss: 0.5967, Test Accuracy: 0.9055
# Epoch: 11/50, Train Loss: 0.0038, Train Accuracy: 0.9993, Test Loss: 0.3572, Test Accuracy: 0.9195
# Epoch: 12/50, Train Loss: 0.0044, Train Accuracy: 0.9990, Test Loss: 0.5611, Test Accuracy: 0.9060
# Epoch: 13/50, Train Loss: 0.0023, Train Accuracy: 0.9996, Test Loss: 0.7344, Test Accuracy: 0.8835
# Epoch: 14/50, Train Loss: 0.0020, Train Accuracy: 0.9997, Test Loss: 0.6089, Test Accuracy: 0.9120
# Epoch: 15/50, Train Loss: 0.0033, Train Accuracy: 0.9990, Test Loss: 0.4089, Test Accuracy: 0.9260
# Epoch: 16/50, Train Loss: 0.0016, Train Accuracy: 0.9997, Test Loss: 0.7104, Test Accuracy: 0.8885
# Epoch: 17/50, Train Loss: 0.0013, Train Accuracy: 0.9998, Test Loss: 0.7816, Test Accuracy: 0.8870
# Epoch: 18/50, Train Loss: 0.0008, Train Accuracy: 0.9998, Test Loss: 0.7083, Test Accuracy: 0.9045
# Epoch: 19/50, Train Loss: 0.0004, Train Accuracy: 0.9998, Test Loss: 0.7086, Test Accuracy: 0.9040
# Epoch: 20/50, Train Loss: 0.0005, Train Accuracy: 0.9999, Test Loss: 0.3567, Test Accuracy: 0.9265
# Epoch: 21/50, Train Loss: 0.0003, Train Accuracy: 0.9999, Test Loss: 0.6923, Test Accuracy: 0.9075
# Epoch: 22/50, Train Loss: 0.0001, Train Accuracy: 1.0000, Test Loss: 0.7529, Test Accuracy: 0.9065
# Epoch: 23/50, Train Loss: 0.0001, Train Accuracy: 1.0000, Test Loss: 0.7282, Test Accuracy: 0.9075
# Epoch: 24/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.7757, Test Accuracy: 0.9085
# Epoch: 25/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.7859, Test Accuracy: 0.9030
# Epoch: 26/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.8135, Test Accuracy: 0.9070
# Epoch: 27/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.7664, Test Accuracy: 0.9100
# Epoch: 28/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.8376, Test Accuracy: 0.9055
# Epoch: 29/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.8600, Test Accuracy: 0.9060
# Epoch: 30/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.8801, Test Accuracy: 0.9040
# Epoch: 31/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.8571, Test Accuracy: 0.9055
# Epoch: 32/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.8972, Test Accuracy: 0.9050
# Epoch: 33/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.8904, Test Accuracy: 0.9055
# Epoch: 34/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.7852, Test Accuracy: 0.9110
# Epoch: 35/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.9258, Test Accuracy: 0.9050
# Epoch: 36/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.9303, Test Accuracy: 0.9025
# Epoch: 37/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.8805, Test Accuracy: 0.9065
# Epoch: 38/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.9245, Test Accuracy: 0.9060
# Epoch: 39/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.9241, Test Accuracy: 0.9045
# Epoch: 40/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.9614, Test Accuracy: 0.9045
# Epoch: 41/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.9300, Test Accuracy: 0.9055
# Epoch: 42/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.8755, Test Accuracy: 0.9100
# Epoch: 43/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.9663, Test Accuracy: 0.9060
# Epoch: 44/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.9049, Test Accuracy: 0.9095
# Epoch: 45/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 1.0221, Test Accuracy: 0.9045
# Epoch: 46/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 1.0026, Test Accuracy: 0.9055
# Epoch: 47/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 1.0464, Test Accuracy: 0.9045
# Epoch: 48/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 1.0341, Test Accuracy: 0.9055
# Epoch: 49/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 1.0622, Test Accuracy: 0.9055
# Epoch: 50/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 1.0566, Test Accuracy: 0.9060
# Number of label 3 in the final training set:  6000
# Number of label 4 in the final training set (after downsampling):  300
# Number of label 3 in the final test set:  1000
# Number of label 4 in the final test set:  1000
# Total samples in final training set:  6300
# Total samples in final test set:  2000
# Number of batches in training set:  99
# Number of batches in test set:  32
# Images shape: torch.Size([64, 1, 28, 28])
# Labels shape: torch.Size([64])
# First image tensor:
# tensor([[[0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.2549, 0.4863, 0.0039, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.3765, 0.3686, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.7216, 0.6667, 0.7725, 0.9608, 0.9098, 0.7373, 0.7882, 0.9647,
#           0.8353, 0.6314, 0.6588, 0.1725, 0.0000, 0.0039, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.2078,
#           0.7216, 0.6118, 0.5804, 0.6157, 0.7451, 0.7412, 0.7412, 0.6667,
#           0.5804, 0.6039, 0.6353, 0.5255, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.5098,
#           0.6941, 0.6118, 0.6353, 0.6118, 0.5529, 0.5529, 0.5569, 0.5961,
#           0.6196, 0.6275, 0.6314, 0.6471, 0.0627, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.6510,
#           0.6745, 0.5686, 0.6118, 0.6157, 0.6431, 0.6196, 0.6431, 0.6275,
#           0.6157, 0.6275, 0.6353, 0.7059, 0.2392, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.7216,
#           0.7412, 0.6902, 0.5686, 0.6118, 0.6157, 0.6039, 0.6118, 0.6039,
#           0.5961, 0.6353, 0.6784, 0.6980, 0.4275, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.7843,
#           0.7686, 0.7412, 0.5882, 0.6039, 0.6157, 0.6196, 0.6039, 0.6196,
#           0.5686, 0.8667, 0.7529, 0.7137, 0.5490, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0
 0.0000, 0.0000, 0.0039, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0039, 0.0000,
#           0.0471, 0.6980, 0.6078, 0.6000, 0.5961, 0.6510, 0.7098, 1.0000,
#           0.7059, 0.6392, 0.8039, 0.0000, 0.0000, 0.0039, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0039, 0.0000,
#           0.0431, 0.7098, 0.6039, 0.6000, 0.6000, 0.6471, 0.7451, 0.9176,
#           0.7137, 0.6627, 0.7529, 0.0000, 0.0000, 0.0039, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0039, 0.0000,
#           0.0471, 0.6078, 0.6000, 0.6118, 0.6118, 0.6510, 0.7804, 0.9176,
#           0.7294, 0.6980, 0.6157, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0078, 0.0000,
#           0.0510, 0.5843, 0.5647, 0.5412, 0.5569, 0.5686, 0.7804, 0.9020,
#           0.6980, 0.6706, 0.5765, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0078, 0.0000,
#           0.0353, 0.7176, 0.7216, 0.7647, 0.7804, 0.8392, 0.9804, 0.9137,
#           0.8078, 0.8549, 0.6588, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.4235, 0.4941, 0.5059, 0.5412, 0.5373, 0.4863, 0.4667,
#           0.4588, 0.5569, 0.2431, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000]]])
# First image label: 1
# X_train.shape: (7200, 784)
# y_train.shape: (7200,)
# X_test.shape: (2000, 784)
# y_test.shape: (2000,)
# ##############################################
# SMOTE started!
# Resampled dataset shape Counter({np.int64(0): 6000, np.int64(1): 6000})
# ##############################################
# SMOTE done!
# X_train.shape: (12000, 784)
# y_train.shape: (12000,)
# X_test.shape: (2000, 784)
# y_test.shape: (2000,)
# X_train_tensor.shape: torch.Size([12000, 784])
# y_train_tensor.shape: torch.Size([12000])
# 总共恢复的图像数量： 12000
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# reconstructed_images.shape: torch.Size([12000, 28, 28])
# Number of batches in new training set:  188
# Images shape: torch.Size([64, 1, 28, 28])
# Labels shape: torch.Size([64])
# Epoch: 1/50, Train Loss: 0.2551, Train Accuracy: 0.8949, Test Loss: 0.2030, Test Accuracy: 0.9185
# ==> New best model saved at epoch 1 with Test Accuracy: 0.9185
# TP: 851.0
# FP: 14.0
# FN: 149.0
# TN: 986.0
# Accuracy: 0.9185
# Misclassification rate: 0.0815
# Sensitivity (Recall): 0.8510
# Specificity: 0.9860
# Precision: 0.9838
# Negative Predictive Value: 0.8687
# G-mean: 0.9160
# F-measure: 0.9126
# Discriminant Power: 3.3064
# F2-measure: 0.9540
# InvF0.5-measure: 0.8746
# AGF: 0.9135
# Balanced Accuracy: 0.9185
# Matthew's Correlation Coefficient: 0.8447
# Cohen's Kappa: 0.8370
# Youden's Index: 0.8370
# Positive Likelihood Ratio: 60.7857
# Negative Likelihood Ratio: 0.1511
# Epoch: 2/50, Train Loss: 0.1194, Train Accuracy: 0.9592, Test Loss: 0.1375, Test Accuracy: 0.9430
# ==> New best model saved at epoch 2 with Test Accuracy: 0.9430
# TP: 940.0
# FP: 54.0
# FN: 60.0
# TN: 946.0
# Accuracy: 0.9430
# Misclassification rate: 0.0570
# Sensitivity (Recall): 0.9400
# Specificity: 0.9460
# Precision: 0.9457
# Negative Predictive Value: 0.9404
# G-mean: 0.9430
# F-measure: 0.9428
# Discriminant Power: 3.0956
# F2-measure: 0.9445
# InvF0.5-measure: 0.9411
# AGF: 0.9428
# Balanced Accuracy: 0.9430
# Matthew's Correlation Coefficient: 0.8860
# Cohen's Kappa: 0.8860
# Youden's Index: 0.8860
# Positive Likelihood Ratio: 17.4074
# Negative Likelihood Ratio: 0.0634
# Epoch: 3/50, Train Loss: 0.0941, Train Accuracy: 0.9692, Test Loss: 0.1273, Test Accuracy: 0.9475
# ==> New best model saved at epoch 3 with Test Accuracy: 0.9475
# TP: 941.0
# FP: 46.0
# FN: 59.0
# TN: 954.0
# Accuracy: 0.9475
# Misclassification rate: 0.0525
# Sensitivity (Recall): 0.9410
# Specificity: 0.9540
# Precision: 0.9534
# Negative Predictive Value: 0.9418
# G-mean: 0.9475
# F-measure: 0.9472
# Discriminant Power: 3.1985
# F2-measure: 0.9509
# InvF0.5-measure: 0.9435
# AGF: 0.9472
# Balanced Accuracy: 0.9475
# Matthew's Correlation Coefficient: 0.8951
# Cohen's Kappa: 0.8950
# Youden's Index: 0.8950
# Positive Likelihood Ratio: 20.4565
# Negative Likelihood Ratio: 0.0618
# Epoch: 4/50, Train Loss: 0.0769, Train Accuracy: 0.9745, Test Loss: 0.1294, Test Accuracy: 0.9480
# ==> New best model saved at epoch 4 with Test Accuracy: 0.9480
# TP: 967.0
# FP: 71.0
# FN: 33.0
# TN: 929.0
# Accuracy: 0.9480
# Misclassification rate: 0.0520
# Sensitivity (Recall): 0.9670
# Specificity: 0.9290
# Precision: 0.9316
# Negative Predictive Value: 0.9657
# G-mean: 0.9478
# F-measure: 0.9490
# Discriminant Power: 3.2799
# F2-measure: 0.9385
# InvF0.5-measure: 0.9597
# AGF: 0.9490
# Balanced Accuracy: 0.9480
# Matthew's Correlation Coefficient: 0.8966
# Cohen's Kappa: 0.8960
# Youden's Index: 0.8960
# Positive Likelihood Ratio: 13.6197
# Negative Likelihood Ratio: 0.0355
# Epoch: 5/50, Train Loss: 0.0736, Train Accuracy: 0.9775, Test Loss: 0.1294, Test Accuracy: 0.9510
# ==> New best model saved at epoch 5 with Test Accuracy: 0.9510
# TP: 969.0
# FP: 67.0
# FN: 31.0
# TN: 933.0
# Accuracy: 0.9510
# Misclassification rate: 0.0490
# Sensitivity (Recall): 0.9690
# Specificity: 0.9330
# Precision: 0.9353
# Negative Predictive Value: 0.9678
# G-mean: 0.9508
# F-measure: 0.9519
# Discriminant Power: 3.3499
# F2-measure: 0.9419
# InvF0.5-measure: 0.9621
# AGF: 0.9519
# Balanced Accuracy: 0.9510
# Matthew's Correlation Coefficient: 0.9026
# Cohen's Kappa: 0.9020
# Youden's Index: 0.9020
# Positive Likelihood Ratio: 14.4627
# Negative Likelihood Ratio: 0.0332
# Epoch: 6/50, Train Loss: 0.0564, Train Accuracy: 0.9817, Test Loss: 0.1134, Test Accuracy: 0.9570
# ==> New best model saved at epoch 6 with Test Accuracy: 0.9570
# TP: 967.0
# FP: 53.0
# FN: 33.0
# TN: 947.0
# Accuracy: 0.9570
# Misclassification rate: 0.0430
# Sensitivity (Recall): 0.9670
# Specificity: 0.9470
# Precision: 0.9480
# Negative Predictive Value: 0.9663
# G-mean: 0.9569
# F-measure: 0.9574
# Discriminant Power: 3.4517
# F2-measure: 0.9518
# InvF0.5-measure: 0.9631
# AGF: 0.9574
# Balanced Accuracy: 0.9570
# Matthew's Correlation Coefficient: 0.9142
# Cohen's Kappa: 0.9140
# Youden's Index: 0.9140
# Positive Likelihood Ratio: 18.2453
# Negative Likelihood Ratio: 0.0348
# Epoch: 7/50, Train Loss: 0.0471, Train Accuracy: 0.9852, Test Loss: 0.1538, Test Accuracy: 0.9510
# Epoch: 8/50, Train Loss: 0.0368, Train Accuracy: 0.9888, Test Loss: 0.1284, Test Accuracy: 0.9570
# Epoch: 9/50, Train Loss: 0.0341, Train Accuracy: 0.9900, Test Loss: 0.1450, Test Accuracy: 0.9515
# Epoch: 10/50, Train Loss: 0.0293, Train Accuracy: 0.9908, Test Loss: 0.1167, Test Accuracy: 0.9600
# ==> New best model saved at epoch 10 with Test Accuracy: 0.9600
# TP: 967.0
# FP: 47.0
# FN: 33.0
# TN: 953.0
# Accuracy: 0.9600
# Misclassification rate: 0.0400
# Sensitivity (Recall): 0.9670
# Specificity: 0.9530
# Precision: 0.9536
# Negative Predictive Value: 0.9665
# G-mean: 0.9600
# F-measure: 0.9603
# Discriminant Power: 3.5214
# F2-measure: 0.9563
# InvF0.5-measure: 0.9643
# AGF: 0.9603
# Balanced Accuracy: 0.9600
# Matthew's Correlation Coefficient: 0.9201
# Cohen's Kappa: 0.9200
# Youden's Index: 0.9200
# Positive Likelihood Ratio: 20.5745
# Negative Likelihood Ratio: 0.0346
# Epoch: 11/50, Train Loss: 0.0219, Train Accuracy: 0.9937, Test Loss: 0.1594, Test Accuracy: 0.9540
# Epoch: 12/50, Train Loss: 0.0217, Train Accuracy: 0.9935, Test Loss: 0.1305, Test Accuracy: 0.9605
# ==> New best model saved at epoch 12 with Test Accuracy: 0.9605
# TP: 978.0
# FP: 57.0
# FN: 22.0
# TN: 943.0
# Accuracy: 0.9605
# Misclassification rate: 0.0395
# Sensitivity (Recall): 0.9780
# Specificity: 0.9430
# Precision: 0.9449
# Negative Predictive Value: 0.9772
# G-mean: 0.9603
# F-measure: 0.9612
# Discriminant Power: 3.6390
# F2-measure: 0.9514
# InvF0.5-measure: 0.9712
# AGF: 0.9612
# Balanced Accuracy: 0.9605
# Matthew's Correlation Coefficient: 0.9216
# Cohen's Kappa: 0.9210
# Youden's Index: 0.9210
# Positive Likelihood Ratio: 17.1579
# Negative Likelihood Ratio: 0.0233
# Epoch: 13/50, Train Loss: 0.0173, Train Accuracy: 0.9944, Test Loss: 0.1395, Test Accuracy: 0.9585
# Epoch: 14/50, Train Loss: 0.0108, Train Accuracy: 0.9967, Test Loss: 0.1484, Test Accuracy: 0.9575
# Epoch: 15/50, Train Loss: 0.0113, Train Accuracy: 0.9962, Test Loss: 0.1302, Test Accuracy: 0.9665
# ==> New best model saved at epoch 15 with Test Accuracy: 0.9665
# TP: 969.0
# FP: 36.0
# FN: 31.0
# TN: 964.0
# Accuracy: 0.9665
# Misclassification rate: 0.0335
# Sensitivity (Recall): 0.9690
# Specificity: 0.9640
# Precision: 0.9642
# Negative Predictive Value: 0.9688
# G-mean: 0.9665
# F-measure: 0.9666
# Discriminant Power: 3.7104
# F2-measure: 0.9651
# InvF0.5-measure: 0.9680
# AGF: 0.9666
# Balanced Accuracy: 0.9665
# Matthew's Correlation Coefficient: 0.9330
# Cohen's Kappa: 0.9330
# Youden's Index: 0.9330
# Positive Likelihood Ratio: 26.9167
