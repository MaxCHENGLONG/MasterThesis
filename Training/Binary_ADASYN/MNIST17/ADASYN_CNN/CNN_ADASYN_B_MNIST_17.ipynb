# %%
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
import torchvision
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
import numpy as np
import torch
import matplotlib.pyplot as plt
import sys
import os
from imblearn.over_sampling import BorderlineSMOTE
sys.path.append(os.path.abspath("/Users/max/MasterThesis/Training/"))
from imblearn.over_sampling import ADASYN

# %%
fractions = [0.005, 0.01, 0.02, 0.05, 0.1, 0.2]
for frac in range(len(fractions)):
    import torch
    from torch.utils.data import DataLoader, Subset, ConcatDataset, TensorDataset
    from torchvision import datasets, transforms
    import numpy as np

    # 数据预处理
    mnist17_transforms = transforms.Compose([
        transforms.ToTensor(), 
        transforms.Normalize((0.1307,), (0.3081,))
    ])

    # 加载 MNIST 数据集
    full_train_datasets = datasets.MNIST(root="/Users/max/MasterThesisData/MNIST", train=True, transform=mnist17_transforms, download=True)
    full_test_datasets = datasets.MNIST(root="/Users/max/MasterThesisData/MNIST", train=False, transform=mnist17_transforms, download=True)

    # 选取标签为 1 和 7 的索引
    indices1_train = [i for i in range(len(full_train_datasets)) if full_train_datasets.targets[i] == 1]
    indices7_train = [i for i in range(len(full_train_datasets)) if full_train_datasets.targets[i] == 7]

    indices1_test = [i for i in range(len(full_test_datasets)) if full_test_datasets.targets[i] == 1]
    indices7_test = [i for i in range(len(full_test_datasets)) if full_test_datasets.targets[i] == 7]

    # 获取训练集中标签为 1 和 7 的数据
    mnist1_train_data = full_train_datasets.data[indices1_train]
    mnist1_train_labels = torch.ones(len(indices1_train), dtype=torch.long)  # 标签 1 保持不变

    mnist7_train_data = full_train_datasets.data[indices7_train]
    mnist7_train_labels = torch.zeros(len(indices7_train), dtype=torch.long)  # 标签 7 映射为 0

    # 获取测试集中标签为 1 和 7 的数据
    mnist1_test_data = full_test_datasets.data[indices1_test]
    mnist1_test_labels = torch.ones(len(indices1_test), dtype=torch.long)  # 标签 1 保持不变

    mnist7_test_data = full_test_datasets.data[indices7_test]
    mnist7_test_labels = torch.zeros(len(indices7_test), dtype=torch.long)  # 标签 7 映射为 0

    # we can set the imbalanced ratio 0.005, 0.01, 0.02, 0.05, 0.1, 0.2
    fraction = int(fractions[frac] * len(mnist1_train_data))  ### control the fraction of the data to be used
    selected_indices_7 = np.random.choice(len(mnist7_train_data), fraction, replace=False)

    fraction_mnist7_train_data = mnist7_train_data[selected_indices_7]
    fraction_mnist7_train_labels = mnist7_train_labels[selected_indices_7]

    # 创建最终的训练和测试数据集
    Final_train_data = torch.cat([mnist1_train_data, fraction_mnist7_train_data], dim=0)
    Final_train_labels = torch.cat([mnist1_train_labels, fraction_mnist7_train_labels], dim=0)

    Final_test_data = torch.cat([mnist1_test_data, mnist7_test_data], dim=0)
    Final_test_labels = torch.cat([mnist1_test_labels, mnist7_test_labels], dim=0)

    # 创建 TensorDataset
    Final_train_datasets = TensorDataset(Final_train_data.unsqueeze(1).float() / 255, Final_train_labels)
    Final_test_datasets = TensorDataset(Final_test_data.unsqueeze(1).float() / 255, Final_test_labels)

    # 数据加载器
    train_loader = DataLoader(Final_train_datasets, batch_size=64, shuffle=True)
    test_loader = DataLoader(Final_test_datasets, batch_size=64, shuffle=False)

    # 打印信息
    print("Number of label 1 in the final training set: ", len(mnist1_train_data))
    print("Number of label 7 in the final training set (after downsampling): ", len(fraction_mnist7_train_data))
    print("Number of label 1 in the final test set: ", len(mnist1_test_data))
    print("Number of label 7 in the final test set: ", len(mnist7_test_data))

    print("Total samples in final training set: ", len(Final_train_datasets))
    print("Total samples in final test set: ", len(Final_test_datasets))

    print("Number of batches in training set: ", len(train_loader))
    print("Number of batches in test set: ", len(test_loader))



    # 获取一个 batch
    images, labels = next(iter(train_loader))

    # 查看 Tensor 形状
    print(f"Images shape: {images.shape}")  # 形状为 (batch_size, channels, height, width)
    print(f"Labels shape: {labels.shape}")  # 形状为 (batch_size,)

    # 查看第一个样本的 Tensor 值
    print(f"First image tensor:\n{images[0]}")  # 打印第一个样本的 Tensor 数据
    print(f"First image label: {labels[0]}")  # 打印第一个样本的标签

    # 如果需要转换回 NumPy 并可视化：
    import matplotlib.pyplot as plt

    # 转换为 NumPy 并显示
    plt.imshow(images[0].squeeze().numpy(), cmap="gray")
    plt.title(f"Label: {labels[0].item()}")
    plt.show()

    import numpy as np

    # 指定图片大小，图像大小为20宽、5高的绘图(单位为英寸inch)
    plt.figure(figsize=(20, 5)) 
    for i, imgs in enumerate(images[:20]):
        # 维度缩减
        npimg = np.squeeze(imgs.numpy())
        # 将整个figure分成2行10列，绘制第i+1个子图。
        plt.subplot(2, 10, i+1)
        plt.imshow(npimg, cmap=plt.cm.binary)
        plt.axis('off')


    X_train = []
    y_train = []

    for batch in train_loader:
        images, labels = batch  # images: (batch_size, 1, 28, 28), labels: (batch_size,)
        if hasattr(images, 'numpy'): # images is tensor
            images = images.numpy()
        # batch_size = 64
        for img, label in zip(images, labels):
            #print(f"Original shape: {img.shape}")  #  
            flattened_img = img.flatten()           
            #print(f"Flattened shape: {flattened_img.shape}")
            X_train.append(flattened_img) # 
            y_train.append(label)


    X_test = [] # features
    y_test = [] # labels
    for batch in test_loader:
        images, labels = batch  # images: (batch_size, 1,28  ,28 ), labels: (batch_size,)
        if hasattr(images, 'numpy'): # images is tensor
            images = images.numpy()
        # batch_size = 64
        for img, label in zip(images, labels):
            flattened_img = img.flatten()           # flatten the image
            X_test.append(flattened_img)
            y_test.append(label)


    X_train = np.array(X_train)
    y_train = np.array(y_train)
    X_test = np.array(X_test)
    y_test = np.array(y_test)
    print("X_train.shape:", X_train.shape)
    print("y_train.shape:", y_train.shape)
    print("X_test.shape:", X_test.shape)
    print("y_test.shape:", y_test.shape)



    from imblearn.over_sampling import SMOTE
    from collections import Counter

    sm = ADASYN(random_state=42)
    X_train, y_train = sm.fit_resample(X_train, y_train)
    print('Resampled dataset shape %s' % Counter(y_train))
    print("##############################################")
    print("SMOTE done!")
    print("X_train.shape:", X_train.shape)
    print("y_train.shape:", y_train.shape)
    print("X_test.shape:", X_test.shape)
    print("y_test.shape:", y_test.shape)
    import torch
    from torch.utils.data import TensorDataset, DataLoader

    # 假设 X_train 和 y_train 都是 numpy 数组
    # 注意：如果你的像素值范围在 0~255，建议在转换为 tensor 时进行归一化
    X_train_tensor= torch.tensor(X_train, dtype=torch.float32)
    y_train_tensor = torch.tensor(y_train, dtype=torch.long)
    print("X_train_tensor.shape:", X_train_tensor.shape)
    print("y_train_tensor.shape:", y_train_tensor.shape)

    # 假设 X_train_tensor 的形状为 (N, 784)，每个样本是一个扁平化的 28x28 图像
    reconstructed_images = []  # 用于保存恢复后的图像

    for i in range(len(X_train_tensor)):
        flattened_img = X_train_tensor[i]        # 取出第 i 个样本，形状 (784,)
        original_img = flattened_img.view(28, 28)  # 恢复为 (28, 28) 图像
        reconstructed_images.append(original_img)  # 存入列表

    print("总共恢复的图像数量：", len(reconstructed_images))

    # 可视化恢复后的图像
    plt.figure(figsize=(20, 5))
    for i, img in enumerate(reconstructed_images[:20]):
        plt.subplot(2, 10, i+1)
        plt.imshow(img, cmap="gray")
        plt.axis('off')
    plt.show()


    # 创建 Dataset
    reconstructed_images = torch.stack(reconstructed_images)  # 将列表转换为张量
    print("reconstructed_images.shape:", reconstructed_images.shape)  # (N, 28, 28)
    final_train_datasets = TensorDataset(reconstructed_images.unsqueeze(1).float(), y_train_tensor)

    # 使用新的 Dataset 构建新的 DataLoader
    new_train_loader = DataLoader(final_train_datasets, batch_size=64, shuffle=True)
    print("Number of batches in new training set: ", len(new_train_loader))

    # 获取一个 batch
    images, labels = next(iter(new_train_loader))
    print(f"Images shape: {images.shape}")  # 形状为 (batch_size, channels, height, width)
    print(f"Labels shape: {labels.shape}")  # 形状为 (batch_size,)
    from torchinfo import summary
    import torch
    import torch.nn as nn
    from CNN1 import BinaryCNN1
    # 将模型转移到GPU中（我们模型运行均在GPU中进行）
    model = BinaryCNN1().to(device)
    summary(model)
    # define the optimizer and loss function
    import torch.optim as optimizer
    from self_metrics import Binary_got_metrics
    loss_function = nn.CrossEntropyLoss()
    learning_rate = 0.001
    optimizer = optimizer.Adam(model.parameters(), lr=learning_rate)

    # model training
    def train(dataloader, model, loss_function, optimizer):
        size = len(dataloader.dataset)
        num_batches = len(dataloader)
        train_loss, train_accuracy = 0, 0
        for images, labels in dataloader:
            images, labels = images.to(device), labels.to(device)
            # Compute prediction error
            prediction = model(images)
            loss = loss_function(prediction, labels)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            train_loss += loss.item()
            train_accuracy += (prediction.argmax(1) == labels).type(torch.float).sum().item()

        train_loss /= num_batches
        train_accuracy /= size

        return train_loss, train_accuracy



    # model evaluation
    def test(dataloader, model, loss_function):
        size = len(dataloader.dataset)
        num_batches = len(dataloader)
        test_loss, test_accuracy = 0, 0
        # 1(1) is positive, 0(7) is negative
        # TP: 1 classified as 1
        # TN: 0 classified as 0
        # FP: 0 classified as 1
        # FN: 1 classified as 0
        TP, TN, FP, FN = 0, 0, 0, 0
        with torch.no_grad():
            for images, labels in dataloader:
                images, labels = images.to(device), labels.to(device)
                prediction = model(images)
                test_loss += loss_function(prediction, labels).item()
                test_accuracy += (prediction.argmax(1) == labels).type(torch.float).sum().item()
                TP += ((prediction.argmax(1) == 1) & (labels == 1)).type(torch.float).sum().item()
                TN += ((prediction.argmax(1) == 0) & (labels == 0)).type(torch.float).sum().item()
                FP += ((prediction.argmax(1) == 1) & (labels == 0)).type(torch.float).sum().item()
                FN += ((prediction.argmax(1) == 0) & (labels == 1)).type(torch.float).sum().item()


        test_loss /= num_batches
        test_accuracy /= size
        return test_loss, test_accuracy, TP, TN, FP, FN

    # training the model
    epochs = 50
    train_loss_list = []
    train_accuracy_list = []
    test_loss_list = []
    test_accuracy_list = []

    best_model_TP = 0
    best_model_TN = 0
    best_model_FP = 0
    best_model_FN = 0
    best_test_accuracy = 0.0 # for saving the best model
    for epoch in range(epochs):
        model.train()
        train_loss, train_accuracy = train(new_train_loader, model, loss_function, optimizer)
        model.eval()
        test_loss, test_accuracy,TP, TN, FP, FN  = test(test_loader, model, loss_function)
        train_loss_list.append(train_loss)
        train_accuracy_list.append(train_accuracy)
        test_loss_list.append(test_loss)
        test_accuracy_list.append(test_accuracy)

        print(f"Epoch: {epoch+1}/{epochs}, Train Loss: {train_loss:.4f}, Train Accuracy: {train_accuracy:.4f}, Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.4f}") 

        if test_accuracy > best_test_accuracy:
            best_test_accuracy = test_accuracy
            best_model_TP = TP
            best_model_TN = TN
            best_model_FP = FP
            best_model_FN = FN
            save_path = f"BinaryMNIST17_{fraction}.pth"
            torch.save(model.state_dict(), save_path)
            print(f"==> New best model saved at epoch {epoch+1} with Test Accuracy: {test_accuracy:.4f}")
            #print(f"==> TP: {TP}, TN: {TN}, FP: {FP}, FN: {FN}")
            Accuracy, misclassification_rate, Sensitivity, Specificity, Precision, Negative_Predictive_Value, Gmean, Fmean, DPower, F2measure, InvF_05, AGFmeasure, Balanced_Accuracy, MCCmeasure, Kappa, Youden_Index, LR_pos, LR_neg = Binary_got_metrics(best_model_TP, best_model_FP, best_model_FN, best_model_TN)
            import json

            # 构造一个包含所有指标数据的字典
            metrics_dict = {
                "Number of label 3 in the final training set": len(mnist1_train_data),
                "Number of label 4 in the final training set (after downsampling)": len(fraction_mnist7_train_data),
                "Number of label 3 in the final test set": len(mnist1_test_data),
                "Number of label 4 in the final test set": len(mnist7_test_data),
                "Total samples in final training set": len(Final_train_datasets),
                "Total samples in final test set": len(Final_test_datasets),
                "Number of batches in training set": len(train_loader),
                "Number of batches in test set": len(test_loader),
                "TP": TP,
                "FP": FP,
                "FN": FN,
                "TN": TN,
                "Accuracy": round(Accuracy, 4),
                "Misclassification rate": round(misclassification_rate, 4),
                "Sensitivity (Recall)": round(Sensitivity, 4),
                "Specificity": round(Specificity, 4),
                "Precision": round(Precision, 4),
                "Negative Predictive Value": round(Negative_Predictive_Value, 4),
                "G-mean": round(Gmean, 4),
                "F-measure": round(Fmean, 4),
                "Discriminant Power (DP)": round(DPower, 4),
                "F2-measure": round(F2measure, 4),
                "InvF0.5-measure": round(InvF_05, 4),
                "AGF": round(AGFmeasure, 4),
                "Balanced Accuracy": round(Balanced_Accuracy, 4),
                "Matthew's Correlation Coefficient (MCC)": round(MCCmeasure, 4),
                "Cohen's Kappa": round(Kappa, 4),
                "Youden's Index": round(Youden_Index, 4),
                "Positive Likelihood Ratio (LR+)": round(LR_pos, 4),
                "Negative Likelihood Ratio (LR-)": round(LR_neg, 4)
            }

            # 指定 JSON 文件保存路径
            metrics_results_path = f"ADASYN_CNNBinaryMNIST17_{fraction}_metrics_results.json"

            # 将字典保存为 JSON 文件
            with open(metrics_results_path, "w") as f:
                json.dump(metrics_dict, f, indent=4)
# Out:
# Number of label 1 in the final training set:  6742
# Number of label 7 in the final training set (after downsampling):  33
# Number of label 1 in the final test set:  1135
# Number of label 7 in the final test set:  1028
# Total samples in final training set:  6775
# Total samples in final test set:  2163
# Number of batches in training set:  106
# Number of batches in test set:  34
# Images shape: torch.Size([64, 1, 28, 28])
# Labels shape: torch.Size([64])
# First image tensor:
# tensor([[[0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.3216, 1.0000, 0.4980, 0.3137, 0.1059,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.7922, 0.9922, 0.9922, 0.9922, 0.3412,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.7922, 0.9922, 0.9922, 0.9922, 0.9490,
#           0.0275, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.7922, 0.9922, 0.9922, 0.9922, 0.9922,
#           0.0314, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0314, 0.5059, 0.9647, 0.9922, 0.9922, 0.9922, 0.9922,
#           0.0314, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.1725, 0.9922, 0.9922, 0.9922, 0.9922, 0.9922, 0.9922,
#           0.0314, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.1569, 0.9373, 0.9922, 0.9922, 0.9922, 0.9922, 0.9922,
#           0.5765, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.2824, 0.9059, 0.9922, 0.9922, 0.9922, 0.9922,
#           0.8314, 0.1725, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.2941, 0.9922, 0.9922, 0.9922, 0.9922,
#           0.9922, 0.4078, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.1059, 0.9922, 0.9922, 0.9922, 0.9922,
#           0.9922, 0.6078, 0.0353, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.1059, 0.9922, 0.9922, 0.7647, 0.3412,
#           0.9725, 0.9922, 0.0980, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.1059, 0.9922, 0.9922, 0.9804, 0.3294,
#           0.7725, 0.9922, 0.2902, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.1059, 0.9922, 0.9922, 0.9922, 0.3412,
#           0.1137, 0.7490, 0.9059, 0.5843, 0.0980, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.1059, 0.9922, 0.9922, 0.9922, 0.3412,
#           0.0000, 0.0588, 0.9059, 0.9922, 0.1686, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.1059, 0.9922, 0.9922, 0.9922, 0.3412,
#           0.0000, 0.0000, 0.4314, 0.7451, 0.1686, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.1059, 0.9922, 0.9922, 0.9922, 0.3412,
#           0.0000, 0.0000, 0.0000, 0.0863, 0.0314, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.1059, 0.9922, 0.9922, 0.9922, 0.3412,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.1059, 0.9922, 0.9922, 0.9922, 0.3412,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.1059, 0.9922, 0.9922, 0.9922, 0.3412,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.1059, 0.9922, 0.9922, 0.9922, 0.3412,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000]]])
# First image label: 1
# X_train.shape: (6775, 784)
# y_train.shape: (6775,)
# X_test.shape: (2163, 784)
# y_test.shape: (2163,)
# Resampled dataset shape Counter({np.int64(1): 6742, np.int64(0): 6741})
# ##############################################
# SMOTE done!
# X_train.shape: (13483, 784)
# y_train.shape: (13483,)
# X_test.shape: (2163, 784)
# y_test.shape: (2163,)
# X_train_tensor.shape: torch.Size([13483, 784])
# y_train_tensor.shape: torch.Size([13483])
# 总共恢复的图像数量： 13483
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# reconstructed_images.shape: torch.Size([13483, 28, 28])
# Number of batches in new training set:  211
# Images shape: torch.Size([64, 1, 28, 28])
# Labels shape: torch.Size([64])
# Epoch: 1/50, Train Loss: 0.0396, Train Accuracy: 0.9898, Test Loss: 0.1331, Test Accuracy: 0.9760
# ==> New best model saved at epoch 1 with Test Accuracy: 0.9760
# TP: 1135.0
# FP: 52.0
# FN: 0.0
# TN: 976.0
# Accuracy: 0.9760
# Misclassification rate: 0.0240
# Sensitivity (Recall): 1.0000
# Specificity: 0.9494
# Precision: 0.9562
# Negative Predictive Value: 1.0000
# G-mean: 0.9744
# F-measure: 0.9776
# Discriminant Power: Infinity
# F2-measure: 0.9646
# InvF0.5-measure: 0.9909
# AGF: 0.9777
# Balanced Accuracy: 0.9747
# Matthew's Correlation Coefficient: 0.9528
# Cohen's Kappa: 0.9517
# Youden's Index: 0.9494
# Positive Likelihood Ratio: 19.7692
# Negative Likelihood Ratio: 0.0000
# Epoch: 2/50, Train Loss: 0.0013, Train Accuracy: 0.9997, Test Loss: 0.2529, Test Accuracy: 0.9644
# Epoch: 3/50, Train Loss: 0.0010, Train Accuracy: 0.9998, Test Loss: 0.2393, Test Accuracy: 0.9676
# Epoch: 4/50, Train Loss: 0.0001, Train Accuracy: 1.0000, Test Loss: 0.2329, Test Accuracy: 0.9699
# Epoch: 5/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2472, Test Accuracy: 0.9686
# Epoch: 6/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2347, Test Accuracy: 0.9713
# Epoch: 7/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2421, Test Accuracy: 0.9704
# Epoch: 8/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2518, Test Accuracy: 0.9704
# Epoch: 9/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2659, Test Accuracy: 0.9699
# Epoch: 10/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2614, Test Accuracy: 0.9704
# Epoch: 11/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2636, Test Accuracy: 0.9704
# Epoch: 12/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2858, Test Accuracy: 0.9690
# Epoch: 13/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2836, Test Accuracy: 0.9695
# Epoch: 14/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2826, Test Accuracy: 0.9704
# Epoch: 15/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2901, Test Accuracy: 0.9695
# Epoch: 16/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.3023, Test Accuracy: 0.9690
# Epoch: 17/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.3028, Test Accuracy: 0.9695
# Epoch: 18/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.3090, Test Accuracy: 0.9690
# Epoch: 19/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.3190, Test Accuracy: 0.9686
# Epoch: 20/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.3092, Test Accuracy: 0.9695
# Epoch: 21/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.3280, Test Accuracy: 0.9686
# Epoch: 22/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.3215, Test Accuracy: 0.9695
# Epoch: 23/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.3219, Test Accuracy: 0.9695
# Epoch: 24/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.3344, Test Accuracy: 0.9690
# Epoch: 25/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.3422, Test Accuracy: 0.9686
# Epoch: 26/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.3432, Test Accuracy: 0.9686
# Epoch: 27/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.3524, Test Accuracy: 0.9686
# Epoch: 28/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.3512, Test Accuracy: 0.9690
# Epoch: 29/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.3670, Test Accuracy: 0.9686
# Epoch: 30/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.3614, Test Accuracy: 0.9686
# Epoch: 31/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.3620, Test Accuracy: 0.9690
# Epoch: 32/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.3894, Test Accuracy: 0.9672
# Epoch: 33/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.3769, Test Accuracy: 0.9686
# Epoch: 34/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.3810, Test Accuracy: 0.9686
# Epoch: 35/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.3700, Test Accuracy: 0.9695
# Epoch: 36/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.4023, Test Accuracy: 0.9672
# Epoch: 37/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.4045, Test Accuracy: 0.9676
# Epoch: 38/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.4053, Test Accuracy: 0.9681
# Epoch: 39/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.3992, Test Accuracy: 0.9686
# Epoch: 40/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.4125, Test Accuracy: 0.9681
# Epoch: 41/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.4030, Test Accuracy: 0.9686
# Epoch: 42/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.4203, Test Accuracy: 0.9681
# Epoch: 43/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.4313, Test Accuracy: 0.9676
# Epoch: 44/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.4187, Test Accuracy: 0.9686
# Epoch: 45/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.4434, Test Accuracy: 0.9676
# Epoch: 46/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.4600, Test Accuracy: 0.9667
# Epoch: 47/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.4391, Test Accuracy: 0.9676
# Epoch: 48/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.4415, Test Accuracy: 0.9676
# Epoch: 49/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.4568, Test Accuracy: 0.9676
# Epoch: 50/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.4675, Test Accuracy: 0.9667
# Number of label 1 in the final training set:  6742
# Number of label 7 in the final training set (after downsampling):  67
# Number of label 1 in the final test set:  1135
# Number of label 7 in the final test set:  1028
# Total samples in final training set:  6809
# Total samples in final test set:  2163
# Number of batches in training set:  107
# Number of batches in test set:  34
# Images shape: torch.Size([64, 1, 28, 28])
# Labels shape: torch.Size([64])
# First image tensor:
# tensor([[[0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.1216, 0.7451,
#           0.0784, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.1922, 0.9765,
#           0.2000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.1922, 1.0000,
#           0.3216, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.4196, 0.9647,
#           0.1255, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.5647, 0.9412,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.5647, 0.8118,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.5647, 0.5608,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.5647, 0.5608,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.8314, 0.5608,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.9451, 0.3529,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.1412, 0.9686, 0.1882,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.3255, 0.8706, 0.0627,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.6706, 0.8078, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.6980, 0.8078, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.6980, 0.8078, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.6980, 0.8078, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.6980, 0.6588, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.6980, 0.4353, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.3216, 0.5922, 0.0275,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.4275, 0.4745,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000]]])
# First image label: 1
# X_train.shape: (6809, 784)
# y_train.shape: (6809,)
# X_test.shape: (2163, 784)
# y_test.shape: (2163,)
# Resampled dataset shape Counter({np.int64(0): 6743, np.int64(1): 6742})
# ##############################################
# SMOTE done!
# X_train.shape: (13485, 784)
# y_train.shape: (13485,)
# X_test.shape: (2163, 784)
# y_test.shape: (2163,)
# X_train_tensor.shape: torch.Size([13485, 784])
# y_train_tensor.shape: torch.Size([13485])
# 总共恢复的图像数量： 13485
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# reconstructed_images.shape: torch.Size([13485, 28, 28])
# Number of batches in new training set:  211
# Images shape: torch.Size([64, 1, 28, 28])
# Labels shape: torch.Size([64])
# Epoch: 1/50, Train Loss: 0.0342, Train Accuracy: 0.9902, Test Loss: 0.0641, Test Accuracy: 0.9866
# ==> New best model saved at epoch 1 with Test Accuracy: 0.9866
# TP: 1135.0
# FP: 29.0
# FN: 0.0
# TN: 999.0
# Accuracy: 0.9866
# Misclassification rate: 0.0134
# Sensitivity (Recall): 1.0000
# Specificity: 0.9718
# Precision: 0.9751
# Negative Predictive Value: 1.0000
# G-mean: 0.9858
# F-measure: 0.9874
# Discriminant Power: Infinity
# F2-measure: 0.9800
# InvF0.5-measure: 0.9949
# AGF: 0.9874
# Balanced Accuracy: 0.9859
# Matthew's Correlation Coefficient: 0.9734
# Cohen's Kappa: 0.9731
# Youden's Index: 0.9718
# Positive Likelihood Ratio: 35.4483
# Negative Likelihood Ratio: 0.0000
# Epoch: 2/50, Train Loss: 0.0015, Train Accuracy: 0.9996, Test Loss: 0.0914, Test Accuracy: 0.9829
# Epoch: 3/50, Train Loss: 0.0005, Train Accuracy: 0.9999, Test Loss: 0.1406, Test Accuracy: 0.9760
# Epoch: 4/50, Train Loss: 0.0002, Train Accuracy: 0.9999, Test Loss: 0.2141, Test Accuracy: 0.9644
# Epoch: 5/50, Train Loss: 0.0014, Train Accuracy: 0.9996, Test Loss: 0.1197, Test Accuracy: 0.9792
# Epoch: 6/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1361, Test Accuracy: 0.9760
# Epoch: 7/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1414, Test Accuracy: 0.9764
# Epoch: 8/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1453, Test Accuracy: 0.9773
# Epoch: 9/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1483, Test Accuracy: 0.9769
# Epoch: 10/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1689, Test Accuracy: 0.9755
# Epoch: 11/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1642, Test Accuracy: 0.9755
# Epoch: 12/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1586, Test Accuracy: 0.9783
# Epoch: 13/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1642, Test Accuracy: 0.9778
# Epoch: 14/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1684, Test Accuracy: 0.9778
# Epoch: 15/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1726, Test Accuracy: 0.9773
# Epoch: 16/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1758, Test Accuracy: 0.9773
# Epoch: 17/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1740, Test Accuracy: 0.9778
# Epoch: 18/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1787, Test Accuracy: 0.9778
# Epoch: 19/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1786, Test Accuracy: 0.9778
# Epoch: 20/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1889, Test Accuracy: 0.9773
# Epoch: 21/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1832, Test Accuracy: 0.9778
# Epoch: 22/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1896, Test Accuracy: 0.9773
# Epoch: 23/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1927, Test Accuracy: 0.9773
# Epoch: 24/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1913, Test Accuracy: 0.9778
# Epoch: 25/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1958, Test Accuracy: 0.9773
# Epoch: 26/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1986, Test Accuracy: 0.9773
# Epoch: 27/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2000, Test Accuracy: 0.9773
# Epoch: 28/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2005, Test Accuracy: 0.9773
# Epoch: 29/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2020, Test Accuracy: 0.9773
# Epoch: 30/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2129, Test Accuracy: 0.9773
# Epoch: 31/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2103, Test Accuracy: 0.9773
# Epoch: 32/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2116, Test Accuracy: 0.9773
# Epoch: 33/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2150, Test Accuracy: 0.9773
# Epoch: 34/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2161, Test Accuracy: 0.9773
# Epoch: 35/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2182, Test Accuracy: 0.9773
# Epoch: 36/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2213, Test Accuracy: 0.9773
# Epoch: 37/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2280, Test Accuracy: 0.9773
# Epoch: 38/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2226, Test Accuracy: 0.9773
# Epoch: 39/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2303, Test Accuracy: 0.9773
# Epoch: 40/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2313, Test Accuracy: 0.9773
# Epoch: 41/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2575, Test Accuracy: 0.9741
# Epoch: 42/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2280, Test Accuracy: 0.9773
# Epoch: 43/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2309, Test Accuracy: 0.9769
# Epoch: 44/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2530, Test Accuracy: 0.9750
# Epoch: 45/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2384, Test Accuracy: 0.9769
# Epoch: 46/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2503, Test Accuracy: 0.9764
# Epoch: 47/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2411, Test Accuracy: 0.9769
# Epoch: 48/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2477, Test Accuracy: 0.9769
# Epoch: 49/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2570, Test Accuracy: 0.9750
# Epoch: 50/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2472, Test Accuracy: 0.9769
# Number of label 1 in the final training set:  6742
# Number of label 7 in the final training set (after downsampling):  134
# Number of label 1 in the final test set:  1135
# Number of label 7 in the final test set:  1028
# Total samples in final training set:  6876
# Total samples in final test set:  2163
# Number of batches in training set:  108
# Number of batches in test set:  34
# Images shape: torch.Size([64, 1, 28, 28])
# Labels shape: torch.Size([64])
# First image tensor:
# tensor([[[0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.6588, 0.9294,
#           0.5804, 0.0471, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.8275, 0.9922,
#           0.9882, 0.0824, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.2667, 0.9765, 0.9922,
#           0.9882, 0.0824, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.6627, 0.9882, 0.9922,
#           0.9882, 0.0824, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.6627, 0.9882, 0.9922,
#           0.8510, 0.0471, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.6627, 0.9922, 1.0000,
#           0.6588, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0627, 0.9098, 0.9882, 0.9922,
#           0.5176, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0863, 0.9882, 0.9882, 0.9804,
#           0.2275, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.1882, 0.9882, 0.9882, 0.8275,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.4980, 0.9882, 0.9882, 0.8275,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.5020, 0.9922, 0.9922, 0.8314,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.4980, 0.9882, 0.9882, 0.8275,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.4980, 0.9882, 0.9882, 0.8275,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.3255, 0.9882, 0.9882, 0.7255,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.4980, 0.9882, 0.9882, 0.4157,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.5020, 0.9922, 0.9922, 0.4863,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.1882, 0.9882, 0.9882, 0.8275,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0431, 0.7922, 0.9882, 0.8275,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.2510, 0.9882, 0.9373,
#           0.4431, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0431, 0.6824, 0.9255,
#           0.2118, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000]]])
# First image label: 1
# X_train.shape: (6876, 784)
# y_train.shape: (6876,)
# X_test.shape: (2163, 784)
# y_test.shape: (2163,)
# Resampled dataset shape Counter({np.int64(0): 6744, np.int64(1): 6742})
# ##############################################
# SMOTE done!
# X_train.shape: (13486, 784)
# y_train.shape: (13486,)
# X_test.shape: (2163, 784)
# y_test.shape: (2163,)
# X_train_tensor.shape: torch.Size([13486, 784])
# y_train_tensor.shape: torch.Size([13486])
# 总共恢复的图像数量： 13486
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# reconstructed_images.shape: torch.Size([13486, 28, 28])
# Number of batches in new training set:  211
# Images shape: torch.Size([64, 1, 28, 28])
# Labels shape: torch.Size([64])
# Epoch: 1/50, Train Loss: 0.0470, Train Accuracy: 0.9870, Test Loss: 0.0770, Test Accuracy: 0.9806
# ==> New best model saved at epoch 1 with Test Accuracy: 0.9806
# TP: 1135.0
# FP: 42.0
# FN: 0.0
# TN: 986.0
# Accuracy: 0.9806
# Misclassification rate: 0.0194
# Sensitivity (Recall): 1.0000
# Specificity: 0.9591
# Precision: 0.9643
# Negative Predictive Value: 1.0000
# G-mean: 0.9794
# F-measure: 0.9818
# Discriminant Power: Infinity
# F2-measure: 0.9712
# InvF0.5-measure: 0.9927
# AGF: 0.9819
# Balanced Accuracy: 0.9796
# Matthew's Correlation Coefficient: 0.9617
# Cohen's Kappa: 0.9610
# Youden's Index: 0.9591
# Positive Likelihood Ratio: 24.4762
# Negative Likelihood Ratio: 0.0000
# Epoch: 2/50, Train Loss: 0.0036, Train Accuracy: 0.9993, Test Loss: 0.0777, Test Accuracy: 0.9847
# ==> New best model saved at epoch 2 with Test Accuracy: 0.9847
# TP: 1135.0
# FP: 33.0
# FN: 0.0
# TN: 995.0
# Accuracy: 0.9847
# Misclassification rate: 0.0153
# Sensitivity (Recall): 1.0000
# Specificity: 0.9679
# Precision: 0.9717
# Negative Predictive Value: 1.0000
# G-mean: 0.9838
# F-measure: 0.9857
# Discriminant Power: Infinity
# F2-measure: 0.9773
# InvF0.5-measure: 0.9942
# AGF: 0.9857
# Balanced Accuracy: 0.9839
# Matthew's Correlation Coefficient: 0.9698
# Cohen's Kappa: 0.9694
# Youden's Index: 0.9679
# Positive Likelihood Ratio: 31.1515
# Negative Likelihood Ratio: 0.0000
# Epoch: 3/50, Train Loss: 0.0011, Train Accuracy: 0.9997, Test Loss: 0.1179, Test Accuracy: 0.9792
# Epoch: 4/50, Train Loss: 0.0004, Train Accuracy: 0.9999, Test Loss: 0.1609, Test Accuracy: 0.9750
# Epoch: 5/50, Train Loss: 0.0005, Train Accuracy: 0.9998, Test Loss: 0.1786, Test Accuracy: 0.9741
# Epoch: 6/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1478, Test Accuracy: 0.9801
# Epoch: 7/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1584, Test Accuracy: 0.9787
# Epoch: 8/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1646, Test Accuracy: 0.9787
# Epoch: 9/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1667, Test Accuracy: 0.9792
# Epoch: 10/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1602, Test Accuracy: 0.9806
# Epoch: 11/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1548, Test Accuracy: 0.9815
# Epoch: 12/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1655, Test Accuracy: 0.9806
# Epoch: 13/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1719, Test Accuracy: 0.9797
# Epoch: 14/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1734, Test Accuracy: 0.9797
# Epoch: 15/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1717, Test Accuracy: 0.9806
# Epoch: 16/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1702, Test Accuracy: 0.9810
# Epoch: 17/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1741, Test Accuracy: 0.9806
# Epoch: 18/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1785, Test Accuracy: 0.9806
# Epoch: 19/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1777, Test Accuracy: 0.9806
# Epoch: 20/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1761, Test Accuracy: 0.9810
# Epoch: 21/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1846, Test Accuracy: 0.9806
# Epoch: 22/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1825, Test Accuracy: 0.9806
# Epoch: 23/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1788, Test Accuracy: 0.9815
# Epoch: 24/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1840, Test Accuracy: 0.9810
# Epoch: 25/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1851, Test Accuracy: 0.9806
# Epoch: 26/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1922, Test Accuracy: 0.9801
# Epoch: 27/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1874, Test Accuracy: 0.9815
# Epoch: 28/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1940, Test Accuracy: 0.9801
# Epoch: 29/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1948, Test Accuracy: 0.9801
# Epoch: 30/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1959, Test Accuracy: 0.9801
# Epoch: 31/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2060, Test Accuracy: 0.9792
# Epoch: 32/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.1989, Test Accuracy: 0.9801
# Epoch: 33/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2025, Test Accuracy: 0.9801
# Epoch: 34/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2081, Test Accuracy: 0.9797
# Epoch: 35/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2055, Test Accuracy: 0.9801
# Epoch: 36/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2161, Test Accuracy: 0.9792
# Epoch: 37/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2092, Test Accuracy: 0.9801
# Epoch: 38/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2190, Test Accuracy: 0.9792
# Epoch: 39/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2157, Test Accuracy: 0.9797
# Epoch: 40/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2191, Test Accuracy: 0.9792
# Epoch: 41/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2108, Test Accuracy: 0.9810
# Epoch: 42/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2258, Test Accuracy: 0.9792
# Epoch: 43/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2256, Test Accuracy: 0.9792
# Epoch: 44/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2265, Test Accuracy: 0.9792
# Epoch: 45/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2197, Test Accuracy: 0.9810
# Epoch: 46/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2327, Test Accuracy: 0.9792
# Epoch: 47/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2348, Test Accuracy: 0.9792
# Epoch: 48/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2294, Test Accuracy: 0.9792
# Epoch: 49/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2309, Test Accuracy: 0.9792
# Epoch: 50/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.2376, Test Accuracy: 0.9792
# Number of label 1 in the final training set:  6742
# Number of label 7 in the final training set (after downsampling):  337
# Number of label 1 in the final test set:  1135
# Number of label 7 in the final test set:  1028
# Total samples in final training set:  7079
# Total samples in final test set:  2163
# Number of batches in training set:  111
# Number of batches in test set:  34
# Images shape: torch.Size([64, 1, 28, 28])
# Labels shape: torch.Size([64])
# First image tensor:
# tensor([[[0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.9176, 1.0000, 0.7294, 0.1333, 0.0588,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.9098, 0.9882, 0.9882, 0.9882, 0.4275,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.9098, 0.9882, 0.9882, 0.9882, 0.6471,
#           0.1176, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.9098, 0.9882, 0.9882, 0.9882, 0.9882,
#           0.2980, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.9098, 0.9882, 0.9882, 0.9882, 0.9882,
#           0.2980, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.9098, 0.9882, 0.9882, 0.9882, 0.9882,
#           0.2980, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.9098, 0.9882, 0.9882, 0.9882, 0.9882,
#           0.9333, 0.1529, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.9098, 0.9882, 0.9882, 0.9882, 0.9882,
#           0.9882, 0.1686, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.9098, 0.9882, 0.9882, 0.9882, 0.9882,
#           0.9882, 0.1686, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.9098, 0.9882, 0.9882, 0.9882, 0.9882,
#           0.9882, 0.5255, 0.0157, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.9098, 0.9882, 0.9882, 0.9882, 0.9882,
#           0.9882, 0.9882, 0.0353, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
# ...
# Number of label 1 in the final training set:  6742
# Number of label 7 in the final training set (after downsampling):  1348
# Number of label 1 in the final test set:  1135
# Number of label 7 in the final test set:  1028
# Total samples in final training set:  8090
# Total samples in final test set:  2163
# Number of batches in training set:  127
# Number of batches in test set:  34
# Images shape: torch.Size([64, 1, 28, 28])
# Labels shape: torch.Size([64])
# First image tensor:
# tensor([[[0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0745, 0.4392, 0.7216, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0353, 0.6510, 0.8627, 0.9882, 0.9882, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.5020, 0.9882, 0.9882, 0.6157, 0.1255, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0431, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.7020, 1.0000, 0.9922, 0.6784, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.1765, 0.2784, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.2353,
#           0.9569, 0.9922, 0.8745, 0.0980, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.6000, 0.1765, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0745, 0.7373,
#           0.9882, 0.9922, 0.6824, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.3176, 0.5529, 0.0353, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.4392, 0.9882,
#           0.9882, 0.7529, 0.0667, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0431, 0.6314, 0.0235, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0863, 0.8431, 0.9882,
#           0.9882, 0.2471, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.2510, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0431, 0.7961, 0.9922, 0.9922,
#           0.5020, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.1647, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.3490, 0.8588, 0.9882, 0.8235,
#           0.0471, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.1255, 0.6667, 0.9882, 0.9137, 0.5529,
#           0.0235, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.4118, 0.9922, 0.9882, 0.5529, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.6980, 0.9922, 0.9882, 0.4745, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.3647, 0.9922, 1.0000, 0.5647, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0510, 0.6824, 0.9882, 0.9765, 0.2941, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.4039, 0.7176, 0.7176, 0.4510, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000]]])
# First image label: 1
# X_train.shape: (8090, 784)
# y_train.shape: (8090,)
# X_test.shape: (2163, 784)
# y_test.shape: (2163,)
# Resampled dataset shape Counter({np.int64(1): 6742, np.int64(0): 6724})
# ##############################################
# SMOTE done!
# X_train.shape: (13466, 784)
# y_train.shape: (13466,)
# X_test.shape: (2163, 784)
# y_test.shape: (2163,)
# X_train_tensor.shape: torch.Size([13466, 784])
# y_train_tensor.shape: torch.Size([13466])
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# 总共恢复的图像数量： 13466
# reconstructed_images.shape: torch.Size([13466, 28, 28])
# Number of batches in new training set:  211
# Images shape: torch.Size([64, 1, 28, 28])
# Labels shape: torch.Size([64])
# Epoch: 1/50, Train Loss: 0.0719, Train Accuracy: 0.9770, Test Loss: 0.0089, Test Accuracy: 0.9968
# ==> New best model saved at epoch 1 with Test Accuracy: 0.9968
# TP: 1131.0
# FP: 3.0
# FN: 4.0
# TN: 1025.0
# Accuracy: 0.9968
# Misclassification rate: 0.0032
# Sensitivity (Recall): 0.9965
# Specificity: 0.9971
# Precision: 0.9974
# Negative Predictive Value: 0.9961
# G-mean: 0.9968
# F-measure: 0.9969
# Discriminant Power: 6.3284
# F2-measure: 0.9972
# InvF0.5-measure: 0.9967
# AGF: 0.9969
# Balanced Accuracy: 0.9968
# Matthew's Correlation Coefficient: 0.9935
# Cohen's Kappa: 0.9935
# Youden's Index: 0.9936
# Positive Likelihood Ratio: 341.4590
# Negative Likelihood Ratio: 0.0035
# Epoch: 2/50, Train Loss: 0.0121, Train Accuracy: 0.9973, Test Loss: 0.0097, Test Accuracy: 0.9972
# ==> New best model saved at epoch 2 with Test Accuracy: 0.9972
# TP: 1133.0
# FP: 4.0
# FN: 2.0
# TN: 1024.0
# Accuracy: 0.9972
# Misclassification rate: 0.0028
# Sensitivity (Recall): 0.9982
# Specificity: 0.9961
# Precision: 0.9965
# Negative Predictive Value: 0.9981
# G-mean: 0.9972
# F-measure: 0.9974
# Discriminant Power: 6.5524
# F2-measure: 0.9968
# InvF0.5-measure: 0.9979
# AGF: 0.9974
# Balanced Accuracy: 0.9972
# Matthew's Correlation Coefficient: 0.9944
# Cohen's Kappa: 0.9944
# Youden's Index: 0.9943
# Positive Likelihood Ratio: 256.5471
# Negative Likelihood Ratio: 0.0018
# Epoch: 3/50, Train Loss: 0.0075, Train Accuracy: 0.9982, Test Loss: 0.0149, Test Accuracy: 0.9958
# Epoch: 4/50, Train Loss: 0.0036, Train Accuracy: 0.9993, Test Loss: 0.0124, Test Accuracy: 0.9968
# Epoch: 5/50, Train Loss: 0.0041, Train Accuracy: 0.9992, Test Loss: 0.0074, Test Accuracy: 0.9977
# ==> New best model saved at epoch 5 with Test Accuracy: 0.9977
# TP: 1135.0
# FP: 5.0
# FN: 0.0
# TN: 1023.0
# Accuracy: 0.9977
# Misclassification rate: 0.0023
# Sensitivity (Recall): 1.0000
# Specificity: 0.9951
# Precision: 0.9956
# Negative Predictive Value: 1.0000
# G-mean: 0.9976
# F-measure: 0.9978
# Discriminant Power: Infinity
# F2-measure: 0.9965
# InvF0.5-measure: 0.9991
# AGF: 0.9978
# Balanced Accuracy: 0.9976
# Matthew's Correlation Coefficient: 0.9954
# Cohen's Kappa: 0.9954
# Youden's Index: 0.9951
# Positive Likelihood Ratio: 205.6000
# Negative Likelihood Ratio: 0.0000
# Epoch: 6/50, Train Loss: 0.0024, Train Accuracy: 0.9995, Test Loss: 0.0266, Test Accuracy: 0.9921
# Epoch: 7/50, Train Loss: 0.0009, Train Accuracy: 0.9999, Test Loss: 0.0134, Test Accuracy: 0.9954
# Epoch: 8/50, Train Loss: 0.0006, Train Accuracy: 0.9997, Test Loss: 0.0193, Test Accuracy: 0.9954
# Epoch: 9/50, Train Loss: 0.0007, Train Accuracy: 0.9997, Test Loss: 0.0065, Test Accuracy: 0.9986
# ==> New best model saved at epoch 9 with Test Accuracy: 0.9986
# TP: 1135.0
# FP: 3.0
# FN: 0.0
# TN: 1025.0
# Accuracy: 0.9986
# Misclassification rate: 0.0014
# Sensitivity (Recall): 1.0000
# Specificity: 0.9971
# Precision: 0.9974
# Negative Predictive Value: 1.0000
# G-mean: 0.9985
# F-measure: 0.9987
# Discriminant Power: Infinity
# F2-measure: 0.9979
# InvF0.5-measure: 0.9995
# AGF: 0.9987
# Balanced Accuracy: 0.9985
# Matthew's Correlation Coefficient: 0.9972
# Cohen's Kappa: 0.9972
# Youden's Index: 0.9971
# Positive Likelihood Ratio: 342.6667
# Negative Likelihood Ratio: 0.0000
# Epoch: 10/50, Train Loss: 0.0009, Train Accuracy: 0.9998, Test Loss: 0.0245, Test Accuracy: 0.9935
# Epoch: 11/50, Train Loss: 0.0001, Train Accuracy: 1.0000, Test Loss: 0.0173, Test Accuracy: 0.9958
# Epoch: 12/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0140, Test Accuracy: 0.9963
# Epoch: 13/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0139, Test Accuracy: 0.9963
# Epoch: 14/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0151, Test Accuracy: 0.9963
# Epoch: 15/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0145, Test Accuracy: 0.9963
# Epoch: 16/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0146, Test Accuracy: 0.9963
# Epoch: 17/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0147, Test Accuracy: 0.9963
# Epoch: 18/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0155, Test Accuracy: 0.9963
# Epoch: 19/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0166, Test Accuracy: 0.9963
# Epoch: 20/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0160, Test Accuracy: 0.9963
# Epoch: 21/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0157, Test Accuracy: 0.9963
# Epoch: 22/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0178, Test Accuracy: 0.9963
# Epoch: 23/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0170, Test Accuracy: 0.9963
# Epoch: 24/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0159, Test Accuracy: 0.9963
# Epoch: 25/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0160, Test Accuracy: 0.9963
# Epoch: 26/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0185, Test Accuracy: 0.9963
# Epoch: 27/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0180, Test Accuracy: 0.9963
# Epoch: 28/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0163, Test Accuracy: 0.9963
# Epoch: 29/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0188, Test Accuracy: 0.9963
# Epoch: 30/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0192, Test Accuracy: 0.9963
# Epoch: 31/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0212, Test Accuracy: 0.9963
# Epoch: 32/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0196, Test Accuracy: 0.9963
# Epoch: 33/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0195, Test Accuracy: 0.9963
# Epoch: 34/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0184, Test Accuracy: 0.9963
# Epoch: 35/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0210, Test Accuracy: 0.9963
# Epoch: 36/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0211, Test Accuracy: 0.9963
# Epoch: 37/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0221, Test Accuracy: 0.9963
# Epoch: 38/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0207, Test Accuracy: 0.9963
# Epoch: 39/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0231, Test Accuracy: 0.9963
# Epoch: 40/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0208, Test Accuracy: 0.9963
# Epoch: 41/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0211, Test Accuracy: 0.9963
# Epoch: 42/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0227, Test Accuracy: 0.9963
# Epoch: 43/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0215, Test Accuracy: 0.9963
# Epoch: 44/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0237, Test Accuracy: 0.9963
# Epoch: 45/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0238, Test Accuracy: 0.9963
# Epoch: 46/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0229, Test Accuracy: 0.9963
# Epoch: 47/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0228, Test Accuracy: 0.9963
# Epoch: 48/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0235, Test Accuracy: 0.9963
# Epoch: 49/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0235, Test Accuracy: 0.9963
# Epoch: 50/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0220, Test Accuracy: 0.9963
