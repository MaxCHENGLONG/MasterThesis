# %%
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
import torchvision
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
import numpy as np
import torch
import matplotlib.pyplot as plt
import sys
import os
sys.path.append(os.path.abspath("/Users/max/MasterThesis/Training/"))

# %%
# frac = [0.005, 0.01, 0.02, 0.05, 0.1, 0.2]
frac = 0.2
import torch
from torch.utils.data import DataLoader, Subset, ConcatDataset, TensorDataset
from torchvision import datasets, transforms
import numpy as np

# 数据预处理
mnist17_transforms = transforms.Compose([
    transforms.ToTensor(), 
    transforms.Normalize((0.1307,), (0.3081,))
])

# 加载 MNIST 数据集
full_train_datasets = datasets.MNIST(root="/Users/max/MasterThesisData/MNIST", train=True, transform=mnist17_transforms, download=True)
full_test_datasets = datasets.MNIST(root="/Users/max/MasterThesisData/MNIST", train=False, transform=mnist17_transforms, download=True)

# 选取标签为 1 和 7 的索引
indices1_train = [i for i in range(len(full_train_datasets)) if full_train_datasets.targets[i] == 1]
indices7_train = [i for i in range(len(full_train_datasets)) if full_train_datasets.targets[i] == 7]

indices1_test = [i for i in range(len(full_test_datasets)) if full_test_datasets.targets[i] == 1]
indices7_test = [i for i in range(len(full_test_datasets)) if full_test_datasets.targets[i] == 7]

# 获取训练集中标签为 1 和 7 的数据
mnist1_train_data = full_train_datasets.data[indices1_train]
mnist1_train_labels = torch.ones(len(indices1_train), dtype=torch.long)  # 标签 1 保持不变

mnist7_train_data = full_train_datasets.data[indices7_train]
mnist7_train_labels = torch.zeros(len(indices7_train), dtype=torch.long)  # 标签 7 映射为 0

# 获取测试集中标签为 1 和 7 的数据
mnist1_test_data = full_test_datasets.data[indices1_test]
mnist1_test_labels = torch.ones(len(indices1_test), dtype=torch.long)  # 标签 1 保持不变

mnist7_test_data = full_test_datasets.data[indices7_test]
mnist7_test_labels = torch.zeros(len(indices7_test), dtype=torch.long)  # 标签 7 映射为 0

# we can set the imbalanced ratio 0.005, 0.01, 0.02, 0.05, 0.1, 0.2
fraction = int(frac * len(mnist1_train_data))  ### control the fraction of the data to be used
selected_indices_7 = np.random.choice(len(mnist7_train_data), fraction, replace=False)

fraction_mnist7_train_data = mnist7_train_data[selected_indices_7]
fraction_mnist7_train_labels = mnist7_train_labels[selected_indices_7]

# 创建最终的训练和测试数据集
Final_train_data = torch.cat([mnist1_train_data, fraction_mnist7_train_data], dim=0)
Final_train_labels = torch.cat([mnist1_train_labels, fraction_mnist7_train_labels], dim=0)

Final_test_data = torch.cat([mnist1_test_data, mnist7_test_data], dim=0)
Final_test_labels = torch.cat([mnist1_test_labels, mnist7_test_labels], dim=0)

# 创建 TensorDataset
Final_train_datasets = TensorDataset(Final_train_data.unsqueeze(1).float() / 255, Final_train_labels)
Final_test_datasets = TensorDataset(Final_test_data.unsqueeze(1).float() / 255, Final_test_labels)

# 数据加载器
train_loader = DataLoader(Final_train_datasets, batch_size=64, shuffle=True)
test_loader = DataLoader(Final_test_datasets, batch_size=64, shuffle=False)

# 打印信息
print("Number of label 1 in the final training set: ", len(mnist1_train_data))
print("Number of label 7 in the final training set (after downsampling): ", len(fraction_mnist7_train_data))
print("Number of label 1 in the final test set: ", len(mnist1_test_data))
print("Number of label 7 in the final test set: ", len(mnist7_test_data))

print("Total samples in final training set: ", len(Final_train_datasets))
print("Total samples in final test set: ", len(Final_test_datasets))

print("Number of batches in training set: ", len(train_loader))
print("Number of batches in test set: ", len(test_loader))



# 获取一个 batch
images, labels = next(iter(train_loader))

# 查看 Tensor 形状
print(f"Images shape: {images.shape}")  # 形状为 (batch_size, channels, height, width)
print(f"Labels shape: {labels.shape}")  # 形状为 (batch_size,)

# 查看第一个样本的 Tensor 值
print(f"First image tensor:\n{images[0]}")  # 打印第一个样本的 Tensor 数据
print(f"First image label: {labels[0]}")  # 打印第一个样本的标签

# 如果需要转换回 NumPy 并可视化：
import matplotlib.pyplot as plt

# 转换为 NumPy 并显示
plt.imshow(images[0].squeeze().numpy(), cmap="gray")
plt.title(f"Label: {labels[0].item()}")
plt.show()
# Out:
# Number of label 1 in the final training set:  6742
# Number of label 7 in the final training set (after downsampling):  1348
# Number of label 1 in the final test set:  1135
# Number of label 7 in the final test set:  1028
# Total samples in final training set:  8090
# Total samples in final test set:  2163
# Number of batches in training set:  127
# Number of batches in test set:  34
# Images shape: torch.Size([64, 1, 28, 28])
# Labels shape: torch.Size([64])
# First image tensor:
# tensor([[[0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.1176, 0.7922,
#           0.9961, 1.0000, 0.9961, 0.1922, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.3255, 0.9922,
#           0.9922, 0.9922, 0.9922, 0.6471, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.1882, 0.8588,
#           0.9922, 0.9922, 0.9922, 0.5569, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.6745,
#           0.9922, 0.9922, 0.9922, 0.1882, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.6745,
#           0.9922, 0.9922, 0.9922, 0.1882, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.4000, 0.9412,
#           0.9922, 0.9922, 0.9922, 0.1882, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.3412, 0.9804, 0.9922,
#           0.9922, 0.9922, 0.9922, 0.1882, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.6118, 0.9922, 0.9922,
#           0.9922, 0.9922, 0.8745, 0.1412, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.1608, 0.8471, 0.9922, 0.9922,
#           0.9922, 0.9922, 0.5412, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.2588, 0.9922, 0.9922, 0.9922,
#           0.9922, 0.8980, 0.0157, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.6941, 0.9922, 0.9922, 0.9922,
#           0.9922, 0.4588, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.2157, 0.9373, 0.9922, 0.9922, 0.9922,
#           0.9922, 0.2549, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.5451, 0.9922, 0.9922, 0.9922, 0.9922,
#           0.9529, 0.2275, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0902, 0.7490, 0.9922, 0.9922, 0.9922, 0.9922,
#           0.6039, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.1961, 0.9922, 0.9922, 0.9922, 0.9922, 0.9647,
#           0.1176, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.5255, 0.9922, 0.9922, 0.9922, 0.9922, 0.6235,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.1137, 0.8706, 0.9922, 0.9922, 0.9922, 0.9922, 0.3176,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.4863, 0.9922, 0.9922, 0.9922, 0.9922, 0.9922, 0.3176,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.4863, 0.9922, 0.9922, 0.9922, 0.9922, 0.6863, 0.0196,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.4863, 0.9922, 0.9922, 0.9922, 0.9922, 0.6706, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000]]])
# First image label: 1

# %%
import numpy as np

# 指定图片大小，图像大小为20宽、5高的绘图(单位为英寸inch)
plt.figure(figsize=(20, 5)) 
for i, imgs in enumerate(images[:20]):
    # 维度缩减
    npimg = np.squeeze(imgs.numpy())
    # 将整个figure分成2行10列，绘制第i+1个子图。
    plt.subplot(2, 10, i+1)
    plt.imshow(npimg, cmap=plt.cm.binary)
    plt.axis('off')


X_train = []
y_train = []

for batch in train_loader:
    images, labels = batch  # images: (batch_size, 1, 28, 28), labels: (batch_size,)
    if hasattr(images, 'numpy'): # images is tensor
        images = images.numpy()
    # batch_size = 64
    for img, label in zip(images, labels):
        #print(f"Original shape: {img.shape}")  #  
        flattened_img = img.flatten()           
        #print(f"Flattened shape: {flattened_img.shape}")
        X_train.append(flattened_img) # 
        y_train.append(label)


X_test = [] # features
y_test = [] # labels
for batch in test_loader:
    images, labels = batch  # images: (batch_size, 1,28  ,28 ), labels: (batch_size,)
    if hasattr(images, 'numpy'): # images is tensor
        images = images.numpy()
    # batch_size = 64
    for img, label in zip(images, labels):
        flattened_img = img.flatten()           # flatten the image
        X_test.append(flattened_img)
        y_test.append(label)


X_train = np.array(X_train)
y_train = np.array(y_train)
X_test = np.array(X_test)
y_test = np.array(y_test)
print("X_train.shape:", X_train.shape)
print("y_train.shape:", y_train.shape)
print("X_test.shape:", X_test.shape)
print("y_test.shape:", y_test.shape)
from Swim_Maha import SwimMaha
sw = SwimMaha(sd=0.25,minClass=0)
numsampels = len(mnist1_train_data) - len(fraction_mnist7_train_data)
X_train_end, y_train_end = sw.mahaSampling(X_train,y_train,numsampels)
print("X_train_end.shape:", X_train_end.shape)
print("y_train_end.shape:", y_train_end.shape)
X_train = np.concatenate((X_train, X_train_end), axis=0)
y_train = np.concatenate((y_train, y_train_end), axis=0)
print("SWIM_X_train.shape:", X_train.shape)
print("SWIM_y_train.shape:", y_train.shape)
# Out:
# X_train.shape: (8090, 784)
# y_train.shape: (8090,)
# X_test.shape: (2163, 784)
# y_test.shape: (2163,)
# The majority class has linearly dependent columns. Rerun the sampling subSpaceSampling=True. Return original data.
# X_train_end.shape: (8090, 784)
# y_train_end.shape: (8090,)
# SWIM_X_train.shape: (16180, 784)
# SWIM_y_train.shape: (16180,)

# %%
import torch
from torch.utils.data import TensorDataset, DataLoader

# 假设 X_train 和 y_train 都是 numpy 数组
# 注意：如果你的像素值范围在 0~255，建议在转换为 tensor 时进行归一化
X_train_tensor= torch.tensor(X_train, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train, dtype=torch.long)
print("X_train_tensor.shape:", X_train_tensor.shape)
print("y_train_tensor.shape:", y_train_tensor.shape)

# 假设 X_train_tensor 的形状为 (N, 784)，每个样本是一个扁平化的 28x28 图像
reconstructed_images = []  # 用于保存恢复后的图像

for i in range(len(X_train_tensor)):
    flattened_img = X_train_tensor[i]        # 取出第 i 个样本，形状 (784,)
    original_img = flattened_img.view(28, 28)  # 恢复为 (28, 28) 图像
    reconstructed_images.append(original_img)  # 存入列表

print("总共恢复的图像数量：", len(reconstructed_images))

# 可视化恢复后的图像
plt.figure(figsize=(20, 5))
for i, img in enumerate(reconstructed_images[:20]):
    plt.subplot(2, 10, i+1)
    plt.imshow(img, cmap="gray")
    plt.axis('off')
plt.show()


# 创建 Dataset
reconstructed_images = torch.stack(reconstructed_images)  # 将列表转换为张量
print("reconstructed_images.shape:", reconstructed_images.shape)  # (N, 28, 28)
final_train_datasets = TensorDataset(reconstructed_images.unsqueeze(1).float(), y_train_tensor)

# 使用新的 Dataset 构建新的 DataLoader
new_train_loader = DataLoader(final_train_datasets, batch_size=64, shuffle=True)
print("Number of batches in new training set: ", len(new_train_loader))

# 获取一个 batch
images, labels = next(iter(new_train_loader))
print(f"Images shape: {images.shape}")  # 形状为 (batch_size, channels, height, width)
print(f"Labels shape: {labels.shape}")  # 形状为 (batch_size,)
# Out:
# X_train_tensor.shape: torch.Size([16180, 784])
# y_train_tensor.shape: torch.Size([16180])
# 总共恢复的图像数量： 16180
# reconstructed_images.shape: torch.Size([16180, 28, 28])
# Number of batches in new training set:  253
# Images shape: torch.Size([64, 1, 28, 28])
# Labels shape: torch.Size([64])

# %%
from torchinfo import summary
import torch
import torch.nn as nn
from CNN1 import BinaryCNN1
# 将模型转移到GPU中（我们模型运行均在GPU中进行）
model = BinaryCNN1().to(device)
summary(model)
# Out:
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# BinaryCNN1                               --
# ├─Conv2d: 1-1                            320
# ├─MaxPool2d: 1-2                         --
# ├─Conv2d: 1-3                            18,496
# ├─MaxPool2d: 1-4                         --
# ├─Linear: 1-5                            102,464
# ├─Linear: 1-6                            130
# =================================================================
# Total params: 121,410
# Trainable params: 121,410
# Non-trainable params: 0
# =================================================================

# %%
# define the optimizer and loss function
import torch.optim as optimizer
from self_metrics import Binary_got_metrics
loss_function = nn.CrossEntropyLoss()
learning_rate = 0.001
optimizer = optimizer.Adam(model.parameters(), lr=learning_rate)

# model training
def train(dataloader, model, loss_function, optimizer):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    train_loss, train_accuracy = 0, 0
    for images, labels in dataloader:
        images, labels = images.to(device), labels.to(device)
        # Compute prediction error
        prediction = model(images)
        loss = loss_function(prediction, labels)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        train_loss += loss.item()
        train_accuracy += (prediction.argmax(1) == labels).type(torch.float).sum().item()

    train_loss /= num_batches
    train_accuracy /= size

    return train_loss, train_accuracy



# model evaluation
def test(dataloader, model, loss_function):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    test_loss, test_accuracy = 0, 0
    # 1(1) is positive, 0(7) is negative
    # TP: 1 classified as 1
    # TN: 0 classified as 0
    # FP: 0 classified as 1
    # FN: 1 classified as 0
    TP, TN, FP, FN = 0, 0, 0, 0
    with torch.no_grad():
        for images, labels in dataloader:
            images, labels = images.to(device), labels.to(device)
            prediction = model(images)
            test_loss += loss_function(prediction, labels).item()
            test_accuracy += (prediction.argmax(1) == labels).type(torch.float).sum().item()
            TP += ((prediction.argmax(1) == 1) & (labels == 1)).type(torch.float).sum().item()
            TN += ((prediction.argmax(1) == 0) & (labels == 0)).type(torch.float).sum().item()
            FP += ((prediction.argmax(1) == 1) & (labels == 0)).type(torch.float).sum().item()
            FN += ((prediction.argmax(1) == 0) & (labels == 1)).type(torch.float).sum().item()


    test_loss /= num_batches
    test_accuracy /= size
    return test_loss, test_accuracy, TP, TN, FP, FN

# training the model
epochs = 50
train_loss_list = []
train_accuracy_list = []
test_loss_list = []
test_accuracy_list = []

best_model_TP = 0
best_model_TN = 0
best_model_FP = 0
best_model_FN = 0
best_test_accuracy = 0.0 # for saving the best model
for epoch in range(epochs):
    model.train()
    train_loss, train_accuracy = train(new_train_loader, model, loss_function, optimizer)
    model.eval()
    test_loss, test_accuracy,TP, TN, FP, FN  = test(test_loader, model, loss_function)
    train_loss_list.append(train_loss)
    train_accuracy_list.append(train_accuracy)
    test_loss_list.append(test_loss)
    test_accuracy_list.append(test_accuracy)

    print(f"Epoch: {epoch+1}/{epochs}, Train Loss: {train_loss:.4f}, Train Accuracy: {train_accuracy:.4f}, Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.4f}") 

    if test_accuracy > best_test_accuracy:
        best_test_accuracy = test_accuracy
        best_model_TP = TP
        best_model_TN = TN
        best_model_FP = FP
        best_model_FN = FN
        save_path = f"BinaryMNIST17_{fraction}.pth"
        torch.save(model.state_dict(), save_path)
        print(f"==> New best model saved at epoch {epoch+1} with Test Accuracy: {test_accuracy:.4f}")
        #print(f"==> TP: {TP}, TN: {TN}, FP: {FP}, FN: {FN}")
        Accuracy, misclassification_rate, Sensitivity, Specificity, Precision, Negative_Predictive_Value, Gmean, Fmean, DPower, F2measure, InvF_05, AGFmeasure, Balanced_Accuracy, MCCmeasure, Kappa, Youden_Index, LR_pos, LR_neg = Binary_got_metrics(best_model_TP, best_model_FP, best_model_FN, best_model_TN)
        import json

        # 构造一个包含所有指标数据的字典
        metrics_dict = {
            "Number of label 3 in the final training set": len(mnist1_train_data),
            "Number of label 4 in the final training set (after downsampling)": len(fraction_mnist7_train_data),
            "Number of label 3 in the final test set": len(mnist1_test_data),
            "Number of label 4 in the final test set": len(mnist7_test_data),
            "Total samples in final training set": len(Final_train_datasets),
            "Total samples in final test set": len(Final_test_datasets),
            "Number of batches in training set": len(train_loader),
            "Number of batches in test set": len(test_loader),
            "TP": TP,
            "FP": FP,
            "FN": FN,
            "TN": TN,
            "Accuracy": round(Accuracy, 4),
            "Misclassification rate": round(misclassification_rate, 4),
            "Sensitivity (Recall)": round(Sensitivity, 4),
            "Specificity": round(Specificity, 4),
            "Precision": round(Precision, 4),
            "Negative Predictive Value": round(Negative_Predictive_Value, 4),
            "G-mean": round(Gmean, 4),
            "F-measure": round(Fmean, 4),
            "Discriminant Power (DP)": round(DPower, 4),
            "F2-measure": round(F2measure, 4),
            "InvF0.5-measure": round(InvF_05, 4),
            "AGF": round(AGFmeasure, 4),
            "Balanced Accuracy": round(Balanced_Accuracy, 4),
            "Matthew's Correlation Coefficient (MCC)": round(MCCmeasure, 4),
            "Cohen's Kappa": round(Kappa, 4),
            "Youden's Index": round(Youden_Index, 4),
            "Positive Likelihood Ratio (LR+)": round(LR_pos, 4),
            "Negative Likelihood Ratio (LR-)": round(LR_neg, 4)
        }

        # 指定 JSON 文件保存路径
        metrics_results_path = f"SWIM_CNNBinaryMNIST17_{fraction}_metrics_results.json"

        # 将字典保存为 JSON 文件
        with open(metrics_results_path, "w") as f:
            json.dump(metrics_dict, f, indent=4)
# Out:
# Epoch: 1/50, Train Loss: 0.0382, Train Accuracy: 0.9869, Test Loss: 0.0270, Test Accuracy: 0.9917
# ==> New best model saved at epoch 1 with Test Accuracy: 0.9917
# TP: 1134.0
# FP: 17.0
# FN: 1.0
# TN: 1011.0
# Accuracy: 0.9917
# Misclassification rate: 0.0083
# Sensitivity (Recall): 0.9991
# Specificity: 0.9835
# Precision: 0.9852
# Negative Predictive Value: 0.9990
# G-mean: 0.9913
# F-measure: 0.9921
# Discriminant Power: 6.1302
# F2-measure: 0.9880
# InvF0.5-measure: 0.9963
# AGF: 0.9921
# Balanced Accuracy: 0.9913
# Matthew's Correlation Coefficient: 0.9834
# Cohen's Kappa: 0.9833
# Youden's Index: 0.9826
# Positive Likelihood Ratio: 60.4173
# Negative Likelihood Ratio: 0.0009
# Epoch: 2/50, Train Loss: 0.0075, Train Accuracy: 0.9978, Test Loss: 0.0107, Test Accuracy: 0.9958
# ==> New best model saved at epoch 2 with Test Accuracy: 0.9958
# TP: 1133.0
# FP: 7.0
# FN: 2.0
# TN: 1021.0
# Accuracy: 0.9958
# Misclassification rate: 0.0042
# Sensitivity (Recall): 0.9982
# Specificity: 0.9932
# Precision: 0.9939
# Negative Predictive Value: 0.9980
# G-mean: 0.9957
# F-measure: 0.9960
# Discriminant Power: 6.2422
# F2-measure: 0.9947
# InvF0.5-measure: 0.9974
# AGF: 0.9960
# Balanced Accuracy: 0.9957
# Matthew's Correlation Coefficient: 0.9917
# Cohen's Kappa: 0.9917
# Youden's Index: 0.9914
# Positive Likelihood Ratio: 146.5984
# Negative Likelihood Ratio: 0.0018
# Epoch: 3/50, Train Loss: 0.0050, Train Accuracy: 0.9984, Test Loss: 0.0211, Test Accuracy: 0.9945
# Epoch: 4/50, Train Loss: 0.0046, Train Accuracy: 0.9980, Test Loss: 0.0353, Test Accuracy: 0.9908
# Epoch: 5/50, Train Loss: 0.0018, Train Accuracy: 0.9994, Test Loss: 0.0170, Test Accuracy: 0.9958
# Epoch: 6/50, Train Loss: 0.0017, Train Accuracy: 0.9996, Test Loss: 0.0160, Test Accuracy: 0.9968
# ==> New best model saved at epoch 6 with Test Accuracy: 0.9968
# TP: 1134.0
# FP: 6.0
# FN: 1.0
# TN: 1022.0
# Accuracy: 0.9968
# Misclassification rate: 0.0032
# Sensitivity (Recall): 0.9991
# Specificity: 0.9942
# Precision: 0.9947
# Negative Predictive Value: 0.9990
# G-mean: 0.9966
# F-measure: 0.9969
# Discriminant Power: 6.7104
# F2-measure: 0.9956
# InvF0.5-measure: 0.9982
# AGF: 0.9969
# Balanced Accuracy: 0.9966
# Matthew's Correlation Coefficient: 0.9935
# Cohen's Kappa: 0.9935
# Youden's Index: 0.9933
# Positive Likelihood Ratio: 171.1824
# Negative Likelihood Ratio: 0.0009
# Epoch: 7/50, Train Loss: 0.0014, Train Accuracy: 0.9994, Test Loss: 0.0146, Test Accuracy: 0.9968
# Epoch: 8/50, Train Loss: 0.0005, Train Accuracy: 0.9999, Test Loss: 0.0232, Test Accuracy: 0.9954
# Epoch: 9/50, Train Loss: 0.0003, Train Accuracy: 0.9999, Test Loss: 0.0319, Test Accuracy: 0.9949
# Epoch: 10/50, Train Loss: 0.0001, Train Accuracy: 1.0000, Test Loss: 0.0215, Test Accuracy: 0.9963
# Epoch: 11/50, Train Loss: 0.0001, Train Accuracy: 1.0000, Test Loss: 0.0286, Test Accuracy: 0.9958
# Epoch: 12/50, Train Loss: 0.0009, Train Accuracy: 0.9996, Test Loss: 0.0601, Test Accuracy: 0.9908
# Epoch: 13/50, Train Loss: 0.0014, Train Accuracy: 0.9995, Test Loss: 0.0241, Test Accuracy: 0.9963
# Epoch: 14/50, Train Loss: 0.0020, Train Accuracy: 0.9994, Test Loss: 0.0359, Test Accuracy: 0.9940
# Epoch: 15/50, Train Loss: 0.0001, Train Accuracy: 1.0000, Test Loss: 0.0258, Test Accuracy: 0.9954
# Epoch: 16/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0257, Test Accuracy: 0.9954
# Epoch: 17/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0304, Test Accuracy: 0.9949
# Epoch: 18/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0300, Test Accuracy: 0.9954
# Epoch: 19/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0281, Test Accuracy: 0.9954
# Epoch: 20/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0314, Test Accuracy: 0.9954
# Epoch: 21/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0311, Test Accuracy: 0.9954
# Epoch: 22/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0320, Test Accuracy: 0.9954
# Epoch: 23/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0310, Test Accuracy: 0.9954
# Epoch: 24/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0365, Test Accuracy: 0.9945
# Epoch: 25/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0338, Test Accuracy: 0.9949
# Epoch: 26/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0315, Test Accuracy: 0.9954
# Epoch: 27/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0324, Test Accuracy: 0.9954
# Epoch: 28/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0328, Test Accuracy: 0.9949
# Epoch: 29/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0326, Test Accuracy: 0.9949
# Epoch: 30/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0314, Test Accuracy: 0.9963
# Epoch: 31/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0312, Test Accuracy: 0.9963
# Epoch: 32/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0359, Test Accuracy: 0.9954
# Epoch: 33/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0333, Test Accuracy: 0.9958
# Epoch: 34/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0358, Test Accuracy: 0.9954
# Epoch: 35/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0358, Test Accuracy: 0.9954
# Epoch: 36/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0351, Test Accuracy: 0.9954
# Epoch: 37/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0336, Test Accuracy: 0.9954
# Epoch: 38/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0342, Test Accuracy: 0.9954
# Epoch: 39/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0381, Test Accuracy: 0.9949
# Epoch: 40/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0380, Test Accuracy: 0.9949
# Epoch: 41/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0369, Test Accuracy: 0.9954
# Epoch: 42/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0386, Test Accuracy: 0.9954
# Epoch: 43/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0399, Test Accuracy: 0.9949
# Epoch: 44/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0384, Test Accuracy: 0.9954
# Epoch: 45/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0386, Test Accuracy: 0.9954
# Epoch: 46/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0410, Test Accuracy: 0.9954
# Epoch: 47/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0428, Test Accuracy: 0.9945
# Epoch: 48/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0430, Test Accuracy: 0.9945
# Epoch: 49/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0429, Test Accuracy: 0.9945
# Epoch: 50/50, Train Loss: 0.0000, Train Accuracy: 1.0000, Test Loss: 0.0431, Test Accuracy: 0.9945
