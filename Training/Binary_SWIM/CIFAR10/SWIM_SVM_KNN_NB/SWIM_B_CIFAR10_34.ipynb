# %%
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
import torchvision
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
import numpy as np
import torch
import matplotlib.pyplot as plt
import sys
import os
sys.path.append(os.path.abspath("/Users/max/MasterThesis/Training/"))

# %%
from Swim_Maha import SwimMaha
fractions = [0.005, 0.01, 0.02, 0.05, 0.1, 0.2]
for frac in range(len(fractions)):
    import torch
    from torch.utils.data import DataLoader, Subset, ConcatDataset, TensorDataset
    from torchvision import datasets, transforms
    import numpy as np

    # CIFAR10 数据归一化参数
    # 数据预处理
    cifar10_transforms = transforms.Compose([
        transforms.ToTensor(), 
        transforms.Normalize((0.4914, 0.4822, 0.4465), (0.247, 0.243, 0.261))
    ])
    # 加载 CIFAR10 数据集
    full_train_dataset = datasets.CIFAR10(
        root="/Users/max/MasterThesisData/CIFAR10", train=True, transform=cifar10_transforms, download=True)
    full_test_dataset = datasets.CIFAR10(
        root="/Users/max/MasterThesisData/CIFAR10", train=False, transform=cifar10_transforms, download=True)

    # 筛选训练集中的标签 3 和 4，并映射标签（标签 3 -> 1，标签 4 -> 0）
    indices3_train = [i for i in range(len(full_train_dataset)) if full_train_dataset.targets[i] == 3]
    indices4_train = [i for i in range(len(full_train_dataset)) if full_train_dataset.targets[i] == 4]

    # 筛选测试集中的标签 3 和 4，并映射标签
    indices3_test = [i for i in range(len(full_test_dataset)) if full_test_dataset.targets[i] == 3]
    indices4_test = [i for i in range(len(full_test_dataset)) if full_test_dataset.targets[i] == 4]

    # 训练集：获取标签为 3 的数据（映射为 1）
    cifar3_train_data = full_train_dataset.data[indices3_train]  # numpy 数组，形状 (n, 32, 32, 3)
    cifar3_train_labels = torch.ones(len(indices3_train), dtype=torch.long)

    # 训练集：获取标签为 4 的数据（映射为 0）
    cifar4_train_data = full_train_dataset.data[indices4_train]
    cifar4_train_labels = torch.zeros(len(indices4_train), dtype=torch.long)

    # 测试集：获取标签为 3 的数据（映射为 1）
    cifar3_test_data = full_test_dataset.data[indices3_test]
    cifar3_test_labels = torch.ones(len(indices3_test), dtype=torch.long)

    # 测试集：获取标签为 4 的数据（映射为 0）
    cifar4_test_data = full_test_dataset.data[indices4_test]
    cifar4_test_labels = torch.zeros(len(indices4_test), dtype=torch.long)

    # 控制不平衡比例，比如这里设定为 0.005（即只选取标签 4 数据中的一小部分）
    fraction = int(fractions[frac] * len(cifar3_train_data))
    selected_indices_4 = np.random.choice(len(cifar4_train_data), fraction, replace=False)
    fraction_cifar4_train_data = cifar4_train_data[selected_indices_4]
    fraction_cifar4_train_labels = cifar4_train_labels[selected_indices_4]

    # 拼接最终的训练和测试数据集
    Final_train_data = np.concatenate([cifar3_train_data, fraction_cifar4_train_data], axis=0)
    Final_train_labels = torch.cat([cifar3_train_labels, fraction_cifar4_train_labels], dim=0)

    Final_test_data = np.concatenate([cifar3_test_data, cifar4_test_data], axis=0)
    Final_test_labels = torch.cat([cifar3_test_labels, cifar4_test_labels], dim=0)

    # 将 numpy 数组转换为 tensor，并调整维度为 (N, C, H, W)
    Final_train_data = torch.from_numpy(Final_train_data).permute(0, 3, 1, 2).float()
    Final_test_data = torch.from_numpy(Final_test_data).permute(0, 3, 1, 2).float()

    # 归一化图像数据：先除以 255，再进行标准化
    # # 创建 TensorDataset
    # Final_train_datasets = TensorDataset(Final_train_data.unsqueeze(3).float() / 255, Final_train_labels)
    # Final_test_datasets = TensorDataset(Final_test_data.unsqueeze(3).float() / 255, Final_test_labels)

    # 创建 TensorDataset
    Final_train_dataset = TensorDataset(Final_train_data.float() / 255, Final_train_labels)
    Final_test_dataset = TensorDataset(Final_test_data.float() / 255, Final_test_labels)

    # 数据加载器
    train_loader = DataLoader(Final_train_dataset, batch_size=64, shuffle=True)
    test_loader = DataLoader(Final_test_dataset, batch_size=64, shuffle=False)

    # 打印数据信息
    print("Number of label 1 in the final training set: ", len(cifar3_train_data))
    print("Number of label 0 in the final training set (after downsampling): ", len(fraction_cifar4_train_data))
    print("Number of label 1 in the final test set: ", len(cifar3_test_data))
    print("Number of label 0 in the final test set: ", len(cifar4_test_data))

    print("Total samples in final training set: ", len(Final_train_dataset))
    print("Total samples in final test set: ", len(Final_test_dataset))

    print("Number of batches in training set: ", len(train_loader))
    print("Number of batches in test set: ", len(test_loader))


    
    ## 获取一个 batch
    images, labels = next(iter(train_loader))

    # 打印张量信息
    print(f"Images shape: {images.shape}")  # (batch_size, 3, 32, 32)
    print(f"Labels shape: {labels.shape}")

    # 将第一张图像的维度转换为 (H, W, C) 并显示
    img = images[0].permute(1, 2, 0).numpy()  # (32, 32, 3)
    plt.imshow(img)  # 对于彩色图像，无需指定 cmap
    plt.title(f"Label: {labels[0].item()}")
    plt.show()

    plt.figure(figsize=(20, 5))
    for i, img_tensor in enumerate(images[:20]):
        # 将每张图像转换为 (H, W, C)
        npimg = img_tensor.permute(1, 2, 0).numpy()
        plt.subplot(2, 10, i+1)
        plt.imshow(npimg)  # 彩色图像，不指定 cmap
        plt.axis('off')
    plt.show()


    X_train = []
    y_train = []

    for batch in train_loader:
        images, labels = batch  # images: (batch_size, 1, 28, 28), labels: (batch_size,)
        if hasattr(images, 'numpy'): # images is tensor
            images = images.numpy()
        # batch_size = 64
        for img, label in zip(images, labels):
            #print(f"Original shape: {img.shape}")  #  
            flattened_img = img.flatten()           
            #print(f"Flattened shape: {flattened_img.shape}")
            X_train.append(flattened_img) # 
            y_train.append(label)


    X_test = [] # features
    y_test = [] # labels
    for batch in test_loader:
        images, labels = batch  # images: (batch_size, 1,28  ,28 ), labels: (batch_size,)
        if hasattr(images, 'numpy'): # images is tensor
            images = images.numpy()
        # batch_size = 64
        for img, label in zip(images, labels):
            flattened_img = img.flatten()           # flatten the image
            X_test.append(flattened_img)
            y_test.append(label)


    X_train = np.array(X_train)
    y_train = np.array(y_train)
    X_test = np.array(X_test)
    y_test = np.array(y_test)
    print("X_train.shape:", X_train.shape)
    print("y_train.shape:", y_train.shape)
    print("X_test.shape:", X_test.shape)
    print("y_test.shape:", y_test.shape)
    from Swim_Maha import SwimMaha
    sw = SwimMaha(sd=0.25,minClass=0)
    numsampels = len(cifar3_train_data) - len(fraction_cifar4_train_data)
    X_train_end, y_train_end = sw.mahaSampling(X_train,y_train,numsampels)
    print("X_train_end.shape:", X_train_end.shape)
    print("y_train_end.shape:", y_train_end.shape)
    X_train = np.concatenate((X_train, X_train_end), axis=0)
    y_train = np.concatenate((y_train, y_train_end), axis=0)
    print("SWIM_X_train.shape:", X_train.shape)
    print("SWIM_y_train.shape:", y_train.shape)
    # training model

    from sklearn import svm
    from sklearn.preprocessing import StandardScaler

    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_test = scaler.transform(X_test)

    clf = svm.SVC(kernel='linear', C=1.0)
    clf.fit(X_train, y_train)
    y_pred = clf.predict(X_test)
    print("y_pred.shape:", y_pred.shape)

    from self_metrics import Binary_got_metrics
    from self_metrics import Binary_got_cofusion_matrix
    from self_metrics import Binary_got_metrics
    TP, FP, FN, TN = Binary_got_cofusion_matrix(y_test, y_pred, labels = [1,0])


    Accuracy, misclassification_rate, Sensitivity, Specificity, Precision, Negative_Predictive_Value, Gmean, Fmean, DPower, F2measure, InvF_05, AGFmeasure, Balanced_Accuracy, MCCmeasure, Kappa, Youden_Index, LR_pos, LR_neg = Binary_got_metrics(TP, FP, FN, TN)
    import json

            # 构造一个包含所有指标数据的字典
    metrics_dict = {
                "Number of label 3 in the final training set": len(cifar3_train_data),
                "Number of label 4 in the final training set (after downsampling)": len(fraction_cifar4_train_data),
                "Number of label 3 in the final test set": len(cifar3_test_data),
                "Number of label 4 in the final test set": len(cifar4_test_data),
                "Total samples in final training set": len(Final_train_dataset),
                "Total samples in final test set": len(Final_test_dataset),
                "Number of batches in training set": len(train_loader),
                "Number of batches in test set": len(test_loader),
                "TP": TP,
                "FP": FP,
                "FN": FN,
                "TN": TN,
                "Accuracy": round(Accuracy, 4),
                "Misclassification rate": round(misclassification_rate, 4),
                "Sensitivity (Recall)": round(Sensitivity, 4),
                "Specificity": round(Specificity, 4),
                "Precision": round(Precision, 4),
                "Negative Predictive Value": round(Negative_Predictive_Value, 4),
                "G-mean": round(Gmean, 4),
                "F-measure": round(Fmean, 4),
                "Discriminant Power (DP)": round(DPower, 4),
                "F2-measure": round(F2measure, 4),
                "InvF0.5-measure": round(InvF_05, 4),
                "AGF": round(AGFmeasure, 4),
                "Balanced Accuracy": round(Balanced_Accuracy, 4),
                "Matthew's Correlation Coefficient (MCC)": round(MCCmeasure, 4),
                "Cohen's Kappa": round(Kappa, 4),
                "Youden's Index": round(Youden_Index, 4),
                "Positive Likelihood Ratio (LR+)": round(LR_pos, 4),
                "Negative Likelihood Ratio (LR-)": round(LR_neg, 4)
            }

            # 指定 JSON 文件保存路径
    metrics_results_path = f"SWIM_SVMBinaryCIFAR1034_{fraction}_metrics_results.json"
    # 将字典保存为 JSON 文件
    with open(metrics_results_path, "w") as f:
        json.dump(metrics_dict, f, indent=4)
# Out:
# Number of label 1 in the final training set:  5000
# Number of label 0 in the final training set (after downsampling):  25
# Number of label 1 in the final test set:  1000
# Number of label 0 in the final test set:  1000
# Total samples in final training set:  5025
# Total samples in final test set:  2000
# Number of batches in training set:  79
# Number of batches in test set:  32
# Images shape: torch.Size([64, 3, 32, 32])
# Labels shape: torch.Size([64])
# X_train.shape: (5025, 3072)
# y_train.shape: (5025,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# The majority class has linearly dependent columns. Rerun the sampling subSpaceSampling=True. Return original data.
# X_train_end.shape: (5025, 3072)
# y_train_end.shape: (5025,)
# SWIM_X_train.shape: (10050, 3072)
# SWIM_y_train.shape: (10050,)
# y_pred.shape: (2000,)
# TP: 994
# FP: 986
# FN: 6
# TN: 14
# Accuracy: 0.5040
# Misclassification rate: 0.4960
# Sensitivity (Recall): 0.9940
# Specificity: 0.0140
# Precision: 0.5020
# Negative Predictive Value: 0.7000
# G-mean: 0.1180
# F-measure: 0.6671
# Discriminant Power: 0.4716
# F2-measure: 0.5572
# InvF0.5-measure: 0.8311
# AGF: 0.6805
# Balanced Accuracy: 0.5040
# Matthew's Correlation Coefficient: 0.0402
# Cohen's Kappa: 0.0080
# Youden's Index: 0.0080
# Positive Likelihood Ratio: 1.0081
# Negative Likelihood Ratio: 0.4286
# Number of label 1 in the final training set:  5000
# Number of label 0 in the final training set (after downsampling):  50
# Number of label 1 in the final test set:  1000
# Number of label 0 in the final test set:  1000
# Total samples in final training set:  5050
# Total samples in final test set:  2000
# Number of batches in training set:  79
# Number of batches in test set:  32
# Images shape: torch.Size([64, 3, 32, 32])
# Labels shape: torch.Size([64])
# X_train.shape: (5050, 3072)
# y_train.shape: (5050,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# The majority class has linearly dependent columns. Rerun the sampling subSpaceSampling=True. Return original data.
# X_train_end.shape: (5050, 3072)
# y_train_end.shape: (5050,)
# SWIM_X_train.shape: (10100, 3072)
# SWIM_y_train.shape: (10100,)
# y_pred.shape: (2000,)
# TP: 984
# FP: 940
# FN: 16
# TN: 60
# Accuracy: 0.5220
# Misclassification rate: 0.4780
# Sensitivity (Recall): 0.9840
# Specificity: 0.0600
# Precision: 0.5114
# Negative Predictive Value: 0.7895
# G-mean: 0.2430
# F-measure: 0.6731
# Discriminant Power: 0.7539
# F2-measure: 0.5658
# InvF0.5-measure: 0.8305
# AGF: 0.6855
# Balanced Accuracy: 0.5220
# Matthew's Correlation Coefficient: 0.1151
# Cohen's Kappa: 0.0440
# Youden's Index: 0.0440
# Positive Likelihood Ratio: 1.0468
# Negative Likelihood Ratio: 0.2667
# Number of label 1 in the final training set:  5000
# Number of label 0 in the final training set (after downsampling):  100
# Number of label 1 in the final test set:  1000
# Number of label 0 in the final test set:  1000
# Total samples in final training set:  5100
# Total samples in final test set:  2000
# Number of batches in training set:  80
# Number of batches in test set:  32
# Images shape: torch.Size([64, 3, 32, 32])
# Labels shape: torch.Size([64])
# X_train.shape: (5100, 3072)
# y_train.shape: (5100,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# The majority class has linearly dependent columns. Rerun the sampling subSpaceSampling=True. Return original data.
# X_train_end.shape: (5100, 3072)
# y_train_end.shape: (5100,)
# SWIM_X_train.shape: (10200, 3072)
# SWIM_y_train.shape: (10200,)
# y_pred.shape: (2000,)
# TP: 968
# FP: 839
# FN: 32
# TN: 161
# Accuracy: 0.5645
# Misclassification rate: 0.4355
# Sensitivity (Recall): 0.9680
# Specificity: 0.1610
# Precision: 0.5357
# Negative Predictive Value: 0.8342
# G-mean: 0.3948
# F-measure: 0.6897
# Discriminant Power: 0.9696
# F2-measure: 0.5882
# InvF0.5-measure: 0.8335
# AGF: 0.7002
# Balanced Accuracy: 0.5645
# Matthew's Correlation Coefficient: 0.2184
# Cohen's Kappa: 0.1290
# Youden's Index: 0.1290
# Positive Likelihood Ratio: 1.1538
# Negative Likelihood Ratio: 0.1988
# Number of label 1 in the final training set:  5000
# Number of label 0 in the final training set (after downsampling):  250
# Number of label 1 in the final test set:  1000
# Number of label 0 in the final test set:  1000
# Total samples in final training set:  5250
# Total samples in final test set:  2000
# Number of batches in training set:  83
# Number of batches in test set:  32
# Images shape: torch.Size([64, 3, 32, 32])
# Labels shape: torch.Size([64])
# X_train.shape: (5250, 3072)
# y_train.shape: (5250,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# The majority class has linearly dependent columns. Rerun the sampling subSpaceSampling=True. Return original data.
# X_train_end.shape: (5250, 3072)
# y_train_end.shape: (5250,)
# SWIM_X_train.shape: (10500, 3072)
# SWIM_y_train.shape: (10500,)
# y_pred.shape: (2000,)
# TP: 919
# FP: 795
# FN: 81
# TN: 205
# Accuracy: 0.5620
# Misclassification rate: 0.4380
# Sensitivity (Recall): 0.9190
# Specificity: 0.2050
# Precision: 0.5362
# Negative Predictive Value: 0.7168
# G-mean: 0.4340
# F-measure: 0.6772
# Discriminant Power: 0.5919
# F2-measure: 0.5849
# InvF0.5-measure: 0.8042
# AGF: 0.6858
# Balanced Accuracy: 0.5620
# Matthew's Correlation Coefficient: 0.1771
# Cohen's Kappa: 0.1240
# Youden's Index: 0.1240
# Positive Likelihood Ratio: 1.1560
# Negative Likelihood Ratio: 0.3951
# Number of label 1 in the final training set:  5000
# Number of label 0 in the final training set (after downsampling):  500
# Number of label 1 in the final test set:  1000
# Number of label 0 in the final test set:  1000
# Total samples in final training set:  5500
# Total samples in final test set:  2000
# Number of batches in training set:  86
# Number of batches in test set:  32
# Images shape: torch.Size([64, 3, 32, 32])
# Labels shape: torch.Size([64])
# X_train.shape: (5500, 3072)
# y_train.shape: (5500,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# The majority class has linearly dependent columns. Rerun the sampling subSpaceSampling=True. Return original data.
# X_train_end.shape: (5500, 3072)
# y_train_end.shape: (5500,)
# SWIM_X_train.shape: (11000, 3072)
# SWIM_y_train.shape: (11000,)
# y_pred.shape: (2000,)
# TP: 840
# FP: 678
# FN: 160
# TN: 322
# Accuracy: 0.5810
# Misclassification rate: 0.4190
# Sensitivity (Recall): 0.8400
# Specificity: 0.3220
# Precision: 0.5534
# Negative Predictive Value: 0.6680
# G-mean: 0.5201
# F-measure: 0.6672
# Discriminant Power: 0.5037
# F2-measure: 0.5939
# InvF0.5-measure: 0.7611
# AGF: 0.6723
# Balanced Accuracy: 0.5810
# Matthew's Correlation Coefficient: 0.1894
# Cohen's Kappa: 0.1620
# Youden's Index: 0.1620
# Positive Likelihood Ratio: 1.2389
# Negative Likelihood Ratio: 0.4969
# Number of label 1 in the final training set:  5000
# Number of label 0 in the final training set (after downsampling):  1000
# Number of label 1 in the final test set:  1000
# Number of label 0 in the final test set:  1000
# Total samples in final training set:  6000
# Total samples in final test set:  2000
# Number of batches in training set:  94
# Number of batches in test set:  32
# Images shape: torch.Size([64, 3, 32, 32])
# Labels shape: torch.Size([64])
# X_train.shape: (6000, 3072)
# y_train.shape: (6000,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# The majority class has linearly dependent columns. Rerun the sampling subSpaceSampling=True. Return original data.
# X_train_end.shape: (6000, 3072)
# y_train_end.shape: (6000,)
# SWIM_X_train.shape: (12000, 3072)
# SWIM_y_train.shape: (12000,)
# y_pred.shape: (2000,)
# TP: 808
# FP: 596
# FN: 192
# TN: 404
# Accuracy: 0.6060
# Misclassification rate: 0.3940
# Sensitivity (Recall): 0.8080
# Specificity: 0.4040
# Precision: 0.5755
# Negative Predictive Value: 0.6779
# G-mean: 0.5713
# F-measure: 0.6722
# Discriminant Power: 0.5779
# F2-measure: 0.6106
# InvF0.5-measure: 0.7476
# AGF: 0.6757
# Balanced Accuracy: 0.6060
# Matthew's Correlation Coefficient: 0.2318
# Cohen's Kappa: 0.2120
# Youden's Index: 0.2120
# Positive Likelihood Ratio: 1.3557
# Negative Likelihood Ratio: 0.4752

# %%
from Swim_Maha import SwimMaha
fractions = [0.005, 0.01, 0.02, 0.05, 0.1, 0.2]
for frac in range(len(fractions)):
    import torch
    from torch.utils.data import DataLoader, Subset, ConcatDataset, TensorDataset
    from torchvision import datasets, transforms
    import numpy as np

    # CIFAR10 数据归一化参数
    # 数据预处理
    cifar10_transforms = transforms.Compose([
        transforms.ToTensor(), 
        transforms.Normalize((0.4914, 0.4822, 0.4465), (0.247, 0.243, 0.261))
    ])
    # 加载 CIFAR10 数据集
    full_train_dataset = datasets.CIFAR10(
        root="/Users/max/MasterThesisData/CIFAR10", train=True, transform=cifar10_transforms, download=True)
    full_test_dataset = datasets.CIFAR10(
        root="/Users/max/MasterThesisData/CIFAR10", train=False, transform=cifar10_transforms, download=True)

    # 筛选训练集中的标签 3 和 4，并映射标签（标签 3 -> 1，标签 4 -> 0）
    indices3_train = [i for i in range(len(full_train_dataset)) if full_train_dataset.targets[i] == 3]
    indices4_train = [i for i in range(len(full_train_dataset)) if full_train_dataset.targets[i] == 4]

    # 筛选测试集中的标签 3 和 4，并映射标签
    indices3_test = [i for i in range(len(full_test_dataset)) if full_test_dataset.targets[i] == 3]
    indices4_test = [i for i in range(len(full_test_dataset)) if full_test_dataset.targets[i] == 4]

    # 训练集：获取标签为 3 的数据（映射为 1）
    cifar3_train_data = full_train_dataset.data[indices3_train]  # numpy 数组，形状 (n, 32, 32, 3)
    cifar3_train_labels = torch.ones(len(indices3_train), dtype=torch.long)

    # 训练集：获取标签为 4 的数据（映射为 0）
    cifar4_train_data = full_train_dataset.data[indices4_train]
    cifar4_train_labels = torch.zeros(len(indices4_train), dtype=torch.long)

    # 测试集：获取标签为 3 的数据（映射为 1）
    cifar3_test_data = full_test_dataset.data[indices3_test]
    cifar3_test_labels = torch.ones(len(indices3_test), dtype=torch.long)

    # 测试集：获取标签为 4 的数据（映射为 0）
    cifar4_test_data = full_test_dataset.data[indices4_test]
    cifar4_test_labels = torch.zeros(len(indices4_test), dtype=torch.long)

    # 控制不平衡比例，比如这里设定为 0.005（即只选取标签 4 数据中的一小部分）
    fraction = int(fractions[frac] * len(cifar3_train_data))
    selected_indices_4 = np.random.choice(len(cifar4_train_data), fraction, replace=False)
    fraction_cifar4_train_data = cifar4_train_data[selected_indices_4]
    fraction_cifar4_train_labels = cifar4_train_labels[selected_indices_4]

    # 拼接最终的训练和测试数据集
    Final_train_data = np.concatenate([cifar3_train_data, fraction_cifar4_train_data], axis=0)
    Final_train_labels = torch.cat([cifar3_train_labels, fraction_cifar4_train_labels], dim=0)

    Final_test_data = np.concatenate([cifar3_test_data, cifar4_test_data], axis=0)
    Final_test_labels = torch.cat([cifar3_test_labels, cifar4_test_labels], dim=0)

    # 将 numpy 数组转换为 tensor，并调整维度为 (N, C, H, W)
    Final_train_data = torch.from_numpy(Final_train_data).permute(0, 3, 1, 2).float()
    Final_test_data = torch.from_numpy(Final_test_data).permute(0, 3, 1, 2).float()

    # 归一化图像数据：先除以 255，再进行标准化
    # # 创建 TensorDataset
    # Final_train_datasets = TensorDataset(Final_train_data.unsqueeze(3).float() / 255, Final_train_labels)
    # Final_test_datasets = TensorDataset(Final_test_data.unsqueeze(3).float() / 255, Final_test_labels)

    # 创建 TensorDataset
    Final_train_dataset = TensorDataset(Final_train_data.float() / 255, Final_train_labels)
    Final_test_dataset = TensorDataset(Final_test_data.float() / 255, Final_test_labels)

    # 数据加载器
    train_loader = DataLoader(Final_train_dataset, batch_size=64, shuffle=True)
    test_loader = DataLoader(Final_test_dataset, batch_size=64, shuffle=False)

    # 打印数据信息
    print("Number of label 1 in the final training set: ", len(cifar3_train_data))
    print("Number of label 0 in the final training set (after downsampling): ", len(fraction_cifar4_train_data))
    print("Number of label 1 in the final test set: ", len(cifar3_test_data))
    print("Number of label 0 in the final test set: ", len(cifar4_test_data))

    print("Total samples in final training set: ", len(Final_train_dataset))
    print("Total samples in final test set: ", len(Final_test_dataset))

    print("Number of batches in training set: ", len(train_loader))
    print("Number of batches in test set: ", len(test_loader))


    
    ## 获取一个 batch
    images, labels = next(iter(train_loader))

    # 打印张量信息
    print(f"Images shape: {images.shape}")  # (batch_size, 3, 32, 32)
    print(f"Labels shape: {labels.shape}")

    # 将第一张图像的维度转换为 (H, W, C) 并显示
    img = images[0].permute(1, 2, 0).numpy()  # (32, 32, 3)
    plt.imshow(img)  # 对于彩色图像，无需指定 cmap
    plt.title(f"Label: {labels[0].item()}")
    plt.show()

    plt.figure(figsize=(20, 5))
    for i, img_tensor in enumerate(images[:20]):
        # 将每张图像转换为 (H, W, C)
        npimg = img_tensor.permute(1, 2, 0).numpy()
        plt.subplot(2, 10, i+1)
        plt.imshow(npimg)  # 彩色图像，不指定 cmap
        plt.axis('off')
    plt.show()


    X_train = []
    y_train = []

    for batch in train_loader:
        images, labels = batch  # images: (batch_size, 1, 28, 28), labels: (batch_size,)
        if hasattr(images, 'numpy'): # images is tensor
            images = images.numpy()
        # batch_size = 64
        for img, label in zip(images, labels):
            #print(f"Original shape: {img.shape}")  #  
            flattened_img = img.flatten()           
            #print(f"Flattened shape: {flattened_img.shape}")
            X_train.append(flattened_img) # 
            y_train.append(label)


    X_test = [] # features
    y_test = [] # labels
    for batch in test_loader:
        images, labels = batch  # images: (batch_size, 1,28  ,28 ), labels: (batch_size,)
        if hasattr(images, 'numpy'): # images is tensor
            images = images.numpy()
        # batch_size = 64
        for img, label in zip(images, labels):
            flattened_img = img.flatten()           # flatten the image
            X_test.append(flattened_img)
            y_test.append(label)


    X_train = np.array(X_train)
    y_train = np.array(y_train)
    X_test = np.array(X_test)
    y_test = np.array(y_test)
    print("X_train.shape:", X_train.shape)
    print("y_train.shape:", y_train.shape)
    print("X_test.shape:", X_test.shape)
    print("y_test.shape:", y_test.shape)
    from Swim_Maha import SwimMaha
    sw = SwimMaha(sd=0.25,minClass=0)
    numsampels = len(cifar3_train_data) - len(fraction_cifar4_train_data)
    X_train_end, y_train_end = sw.mahaSampling(X_train,y_train,numsampels)
    print("X_train_end.shape:", X_train_end.shape)
    print("y_train_end.shape:", y_train_end.shape)
    X_train = np.concatenate((X_train, X_train_end), axis=0)
    y_train = np.concatenate((y_train, y_train_end), axis=0)
    print("SWIM_X_train.shape:", X_train.shape)
    print("SWIM_y_train.shape:", y_train.shape)
    # training model
    from sklearn import svm
    from sklearn.preprocessing import StandardScaler
    from sklearn.neighbors import KNeighborsClassifier

    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_test = scaler.transform(X_test)
    from sklearn.naive_bayes import GaussianNB

    # 创建一个Gaussian Naive Bayes分类器
    nb = GaussianNB()
    nb.fit(X_train, y_train)
    y_pred = nb.predict(X_test)
    print("y_pred.shape:", y_pred.shape)


    from self_metrics import Binary_got_metrics
    from self_metrics import Binary_got_cofusion_matrix
    from self_metrics import Binary_got_metrics
    TP, FP, FN, TN = Binary_got_cofusion_matrix(y_test, y_pred, labels = [1,0])


    Accuracy, misclassification_rate, Sensitivity, Specificity, Precision, Negative_Predictive_Value, Gmean, Fmean, DPower, F2measure, InvF_05, AGFmeasure, Balanced_Accuracy, MCCmeasure, Kappa, Youden_Index, LR_pos, LR_neg = Binary_got_metrics(TP, FP, FN, TN)
    import json

            # 构造一个包含所有指标数据的字典
    metrics_dict = {
                "Number of label 3 in the final training set": len(cifar3_train_data),
                "Number of label 4 in the final training set (after downsampling)": len(fraction_cifar4_train_data),
                "Number of label 3 in the final test set": len(cifar3_test_data),
                "Number of label 4 in the final test set": len(cifar4_test_data),
                "Total samples in final training set": len(Final_train_dataset),
                "Total samples in final test set": len(Final_test_dataset),
                "Number of batches in training set": len(train_loader),
                "Number of batches in test set": len(test_loader),
                "TP": TP,
                "FP": FP,
                "FN": FN,
                "TN": TN,
                "Accuracy": round(Accuracy, 4),
                "Misclassification rate": round(misclassification_rate, 4),
                "Sensitivity (Recall)": round(Sensitivity, 4),
                "Specificity": round(Specificity, 4),
                "Precision": round(Precision, 4),
                "Negative Predictive Value": round(Negative_Predictive_Value, 4),
                "G-mean": round(Gmean, 4),
                "F-measure": round(Fmean, 4),
                "Discriminant Power (DP)": round(DPower, 4),
                "F2-measure": round(F2measure, 4),
                "InvF0.5-measure": round(InvF_05, 4),
                "AGF": round(AGFmeasure, 4),
                "Balanced Accuracy": round(Balanced_Accuracy, 4),
                "Matthew's Correlation Coefficient (MCC)": round(MCCmeasure, 4),
                "Cohen's Kappa": round(Kappa, 4),
                "Youden's Index": round(Youden_Index, 4),
                "Positive Likelihood Ratio (LR+)": round(LR_pos, 4),
                "Negative Likelihood Ratio (LR-)": round(LR_neg, 4)
            }

            # 指定 JSON 文件保存路径
    metrics_results_path = f"SWIM_NavieBayesBinaryCIFAR1034_{fraction}_metrics_results.json"
    # 将字典保存为 JSON 文件
    with open(metrics_results_path, "w") as f:
        json.dump(metrics_dict, f, indent=4)
# Out:
# Number of label 1 in the final training set:  5000
# Number of label 0 in the final training set (after downsampling):  25
# Number of label 1 in the final test set:  1000
# Number of label 0 in the final test set:  1000
# Total samples in final training set:  5025
# Total samples in final test set:  2000
# Number of batches in training set:  79
# Number of batches in test set:  32
# Images shape: torch.Size([64, 3, 32, 32])
# Labels shape: torch.Size([64])
# X_train.shape: (5025, 3072)
# y_train.shape: (5025,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# The majority class has linearly dependent columns. Rerun the sampling subSpaceSampling=True. Return original data.
# X_train_end.shape: (5025, 3072)
# y_train_end.shape: (5025,)
# SWIM_X_train.shape: (10050, 3072)
# SWIM_y_train.shape: (10050,)
# y_pred.shape: (2000,)
# TP: 717
# FP: 418
# FN: 283
# TN: 582
# Accuracy: 0.6495
# Misclassification rate: 0.3505
# Sensitivity (Recall): 0.7170
# Specificity: 0.5820
# Precision: 0.6317
# Negative Predictive Value: 0.6728
# G-mean: 0.6460
# F-measure: 0.6717
# Discriminant Power: 0.6950
# F2-measure: 0.6471
# InvF0.5-measure: 0.6981
# AGF: 0.6721
# Balanced Accuracy: 0.6495
# Matthew's Correlation Coefficient: 0.3018
# Cohen's Kappa: 0.2990
# Youden's Index: 0.2990
# Positive Likelihood Ratio: 1.7153
# Negative Likelihood Ratio: 0.4863
# Number of label 1 in the final training set:  5000
# Number of label 0 in the final training set (after downsampling):  50
# Number of label 1 in the final test set:  1000
# Number of label 0 in the final test set:  1000
# Total samples in final training set:  5050
# Total samples in final test set:  2000
# Number of batches in training set:  79
# Number of batches in test set:  32
# Images shape: torch.Size([64, 3, 32, 32])
# Labels shape: torch.Size([64])
# X_train.shape: (5050, 3072)
# y_train.shape: (5050,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# The majority class has linearly dependent columns. Rerun the sampling subSpaceSampling=True. Return original data.
# X_train_end.shape: (5050, 3072)
# y_train_end.shape: (5050,)
# SWIM_X_train.shape: (10100, 3072)
# SWIM_y_train.shape: (10100,)
# y_pred.shape: (2000,)
# TP: 670
# FP: 309
# FN: 330
# TN: 691
# Accuracy: 0.6805
# Misclassification rate: 0.3195
# Sensitivity (Recall): 0.6700
# Specificity: 0.6910
# Precision: 0.6844
# Negative Predictive Value: 0.6768
# G-mean: 0.6804
# F-measure: 0.6771
# Discriminant Power: 0.8342
# F2-measure: 0.6814
# InvF0.5-measure: 0.6728
# AGF: 0.6771
# Balanced Accuracy: 0.6805
# Matthew's Correlation Coefficient: 0.3611
# Cohen's Kappa: 0.3610
# Youden's Index: 0.3610
# Positive Likelihood Ratio: 2.1683
# Negative Likelihood Ratio: 0.4776
# Number of label 1 in the final training set:  5000
# Number of label 0 in the final training set (after downsampling):  100
# Number of label 1 in the final test set:  1000
# Number of label 0 in the final test set:  1000
# Total samples in final training set:  5100
# Total samples in final test set:  2000
# Number of batches in training set:  80
# Number of batches in test set:  32
# Images shape: torch.Size([64, 3, 32, 32])
# Labels shape: torch.Size([64])
# X_train.shape: (5100, 3072)
# y_train.shape: (5100,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# The majority class has linearly dependent columns. Rerun the sampling subSpaceSampling=True. Return original data.
# X_train_end.shape: (5100, 3072)
# y_train_end.shape: (5100,)
# SWIM_X_train.shape: (10200, 3072)
# SWIM_y_train.shape: (10200,)
# y_pred.shape: (2000,)
# TP: 562
# FP: 243
# FN: 438
# TN: 757
# Accuracy: 0.6595
# Misclassification rate: 0.3405
# Sensitivity (Recall): 0.5620
# Specificity: 0.7570
# Precision: 0.6981
# Negative Predictive Value: 0.6335
# G-mean: 0.6523
# F-measure: 0.6227
# Discriminant Power: 0.7639
# F2-measure: 0.6659
# InvF0.5-measure: 0.5848
# AGF: 0.6240
# Balanced Accuracy: 0.6595
# Matthew's Correlation Coefficient: 0.3252
# Cohen's Kappa: 0.3190
# Youden's Index: 0.3190
# Positive Likelihood Ratio: 2.3128
# Negative Likelihood Ratio: 0.5786
# Number of label 1 in the final training set:  5000
# Number of label 0 in the final training set (after downsampling):  250
# Number of label 1 in the final test set:  1000
# Number of label 0 in the final test set:  1000
# Total samples in final training set:  5250
# Total samples in final test set:  2000
# Number of batches in training set:  83
# Number of batches in test set:  32
# Images shape: torch.Size([64, 3, 32, 32])
# Labels shape: torch.Size([64])
# X_train.shape: (5250, 3072)
# y_train.shape: (5250,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# The majority class has linearly dependent columns. Rerun the sampling subSpaceSampling=True. Return original data.
# X_train_end.shape: (5250, 3072)
# y_train_end.shape: (5250,)
# SWIM_X_train.shape: (10500, 3072)
# SWIM_y_train.shape: (10500,)
# y_pred.shape: (2000,)
# TP: 580
# FP: 237
# FN: 420
# TN: 763
# Accuracy: 0.6715
# Misclassification rate: 0.3285
# Sensitivity (Recall): 0.5800
# Specificity: 0.7630
# Precision: 0.7099
# Negative Predictive Value: 0.6450
# G-mean: 0.6652
# F-measure: 0.6384
# Discriminant Power: 0.8226
# F2-measure: 0.6795
# InvF0.5-measure: 0.6020
# AGF: 0.6396
# Balanced Accuracy: 0.6715
# Matthew's Correlation Coefficient: 0.3489
# Cohen's Kappa: 0.3430
# Youden's Index: 0.3430
# Positive Likelihood Ratio: 2.4473
# Negative Likelihood Ratio: 0.5505
# Number of label 1 in the final training set:  5000
# Number of label 0 in the final training set (after downsampling):  500
# Number of label 1 in the final test set:  1000
# Number of label 0 in the final test set:  1000
# Total samples in final training set:  5500
# Total samples in final test set:  2000
# Number of batches in training set:  86
# Number of batches in test set:  32
# Images shape: torch.Size([64, 3, 32, 32])
# Labels shape: torch.Size([64])
# X_train.shape: (5500, 3072)
# y_train.shape: (5500,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# The majority class has linearly dependent columns. Rerun the sampling subSpaceSampling=True. Return original data.
# X_train_end.shape: (5500, 3072)
# y_train_end.shape: (5500,)
# SWIM_X_train.shape: (11000, 3072)
# SWIM_y_train.shape: (11000,)
# y_pred.shape: (2000,)
# TP: 586
# FP: 243
# FN: 414
# TN: 757
# Accuracy: 0.6715
# Misclassification rate: 0.3285
# Sensitivity (Recall): 0.5860
# Specificity: 0.7570
# Precision: 0.7069
# Negative Predictive Value: 0.6465
# G-mean: 0.6660
# F-measure: 0.6408
# Discriminant Power: 0.8180
# F2-measure: 0.6789
# InvF0.5-measure: 0.6068
# AGF: 0.6418
# Balanced Accuracy: 0.6715
# Matthew's Correlation Coefficient: 0.3481
# Cohen's Kappa: 0.3430
# Youden's Index: 0.3430
# Positive Likelihood Ratio: 2.4115
# Negative Likelihood Ratio: 0.5469
# Number of label 1 in the final training set:  5000
# Number of label 0 in the final training set (after downsampling):  1000
# Number of label 1 in the final test set:  1000
# Number of label 0 in the final test set:  1000
# Total samples in final training set:  6000
# Total samples in final test set:  2000
# Number of batches in training set:  94
# Number of batches in test set:  32
# Images shape: torch.Size([64, 3, 32, 32])
# Labels shape: torch.Size([64])
# X_train.shape: (6000, 3072)
# y_train.shape: (6000,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# The majority class has linearly dependent columns. Rerun the sampling subSpaceSampling=True. Return original data.
# X_train_end.shape: (6000, 3072)
# y_train_end.shape: (6000,)
# SWIM_X_train.shape: (12000, 3072)
# SWIM_y_train.shape: (12000,)
# y_pred.shape: (2000,)
# TP: 569
# FP: 223
# FN: 431
# TN: 777
# Accuracy: 0.6730
# Misclassification rate: 0.3270
# Sensitivity (Recall): 0.5690
# Specificity: 0.7770
# Precision: 0.7184
# Negative Predictive Value: 0.6432
# G-mean: 0.6649
# F-measure: 0.6350
# Discriminant Power: 0.8414
# F2-measure: 0.6826
# InvF0.5-measure: 0.5937
# AGF: 0.6366
# Balanced Accuracy: 0.6730
# Matthew's Correlation Coefficient: 0.3537
# Cohen's Kappa: 0.3460
# Youden's Index: 0.3460
# Positive Likelihood Ratio: 2.5516
# Negative Likelihood Ratio: 0.5547

# %%
from Swim_Maha import SwimMaha
fractions = [0.005, 0.01, 0.02, 0.05, 0.1, 0.2]
for frac in range(len(fractions)):
    import torch
    from torch.utils.data import DataLoader, Subset, ConcatDataset, TensorDataset
    from torchvision import datasets, transforms
    import numpy as np

    # CIFAR10 数据归一化参数
    # 数据预处理
    cifar10_transforms = transforms.Compose([
        transforms.ToTensor(), 
        transforms.Normalize((0.4914, 0.4822, 0.4465), (0.247, 0.243, 0.261))
    ])
    # 加载 CIFAR10 数据集
    full_train_dataset = datasets.CIFAR10(
        root="/Users/max/MasterThesisData/CIFAR10", train=True, transform=cifar10_transforms, download=True)
    full_test_dataset = datasets.CIFAR10(
        root="/Users/max/MasterThesisData/CIFAR10", train=False, transform=cifar10_transforms, download=True)

    # 筛选训练集中的标签 3 和 4，并映射标签（标签 3 -> 1，标签 4 -> 0）
    indices3_train = [i for i in range(len(full_train_dataset)) if full_train_dataset.targets[i] == 3]
    indices4_train = [i for i in range(len(full_train_dataset)) if full_train_dataset.targets[i] == 4]

    # 筛选测试集中的标签 3 和 4，并映射标签
    indices3_test = [i for i in range(len(full_test_dataset)) if full_test_dataset.targets[i] == 3]
    indices4_test = [i for i in range(len(full_test_dataset)) if full_test_dataset.targets[i] == 4]

    # 训练集：获取标签为 3 的数据（映射为 1）
    cifar3_train_data = full_train_dataset.data[indices3_train]  # numpy 数组，形状 (n, 32, 32, 3)
    cifar3_train_labels = torch.ones(len(indices3_train), dtype=torch.long)

    # 训练集：获取标签为 4 的数据（映射为 0）
    cifar4_train_data = full_train_dataset.data[indices4_train]
    cifar4_train_labels = torch.zeros(len(indices4_train), dtype=torch.long)

    # 测试集：获取标签为 3 的数据（映射为 1）
    cifar3_test_data = full_test_dataset.data[indices3_test]
    cifar3_test_labels = torch.ones(len(indices3_test), dtype=torch.long)

    # 测试集：获取标签为 4 的数据（映射为 0）
    cifar4_test_data = full_test_dataset.data[indices4_test]
    cifar4_test_labels = torch.zeros(len(indices4_test), dtype=torch.long)

    # 控制不平衡比例，比如这里设定为 0.005（即只选取标签 4 数据中的一小部分）
    fraction = int(fractions[frac] * len(cifar3_train_data))
    selected_indices_4 = np.random.choice(len(cifar4_train_data), fraction, replace=False)
    fraction_cifar4_train_data = cifar4_train_data[selected_indices_4]
    fraction_cifar4_train_labels = cifar4_train_labels[selected_indices_4]

    # 拼接最终的训练和测试数据集
    Final_train_data = np.concatenate([cifar3_train_data, fraction_cifar4_train_data], axis=0)
    Final_train_labels = torch.cat([cifar3_train_labels, fraction_cifar4_train_labels], dim=0)

    Final_test_data = np.concatenate([cifar3_test_data, cifar4_test_data], axis=0)
    Final_test_labels = torch.cat([cifar3_test_labels, cifar4_test_labels], dim=0)

    # 将 numpy 数组转换为 tensor，并调整维度为 (N, C, H, W)
    Final_train_data = torch.from_numpy(Final_train_data).permute(0, 3, 1, 2).float()
    Final_test_data = torch.from_numpy(Final_test_data).permute(0, 3, 1, 2).float()

    # 归一化图像数据：先除以 255，再进行标准化
    # # 创建 TensorDataset
    # Final_train_datasets = TensorDataset(Final_train_data.unsqueeze(3).float() / 255, Final_train_labels)
    # Final_test_datasets = TensorDataset(Final_test_data.unsqueeze(3).float() / 255, Final_test_labels)

    # 创建 TensorDataset
    Final_train_dataset = TensorDataset(Final_train_data.float() / 255, Final_train_labels)
    Final_test_dataset = TensorDataset(Final_test_data.float() / 255, Final_test_labels)

    # 数据加载器
    train_loader = DataLoader(Final_train_dataset, batch_size=64, shuffle=True)
    test_loader = DataLoader(Final_test_dataset, batch_size=64, shuffle=False)

    # 打印数据信息
    print("Number of label 1 in the final training set: ", len(cifar3_train_data))
    print("Number of label 0 in the final training set (after downsampling): ", len(fraction_cifar4_train_data))
    print("Number of label 1 in the final test set: ", len(cifar3_test_data))
    print("Number of label 0 in the final test set: ", len(cifar4_test_data))

    print("Total samples in final training set: ", len(Final_train_dataset))
    print("Total samples in final test set: ", len(Final_test_dataset))

    print("Number of batches in training set: ", len(train_loader))
    print("Number of batches in test set: ", len(test_loader))


    
    ## 获取一个 batch
    images, labels = next(iter(train_loader))

    # 打印张量信息
    print(f"Images shape: {images.shape}")  # (batch_size, 3, 32, 32)
    print(f"Labels shape: {labels.shape}")

    # 将第一张图像的维度转换为 (H, W, C) 并显示
    img = images[0].permute(1, 2, 0).numpy()  # (32, 32, 3)
    plt.imshow(img)  # 对于彩色图像，无需指定 cmap
    plt.title(f"Label: {labels[0].item()}")
    plt.show()

    plt.figure(figsize=(20, 5))
    for i, img_tensor in enumerate(images[:20]):
        # 将每张图像转换为 (H, W, C)
        npimg = img_tensor.permute(1, 2, 0).numpy()
        plt.subplot(2, 10, i+1)
        plt.imshow(npimg)  # 彩色图像，不指定 cmap
        plt.axis('off')
    plt.show()


    X_train = []
    y_train = []

    for batch in train_loader:
        images, labels = batch  # images: (batch_size, 1, 28, 28), labels: (batch_size,)
        if hasattr(images, 'numpy'): # images is tensor
            images = images.numpy()
        # batch_size = 64
        for img, label in zip(images, labels):
            #print(f"Original shape: {img.shape}")  #  
            flattened_img = img.flatten()           
            #print(f"Flattened shape: {flattened_img.shape}")
            X_train.append(flattened_img) # 
            y_train.append(label)


    X_test = [] # features
    y_test = [] # labels
    for batch in test_loader:
        images, labels = batch  # images: (batch_size, 1,28  ,28 ), labels: (batch_size,)
        if hasattr(images, 'numpy'): # images is tensor
            images = images.numpy()
        # batch_size = 64
        for img, label in zip(images, labels):
            flattened_img = img.flatten()           # flatten the image
            X_test.append(flattened_img)
            y_test.append(label)


    X_train = np.array(X_train)
    y_train = np.array(y_train)
    X_test = np.array(X_test)
    y_test = np.array(y_test)
    print("X_train.shape:", X_train.shape)
    print("y_train.shape:", y_train.shape)
    print("X_test.shape:", X_test.shape)
    print("y_test.shape:", y_test.shape)
    from Swim_Maha import SwimMaha
    sw = SwimMaha(sd=0.25,minClass=0)
    numsampels = len(cifar3_train_data) - len(fraction_cifar4_train_data)
    X_train_end, y_train_end = sw.mahaSampling(X_train,y_train,numsampels)
    print("X_train_end.shape:", X_train_end.shape)
    print("y_train_end.shape:", y_train_end.shape)
    X_train = np.concatenate((X_train, X_train_end), axis=0)
    y_train = np.concatenate((y_train, y_train_end), axis=0)
    print("SWIM_X_train.shape:", X_train.shape)
    print("SWIM_y_train.shape:", y_train.shape)
    # training model
    from sklearn import svm
    from sklearn.preprocessing import StandardScaler
    from sklearn.neighbors import KNeighborsClassifier

    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_test = scaler.transform(X_test)
    # 创建一个KNN分类器，设定邻居数为5（你可以根据需要调整n_neighbors的值）
    knn = KNeighborsClassifier(n_neighbors=5)
    knn.fit(X_train, y_train)
    y_pred = knn.predict(X_test)
    print("y_pred.shape:", y_pred.shape)



    from self_metrics import Binary_got_metrics
    from self_metrics import Binary_got_cofusion_matrix
    from self_metrics import Binary_got_metrics
    TP, FP, FN, TN = Binary_got_cofusion_matrix(y_test, y_pred, labels = [1,0])


    Accuracy, misclassification_rate, Sensitivity, Specificity, Precision, Negative_Predictive_Value, Gmean, Fmean, DPower, F2measure, InvF_05, AGFmeasure, Balanced_Accuracy, MCCmeasure, Kappa, Youden_Index, LR_pos, LR_neg = Binary_got_metrics(TP, FP, FN, TN)
    import json

            # 构造一个包含所有指标数据的字典
    metrics_dict = {
                "Number of label 3 in the final training set": len(cifar3_train_data),
                "Number of label 4 in the final training set (after downsampling)": len(fraction_cifar4_train_data),
                "Number of label 3 in the final test set": len(cifar3_test_data),
                "Number of label 4 in the final test set": len(cifar4_test_data),
                "Total samples in final training set": len(Final_train_dataset),
                "Total samples in final test set": len(Final_test_dataset),
                "Number of batches in training set": len(train_loader),
                "Number of batches in test set": len(test_loader),
                "TP": TP,
                "FP": FP,
                "FN": FN,
                "TN": TN,
                "Accuracy": round(Accuracy, 4),
                "Misclassification rate": round(misclassification_rate, 4),
                "Sensitivity (Recall)": round(Sensitivity, 4),
                "Specificity": round(Specificity, 4),
                "Precision": round(Precision, 4),
                "Negative Predictive Value": round(Negative_Predictive_Value, 4),
                "G-mean": round(Gmean, 4),
                "F-measure": round(Fmean, 4),
                "Discriminant Power (DP)": round(DPower, 4),
                "F2-measure": round(F2measure, 4),
                "InvF0.5-measure": round(InvF_05, 4),
                "AGF": round(AGFmeasure, 4),
                "Balanced Accuracy": round(Balanced_Accuracy, 4),
                "Matthew's Correlation Coefficient (MCC)": round(MCCmeasure, 4),
                "Cohen's Kappa": round(Kappa, 4),
                "Youden's Index": round(Youden_Index, 4),
                "Positive Likelihood Ratio (LR+)": round(LR_pos, 4),
                "Negative Likelihood Ratio (LR-)": round(LR_neg, 4)
            }

            # 指定 JSON 文件保存路径
    metrics_results_path = f"SWIM_KNNBinaryCIFAR1034_{fraction}_metrics_results.json"
    # 将字典保存为 JSON 文件
    with open(metrics_results_path, "w") as f:
        json.dump(metrics_dict, f, indent=4)
# Out:
# Number of label 1 in the final training set:  5000
# Number of label 0 in the final training set (after downsampling):  25
# Number of label 1 in the final test set:  1000
# Number of label 0 in the final test set:  1000
# Total samples in final training set:  5025
# Total samples in final test set:  2000
# Number of batches in training set:  79
# Number of batches in test set:  32
# Images shape: torch.Size([64, 3, 32, 32])
# Labels shape: torch.Size([64])
# X_train.shape: (5025, 3072)
# y_train.shape: (5025,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# The majority class has linearly dependent columns. Rerun the sampling subSpaceSampling=True. Return original data.
# X_train_end.shape: (5025, 3072)
# y_train_end.shape: (5025,)
# SWIM_X_train.shape: (10050, 3072)
# SWIM_y_train.shape: (10050,)
# y_pred.shape: (2000,)
# TP: 998
# FP: 996
# FN: 2
# TN: 4
# Accuracy: 0.5010
# Misclassification rate: 0.4990
# Sensitivity (Recall): 0.9980
# Specificity: 0.0040
# Precision: 0.5005
# Negative Predictive Value: 0.6667
# G-mean: 0.0632
# F-measure: 0.6667
# Discriminant Power: 0.3833
# F2-measure: 0.5559
# InvF0.5-measure: 0.8325
# AGF: 0.6803
# Balanced Accuracy: 0.5010
# Matthew's Correlation Coefficient: 0.0183
# Cohen's Kappa: 0.0020
# Youden's Index: 0.0020
# Positive Likelihood Ratio: 1.0020
# Negative Likelihood Ratio: 0.5000
# Number of label 1 in the final training set:  5000
# Number of label 0 in the final training set (after downsampling):  50
# Number of label 1 in the final test set:  1000
# Number of label 0 in the final test set:  1000
# Total samples in final training set:  5050
# Total samples in final test set:  2000
# Number of batches in training set:  79
# Number of batches in test set:  32
# Images shape: torch.Size([64, 3, 32, 32])
# Labels shape: torch.Size([64])
# X_train.shape: (5050, 3072)
# y_train.shape: (5050,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# The majority class has linearly dependent columns. Rerun the sampling subSpaceSampling=True. Return original data.
# X_train_end.shape: (5050, 3072)
# y_train_end.shape: (5050,)
# SWIM_X_train.shape: (10100, 3072)
# SWIM_y_train.shape: (10100,)
# y_pred.shape: (2000,)
# TP: 991
# FP: 925
# FN: 9
# TN: 75
# Accuracy: 0.5330
# Misclassification rate: 0.4670
# Sensitivity (Recall): 0.9910
# Specificity: 0.0750
# Precision: 0.5172
# Negative Predictive Value: 0.8929
# G-mean: 0.2726
# F-measure: 0.6797
# Discriminant Power: 1.2070
# F2-measure: 0.5719
# InvF0.5-measure: 0.8376
# AGF: 0.6921
# Balanced Accuracy: 0.5330
# Matthew's Correlation Coefficient: 0.1645
# Cohen's Kappa: 0.0660
# Youden's Index: 0.0660
# Positive Likelihood Ratio: 1.0714
# Negative Likelihood Ratio: 0.1200
# Number of label 1 in the final training set:  5000
# Number of label 0 in the final training set (after downsampling):  100
# Number of label 1 in the final test set:  1000
# Number of label 0 in the final test set:  1000
# Total samples in final training set:  5100
# Total samples in final test set:  2000
# Number of batches in training set:  80
# Number of batches in test set:  32
# Images shape: torch.Size([64, 3, 32, 32])
# Labels shape: torch.Size([64])
# X_train.shape: (5100, 3072)
# y_train.shape: (5100,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# The majority class has linearly dependent columns. Rerun the sampling subSpaceSampling=True. Return original data.
# X_train_end.shape: (5100, 3072)
# y_train_end.shape: (5100,)
# SWIM_X_train.shape: (10200, 3072)
# SWIM_y_train.shape: (10200,)
# y_pred.shape: (2000,)
# TP: 974
# FP: 836
# FN: 26
# TN: 164
# Accuracy: 0.5690
# Misclassification rate: 0.4310
# Sensitivity (Recall): 0.9740
# Specificity: 0.1640
# Precision: 0.5381
# Negative Predictive Value: 0.8632
# G-mean: 0.3997
# F-measure: 0.6932
# Discriminant Power: 1.0997
# F2-measure: 0.5910
# InvF0.5-measure: 0.8382
# AGF: 0.7038
# Balanced Accuracy: 0.5690
# Matthew's Correlation Coefficient: 0.2353
# Cohen's Kappa: 0.1380
# Youden's Index: 0.1380
# Positive Likelihood Ratio: 1.1651
# Negative Likelihood Ratio: 0.1585
# Number of label 1 in the final training set:  5000
# Number of label 0 in the final training set (after downsampling):  250
# Number of label 1 in the final test set:  1000
# Number of label 0 in the final test set:  1000
# Total samples in final training set:  5250
# Total samples in final test set:  2000
# Number of batches in training set:  83
# Number of batches in test set:  32
# Images shape: torch.Size([64, 3, 32, 32])
# Labels shape: torch.Size([64])
# X_train.shape: (5250, 3072)
# y_train.shape: (5250,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# The majority class has linearly dependent columns. Rerun the sampling subSpaceSampling=True. Return original data.
# X_train_end.shape: (5250, 3072)
# y_train_end.shape: (5250,)
# SWIM_X_train.shape: (10500, 3072)
# SWIM_y_train.shape: (10500,)
# y_pred.shape: (2000,)
# TP: 967
# FP: 779
# FN: 33
# TN: 221
# Accuracy: 0.5940
# Misclassification rate: 0.4060
# Sensitivity (Recall): 0.9670
# Specificity: 0.2210
# Precision: 0.5538
# Negative Predictive Value: 0.8701
# G-mean: 0.4623
# F-measure: 0.7043
# Discriminant Power: 1.1676
# F2-measure: 0.6056
# InvF0.5-measure: 0.8415
# AGF: 0.7138
# Balanced Accuracy: 0.5940
# Matthew's Correlation Coefficient: 0.2823
# Cohen's Kappa: 0.1880
# Youden's Index: 0.1880
# Positive Likelihood Ratio: 1.2413
# Negative Likelihood Ratio: 0.1493
# Number of label 1 in the final training set:  5000
# Number of label 0 in the final training set (after downsampling):  500
# Number of label 1 in the final test set:  1000
# Number of label 0 in the final test set:  1000
# Total samples in final training set:  5500
# Total samples in final test set:  2000
# Number of batches in training set:  86
# Number of batches in test set:  32
# Images shape: torch.Size([64, 3, 32, 32])
# Labels shape: torch.Size([64])
# X_train.shape: (5500, 3072)
# y_train.shape: (5500,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# The majority class has linearly dependent columns. Rerun the sampling subSpaceSampling=True. Return original data.
# X_train_end.shape: (5500, 3072)
# y_train_end.shape: (5500,)
# SWIM_X_train.shape: (11000, 3072)
# SWIM_y_train.shape: (11000,)
# y_pred.shape: (2000,)
# TP: 903
# FP: 563
# FN: 97
# TN: 437
# Accuracy: 0.6700
# Misclassification rate: 0.3300
# Sensitivity (Recall): 0.9030
# Specificity: 0.4370
# Precision: 0.6160
# Negative Predictive Value: 0.8184
# G-mean: 0.6282
# F-measure: 0.7324
# Discriminant Power: 1.0903
# F2-measure: 0.6578
# InvF0.5-measure: 0.8260
# AGF: 0.7371
# Balanced Accuracy: 0.6700
# Matthew's Correlation Coefficient: 0.3843
# Cohen's Kappa: 0.3400
# Youden's Index: 0.3400
# Positive Likelihood Ratio: 1.6039
# Negative Likelihood Ratio: 0.2220
# Number of label 1 in the final training set:  5000
# Number of label 0 in the final training set (after downsampling):  1000
# Number of label 1 in the final test set:  1000
# Number of label 0 in the final test set:  1000
# Total samples in final training set:  6000
# Total samples in final test set:  2000
# Number of batches in training set:  94
# Number of batches in test set:  32
# Images shape: torch.Size([64, 3, 32, 32])
# Labels shape: torch.Size([64])
# X_train.shape: (6000, 3072)
# y_train.shape: (6000,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# The majority class has linearly dependent columns. Rerun the sampling subSpaceSampling=True. Return original data.
# X_train_end.shape: (6000, 3072)
# y_train_end.shape: (6000,)
# SWIM_X_train.shape: (12000, 3072)
# SWIM_y_train.shape: (12000,)
# y_pred.shape: (2000,)
# TP: 814
# FP: 390
# FN: 186
# TN: 610
# Accuracy: 0.7120
# Misclassification rate: 0.2880
# Sensitivity (Recall): 0.8140
# Specificity: 0.6100
# Precision: 0.6761
# Negative Predictive Value: 0.7663
# G-mean: 0.7047
# F-measure: 0.7387
# Discriminant Power: 1.0605
# F2-measure: 0.6998
# InvF0.5-measure: 0.7821
# AGF: 0.7398
# Balanced Accuracy: 0.7120
# Matthew's Correlation Coefficient: 0.4331
# Cohen's Kappa: 0.4240
# Youden's Index: 0.4240
# Positive Likelihood Ratio: 2.0872
# Negative Likelihood Ratio: 0.3049
