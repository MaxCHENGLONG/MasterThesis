# %% [markdown]
# # Binary FashionMNIST Label 3 and label 4 /  3->1 4->0 / 3 is positive 4 is negative CNN

# %%
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
import torchvision
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
import numpy as np
import torch
import matplotlib.pyplot as plt
import sys
import os
sys.path.append(os.path.abspath("/Users/max/MasterThesis/Training/"))

# %%
import torch
from torch.utils.data import DataLoader, Subset, ConcatDataset, TensorDataset
from torchvision import datasets, transforms
import numpy as np

# 数据预处理
mnist34_transforms = transforms.Compose([
    transforms.ToTensor(), 
    transforms.Normalize((0.1307,), (0.3081,))
])

# 加载 FashionMNIST 数据集
full_train_datasets = datasets.FashionMNIST(root="/Users/max/MasterThesisData/FashionMNIST", train=True, transform=mnist34_transforms, download=True)
full_test_datasets = datasets.FashionMNIST(root="/Users/max/MasterThesisData/FashionMNIST", train=False, transform=mnist34_transforms, download=True)

# 选取标签为 3 和 4 的索引
indices3_train = [i for i in range(len(full_train_datasets)) if full_train_datasets.targets[i] == 3]
indices4_train = [i for i in range(len(full_train_datasets)) if full_train_datasets.targets[i] == 4]

indices3_test = [i for i in range(len(full_test_datasets)) if full_test_datasets.targets[i] == 3]
indices4_test = [i for i in range(len(full_test_datasets)) if full_test_datasets.targets[i] == 4]

# 获取训练集中标签为 3 和 4 的数据
mnist3_train_data = full_train_datasets.data[indices3_train]
mnist3_train_labels = torch.ones(len(indices3_train), dtype=torch.long)  # 标签 3 映射为 1 

mnist4_train_data = full_train_datasets.data[indices4_train]
mnist4_train_labels = torch.zeros(len(indices4_train), dtype=torch.long)  # 标签 4 映射为 0

# 获取测试集中标签为 3 和 4 的数据
mnist3_test_data = full_test_datasets.data[indices3_test]
mnist3_test_labels = torch.ones(len(indices3_test), dtype=torch.long)  # 标签 3 映射为 1 

mnist4_test_data = full_test_datasets.data[indices4_test]
mnist4_test_labels = torch.zeros(len(indices4_test), dtype=torch.long)  # 标签 4 映射为 0

# we can set the imbalanced ratio 0.005, 0.01, 0.02, 0.05, 0.1, 0.2
fraction = int(0.20 * len(mnist3_train_data))  ### control the fraction of the data to be used
selected_indices_4 = np.random.choice(len(mnist4_train_data), fraction, replace=False)

fraction_mnist4_train_data = mnist4_train_data[selected_indices_4]
fraction_mnist4_train_labels = mnist4_train_labels[selected_indices_4]

# 创建最终的训练和测试数据集
Final_train_data = torch.cat([mnist3_train_data, fraction_mnist4_train_data], dim=0)
Final_train_labels = torch.cat([mnist3_train_labels, fraction_mnist4_train_labels], dim=0)

Final_test_data = torch.cat([mnist3_test_data, mnist4_test_data], dim=0)
Final_test_labels = torch.cat([mnist3_test_labels, mnist4_test_labels], dim=0)

# 创建 TensorDataset
Final_train_datasets = TensorDataset(Final_train_data.unsqueeze(1).float() / 255, Final_train_labels)
Final_test_datasets = TensorDataset(Final_test_data.unsqueeze(1).float() / 255, Final_test_labels)

# 数据加载器
train_loader = DataLoader(Final_train_datasets, batch_size=64, shuffle=True)
test_loader = DataLoader(Final_test_datasets, batch_size=64, shuffle=False)

# 打印信息
print("Number of label 3 in the final training set: ", len(mnist3_train_data))
print("Number of label 4 in the final training set (after downsampling): ", len(fraction_mnist4_train_data))
print("Number of label 3 in the final test set: ", len(mnist3_test_data))
print("Number of label 4 in the final test set: ", len(mnist4_test_data))

print("Total samples in final training set: ", len(Final_train_datasets))
print("Total samples in final test set: ", len(Final_test_datasets))

print("Number of batches in training set: ", len(train_loader))
print("Number of batches in test set: ", len(test_loader))
# Out:
# Number of label 3 in the final training set:  6000
# Number of label 4 in the final training set (after downsampling):  1200
# Number of label 3 in the final test set:  1000
# Number of label 4 in the final test set:  1000
# Total samples in final training set:  7200
# Total samples in final test set:  2000
# Number of batches in training set:  113
# Number of batches in test set:  32

# %%
# 获取一个 batch
images, labels = next(iter(train_loader))

# 查看 Tensor 形状
print(f"Images shape: {images.shape}")  # 形状为 (batch_size, channels, height, width)
print(f"Labels shape: {labels.shape}")  # 形状为 (batch_size,)

# 查看第一个样本的 Tensor 值
print(f"First image tensor:\n{images[0]}")  # 打印第一个样本的 Tensor 数据
print(f"First image label: {labels[0]}")  # 打印第一个样本的标签

# 如果需要转换回 NumPy 并可视化：
import matplotlib.pyplot as plt

# 转换为 NumPy 并显示
plt.imshow(images[0].squeeze().numpy(), cmap="gray")
plt.title(f"Label: {labels[0].item()}")
plt.show()


import numpy as np

 # 指定图片大小，图像大小为20宽、5高的绘图(单位为英寸inch)
plt.figure(figsize=(20, 5)) 
for i, imgs in enumerate(images[:20]):
    # 维度缩减
    npimg = np.squeeze(imgs.numpy())
    # 将整个figure分成2行10列，绘制第i+1个子图。
    plt.subplot(2, 10, i+1)
    plt.imshow(npimg, cmap=plt.cm.binary)
    plt.axis('off')
# Out:
# Images shape: torch.Size([64, 1, 28, 28])
# Labels shape: torch.Size([64])
# First image tensor:
# tensor([[[0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.1176, 0.0000, 0.0000, 0.0000, 0.0235,
#           0.0314, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.3922, 0.7882, 0.9216, 0.8941, 0.9137, 0.9373, 0.8980,
#           0.8980, 0.5922, 0.0314, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.7961, 1.0000, 0.9451, 0.9255, 0.9647, 0.9608, 0.9608, 0.9255,
#           0.9255, 0.9922, 0.9294, 0.0863, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.9020, 0.9412, 0.9137, 0.9216, 0.9020, 0.9020, 0.9059, 0.9137,
#           0.9176, 0.8980, 1.0000, 0.5412, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0196,
#           0.9529, 0.9373, 0.9294, 0.9176, 0.9137, 0.9098, 0.9059, 0.9098,
#           0.9176, 0.9176, 0.9882, 0.7804, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.1451,
#           0.9961, 0.9490, 0.9294, 0.9137, 0.9098, 0.9137, 0.9176, 0.9216,
#           0.9176, 0.9255, 0.9765, 0.9373, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.2627,
#           0.9882, 0.9725, 0.9569, 0.9451, 0.9333, 0.9373, 0.9373, 0.9373,
#           0.9412, 0.9490, 0.9608, 0.9216, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.3490,
#           1.0000, 0.9176, 0.9529, 0.9529, 0.9333, 0.9412, 0.9451, 0.9255,
#           1.0000, 0.7216, 0.8941, 0.9961, 0.2275, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.5569,
#           1.0000, 0.8078, 0.9294, 0.9608, 0.9333, 0.9451, 0.9490, 0.9137,
#           1.0000, 0.4863, 0.7255, 1.0000, 0.5843, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.6275,
#           1.0000, 0.6667, 0.9961, 0.9490, 0.9412, 0.9451, 0.9490, 0.9176,
#           1.0000, 0.5804, 0.4588, 1.0000, 0.6078, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.2000, 1.0000, 0.9333, 0.9490, 0.9451, 0.9451, 0.9255,
#           0.9804, 0.8627, 0.0000, 0.0392, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.3255, 1.0000, 0.9294, 0.9490, 0.9451, 0.9451, 0.9373,
#           0.9686, 0.9882, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0157,
#           0.0000, 0.4000, 1.0000, 0.9294, 0.9490, 0.9451, 0.9451, 0.9412,
#           0.9647, 1.0000, 0.0000, 0.0000, 0.0039, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0078,
#           0.0000, 0.4627, 1.0000, 0.9294, 0.9490, 0.9451, 0.9451, 0.9373,
#           0.9529, 0.9020, 0.0000, 0.0000, 0.0039, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0039,
#           0.0000, 0.5412, 1.0000, 0.9294, 0.9490, 0.9451, 0.9451, 0.9412,
#           0.9451, 0.9373, 0.0431, 0.0000, 0.0078, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.6667, 0.9961, 0.9333, 0.9490, 0.9451, 0.9490, 0.9490,
#           0.9373, 0.9922, 0.1686, 0.0000, 0.0118, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.7529, 1.0000, 0.9333, 0.9490, 0.9490, 0.9490, 0.9569,
#           0.9294, 1.0000, 0.2510, 0.0000, 0.0157, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.7490, 1.0000, 0.9333, 0.9490, 0.9490, 0.9490, 0.9529,
#           0.9294, 1.0000, 0.3255, 0.0000, 0.0157, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.7569, 0.9961, 0.9333, 0.9490, 0.9490, 0.9490, 0.9529,
#           0.9333, 1.0000, 0.4588, 0.0000, 0.0078, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.7608, 0.9922, 0.9333, 0.9490, 0.9490, 0.9529, 0.9569,
#           0.9333, 1.0000, 0.5961, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.7725, 0.9922, 0.9333, 0.9490, 0.9490, 0.9529, 0.9569,
#           0.9333, 1.0000, 0.6784, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.7725, 0.9882, 0.9333, 0.9490, 0.9490, 0.9529, 0.9569,
#           0.9333, 0.9961, 0.7490, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.7686, 0.9843, 0.9294, 0.9490, 0.9529, 0.9529, 0.9569,
#           0.9373, 0.9922, 0.7961, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.7843, 0.9804, 0.9294, 0.9490, 0.9529, 0.9529, 0.9569,
#           0.9412, 0.9804, 0.8745, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.8314, 0.9843, 0.9294, 0.9529, 0.9490, 0.9569, 0.9608,
#           0.9412, 0.9686, 0.8000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0039,
#           0.0000, 0.7686, 0.9765, 0.9137, 0.9373, 0.9255, 0.9255, 0.9412,
#           0.9255, 0.9647, 0.7647, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0039,
#           0.0000, 0.4706, 1.0000, 0.9725, 0.9843, 1.0000, 1.0000, 1.0000,
#           0.9922, 1.0000, 0.7725, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0039,
#           0.0000, 0.0000, 0.5804, 0.5725, 0.6039, 0.6314, 0.5569, 0.5255,
#           0.5255, 0.5569, 0.0510, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000]]])
# First image label: 1

# %%
from torchinfo import summary
import torch
import torch.nn as nn
from CNN1 import BinaryCNN1
# 将模型转移到GPU中（我们模型运行均在GPU中进行）
model = BinaryCNN1().to(device)
summary(model)
# Out:
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# BinaryCNN1                               --
# ├─Conv2d: 1-1                            320
# ├─MaxPool2d: 1-2                         --
# ├─Conv2d: 1-3                            18,496
# ├─MaxPool2d: 1-4                         --
# ├─Linear: 1-5                            102,464
# ├─Linear: 1-6                            130
# =================================================================
# Total params: 121,410
# Trainable params: 121,410
# Non-trainable params: 0
# =================================================================

# %%
# define the optimizer and loss function
import torch.optim as optimizer
from self_metrics import Binary_got_metrics
loss_function = nn.CrossEntropyLoss()
learning_rate = 0.001
optimizer = optimizer.Adam(model.parameters(), lr=learning_rate)

# model training
def train(dataloader, model, loss_function, optimizer):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    train_loss, train_accuracy = 0, 0
    for images, labels in dataloader:
        images, labels = images.to(device), labels.to(device)
        # Compute prediction error
        prediction = model(images)
        loss = loss_function(prediction, labels)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        train_loss += loss.item()
        train_accuracy += (prediction.argmax(1) == labels).type(torch.float).sum().item()

    train_loss /= num_batches
    train_accuracy /= size

    return train_loss, train_accuracy



# model evaluation
def test(dataloader, model, loss_function):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    test_loss, test_accuracy = 0, 0
    # 1(1) is positive, 0(7) is negative
    # TP: 1 classified as 1
    # TN: 0 classified as 0
    # FP: 0 classified as 1
    # FN: 1 classified as 0
    TP, TN, FP, FN = 0, 0, 0, 0
    with torch.no_grad():
        for images, labels in dataloader:
            images, labels = images.to(device), labels.to(device)
            prediction = model(images)
            test_loss += loss_function(prediction, labels).item()
            test_accuracy += (prediction.argmax(1) == labels).type(torch.float).sum().item()
            TP += ((prediction.argmax(1) == 1) & (labels == 1)).type(torch.float).sum().item()
            TN += ((prediction.argmax(1) == 0) & (labels == 0)).type(torch.float).sum().item()
            FP += ((prediction.argmax(1) == 1) & (labels == 0)).type(torch.float).sum().item()
            FN += ((prediction.argmax(1) == 0) & (labels == 1)).type(torch.float).sum().item()


    test_loss /= num_batches
    test_accuracy /= size
    return test_loss, test_accuracy, TP, TN, FP, FN

# training the model
epochs = 50
train_loss_list = []
train_accuracy_list = []
test_loss_list = []
test_accuracy_list = []

best_model_TP = 0
best_model_TN = 0
best_model_FP = 0
best_model_FN = 0
best_test_accuracy = 0.0 # for saving the best model
for epoch in range(epochs):
    model.train()
    train_loss, train_accuracy = train(train_loader, model, loss_function, optimizer)
    model.eval()
    test_loss, test_accuracy,TP, TN, FP, FN  = test(test_loader, model, loss_function)
    train_loss_list.append(train_loss)
    train_accuracy_list.append(train_accuracy)
    test_loss_list.append(test_loss)
    test_accuracy_list.append(test_accuracy)

    print(f"Epoch: {epoch+1}/{epochs}, Train Loss: {train_loss:.4f}, Train Accuracy: {train_accuracy:.4f}, Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.4f}") 

    if test_accuracy > best_test_accuracy:
        best_test_accuracy = test_accuracy
        best_model_TP = TP
        best_model_TN = TN
        best_model_FP = FP
        best_model_FN = FN
        save_path = f"BinaryFashionMNIST34_{fraction}.pth"
        torch.save(model.state_dict(), save_path)
        print(f"==> New best model saved at epoch {epoch+1} with Test Accuracy: {test_accuracy:.4f}")
        #print(f"==> TP: {TP}, TN: {TN}, FP: {FP}, FN: {FN}")
        Accuracy, misclassification_rate, Sensitivity, Specificity, Precision, Negative_Predictive_Value, Gmean, Fmean, DPower, F2measure, InvF_05, AGFmeasure, Balanced_Accuracy, MCCmeasure, Kappa, Youden_Index, LR_pos, LR_neg = Binary_got_metrics(best_model_TP, best_model_FP, best_model_FN, best_model_TN)
        # metrics_results_path = f"BinaryMNIST17_{fraction}_metrics_results.txt"
        # with open(metrics_results_path, "w") as f:
        #     print("Number of label 1 in the final training set: ", len(mnist1_train_data), file=f)
        #     print("Number of label 7 in the final training set (after downsampling): ", len(fraction_mnist7_train_data), file=f)
        #     print("Number of label 1 in the final test set: ", len(mnist1_test_data), file=f)
        #     print("Number of label 7 in the final test set: ", len(mnist7_test_data), file=f)

        #     print("Total samples in final training set: ", len(Final_train_datasets), file=f)
        #     print("Total samples in final test set: ", len(Final_test_datasets), file=f)

        #     print("Number of batches in training set: ", len(train_loader), file=f)
        #     print("Number of batches in test set: ", len(test_loader), file=f)
        #     print(f"TP: {TP}", file=f)
        #     print(f"FP: {FP}", file=f)
        #     print(f"FN: {FN}", file=f)
        #     print(f"TN: {TN}", file=f)
        #     print(f"Accuracy: {Accuracy:.4f}", file=f)
        #     print(f"Misclassification rate: {misclassification_rate:.4f}", file=f)
        #     print(f"Sensitivity (Recall): {Sensitivity:.4f}", file=f)
        #     print(f"Specificity: {Specificity:.4f}", file=f)
        #     print(f"Precision: {Precision:.4f}", file=f)
        #     print(f"Negative Predictive Value: {Negative_Predictive_Value:.4f}", file=f)
        #     print(f"G-mean: {Gmean:.4f}", file=f)
        #     print(f"F-measure: {Fmean:.4f}", file=f)
        #     print(f"Discriminant Power (DP): {DPower:.4f}", file=f)
        #     print(f"F2-measure: {F2measure:.4f}", file=f)
        #     print(f"InvF0.5-measure: {InvF_05:.4f}", file=f)
        #     print(f"AGF: {AGFmeasure:.4f}", file=f)
        #     print(f"Balanced Accuracy: {Balanced_Accuracy:.4f}", file=f)
        #     print(f"Matthew's Correlation Coefficient (MCC): {MCCmeasure:.4f}", file=f)
        #     print(f"Cohen's Kappa: {Kappa:.4f}", file=f)
        #     print(f"Youden's Index: {Youden_Index:.4f}", file=f)
        #     print(f"Positive Likelihood Ratio (LR+): {LR_pos:.4f}", file=f)
        #     print(f"Negative Likelihood Ratio (LR-): {LR_neg:.4f}", file=f)
        import json

        # 构造一个包含所有指标数据的字典
        metrics_dict = {
            "Number of label 3 in the final training set": len(mnist3_train_data),
            "Number of label 4 in the final training set (after downsampling)": len(fraction_mnist4_train_data),
            "Number of label 3 in the final test set": len(mnist3_test_data),
            "Number of label 4 in the final test set": len(mnist4_test_data),
            "Total samples in final training set": len(Final_train_datasets),
            "Total samples in final test set": len(Final_test_datasets),
            "Number of batches in training set": len(train_loader),
            "Number of batches in test set": len(test_loader),
            "TP": TP,
            "FP": FP,
            "FN": FN,
            "TN": TN,
            "Accuracy": round(Accuracy, 4),
            "Misclassification rate": round(misclassification_rate, 4),
            "Sensitivity (Recall)": round(Sensitivity, 4),
            "Specificity": round(Specificity, 4),
            "Precision": round(Precision, 4),
            "Negative Predictive Value": round(Negative_Predictive_Value, 4),
            "G-mean": round(Gmean, 4),
            "F-measure": round(Fmean, 4),
            "Discriminant Power (DP)": round(DPower, 4),
            "F2-measure": round(F2measure, 4),
            "InvF0.5-measure": round(InvF_05, 4),
            "AGF": round(AGFmeasure, 4),
            "Balanced Accuracy": round(Balanced_Accuracy, 4),
            "Matthew's Correlation Coefficient (MCC)": round(MCCmeasure, 4),
            "Cohen's Kappa": round(Kappa, 4),
            "Youden's Index": round(Youden_Index, 4),
            "Positive Likelihood Ratio (LR+)": round(LR_pos, 4),
            "Negative Likelihood Ratio (LR-)": round(LR_neg, 4)
        }

        # 指定 JSON 文件保存路径
        metrics_results_path = f"BinaryFashionMNIST34_{fraction}_metrics_results.json"

        # 将字典保存为 JSON 文件
        with open(metrics_results_path, "w") as f:
            json.dump(metrics_dict, f, indent=4)
# Out:
# Epoch: 1/50, Train Loss: 0.1933, Train Accuracy: 0.9285, Test Loss: 0.2847, Test Accuracy: 0.8870
# ==> New best model saved at epoch 1 with Test Accuracy: 0.8870
# TP: 996.0
# FP: 222.0
# FN: 4.0
# TN: 778.0
# Accuracy: 0.8870
# Misclassification rate: 0.1130
# Sensitivity (Recall): 0.9960
# Specificity: 0.7780
# Precision: 0.8177
# Negative Predictive Value: 0.9949
# G-mean: 0.8803
# F-measure: 0.8981
# Discriminant Power: 3.7333
# F2-measure: 0.8481
# InvF0.5-measure: 0.9544
# AGF: 0.8997
# Balanced Accuracy: 0.8870
# Matthew's Correlation Coefficient: 0.7931
# Cohen's Kappa: 0.7740
# Youden's Index: 0.7740
# Positive Likelihood Ratio: 4.4865
# Negative Likelihood Ratio: 0.0051
# Epoch: 2/50, Train Loss: 0.0945, Train Accuracy: 0.9658, Test Loss: 0.1341, Test Accuracy: 0.9445
# ==> New best model saved at epoch 2 with Test Accuracy: 0.9445
# TP: 978.0
# FP: 89.0
# FN: 22.0
# TN: 911.0
# Accuracy: 0.9445
# Misclassification rate: 0.0555
# Sensitivity (Recall): 0.9780
# Specificity: 0.9110
# Precision: 0.9166
# Negative Predictive Value: 0.9764
# G-mean: 0.9439
# F-measure: 0.9463
# Discriminant Power: 3.3743
# F2-measure: 0.9282
# InvF0.5-measure: 0.9651
# AGF: 0.9465
# Balanced Accuracy: 0.9445
# Matthew's Correlation Coefficient: 0.8910
# Cohen's Kappa: 0.8890
# Youden's Index: 0.8890
# Positive Likelihood Ratio: 10.9888
# Negative Likelihood Ratio: 0.0241
# Epoch: 3/50, Train Loss: 0.0814, Train Accuracy: 0.9690, Test Loss: 0.1771, Test Accuracy: 0.9315
# Epoch: 4/50, Train Loss: 0.0730, Train Accuracy: 0.9718, Test Loss: 0.1728, Test Accuracy: 0.9350
# Epoch: 5/50, Train Loss: 0.0684, Train Accuracy: 0.9750, Test Loss: 0.1690, Test Accuracy: 0.9395
# Epoch: 6/50, Train Loss: 0.0606, Train Accuracy: 0.9774, Test Loss: 0.1205, Test Accuracy: 0.9495
# ==> New best model saved at epoch 6 with Test Accuracy: 0.9495
# TP: 986.0
# FP: 87.0
# FN: 14.0
# TN: 913.0
# Accuracy: 0.9495
# Misclassification rate: 0.0505
# Sensitivity (Recall): 0.9860
# Specificity: 0.9130
# Precision: 0.9189
# Negative Predictive Value: 0.9849
# G-mean: 0.9488
# F-measure: 0.9513
# Discriminant Power: 3.6418
# F2-measure: 0.9316
# InvF0.5-measure: 0.9718
# AGF: 0.9515
# Balanced Accuracy: 0.9495
# Matthew's Correlation Coefficient: 0.9014
# Cohen's Kappa: 0.8990
# Youden's Index: 0.8990
# Positive Likelihood Ratio: 11.3333
# Negative Likelihood Ratio: 0.0153
# Epoch: 7/50, Train Loss: 0.0593, Train Accuracy: 0.9779, Test Loss: 0.0955, Test Accuracy: 0.9580
# ==> New best model saved at epoch 7 with Test Accuracy: 0.9580
# TP: 967.0
# FP: 51.0
# FN: 33.0
# TN: 949.0
# Accuracy: 0.9580
# Misclassification rate: 0.0420
# Sensitivity (Recall): 0.9670
# Specificity: 0.9490
# Precision: 0.9499
# Negative Predictive Value: 0.9664
# G-mean: 0.9580
# F-measure: 0.9584
# Discriminant Power: 3.4741
# F2-measure: 0.9533
# InvF0.5-measure: 0.9635
# AGF: 0.9584
# Balanced Accuracy: 0.9580
# Matthew's Correlation Coefficient: 0.9161
# Cohen's Kappa: 0.9160
# Youden's Index: 0.9160
# Positive Likelihood Ratio: 18.9608
# Negative Likelihood Ratio: 0.0348
# Epoch: 8/50, Train Loss: 0.0523, Train Accuracy: 0.9803, Test Loss: 0.0949, Test Accuracy: 0.9620
# ==> New best model saved at epoch 8 with Test Accuracy: 0.9620
# TP: 973.0
# FP: 49.0
# FN: 27.0
# TN: 951.0
# Accuracy: 0.9620
# Misclassification rate: 0.0380
# Sensitivity (Recall): 0.9730
# Specificity: 0.9510
# Precision: 0.9521
# Negative Predictive Value: 0.9724
# G-mean: 0.9619
# F-measure: 0.9624
# Discriminant Power: 3.6113
# F2-measure: 0.9562
# InvF0.5-measure: 0.9687
# AGF: 0.9624
# Balanced Accuracy: 0.9620
# Matthew's Correlation Coefficient: 0.9242
# Cohen's Kappa: 0.9240
# Youden's Index: 0.9240
# Positive Likelihood Ratio: 19.8571
# Negative Likelihood Ratio: 0.0284
# Epoch: 9/50, Train Loss: 0.0492, Train Accuracy: 0.9814, Test Loss: 0.1446, Test Accuracy: 0.9515
# Epoch: 10/50, Train Loss: 0.0472, Train Accuracy: 0.9825, Test Loss: 0.2192, Test Accuracy: 0.9320
# Epoch: 11/50, Train Loss: 0.0388, Train Accuracy: 0.9869, Test Loss: 0.0992, Test Accuracy: 0.9595
# Epoch: 12/50, Train Loss: 0.0356, Train Accuracy: 0.9883, Test Loss: 0.1157, Test Accuracy: 0.9615
# Epoch: 13/50, Train Loss: 0.0360, Train Accuracy: 0.9864, Test Loss: 0.1121, Test Accuracy: 0.9570
# Epoch: 14/50, Train Loss: 0.0278, Train Accuracy: 0.9906, Test Loss: 0.1910, Test Accuracy: 0.9505
# Epoch: 15/50, Train Loss: 0.0262, Train Accuracy: 0.9912, Test Loss: 0.0888, Test Accuracy: 0.9625
# ==> New best model saved at epoch 15 with Test Accuracy: 0.9625
# TP: 966.0
# FP: 41.0
# FN: 34.0
# TN: 959.0
# Accuracy: 0.9625
# Misclassification rate: 0.0375
# Sensitivity (Recall): 0.9660
# Specificity: 0.9590
# Precision: 0.9593
# Negative Predictive Value: 0.9658
# G-mean: 0.9625
# F-measure: 0.9626
# Discriminant Power: 3.5832
# F2-measure: 0.9606
# InvF0.5-measure: 0.9646
# AGF: 0.9626
# Balanced Accuracy: 0.9625
# Matthew's Correlation Coefficient: 0.9250
# Cohen's Kappa: 0.9250
# Youden's Index: 0.9250
# Positive Likelihood Ratio: 23.5610
# Negative Likelihood Ratio: 0.0355
# Epoch: 16/50, Train Loss: 0.0207, Train Accuracy: 0.9942, Test Loss: 0.1213, Test Accuracy: 0.9595
# Epoch: 17/50, Train Loss: 0.0212, Train Accuracy: 0.9928, Test Loss: 0.1005, Test Accuracy: 0.9635
# ==> New best model saved at epoch 17 with Test Accuracy: 0.9635
# TP: 982.0
# FP: 55.0
# FN: 18.0
# TN: 945.0
# Accuracy: 0.9635
# Misclassification rate: 0.0365
# Sensitivity (Recall): 0.9820
# Specificity: 0.9450
# Precision: 0.9470
# Negative Predictive Value: 0.9813
# G-mean: 0.9633
# F-measure: 0.9642
# Discriminant Power: 3.7728
# F2-measure: 0.9538
# InvF0.5-measure: 0.9748
# AGF: 0.9642
# Balanced Accuracy: 0.9635
# Matthew's Correlation Coefficient: 0.9276
# Cohen's Kappa: 0.9270
# Youden's Index: 0.9270
# Positive Likelihood Ratio: 17.8545
# Negative Likelihood Ratio: 0.0190
# Epoch: 18/50, Train Loss: 0.0181, Train Accuracy: 0.9942, Test Loss: 0.1158, Test Accuracy: 0.9615
# Epoch: 19/50, Train Loss: 0.0155, Train Accuracy: 0.9950, Test Loss: 0.1283, Test Accuracy: 0.9595
# Epoch: 20/50, Train Loss: 0.0108, Train Accuracy: 0.9972, Test Loss: 0.1610, Test Accuracy: 0.9575
# Epoch: 21/50, Train Loss: 0.0089, Train Accuracy: 0.9978, Test Loss: 0.1549, Test Accuracy: 0.9625
# Epoch: 22/50, Train Loss: 0.0086, Train Accuracy: 0.9975, Test Loss: 0.1257, Test Accuracy: 0.9650
# ==> New best model saved at epoch 22 with Test Accuracy: 0.9650
# TP: 986.0
# FP: 56.0
# FN: 14.0
# TN: 944.0
# Accuracy: 0.9650
# Misclassification rate: 0.0350
# Sensitivity (Recall): 0.9860
# Specificity: 0.9440
# Precision: 0.9463
# Negative Predictive Value: 0.9854
# G-mean: 0.9648
# F-measure: 0.9657
# Discriminant Power: 3.9031
# F2-measure: 0.9539
# InvF0.5-measure: 0.9778
# AGF: 0.9658
# Balanced Accuracy: 0.9650
# Matthew's Correlation Coefficient: 0.9308
# Cohen's Kappa: 0.9300
# Youden's Index: 0.9300
# Positive Likelihood Ratio: 17.6071
# Negative Likelihood Ratio: 0.0148
# Epoch: 23/50, Train Loss: 0.0064, Train Accuracy: 0.9979, Test Loss: 0.1867, Test Accuracy: 0.9590
# Epoch: 24/50, Train Loss: 0.0037, Train Accuracy: 0.9997, Test Loss: 0.1860, Test Accuracy: 0.9590
# Epoch: 25/50, Train Loss: 0.0029, Train Accuracy: 0.9999, Test Loss: 0.2001, Test Accuracy: 0.9585
# Epoch: 26/50, Train Loss: 0.0016, Train Accuracy: 0.9999, Test Loss: 0.1857, Test Accuracy: 0.9595
# Epoch: 27/50, Train Loss: 0.0012, Train Accuracy: 1.0000, Test Loss: 0.2308, Test Accuracy: 0.9590
# Epoch: 28/50, Train Loss: 0.0009, Train Accuracy: 1.0000, Test Loss: 0.1872, Test Accuracy: 0.9630
# Epoch: 29/50, Train Loss: 0.0010, Train Accuracy: 1.0000, Test Loss: 0.1872, Test Accuracy: 0.9625
# Epoch: 30/50, Train Loss: 0.0007, Train Accuracy: 1.0000, Test Loss: 0.1871, Test Accuracy: 0.9620
# Epoch: 31/50, Train Loss: 0.0005, Train Accuracy: 1.0000, Test Loss: 0.2182, Test Accuracy: 0.9605
# Epoch: 32/50, Train Loss: 0.0004, Train Accuracy: 1.0000, Test Loss: 0.2682, Test Accuracy: 0.9575
# Epoch: 33/50, Train Loss: 0.0004, Train Accuracy: 1.0000, Test Loss: 0.2163, Test Accuracy: 0.9620
# Epoch: 34/50, Train Loss: 0.0003, Train Accuracy: 1.0000, Test Loss: 0.2237, Test Accuracy: 0.9615
# Epoch: 35/50, Train Loss: 0.0003, Train Accuracy: 1.0000, Test Loss: 0.2334, Test Accuracy: 0.9595
# Epoch: 36/50, Train Loss: 0.0002, Train Accuracy: 1.0000, Test Loss: 0.2190, Test Accuracy: 0.9625
# Epoch: 37/50, Train Loss: 0.0002, Train Accuracy: 1.0000, Test Loss: 0.2390, Test Accuracy: 0.9610
# Epoch: 38/50, Train Loss: 0.0002, Train Accuracy: 1.0000, Test Loss: 0.2301, Test Accuracy: 0.9620
# Epoch: 39/50, Train Loss: 0.0002, Train Accuracy: 1.0000, Test Loss: 0.2673, Test Accuracy: 0.9590
# Epoch: 40/50, Train Loss: 0.0001, Train Accuracy: 1.0000, Test Loss: 0.2591, Test Accuracy: 0.9595
# Epoch: 41/50, Train Loss: 0.0001, Train Accuracy: 1.0000, Test Loss: 0.2618, Test Accuracy: 0.9600
# Epoch: 42/50, Train Loss: 0.0001, Train Accuracy: 1.0000, Test Loss: 0.2559, Test Accuracy: 0.9615
# Epoch: 43/50, Train Loss: 0.0001, Train Accuracy: 1.0000, Test Loss: 0.2484, Test Accuracy: 0.9620
# Epoch: 44/50, Train Loss: 0.0001, Train Accuracy: 1.0000, Test Loss: 0.2805, Test Accuracy: 0.9590
# Epoch: 45/50, Train Loss: 0.0001, Train Accuracy: 1.0000, Test Loss: 0.2725, Test Accuracy: 0.9605
# Epoch: 46/50, Train Loss: 0.0001, Train Accuracy: 1.0000, Test Loss: 0.2787, Test Accuracy: 0.9595
# Epoch: 47/50, Train Loss: 0.0001, Train Accuracy: 1.0000, Test Loss: 0.2568, Test Accuracy: 0.9620
# Epoch: 48/50, Train Loss: 0.0001, Train Accuracy: 1.0000, Test Loss: 0.2764, Test Accuracy: 0.9605
# Epoch: 49/50, Train Loss: 0.0001, Train Accuracy: 1.0000, Test Loss: 0.2882, Test Accuracy: 0.9600
# Epoch: 50/50, Train Loss: 0.0001, Train Accuracy: 1.0000, Test Loss: 0.2913, Test Accuracy: 0.9595
