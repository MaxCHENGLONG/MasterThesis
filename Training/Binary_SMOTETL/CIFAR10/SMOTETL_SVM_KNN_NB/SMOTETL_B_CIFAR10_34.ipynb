# %%
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
import torchvision
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
import numpy as np
import torch
import matplotlib.pyplot as plt
import sys
import os
sys.path.append(os.path.abspath("/Users/max/MasterThesis/Training/"))

# %%
from Swim_Maha import SwimMaha
fractions = [0.005, 0.01, 0.02, 0.05, 0.1, 0.2]
for frac in range(len(fractions)):
    import torch
    from torch.utils.data import DataLoader, Subset, ConcatDataset, TensorDataset
    from torchvision import datasets, transforms
    import numpy as np

    # CIFAR10 数据归一化参数
    # 数据预处理
    cifar10_transforms = transforms.Compose([
        transforms.ToTensor(), 
        transforms.Normalize((0.4914, 0.4822, 0.4465), (0.247, 0.243, 0.261))
    ])
    # 加载 CIFAR10 数据集
    full_train_dataset = datasets.CIFAR10(
        root="/Users/max/MasterThesisData/CIFAR10", train=True, transform=cifar10_transforms, download=True)
    full_test_dataset = datasets.CIFAR10(
        root="/Users/max/MasterThesisData/CIFAR10", train=False, transform=cifar10_transforms, download=True)

    # 筛选训练集中的标签 3 和 4，并映射标签（标签 3 -> 1，标签 4 -> 0）
    indices3_train = [i for i in range(len(full_train_dataset)) if full_train_dataset.targets[i] == 3]
    indices4_train = [i for i in range(len(full_train_dataset)) if full_train_dataset.targets[i] == 4]

    # 筛选测试集中的标签 3 和 4，并映射标签
    indices3_test = [i for i in range(len(full_test_dataset)) if full_test_dataset.targets[i] == 3]
    indices4_test = [i for i in range(len(full_test_dataset)) if full_test_dataset.targets[i] == 4]

    # 训练集：获取标签为 3 的数据（映射为 1）
    cifar3_train_data = full_train_dataset.data[indices3_train]  # numpy 数组，形状 (n, 32, 32, 3)
    cifar3_train_labels = torch.ones(len(indices3_train), dtype=torch.long)

    # 训练集：获取标签为 4 的数据（映射为 0）
    cifar4_train_data = full_train_dataset.data[indices4_train]
    cifar4_train_labels = torch.zeros(len(indices4_train), dtype=torch.long)

    # 测试集：获取标签为 3 的数据（映射为 1）
    cifar3_test_data = full_test_dataset.data[indices3_test]
    cifar3_test_labels = torch.ones(len(indices3_test), dtype=torch.long)

    # 测试集：获取标签为 4 的数据（映射为 0）
    cifar4_test_data = full_test_dataset.data[indices4_test]
    cifar4_test_labels = torch.zeros(len(indices4_test), dtype=torch.long)

    # 控制不平衡比例，比如这里设定为 0.005（即只选取标签 4 数据中的一小部分）
    fraction = int(fractions[frac] * len(cifar3_train_data))
    selected_indices_4 = np.random.choice(len(cifar4_train_data), fraction, replace=False)
    fraction_cifar4_train_data = cifar4_train_data[selected_indices_4]
    fraction_cifar4_train_labels = cifar4_train_labels[selected_indices_4]

    # 拼接最终的训练和测试数据集
    Final_train_data = np.concatenate([cifar3_train_data, fraction_cifar4_train_data], axis=0)
    Final_train_labels = torch.cat([cifar3_train_labels, fraction_cifar4_train_labels], dim=0)

    Final_test_data = np.concatenate([cifar3_test_data, cifar4_test_data], axis=0)
    Final_test_labels = torch.cat([cifar3_test_labels, cifar4_test_labels], dim=0)

    # 将 numpy 数组转换为 tensor，并调整维度为 (N, C, H, W)
    Final_train_data = torch.from_numpy(Final_train_data).permute(0, 3, 1, 2).float()
    Final_test_data = torch.from_numpy(Final_test_data).permute(0, 3, 1, 2).float()

    # 归一化图像数据：先除以 255，再进行标准化
    # # 创建 TensorDataset
    # Final_train_datasets = TensorDataset(Final_train_data.unsqueeze(3).float() / 255, Final_train_labels)
    # Final_test_datasets = TensorDataset(Final_test_data.unsqueeze(3).float() / 255, Final_test_labels)

    # 创建 TensorDataset
    Final_train_dataset = TensorDataset(Final_train_data.float() / 255, Final_train_labels)
    Final_test_dataset = TensorDataset(Final_test_data.float() / 255, Final_test_labels)

    # 数据加载器
    train_loader = DataLoader(Final_train_dataset, batch_size=64, shuffle=True)
    test_loader = DataLoader(Final_test_dataset, batch_size=64, shuffle=False)

    # 打印数据信息
    print("Number of label 1 in the final training set: ", len(cifar3_train_data))
    print("Number of label 0 in the final training set (after downsampling): ", len(fraction_cifar4_train_data))
    print("Number of label 1 in the final test set: ", len(cifar3_test_data))
    print("Number of label 0 in the final test set: ", len(cifar4_test_data))

    print("Total samples in final training set: ", len(Final_train_dataset))
    print("Total samples in final test set: ", len(Final_test_dataset))

    print("Number of batches in training set: ", len(train_loader))
    print("Number of batches in test set: ", len(test_loader))


    
    ## 获取一个 batch
    images, labels = next(iter(train_loader))

    # 打印张量信息
    print(f"Images shape: {images.shape}")  # (batch_size, 3, 32, 32)
    print(f"Labels shape: {labels.shape}")

    # 将第一张图像的维度转换为 (H, W, C) 并显示
    img = images[0].permute(1, 2, 0).numpy()  # (32, 32, 3)
    plt.imshow(img)  # 对于彩色图像，无需指定 cmap
    plt.title(f"Label: {labels[0].item()}")
    plt.show()

    plt.figure(figsize=(20, 5))
    for i, img_tensor in enumerate(images[:20]):
        # 将每张图像转换为 (H, W, C)
        npimg = img_tensor.permute(1, 2, 0).numpy()
        plt.subplot(2, 10, i+1)
        plt.imshow(npimg)  # 彩色图像，不指定 cmap
        plt.axis('off')
    plt.show()


    X_train = []
    y_train = []

    for batch in train_loader:
        images, labels = batch  # images: (batch_size, 1, 28, 28), labels: (batch_size,)
        if hasattr(images, 'numpy'): # images is tensor
            images = images.numpy()
        # batch_size = 64
        for img, label in zip(images, labels):
            #print(f"Original shape: {img.shape}")  #  
            flattened_img = img.flatten()           
            #print(f"Flattened shape: {flattened_img.shape}")
            X_train.append(flattened_img) # 
            y_train.append(label)


    X_test = [] # features
    y_test = [] # labels
    for batch in test_loader:
        images, labels = batch  # images: (batch_size, 1,28  ,28 ), labels: (batch_size,)
        if hasattr(images, 'numpy'): # images is tensor
            images = images.numpy()
        # batch_size = 64
        for img, label in zip(images, labels):
            flattened_img = img.flatten()           # flatten the image
            X_test.append(flattened_img)
            y_test.append(label)


    X_train = np.array(X_train)
    y_train = np.array(y_train)
    X_test = np.array(X_test)
    y_test = np.array(y_test)
    print("X_train.shape:", X_train.shape)
    print("y_train.shape:", y_train.shape)
    print("X_test.shape:", X_test.shape)
    print("y_test.shape:", y_test.shape)
    ### SMOTE

    from imblearn.over_sampling import SMOTE
    from collections import Counter
    from imblearn.combine import SMOTETomek
    sm = SMOTETomek(random_state=42)
    X_train, y_train = sm.fit_resample(X_train, y_train)
    print('Resampled dataset shape %s' % Counter(y_train))
    print("##############################################")
    print("SMOTE done!")
    print("X_train.shape:", X_train.shape)
    print("y_train.shape:", y_train.shape)
    print("X_test.shape:", X_test.shape)
    print("y_test.shape:", y_test.shape)
    # training model

    from sklearn import svm
    from sklearn.preprocessing import StandardScaler

    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_test = scaler.transform(X_test)

    clf = svm.SVC(kernel='linear', C=1.0)
    clf.fit(X_train, y_train)
    y_pred = clf.predict(X_test)
    print("y_pred.shape:", y_pred.shape)

    from self_metrics import Binary_got_metrics
    from self_metrics import Binary_got_cofusion_matrix
    from self_metrics import Binary_got_metrics
    TP, FP, FN, TN = Binary_got_cofusion_matrix(y_test, y_pred, labels = [1,0])


    Accuracy, misclassification_rate, Sensitivity, Specificity, Precision, Negative_Predictive_Value, Gmean, Fmean, DPower, F2measure, InvF_05, AGFmeasure, Balanced_Accuracy, MCCmeasure, Kappa, Youden_Index, LR_pos, LR_neg = Binary_got_metrics(TP, FP, FN, TN)
    import json

            # 构造一个包含所有指标数据的字典
    metrics_dict = {
                "Number of label 3 in the final training set": len(cifar3_train_data),
                "Number of label 4 in the final training set (after downsampling)": len(fraction_cifar4_train_data),
                "Number of label 3 in the final test set": len(cifar3_test_data),
                "Number of label 4 in the final test set": len(cifar4_test_data),
                "Total samples in final training set": len(Final_train_dataset),
                "Total samples in final test set": len(Final_test_dataset),
                "Number of batches in training set": len(train_loader),
                "Number of batches in test set": len(test_loader),
                "TP": TP,
                "FP": FP,
                "FN": FN,
                "TN": TN,
                "Accuracy": round(Accuracy, 4),
                "Misclassification rate": round(misclassification_rate, 4),
                "Sensitivity (Recall)": round(Sensitivity, 4),
                "Specificity": round(Specificity, 4),
                "Precision": round(Precision, 4),
                "Negative Predictive Value": round(Negative_Predictive_Value, 4),
                "G-mean": round(Gmean, 4),
                "F-measure": round(Fmean, 4),
                "Discriminant Power (DP)": round(DPower, 4),
                "F2-measure": round(F2measure, 4),
                "InvF0.5-measure": round(InvF_05, 4),
                "AGF": round(AGFmeasure, 4),
                "Balanced Accuracy": round(Balanced_Accuracy, 4),
                "Matthew's Correlation Coefficient (MCC)": round(MCCmeasure, 4),
                "Cohen's Kappa": round(Kappa, 4),
                "Youden's Index": round(Youden_Index, 4),
                "Positive Likelihood Ratio (LR+)": round(LR_pos, 4),
                "Negative Likelihood Ratio (LR-)": round(LR_neg, 4)
            }

            # 指定 JSON 文件保存路径
    metrics_results_path = f"SMOTETL_SVMBinaryCIFAR1034_{fraction}_metrics_results.json"
    # 将字典保存为 JSON 文件
    with open(metrics_results_path, "w") as f:
        json.dump(metrics_dict, f, indent=4)
# Out:
# Number of label 1 in the final training set:  5000
# Number of label 0 in the final training set (after downsampling):  25
# Number of label 1 in the final test set:  1000
# Number of label 0 in the final test set:  1000
# Total samples in final training set:  5025
# Total samples in final test set:  2000
# Number of batches in training set:  79
# Number of batches in test set:  32
# Images shape: torch.Size([64, 3, 32, 32])
# Labels shape: torch.Size([64])
# X_train.shape: (5025, 3072)
# y_train.shape: (5025,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# Resampled dataset shape Counter({np.int64(1): 5000, np.int64(0): 5000})
# ##############################################
# SMOTE done!
# X_train.shape: (10000, 3072)
# y_train.shape: (10000,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# y_pred.shape: (2000,)
# TP: 995
# FP: 983
# FN: 5
# TN: 17
# Accuracy: 0.5060
# Misclassification rate: 0.4940
# Sensitivity (Recall): 0.9950
# Specificity: 0.0170
# Precision: 0.5030
# Negative Predictive Value: 0.7727
# G-mean: 0.1301
# F-measure: 0.6682
# Discriminant Power: 0.6814
# F2-measure: 0.5582
# InvF0.5-measure: 0.8322
# AGF: 0.6816
# Balanced Accuracy: 0.5060
# Matthew's Correlation Coefficient: 0.0575
# Cohen's Kappa: 0.0120
# Youden's Index: 0.0120
# Positive Likelihood Ratio: 1.0122
# Negative Likelihood Ratio: 0.2941
# Number of label 1 in the final training set:  5000
# Number of label 0 in the final training set (after downsampling):  50
# Number of label 1 in the final test set:  1000
# Number of label 0 in the final test set:  1000
# Total samples in final training set:  5050
# Total samples in final test set:  2000
# Number of batches in training set:  79
# Number of batches in test set:  32
# Images shape: torch.Size([64, 3, 32, 32])
# Labels shape: torch.Size([64])
# X_train.shape: (5050, 3072)
# y_train.shape: (5050,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# Resampled dataset shape Counter({np.int64(1): 5000, np.int64(0): 5000})
# ##############################################
# SMOTE done!
# X_train.shape: (10000, 3072)
# y_train.shape: (10000,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# y_pred.shape: (2000,)
# TP: 982
# FP: 933
# FN: 18
# TN: 67
# Accuracy: 0.5245
# Misclassification rate: 0.4755
# Sensitivity (Recall): 0.9820
# Specificity: 0.0670
# Precision: 0.5128
# Negative Predictive Value: 0.7882
# G-mean: 0.2565
# F-measure: 0.6738
# Discriminant Power: 0.7528
# F2-measure: 0.5670
# InvF0.5-measure: 0.8301
# AGF: 0.6860
# Balanced Accuracy: 0.5245
# Matthew's Correlation Coefficient: 0.1215
# Cohen's Kappa: 0.0490
# Youden's Index: 0.0490
# Positive Likelihood Ratio: 1.0525
# Negative Likelihood Ratio: 0.2687
# Number of label 1 in the final training set:  5000
# Number of label 0 in the final training set (after downsampling):  100
# Number of label 1 in the final test set:  1000
# Number of label 0 in the final test set:  1000
# Total samples in final training set:  5100
# Total samples in final test set:  2000
# Number of batches in training set:  80
# Number of batches in test set:  32
# Images shape: torch.Size([64, 3, 32, 32])
# Labels shape: torch.Size([64])
# X_train.shape: (5100, 3072)
# y_train.shape: (5100,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# Resampled dataset shape Counter({np.int64(1): 5000, np.int64(0): 5000})
# ##############################################
# SMOTE done!
# X_train.shape: (10000, 3072)
# y_train.shape: (10000,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# y_pred.shape: (2000,)
# TP: 950
# FP: 909
# FN: 50
# TN: 91
# Accuracy: 0.5205
# Misclassification rate: 0.4795
# Sensitivity (Recall): 0.9500
# Specificity: 0.0910
# Precision: 0.5110
# Negative Predictive Value: 0.6454
# G-mean: 0.2940
# F-measure: 0.6646
# Discriminant Power: 0.3545
# F2-measure: 0.5631
# InvF0.5-measure: 0.8107
# AGF: 0.6756
# Balanced Accuracy: 0.5205
# Matthew's Correlation Coefficient: 0.0801
# Cohen's Kappa: 0.0410
# Youden's Index: 0.0410
# Positive Likelihood Ratio: 1.0451
# Negative Likelihood Ratio: 0.5495
# Number of label 1 in the final training set:  5000
# Number of label 0 in the final training set (after downsampling):  250
# Number of label 1 in the final test set:  1000
# Number of label 0 in the final test set:  1000
# Total samples in final training set:  5250
# Total samples in final test set:  2000
# Number of batches in training set:  83
# Number of batches in test set:  32
# Images shape: torch.Size([64, 3, 32, 32])
# Labels shape: torch.Size([64])
# X_train.shape: (5250, 3072)
# y_train.shape: (5250,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# Resampled dataset shape Counter({np.int64(1): 5000, np.int64(0): 5000})
# ##############################################
# SMOTE done!
# X_train.shape: (10000, 3072)
# y_train.shape: (10000,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# y_pred.shape: (2000,)
# TP: 890
# FP: 785
# FN: 110
# TN: 215
# Accuracy: 0.5525
# Misclassification rate: 0.4475
# Sensitivity (Recall): 0.8900
# Specificity: 0.2150
# Precision: 0.5313
# Negative Predictive Value: 0.6615
# G-mean: 0.4374
# F-measure: 0.6654
# Discriminant Power: 0.4387
# F2-measure: 0.5779
# InvF0.5-measure: 0.7841
# AGF: 0.6732
# Balanced Accuracy: 0.5525
# Matthew's Correlation Coefficient: 0.1423
# Cohen's Kappa: 0.1050
# Youden's Index: 0.1050
# Positive Likelihood Ratio: 1.1338
# Negative Likelihood Ratio: 0.5116
# Number of label 1 in the final training set:  5000
# Number of label 0 in the final training set (after downsampling):  500
# Number of label 1 in the final test set:  1000
# Number of label 0 in the final test set:  1000
# Total samples in final training set:  5500
# Total samples in final test set:  2000
# Number of batches in training set:  86
# Number of batches in test set:  32
# Images shape: torch.Size([64, 3, 32, 32])
# Labels shape: torch.Size([64])
# X_train.shape: (5500, 3072)
# y_train.shape: (5500,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# Resampled dataset shape Counter({np.int64(0): 5000, np.int64(1): 5000})
# ##############################################
# SMOTE done!
# X_train.shape: (10000, 3072)
# y_train.shape: (10000,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# y_pred.shape: (2000,)
# TP: 865
# FP: 664
# FN: 135
# TN: 336
# Accuracy: 0.6005
# Misclassification rate: 0.3995
# Sensitivity (Recall): 0.8650
# Specificity: 0.3360
# Precision: 0.5657
# Negative Predictive Value: 0.7134
# G-mean: 0.5391
# F-measure: 0.6841
# Discriminant Power: 0.6485
# F2-measure: 0.6078
# InvF0.5-measure: 0.7822
# AGF: 0.6895
# Balanced Accuracy: 0.6005
# Matthew's Correlation Coefficient: 0.2369
# Cohen's Kappa: 0.2010
# Youden's Index: 0.2010
# Positive Likelihood Ratio: 1.3027
# Negative Likelihood Ratio: 0.4018
# Number of label 1 in the final training set:  5000
# Number of label 0 in the final training set (after downsampling):  1000
# Number of label 1 in the final test set:  1000
# Number of label 0 in the final test set:  1000
# Total samples in final training set:  6000
# Total samples in final test set:  2000
# Number of batches in training set:  94
# Number of batches in test set:  32
# Images shape: torch.Size([64, 3, 32, 32])
# Labels shape: torch.Size([64])
# X_train.shape: (6000, 3072)
# y_train.shape: (6000,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# Resampled dataset shape Counter({np.int64(1): 5000, np.int64(0): 5000})
# ##############################################
# SMOTE done!
# X_train.shape: (10000, 3072)
# y_train.shape: (10000,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# y_pred.shape: (2000,)
# TP: 803
# FP: 551
# FN: 197
# TN: 449
# Accuracy: 0.6260
# Misclassification rate: 0.3740
# Sensitivity (Recall): 0.8030
# Specificity: 0.4490
# Precision: 0.5931
# Negative Predictive Value: 0.6950
# G-mean: 0.6005
# F-measure: 0.6822
# Discriminant Power: 0.6618
# F2-measure: 0.6258
# InvF0.5-measure: 0.7499
# AGF: 0.6850
# Balanced Accuracy: 0.6260
# Matthew's Correlation Coefficient: 0.2694
# Cohen's Kappa: 0.2520
# Youden's Index: 0.2520
# Positive Likelihood Ratio: 1.4574
# Negative Likelihood Ratio: 0.4388

# %%
from Swim_Maha import SwimMaha
fractions = [0.005, 0.01, 0.02, 0.05, 0.1, 0.2]
for frac in range(len(fractions)):
    import torch
    from torch.utils.data import DataLoader, Subset, ConcatDataset, TensorDataset
    from torchvision import datasets, transforms
    import numpy as np

    # CIFAR10 数据归一化参数
    # 数据预处理
    cifar10_transforms = transforms.Compose([
        transforms.ToTensor(), 
        transforms.Normalize((0.4914, 0.4822, 0.4465), (0.247, 0.243, 0.261))
    ])
    # 加载 CIFAR10 数据集
    full_train_dataset = datasets.CIFAR10(
        root="/Users/max/MasterThesisData/CIFAR10", train=True, transform=cifar10_transforms, download=True)
    full_test_dataset = datasets.CIFAR10(
        root="/Users/max/MasterThesisData/CIFAR10", train=False, transform=cifar10_transforms, download=True)

    # 筛选训练集中的标签 3 和 4，并映射标签（标签 3 -> 1，标签 4 -> 0）
    indices3_train = [i for i in range(len(full_train_dataset)) if full_train_dataset.targets[i] == 3]
    indices4_train = [i for i in range(len(full_train_dataset)) if full_train_dataset.targets[i] == 4]

    # 筛选测试集中的标签 3 和 4，并映射标签
    indices3_test = [i for i in range(len(full_test_dataset)) if full_test_dataset.targets[i] == 3]
    indices4_test = [i for i in range(len(full_test_dataset)) if full_test_dataset.targets[i] == 4]

    # 训练集：获取标签为 3 的数据（映射为 1）
    cifar3_train_data = full_train_dataset.data[indices3_train]  # numpy 数组，形状 (n, 32, 32, 3)
    cifar3_train_labels = torch.ones(len(indices3_train), dtype=torch.long)

    # 训练集：获取标签为 4 的数据（映射为 0）
    cifar4_train_data = full_train_dataset.data[indices4_train]
    cifar4_train_labels = torch.zeros(len(indices4_train), dtype=torch.long)

    # 测试集：获取标签为 3 的数据（映射为 1）
    cifar3_test_data = full_test_dataset.data[indices3_test]
    cifar3_test_labels = torch.ones(len(indices3_test), dtype=torch.long)

    # 测试集：获取标签为 4 的数据（映射为 0）
    cifar4_test_data = full_test_dataset.data[indices4_test]
    cifar4_test_labels = torch.zeros(len(indices4_test), dtype=torch.long)

    # 控制不平衡比例，比如这里设定为 0.005（即只选取标签 4 数据中的一小部分）
    fraction = int(fractions[frac] * len(cifar3_train_data))
    selected_indices_4 = np.random.choice(len(cifar4_train_data), fraction, replace=False)
    fraction_cifar4_train_data = cifar4_train_data[selected_indices_4]
    fraction_cifar4_train_labels = cifar4_train_labels[selected_indices_4]

    # 拼接最终的训练和测试数据集
    Final_train_data = np.concatenate([cifar3_train_data, fraction_cifar4_train_data], axis=0)
    Final_train_labels = torch.cat([cifar3_train_labels, fraction_cifar4_train_labels], dim=0)

    Final_test_data = np.concatenate([cifar3_test_data, cifar4_test_data], axis=0)
    Final_test_labels = torch.cat([cifar3_test_labels, cifar4_test_labels], dim=0)

    # 将 numpy 数组转换为 tensor，并调整维度为 (N, C, H, W)
    Final_train_data = torch.from_numpy(Final_train_data).permute(0, 3, 1, 2).float()
    Final_test_data = torch.from_numpy(Final_test_data).permute(0, 3, 1, 2).float()

    # 归一化图像数据：先除以 255，再进行标准化
    # # 创建 TensorDataset
    # Final_train_datasets = TensorDataset(Final_train_data.unsqueeze(3).float() / 255, Final_train_labels)
    # Final_test_datasets = TensorDataset(Final_test_data.unsqueeze(3).float() / 255, Final_test_labels)

    # 创建 TensorDataset
    Final_train_dataset = TensorDataset(Final_train_data.float() / 255, Final_train_labels)
    Final_test_dataset = TensorDataset(Final_test_data.float() / 255, Final_test_labels)

    # 数据加载器
    train_loader = DataLoader(Final_train_dataset, batch_size=64, shuffle=True)
    test_loader = DataLoader(Final_test_dataset, batch_size=64, shuffle=False)

    # 打印数据信息
    print("Number of label 1 in the final training set: ", len(cifar3_train_data))
    print("Number of label 0 in the final training set (after downsampling): ", len(fraction_cifar4_train_data))
    print("Number of label 1 in the final test set: ", len(cifar3_test_data))
    print("Number of label 0 in the final test set: ", len(cifar4_test_data))

    print("Total samples in final training set: ", len(Final_train_dataset))
    print("Total samples in final test set: ", len(Final_test_dataset))

    print("Number of batches in training set: ", len(train_loader))
    print("Number of batches in test set: ", len(test_loader))


    
    ## 获取一个 batch
    images, labels = next(iter(train_loader))

    # 打印张量信息
    print(f"Images shape: {images.shape}")  # (batch_size, 3, 32, 32)
    print(f"Labels shape: {labels.shape}")

    # 将第一张图像的维度转换为 (H, W, C) 并显示
    img = images[0].permute(1, 2, 0).numpy()  # (32, 32, 3)
    plt.imshow(img)  # 对于彩色图像，无需指定 cmap
    plt.title(f"Label: {labels[0].item()}")
    plt.show()

    plt.figure(figsize=(20, 5))
    for i, img_tensor in enumerate(images[:20]):
        # 将每张图像转换为 (H, W, C)
        npimg = img_tensor.permute(1, 2, 0).numpy()
        plt.subplot(2, 10, i+1)
        plt.imshow(npimg)  # 彩色图像，不指定 cmap
        plt.axis('off')
    plt.show()


    X_train = []
    y_train = []

    for batch in train_loader:
        images, labels = batch  # images: (batch_size, 1, 28, 28), labels: (batch_size,)
        if hasattr(images, 'numpy'): # images is tensor
            images = images.numpy()
        # batch_size = 64
        for img, label in zip(images, labels):
            #print(f"Original shape: {img.shape}")  #  
            flattened_img = img.flatten()           
            #print(f"Flattened shape: {flattened_img.shape}")
            X_train.append(flattened_img) # 
            y_train.append(label)


    X_test = [] # features
    y_test = [] # labels
    for batch in test_loader:
        images, labels = batch  # images: (batch_size, 1,28  ,28 ), labels: (batch_size,)
        if hasattr(images, 'numpy'): # images is tensor
            images = images.numpy()
        # batch_size = 64
        for img, label in zip(images, labels):
            flattened_img = img.flatten()           # flatten the image
            X_test.append(flattened_img)
            y_test.append(label)


    X_train = np.array(X_train)
    y_train = np.array(y_train)
    X_test = np.array(X_test)
    y_test = np.array(y_test)
    print("X_train.shape:", X_train.shape)
    print("y_train.shape:", y_train.shape)
    print("X_test.shape:", X_test.shape)
    print("y_test.shape:", y_test.shape)
    ### SMOTE

    from imblearn.over_sampling import SMOTE
    from collections import Counter
    from imblearn.combine import SMOTETomek
    sm = SMOTETomek(random_state=42)
    X_train, y_train = sm.fit_resample(X_train, y_train)
    print('Resampled dataset shape %s' % Counter(y_train))
    print("##############################################")
    print("SMOTE done!")
    print("X_train.shape:", X_train.shape)
    print("y_train.shape:", y_train.shape)
    print("X_test.shape:", X_test.shape)
    print("y_test.shape:", y_test.shape)
    # training model
    from sklearn import svm
    from sklearn.preprocessing import StandardScaler
    from sklearn.neighbors import KNeighborsClassifier

    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_test = scaler.transform(X_test)
    from sklearn.naive_bayes import GaussianNB

    # 创建一个Gaussian Naive Bayes分类器
    nb = GaussianNB()
    nb.fit(X_train, y_train)
    y_pred = nb.predict(X_test)
    print("y_pred.shape:", y_pred.shape)


    from self_metrics import Binary_got_metrics
    from self_metrics import Binary_got_cofusion_matrix
    from self_metrics import Binary_got_metrics
    TP, FP, FN, TN = Binary_got_cofusion_matrix(y_test, y_pred, labels = [1,0])


    Accuracy, misclassification_rate, Sensitivity, Specificity, Precision, Negative_Predictive_Value, Gmean, Fmean, DPower, F2measure, InvF_05, AGFmeasure, Balanced_Accuracy, MCCmeasure, Kappa, Youden_Index, LR_pos, LR_neg = Binary_got_metrics(TP, FP, FN, TN)
    import json

            # 构造一个包含所有指标数据的字典
    metrics_dict = {
                "Number of label 3 in the final training set": len(cifar3_train_data),
                "Number of label 4 in the final training set (after downsampling)": len(fraction_cifar4_train_data),
                "Number of label 3 in the final test set": len(cifar3_test_data),
                "Number of label 4 in the final test set": len(cifar4_test_data),
                "Total samples in final training set": len(Final_train_dataset),
                "Total samples in final test set": len(Final_test_dataset),
                "Number of batches in training set": len(train_loader),
                "Number of batches in test set": len(test_loader),
                "TP": TP,
                "FP": FP,
                "FN": FN,
                "TN": TN,
                "Accuracy": round(Accuracy, 4),
                "Misclassification rate": round(misclassification_rate, 4),
                "Sensitivity (Recall)": round(Sensitivity, 4),
                "Specificity": round(Specificity, 4),
                "Precision": round(Precision, 4),
                "Negative Predictive Value": round(Negative_Predictive_Value, 4),
                "G-mean": round(Gmean, 4),
                "F-measure": round(Fmean, 4),
                "Discriminant Power (DP)": round(DPower, 4),
                "F2-measure": round(F2measure, 4),
                "InvF0.5-measure": round(InvF_05, 4),
                "AGF": round(AGFmeasure, 4),
                "Balanced Accuracy": round(Balanced_Accuracy, 4),
                "Matthew's Correlation Coefficient (MCC)": round(MCCmeasure, 4),
                "Cohen's Kappa": round(Kappa, 4),
                "Youden's Index": round(Youden_Index, 4),
                "Positive Likelihood Ratio (LR+)": round(LR_pos, 4),
                "Negative Likelihood Ratio (LR-)": round(LR_neg, 4)
            }

            # 指定 JSON 文件保存路径
    metrics_results_path = f"SMOTETL_NavieBayesBinaryCIFAR1034_{fraction}_metrics_results.json"
    # 将字典保存为 JSON 文件
    with open(metrics_results_path, "w") as f:
        json.dump(metrics_dict, f, indent=4)
# Out:
# Number of label 1 in the final training set:  5000
# Number of label 0 in the final training set (after downsampling):  25
# Number of label 1 in the final test set:  1000
# Number of label 0 in the final test set:  1000
# Total samples in final training set:  5025
# Total samples in final test set:  2000
# Number of batches in training set:  79
# Number of batches in test set:  32
# Images shape: torch.Size([64, 3, 32, 32])
# Labels shape: torch.Size([64])
# X_train.shape: (5025, 3072)
# y_train.shape: (5025,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# Resampled dataset shape Counter({np.int64(1): 5000, np.int64(0): 5000})
# ##############################################
# SMOTE done!
# X_train.shape: (10000, 3072)
# y_train.shape: (10000,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# y_pred.shape: (2000,)
# TP: 772
# FP: 432
# FN: 228
# TN: 568
# Accuracy: 0.6700
# Misclassification rate: 0.3300
# Sensitivity (Recall): 0.7720
# Specificity: 0.5680
# Precision: 0.6412
# Negative Predictive Value: 0.7136
# G-mean: 0.6622
# F-measure: 0.7005
# Discriminant Power: 0.8233
# F2-measure: 0.6637
# InvF0.5-measure: 0.7417
# AGF: 0.7016
# Balanced Accuracy: 0.6700
# Matthew's Correlation Coefficient: 0.3473
# Cohen's Kappa: 0.3400
# Youden's Index: 0.3400
# Positive Likelihood Ratio: 1.7870
# Negative Likelihood Ratio: 0.4014
# Number of label 1 in the final training set:  5000
# Number of label 0 in the final training set (after downsampling):  50
# Number of label 1 in the final test set:  1000
# Number of label 0 in the final test set:  1000
# Total samples in final training set:  5050
# Total samples in final test set:  2000
# Number of batches in training set:  79
# Number of batches in test set:  32
# Images shape: torch.Size([64, 3, 32, 32])
# Labels shape: torch.Size([64])
# X_train.shape: (5050, 3072)
# y_train.shape: (5050,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# Resampled dataset shape Counter({np.int64(1): 5000, np.int64(0): 5000})
# ##############################################
# SMOTE done!
# X_train.shape: (10000, 3072)
# y_train.shape: (10000,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# y_pred.shape: (2000,)
# TP: 712
# FP: 354
# FN: 288
# TN: 646
# Accuracy: 0.6790
# Misclassification rate: 0.3210
# Sensitivity (Recall): 0.7120
# Specificity: 0.6460
# Precision: 0.6679
# Negative Predictive Value: 0.6916
# G-mean: 0.6782
# F-measure: 0.6893
# Discriminant Power: 0.8306
# F2-measure: 0.6763
# InvF0.5-measure: 0.7027
# AGF: 0.6894
# Balanced Accuracy: 0.6790
# Matthew's Correlation Coefficient: 0.3588
# Cohen's Kappa: 0.3580
# Youden's Index: 0.3580
# Positive Likelihood Ratio: 2.0113
# Negative Likelihood Ratio: 0.4458
# Number of label 1 in the final training set:  5000
# Number of label 0 in the final training set (after downsampling):  100
# Number of label 1 in the final test set:  1000
# Number of label 0 in the final test set:  1000
# Total samples in final training set:  5100
# Total samples in final test set:  2000
# Number of batches in training set:  80
# Number of batches in test set:  32
# Images shape: torch.Size([64, 3, 32, 32])
# Labels shape: torch.Size([64])
# X_train.shape: (5100, 3072)
# y_train.shape: (5100,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# Resampled dataset shape Counter({np.int64(1): 5000, np.int64(0): 5000})
# ##############################################
# SMOTE done!
# X_train.shape: (10000, 3072)
# y_train.shape: (10000,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# y_pred.shape: (2000,)
# TP: 802
# FP: 431
# FN: 198
# TN: 569
# Accuracy: 0.6855
# Misclassification rate: 0.3145
# Sensitivity (Recall): 0.8020
# Specificity: 0.5690
# Precision: 0.6504
# Negative Predictive Value: 0.7419
# G-mean: 0.6755
# F-measure: 0.7183
# Discriminant Power: 0.9244
# F2-measure: 0.6760
# InvF0.5-measure: 0.7663
# AGF: 0.7197
# Balanced Accuracy: 0.6855
# Matthew's Correlation Coefficient: 0.3815
# Cohen's Kappa: 0.3710
# Youden's Index: 0.3710
# Positive Likelihood Ratio: 1.8608
# Negative Likelihood Ratio: 0.3480
# Number of label 1 in the final training set:  5000
# Number of label 0 in the final training set (after downsampling):  250
# Number of label 1 in the final test set:  1000
# Number of label 0 in the final test set:  1000
# Total samples in final training set:  5250
# Total samples in final test set:  2000
# Number of batches in training set:  83
# Number of batches in test set:  32
# Images shape: torch.Size([64, 3, 32, 32])
# Labels shape: torch.Size([64])
# X_train.shape: (5250, 3072)
# y_train.shape: (5250,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# Resampled dataset shape Counter({np.int64(1): 5000, np.int64(0): 5000})
# ##############################################
# SMOTE done!
# X_train.shape: (10000, 3072)
# y_train.shape: (10000,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# y_pred.shape: (2000,)
# TP: 736
# FP: 367
# FN: 264
# TN: 633
# Accuracy: 0.6845
# Misclassification rate: 0.3155
# Sensitivity (Recall): 0.7360
# Specificity: 0.6330
# Precision: 0.6673
# Negative Predictive Value: 0.7057
# G-mean: 0.6826
# F-measure: 0.7000
# Discriminant Power: 0.8658
# F2-measure: 0.6800
# InvF0.5-measure: 0.7211
# AGF: 0.7003
# Balanced Accuracy: 0.6845
# Matthew's Correlation Coefficient: 0.3710
# Cohen's Kappa: 0.3690
# Youden's Index: 0.3690
# Positive Likelihood Ratio: 2.0054
# Negative Likelihood Ratio: 0.4171
# Number of label 1 in the final training set:  5000
# Number of label 0 in the final training set (after downsampling):  500
# Number of label 1 in the final test set:  1000
# Number of label 0 in the final test set:  1000
# Total samples in final training set:  5500
# Total samples in final test set:  2000
# Number of batches in training set:  86
# Number of batches in test set:  32
# Images shape: torch.Size([64, 3, 32, 32])
# Labels shape: torch.Size([64])
# X_train.shape: (5500, 3072)
# y_train.shape: (5500,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# Resampled dataset shape Counter({np.int64(1): 5000, np.int64(0): 5000})
# ##############################################
# SMOTE done!
# X_train.shape: (10000, 3072)
# y_train.shape: (10000,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# y_pred.shape: (2000,)
# TP: 714
# FP: 355
# FN: 286
# TN: 645
# Accuracy: 0.6795
# Misclassification rate: 0.3205
# Sensitivity (Recall): 0.7140
# Specificity: 0.6450
# Precision: 0.6679
# Negative Predictive Value: 0.6928
# G-mean: 0.6786
# F-measure: 0.6902
# Discriminant Power: 0.8336
# F2-measure: 0.6766
# InvF0.5-measure: 0.7043
# AGF: 0.6903
# Balanced Accuracy: 0.6795
# Matthew's Correlation Coefficient: 0.3599
# Cohen's Kappa: 0.3590
# Youden's Index: 0.3590
# Positive Likelihood Ratio: 2.0113
# Negative Likelihood Ratio: 0.4434
# Number of label 1 in the final training set:  5000
# Number of label 0 in the final training set (after downsampling):  1000
# Number of label 1 in the final test set:  1000
# Number of label 0 in the final test set:  1000
# Total samples in final training set:  6000
# Total samples in final test set:  2000
# Number of batches in training set:  94
# Number of batches in test set:  32
# Images shape: torch.Size([64, 3, 32, 32])
# Labels shape: torch.Size([64])
# X_train.shape: (6000, 3072)
# y_train.shape: (6000,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# Resampled dataset shape Counter({np.int64(1): 5000, np.int64(0): 5000})
# ##############################################
# SMOTE done!
# X_train.shape: (10000, 3072)
# y_train.shape: (10000,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# y_pred.shape: (2000,)
# TP: 671
# FP: 300
# FN: 329
# TN: 700
# Accuracy: 0.6855
# Misclassification rate: 0.3145
# Sensitivity (Recall): 0.6710
# Specificity: 0.7000
# Precision: 0.6910
# Negative Predictive Value: 0.6803
# G-mean: 0.6853
# F-measure: 0.6809
# Discriminant Power: 0.8601
# F2-measure: 0.6869
# InvF0.5-measure: 0.6749
# AGF: 0.6809
# Balanced Accuracy: 0.6855
# Matthew's Correlation Coefficient: 0.3712
# Cohen's Kappa: 0.3710
# Youden's Index: 0.3710
# Positive Likelihood Ratio: 2.2367
# Negative Likelihood Ratio: 0.4700

# %%
from Swim_Maha import SwimMaha
fractions = [0.005, 0.01, 0.02, 0.05, 0.1, 0.2]
for frac in range(len(fractions)):
    import torch
    from torch.utils.data import DataLoader, Subset, ConcatDataset, TensorDataset
    from torchvision import datasets, transforms
    import numpy as np

    # CIFAR10 数据归一化参数
    # 数据预处理
    cifar10_transforms = transforms.Compose([
        transforms.ToTensor(), 
        transforms.Normalize((0.4914, 0.4822, 0.4465), (0.247, 0.243, 0.261))
    ])
    # 加载 CIFAR10 数据集
    full_train_dataset = datasets.CIFAR10(
        root="/Users/max/MasterThesisData/CIFAR10", train=True, transform=cifar10_transforms, download=True)
    full_test_dataset = datasets.CIFAR10(
        root="/Users/max/MasterThesisData/CIFAR10", train=False, transform=cifar10_transforms, download=True)

    # 筛选训练集中的标签 3 和 4，并映射标签（标签 3 -> 1，标签 4 -> 0）
    indices3_train = [i for i in range(len(full_train_dataset)) if full_train_dataset.targets[i] == 3]
    indices4_train = [i for i in range(len(full_train_dataset)) if full_train_dataset.targets[i] == 4]

    # 筛选测试集中的标签 3 和 4，并映射标签
    indices3_test = [i for i in range(len(full_test_dataset)) if full_test_dataset.targets[i] == 3]
    indices4_test = [i for i in range(len(full_test_dataset)) if full_test_dataset.targets[i] == 4]

    # 训练集：获取标签为 3 的数据（映射为 1）
    cifar3_train_data = full_train_dataset.data[indices3_train]  # numpy 数组，形状 (n, 32, 32, 3)
    cifar3_train_labels = torch.ones(len(indices3_train), dtype=torch.long)

    # 训练集：获取标签为 4 的数据（映射为 0）
    cifar4_train_data = full_train_dataset.data[indices4_train]
    cifar4_train_labels = torch.zeros(len(indices4_train), dtype=torch.long)

    # 测试集：获取标签为 3 的数据（映射为 1）
    cifar3_test_data = full_test_dataset.data[indices3_test]
    cifar3_test_labels = torch.ones(len(indices3_test), dtype=torch.long)

    # 测试集：获取标签为 4 的数据（映射为 0）
    cifar4_test_data = full_test_dataset.data[indices4_test]
    cifar4_test_labels = torch.zeros(len(indices4_test), dtype=torch.long)

    # 控制不平衡比例，比如这里设定为 0.005（即只选取标签 4 数据中的一小部分）
    fraction = int(fractions[frac] * len(cifar3_train_data))
    selected_indices_4 = np.random.choice(len(cifar4_train_data), fraction, replace=False)
    fraction_cifar4_train_data = cifar4_train_data[selected_indices_4]
    fraction_cifar4_train_labels = cifar4_train_labels[selected_indices_4]

    # 拼接最终的训练和测试数据集
    Final_train_data = np.concatenate([cifar3_train_data, fraction_cifar4_train_data], axis=0)
    Final_train_labels = torch.cat([cifar3_train_labels, fraction_cifar4_train_labels], dim=0)

    Final_test_data = np.concatenate([cifar3_test_data, cifar4_test_data], axis=0)
    Final_test_labels = torch.cat([cifar3_test_labels, cifar4_test_labels], dim=0)

    # 将 numpy 数组转换为 tensor，并调整维度为 (N, C, H, W)
    Final_train_data = torch.from_numpy(Final_train_data).permute(0, 3, 1, 2).float()
    Final_test_data = torch.from_numpy(Final_test_data).permute(0, 3, 1, 2).float()

    # 归一化图像数据：先除以 255，再进行标准化
    # # 创建 TensorDataset
    # Final_train_datasets = TensorDataset(Final_train_data.unsqueeze(3).float() / 255, Final_train_labels)
    # Final_test_datasets = TensorDataset(Final_test_data.unsqueeze(3).float() / 255, Final_test_labels)

    # 创建 TensorDataset
    Final_train_dataset = TensorDataset(Final_train_data.float() / 255, Final_train_labels)
    Final_test_dataset = TensorDataset(Final_test_data.float() / 255, Final_test_labels)

    # 数据加载器
    train_loader = DataLoader(Final_train_dataset, batch_size=64, shuffle=True)
    test_loader = DataLoader(Final_test_dataset, batch_size=64, shuffle=False)

    # 打印数据信息
    print("Number of label 1 in the final training set: ", len(cifar3_train_data))
    print("Number of label 0 in the final training set (after downsampling): ", len(fraction_cifar4_train_data))
    print("Number of label 1 in the final test set: ", len(cifar3_test_data))
    print("Number of label 0 in the final test set: ", len(cifar4_test_data))

    print("Total samples in final training set: ", len(Final_train_dataset))
    print("Total samples in final test set: ", len(Final_test_dataset))

    print("Number of batches in training set: ", len(train_loader))
    print("Number of batches in test set: ", len(test_loader))


    
    ## 获取一个 batch
    images, labels = next(iter(train_loader))

    # 打印张量信息
    print(f"Images shape: {images.shape}")  # (batch_size, 3, 32, 32)
    print(f"Labels shape: {labels.shape}")

    # 将第一张图像的维度转换为 (H, W, C) 并显示
    img = images[0].permute(1, 2, 0).numpy()  # (32, 32, 3)
    plt.imshow(img)  # 对于彩色图像，无需指定 cmap
    plt.title(f"Label: {labels[0].item()}")
    plt.show()

    plt.figure(figsize=(20, 5))
    for i, img_tensor in enumerate(images[:20]):
        # 将每张图像转换为 (H, W, C)
        npimg = img_tensor.permute(1, 2, 0).numpy()
        plt.subplot(2, 10, i+1)
        plt.imshow(npimg)  # 彩色图像，不指定 cmap
        plt.axis('off')
    plt.show()


    X_train = []
    y_train = []

    for batch in train_loader:
        images, labels = batch  # images: (batch_size, 1, 28, 28), labels: (batch_size,)
        if hasattr(images, 'numpy'): # images is tensor
            images = images.numpy()
        # batch_size = 64
        for img, label in zip(images, labels):
            #print(f"Original shape: {img.shape}")  #  
            flattened_img = img.flatten()           
            #print(f"Flattened shape: {flattened_img.shape}")
            X_train.append(flattened_img) # 
            y_train.append(label)


    X_test = [] # features
    y_test = [] # labels
    for batch in test_loader:
        images, labels = batch  # images: (batch_size, 1,28  ,28 ), labels: (batch_size,)
        if hasattr(images, 'numpy'): # images is tensor
            images = images.numpy()
        # batch_size = 64
        for img, label in zip(images, labels):
            flattened_img = img.flatten()           # flatten the image
            X_test.append(flattened_img)
            y_test.append(label)


    X_train = np.array(X_train)
    y_train = np.array(y_train)
    X_test = np.array(X_test)
    y_test = np.array(y_test)
    print("X_train.shape:", X_train.shape)
    print("y_train.shape:", y_train.shape)
    print("X_test.shape:", X_test.shape)
    print("y_test.shape:", y_test.shape)
    ### SMOTE

    from imblearn.over_sampling import SMOTE
    from collections import Counter
    from imblearn.combine import SMOTETomek
    sm = SMOTETomek(random_state=42)
    X_train, y_train = sm.fit_resample(X_train, y_train)
    print('Resampled dataset shape %s' % Counter(y_train))
    print("##############################################")
    print("SMOTE done!")
    print("X_train.shape:", X_train.shape)
    print("y_train.shape:", y_train.shape)
    print("X_test.shape:", X_test.shape)
    print("y_test.shape:", y_test.shape)
    # training model
    from sklearn import svm
    from sklearn.preprocessing import StandardScaler
    from sklearn.neighbors import KNeighborsClassifier

    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_test = scaler.transform(X_test)
    # 创建一个KNN分类器，设定邻居数为5（你可以根据需要调整n_neighbors的值）
    knn = KNeighborsClassifier(n_neighbors=5)
    knn.fit(X_train, y_train)
    y_pred = knn.predict(X_test)
    print("y_pred.shape:", y_pred.shape)



    from self_metrics import Binary_got_metrics
    from self_metrics import Binary_got_cofusion_matrix
    from self_metrics import Binary_got_metrics
    TP, FP, FN, TN = Binary_got_cofusion_matrix(y_test, y_pred, labels = [1,0])


    Accuracy, misclassification_rate, Sensitivity, Specificity, Precision, Negative_Predictive_Value, Gmean, Fmean, DPower, F2measure, InvF_05, AGFmeasure, Balanced_Accuracy, MCCmeasure, Kappa, Youden_Index, LR_pos, LR_neg = Binary_got_metrics(TP, FP, FN, TN)
    import json

            # 构造一个包含所有指标数据的字典
    metrics_dict = {
                "Number of label 3 in the final training set": len(cifar3_train_data),
                "Number of label 4 in the final training set (after downsampling)": len(fraction_cifar4_train_data),
                "Number of label 3 in the final test set": len(cifar3_test_data),
                "Number of label 4 in the final test set": len(cifar4_test_data),
                "Total samples in final training set": len(Final_train_dataset),
                "Total samples in final test set": len(Final_test_dataset),
                "Number of batches in training set": len(train_loader),
                "Number of batches in test set": len(test_loader),
                "TP": TP,
                "FP": FP,
                "FN": FN,
                "TN": TN,
                "Accuracy": round(Accuracy, 4),
                "Misclassification rate": round(misclassification_rate, 4),
                "Sensitivity (Recall)": round(Sensitivity, 4),
                "Specificity": round(Specificity, 4),
                "Precision": round(Precision, 4),
                "Negative Predictive Value": round(Negative_Predictive_Value, 4),
                "G-mean": round(Gmean, 4),
                "F-measure": round(Fmean, 4),
                "Discriminant Power (DP)": round(DPower, 4),
                "F2-measure": round(F2measure, 4),
                "InvF0.5-measure": round(InvF_05, 4),
                "AGF": round(AGFmeasure, 4),
                "Balanced Accuracy": round(Balanced_Accuracy, 4),
                "Matthew's Correlation Coefficient (MCC)": round(MCCmeasure, 4),
                "Cohen's Kappa": round(Kappa, 4),
                "Youden's Index": round(Youden_Index, 4),
                "Positive Likelihood Ratio (LR+)": round(LR_pos, 4),
                "Negative Likelihood Ratio (LR-)": round(LR_neg, 4)
            }

            # 指定 JSON 文件保存路径
    metrics_results_path = f"SMOTETL_KNNBinaryCIFAR1034_{fraction}_metrics_results.json"
    # 将字典保存为 JSON 文件
    with open(metrics_results_path, "w") as f:
        json.dump(metrics_dict, f, indent=4)
# Out:
# Number of label 1 in the final training set:  5000
# Number of label 0 in the final training set (after downsampling):  25
# Number of label 1 in the final test set:  1000
# Number of label 0 in the final test set:  1000
# Total samples in final training set:  5025
# Total samples in final test set:  2000
# Number of batches in training set:  79
# Number of batches in test set:  32
# Images shape: torch.Size([64, 3, 32, 32])
# Labels shape: torch.Size([64])
# X_train.shape: (5025, 3072)
# y_train.shape: (5025,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# Resampled dataset shape Counter({np.int64(1): 5000, np.int64(0): 5000})
# ##############################################
# SMOTE done!
# X_train.shape: (10000, 3072)
# y_train.shape: (10000,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# y_pred.shape: (2000,)
# TP: 730
# FP: 351
# FN: 270
# TN: 649
# Accuracy: 0.6895
# Misclassification rate: 0.3105
# Sensitivity (Recall): 0.7300
# Specificity: 0.6490
# Precision: 0.6753
# Negative Predictive Value: 0.7062
# G-mean: 0.6883
# F-measure: 0.7016
# Discriminant Power: 0.8872
# F2-measure: 0.6856
# InvF0.5-measure: 0.7184
# AGF: 0.7018
# Balanced Accuracy: 0.6895
# Matthew's Correlation Coefficient: 0.3802
# Cohen's Kappa: 0.3790
# Youden's Index: 0.3790
# Positive Likelihood Ratio: 2.0798
# Negative Likelihood Ratio: 0.4160
# Number of label 1 in the final training set:  5000
# Number of label 0 in the final training set (after downsampling):  50
# Number of label 1 in the final test set:  1000
# Number of label 0 in the final test set:  1000
# Total samples in final training set:  5050
# Total samples in final test set:  2000
# Number of batches in training set:  79
# Number of batches in test set:  32
# Images shape: torch.Size([64, 3, 32, 32])
# Labels shape: torch.Size([64])
# X_train.shape: (5050, 3072)
# y_train.shape: (5050,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# Resampled dataset shape Counter({np.int64(1): 5000, np.int64(0): 5000})
# ##############################################
# SMOTE done!
# X_train.shape: (10000, 3072)
# y_train.shape: (10000,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# y_pred.shape: (2000,)
# TP: 673
# FP: 283
# FN: 327
# TN: 717
# Accuracy: 0.6950
# Misclassification rate: 0.3050
# Sensitivity (Recall): 0.6730
# Specificity: 0.7170
# Precision: 0.7040
# Negative Predictive Value: 0.6868
# G-mean: 0.6947
# F-measure: 0.6881
# Discriminant Power: 0.9105
# F2-measure: 0.6976
# InvF0.5-measure: 0.6790
# AGF: 0.6882
# Balanced Accuracy: 0.6950
# Matthew's Correlation Coefficient: 0.3904
# Cohen's Kappa: 0.3900
# Youden's Index: 0.3900
# Positive Likelihood Ratio: 2.3781
# Negative Likelihood Ratio: 0.4561
# Number of label 1 in the final training set:  5000
# Number of label 0 in the final training set (after downsampling):  100
# Number of label 1 in the final test set:  1000
# Number of label 0 in the final test set:  1000
# Total samples in final training set:  5100
# Total samples in final test set:  2000
# Number of batches in training set:  80
# Number of batches in test set:  32
# Images shape: torch.Size([64, 3, 32, 32])
# Labels shape: torch.Size([64])
# X_train.shape: (5100, 3072)
# y_train.shape: (5100,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# Resampled dataset shape Counter({np.int64(1): 5000, np.int64(0): 5000})
# ##############################################
# SMOTE done!
# X_train.shape: (10000, 3072)
# y_train.shape: (10000,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# y_pred.shape: (2000,)
# TP: 587
# FP: 213
# FN: 413
# TN: 787
# Accuracy: 0.6870
# Misclassification rate: 0.3130
# Sensitivity (Recall): 0.5870
# Specificity: 0.7870
# Precision: 0.7338
# Negative Predictive Value: 0.6558
# G-mean: 0.6797
# F-measure: 0.6522
# Discriminant Power: 0.9144
# F2-measure: 0.6988
# InvF0.5-measure: 0.6115
# AGF: 0.6537
# Balanced Accuracy: 0.6870
# Matthew's Correlation Coefficient: 0.3817
# Cohen's Kappa: 0.3740
# Youden's Index: 0.3740
# Positive Likelihood Ratio: 2.7559
# Negative Likelihood Ratio: 0.5248
# Number of label 1 in the final training set:  5000
# Number of label 0 in the final training set (after downsampling):  250
# Number of label 1 in the final test set:  1000
# Number of label 0 in the final test set:  1000
# Total samples in final training set:  5250
# Total samples in final test set:  2000
# Number of batches in training set:  83
# Number of batches in test set:  32
# Images shape: torch.Size([64, 3, 32, 32])
# Labels shape: torch.Size([64])
# X_train.shape: (5250, 3072)
# y_train.shape: (5250,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# Resampled dataset shape Counter({np.int64(1): 5000, np.int64(0): 5000})
# ##############################################
# SMOTE done!
# X_train.shape: (10000, 3072)
# y_train.shape: (10000,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# y_pred.shape: (2000,)
# TP: 465
# FP: 145
# FN: 535
# TN: 855
# Accuracy: 0.6600
# Misclassification rate: 0.3400
# Sensitivity (Recall): 0.4650
# Specificity: 0.8550
# Precision: 0.7623
# Negative Predictive Value: 0.6151
# G-mean: 0.6305
# F-measure: 0.5776
# Discriminant Power: 0.9009
# F2-measure: 0.6759
# InvF0.5-measure: 0.5043
# AGF: 0.5838
# Balanced Accuracy: 0.6600
# Matthew's Correlation Coefficient: 0.3475
# Cohen's Kappa: 0.3200
# Youden's Index: 0.3200
# Positive Likelihood Ratio: 3.2069
# Negative Likelihood Ratio: 0.6257
# Number of label 1 in the final training set:  5000
# Number of label 0 in the final training set (after downsampling):  500
# Number of label 1 in the final test set:  1000
# Number of label 0 in the final test set:  1000
# Total samples in final training set:  5500
# Total samples in final test set:  2000
# Number of batches in training set:  86
# Number of batches in test set:  32
# Images shape: torch.Size([64, 3, 32, 32])
# Labels shape: torch.Size([64])
# X_train.shape: (5500, 3072)
# y_train.shape: (5500,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# Resampled dataset shape Counter({np.int64(1): 5000, np.int64(0): 5000})
# ##############################################
# SMOTE done!
# X_train.shape: (10000, 3072)
# y_train.shape: (10000,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# y_pred.shape: (2000,)
# TP: 418
# FP: 58
# FN: 582
# TN: 942
# Accuracy: 0.6800
# Misclassification rate: 0.3200
# Sensitivity (Recall): 0.4180
# Specificity: 0.9420
# Precision: 0.8782
# Negative Predictive Value: 0.6181
# G-mean: 0.6275
# F-measure: 0.5664
# Discriminant Power: 1.3544
# F2-measure: 0.7197
# InvF0.5-measure: 0.4669
# AGF: 0.5797
# Balanced Accuracy: 0.6800
# Matthew's Correlation Coefficient: 0.4227
# Cohen's Kappa: 0.3600
# Youden's Index: 0.3600
# Positive Likelihood Ratio: 7.2069
# Negative Likelihood Ratio: 0.6178
# Number of label 1 in the final training set:  5000
# Number of label 0 in the final training set (after downsampling):  1000
# Number of label 1 in the final test set:  1000
# Number of label 0 in the final test set:  1000
# Total samples in final training set:  6000
# Total samples in final test set:  2000
# Number of batches in training set:  94
# Number of batches in test set:  32
# Images shape: torch.Size([64, 3, 32, 32])
# Labels shape: torch.Size([64])
# X_train.shape: (6000, 3072)
# y_train.shape: (6000,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# Resampled dataset shape Counter({np.int64(0): 5000, np.int64(1): 5000})
# ##############################################
# SMOTE done!
# X_train.shape: (10000, 3072)
# y_train.shape: (10000,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# y_pred.shape: (2000,)
# TP: 321
# FP: 36
# FN: 679
# TN: 964
# Accuracy: 0.6425
# Misclassification rate: 0.3575
# Sensitivity (Recall): 0.3210
# Specificity: 0.9640
# Precision: 0.8992
# Negative Predictive Value: 0.5867
# G-mean: 0.5563
# F-measure: 0.4731
# Discriminant Power: 1.3995
# F2-measure: 0.6610
# InvF0.5-measure: 0.3684
# AGF: 0.4935
# Balanced Accuracy: 0.6425
# Matthew's Correlation Coefficient: 0.3721
# Cohen's Kappa: 0.2850
# Youden's Index: 0.2850
# Positive Likelihood Ratio: 8.9167
# Negative Likelihood Ratio: 0.7044
