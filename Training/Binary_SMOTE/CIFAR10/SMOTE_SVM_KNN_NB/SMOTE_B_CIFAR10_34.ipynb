# %%
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
import torchvision
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
import numpy as np
import torch
import matplotlib.pyplot as plt
import sys
import os
sys.path.append(os.path.abspath("/Users/max/MasterThesis/Training/"))

# %%
from Swim_Maha import SwimMaha
fractions = [0.005, 0.01, 0.02, 0.05, 0.1, 0.2]
for frac in range(len(fractions)):
    import torch
    from torch.utils.data import DataLoader, Subset, ConcatDataset, TensorDataset
    from torchvision import datasets, transforms
    import numpy as np

    # CIFAR10 数据归一化参数
    # 数据预处理
    cifar10_transforms = transforms.Compose([
        transforms.ToTensor(), 
        transforms.Normalize((0.4914, 0.4822, 0.4465), (0.247, 0.243, 0.261))
    ])
    # 加载 CIFAR10 数据集
    full_train_dataset = datasets.CIFAR10(
        root="/Users/max/MasterThesisData/CIFAR10", train=True, transform=cifar10_transforms, download=True)
    full_test_dataset = datasets.CIFAR10(
        root="/Users/max/MasterThesisData/CIFAR10", train=False, transform=cifar10_transforms, download=True)

    # 筛选训练集中的标签 3 和 4，并映射标签（标签 3 -> 1，标签 4 -> 0）
    indices3_train = [i for i in range(len(full_train_dataset)) if full_train_dataset.targets[i] == 3]
    indices4_train = [i for i in range(len(full_train_dataset)) if full_train_dataset.targets[i] == 4]

    # 筛选测试集中的标签 3 和 4，并映射标签
    indices3_test = [i for i in range(len(full_test_dataset)) if full_test_dataset.targets[i] == 3]
    indices4_test = [i for i in range(len(full_test_dataset)) if full_test_dataset.targets[i] == 4]

    # 训练集：获取标签为 3 的数据（映射为 1）
    cifar3_train_data = full_train_dataset.data[indices3_train]  # numpy 数组，形状 (n, 32, 32, 3)
    cifar3_train_labels = torch.ones(len(indices3_train), dtype=torch.long)

    # 训练集：获取标签为 4 的数据（映射为 0）
    cifar4_train_data = full_train_dataset.data[indices4_train]
    cifar4_train_labels = torch.zeros(len(indices4_train), dtype=torch.long)

    # 测试集：获取标签为 3 的数据（映射为 1）
    cifar3_test_data = full_test_dataset.data[indices3_test]
    cifar3_test_labels = torch.ones(len(indices3_test), dtype=torch.long)

    # 测试集：获取标签为 4 的数据（映射为 0）
    cifar4_test_data = full_test_dataset.data[indices4_test]
    cifar4_test_labels = torch.zeros(len(indices4_test), dtype=torch.long)

    # 控制不平衡比例，比如这里设定为 0.005（即只选取标签 4 数据中的一小部分）
    fraction = int(fractions[frac] * len(cifar3_train_data))
    selected_indices_4 = np.random.choice(len(cifar4_train_data), fraction, replace=False)
    fraction_cifar4_train_data = cifar4_train_data[selected_indices_4]
    fraction_cifar4_train_labels = cifar4_train_labels[selected_indices_4]

    # 拼接最终的训练和测试数据集
    Final_train_data = np.concatenate([cifar3_train_data, fraction_cifar4_train_data], axis=0)
    Final_train_labels = torch.cat([cifar3_train_labels, fraction_cifar4_train_labels], dim=0)

    Final_test_data = np.concatenate([cifar3_test_data, cifar4_test_data], axis=0)
    Final_test_labels = torch.cat([cifar3_test_labels, cifar4_test_labels], dim=0)

    # 将 numpy 数组转换为 tensor，并调整维度为 (N, C, H, W)
    Final_train_data = torch.from_numpy(Final_train_data).permute(0, 3, 1, 2).float()
    Final_test_data = torch.from_numpy(Final_test_data).permute(0, 3, 1, 2).float()

    # 归一化图像数据：先除以 255，再进行标准化
    # # 创建 TensorDataset
    # Final_train_datasets = TensorDataset(Final_train_data.unsqueeze(3).float() / 255, Final_train_labels)
    # Final_test_datasets = TensorDataset(Final_test_data.unsqueeze(3).float() / 255, Final_test_labels)

    # 创建 TensorDataset
    Final_train_dataset = TensorDataset(Final_train_data.float() / 255, Final_train_labels)
    Final_test_dataset = TensorDataset(Final_test_data.float() / 255, Final_test_labels)

    # 数据加载器
    train_loader = DataLoader(Final_train_dataset, batch_size=64, shuffle=True)
    test_loader = DataLoader(Final_test_dataset, batch_size=64, shuffle=False)

    # 打印数据信息
    print("Number of label 1 in the final training set: ", len(cifar3_train_data))
    print("Number of label 0 in the final training set (after downsampling): ", len(fraction_cifar4_train_data))
    print("Number of label 1 in the final test set: ", len(cifar3_test_data))
    print("Number of label 0 in the final test set: ", len(cifar4_test_data))

    print("Total samples in final training set: ", len(Final_train_dataset))
    print("Total samples in final test set: ", len(Final_test_dataset))

    print("Number of batches in training set: ", len(train_loader))
    print("Number of batches in test set: ", len(test_loader))


    
    ## 获取一个 batch
    images, labels = next(iter(train_loader))

    # 打印张量信息
    print(f"Images shape: {images.shape}")  # (batch_size, 3, 32, 32)
    print(f"Labels shape: {labels.shape}")

    # 将第一张图像的维度转换为 (H, W, C) 并显示
    img = images[0].permute(1, 2, 0).numpy()  # (32, 32, 3)
    plt.imshow(img)  # 对于彩色图像，无需指定 cmap
    plt.title(f"Label: {labels[0].item()}")
    plt.show()

    plt.figure(figsize=(20, 5))
    for i, img_tensor in enumerate(images[:20]):
        # 将每张图像转换为 (H, W, C)
        npimg = img_tensor.permute(1, 2, 0).numpy()
        plt.subplot(2, 10, i+1)
        plt.imshow(npimg)  # 彩色图像，不指定 cmap
        plt.axis('off')
    plt.show()


    X_train = []
    y_train = []

    for batch in train_loader:
        images, labels = batch  # images: (batch_size, 1, 28, 28), labels: (batch_size,)
        if hasattr(images, 'numpy'): # images is tensor
            images = images.numpy()
        # batch_size = 64
        for img, label in zip(images, labels):
            #print(f"Original shape: {img.shape}")  #  
            flattened_img = img.flatten()           
            #print(f"Flattened shape: {flattened_img.shape}")
            X_train.append(flattened_img) # 
            y_train.append(label)


    X_test = [] # features
    y_test = [] # labels
    for batch in test_loader:
        images, labels = batch  # images: (batch_size, 1,28  ,28 ), labels: (batch_size,)
        if hasattr(images, 'numpy'): # images is tensor
            images = images.numpy()
        # batch_size = 64
        for img, label in zip(images, labels):
            flattened_img = img.flatten()           # flatten the image
            X_test.append(flattened_img)
            y_test.append(label)


    X_train = np.array(X_train)
    y_train = np.array(y_train)
    X_test = np.array(X_test)
    y_test = np.array(y_test)
    print("X_train.shape:", X_train.shape)
    print("y_train.shape:", y_train.shape)
    print("X_test.shape:", X_test.shape)
    print("y_test.shape:", y_test.shape)
    ### SMOTE

    from imblearn.over_sampling import SMOTE
    from collections import Counter

    sm = SMOTE(random_state=42)
    X_train, y_train = sm.fit_resample(X_train, y_train)
    print('Resampled dataset shape %s' % Counter(y_train))
    print("##############################################")
    print("SMOTE done!")
    print("X_train.shape:", X_train.shape)
    print("y_train.shape:", y_train.shape)
    print("X_test.shape:", X_test.shape)
    print("y_test.shape:", y_test.shape)
    # training model

    from sklearn import svm
    from sklearn.preprocessing import StandardScaler

    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_test = scaler.transform(X_test)

    clf = svm.SVC(kernel='linear', C=1.0)
    clf.fit(X_train, y_train)
    y_pred = clf.predict(X_test)
    print("y_pred.shape:", y_pred.shape)

    from self_metrics import Binary_got_metrics
    from self_metrics import Binary_got_cofusion_matrix
    from self_metrics import Binary_got_metrics
    TP, FP, FN, TN = Binary_got_cofusion_matrix(y_test, y_pred, labels = [1,0])


    Accuracy, misclassification_rate, Sensitivity, Specificity, Precision, Negative_Predictive_Value, Gmean, Fmean, DPower, F2measure, InvF_05, AGFmeasure, Balanced_Accuracy, MCCmeasure, Kappa, Youden_Index, LR_pos, LR_neg = Binary_got_metrics(TP, FP, FN, TN)
    import json

            # 构造一个包含所有指标数据的字典
    metrics_dict = {
                "Number of label 3 in the final training set": len(cifar3_train_data),
                "Number of label 4 in the final training set (after downsampling)": len(fraction_cifar4_train_data),
                "Number of label 3 in the final test set": len(cifar3_test_data),
                "Number of label 4 in the final test set": len(cifar4_test_data),
                "Total samples in final training set": len(Final_train_dataset),
                "Total samples in final test set": len(Final_test_dataset),
                "Number of batches in training set": len(train_loader),
                "Number of batches in test set": len(test_loader),
                "TP": TP,
                "FP": FP,
                "FN": FN,
                "TN": TN,
                "Accuracy": round(Accuracy, 4),
                "Misclassification rate": round(misclassification_rate, 4),
                "Sensitivity (Recall)": round(Sensitivity, 4),
                "Specificity": round(Specificity, 4),
                "Precision": round(Precision, 4),
                "Negative Predictive Value": round(Negative_Predictive_Value, 4),
                "G-mean": round(Gmean, 4),
                "F-measure": round(Fmean, 4),
                "Discriminant Power (DP)": round(DPower, 4),
                "F2-measure": round(F2measure, 4),
                "InvF0.5-measure": round(InvF_05, 4),
                "AGF": round(AGFmeasure, 4),
                "Balanced Accuracy": round(Balanced_Accuracy, 4),
                "Matthew's Correlation Coefficient (MCC)": round(MCCmeasure, 4),
                "Cohen's Kappa": round(Kappa, 4),
                "Youden's Index": round(Youden_Index, 4),
                "Positive Likelihood Ratio (LR+)": round(LR_pos, 4),
                "Negative Likelihood Ratio (LR-)": round(LR_neg, 4)
            }

            # 指定 JSON 文件保存路径
    metrics_results_path = f"SMOTE_SVMBinaryCIFAR1034_{fraction}_metrics_results.json"
    # 将字典保存为 JSON 文件
    with open(metrics_results_path, "w") as f:
        json.dump(metrics_dict, f, indent=4)
# Out:
# Number of label 1 in the final training set:  5000
# Number of label 0 in the final training set (after downsampling):  25
# Number of label 1 in the final test set:  1000
# Number of label 0 in the final test set:  1000
# Total samples in final training set:  5025
# Total samples in final test set:  2000
# Number of batches in training set:  79
# Number of batches in test set:  32
# Images shape: torch.Size([64, 3, 32, 32])
# Labels shape: torch.Size([64])
# X_train.shape: (5025, 3072)
# y_train.shape: (5025,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# Resampled dataset shape Counter({np.int64(1): 5000, np.int64(0): 5000})
# ##############################################
# SMOTE done!
# X_train.shape: (10000, 3072)
# y_train.shape: (10000,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# y_pred.shape: (2000,)
# TP: 992
# FP: 995
# FN: 8
# TN: 5
# Accuracy: 0.4985
# Misclassification rate: 0.5015
# Sensitivity (Recall): 0.9920
# Specificity: 0.0050
# Precision: 0.4992
# Negative Predictive Value: 0.3846
# G-mean: 0.0704
# F-measure: 0.6642
# Discriminant Power: -0.2608
# F2-measure: 0.5543
# InvF0.5-measure: 0.8285
# AGF: 0.6777
# Balanced Accuracy: 0.4985
# Matthew's Correlation Coefficient: -0.0187
# Cohen's Kappa: -0.0030
# Youden's Index: -0.0030
# Positive Likelihood Ratio: 0.9970
# Negative Likelihood Ratio: 1.6000
# Number of label 1 in the final training set:  5000
# Number of label 0 in the final training set (after downsampling):  50
# Number of label 1 in the final test set:  1000
# Number of label 0 in the final test set:  1000
# Total samples in final training set:  5050
# Total samples in final test set:  2000
# Number of batches in training set:  79
# Number of batches in test set:  32
# Images shape: torch.Size([64, 3, 32, 32])
# Labels shape: torch.Size([64])
# X_train.shape: (5050, 3072)
# y_train.shape: (5050,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# Resampled dataset shape Counter({np.int64(1): 5000, np.int64(0): 5000})
# ##############################################
# SMOTE done!
# X_train.shape: (10000, 3072)
# y_train.shape: (10000,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# y_pred.shape: (2000,)
# TP: 986
# FP: 973
# FN: 14
# TN: 27
# Accuracy: 0.5065
# Misclassification rate: 0.4935
# Sensitivity (Recall): 0.9860
# Specificity: 0.0270
# Precision: 0.5033
# Negative Predictive Value: 0.6585
# G-mean: 0.1632
# F-measure: 0.6664
# Discriminant Power: 0.3694
# F2-measure: 0.5579
# InvF0.5-measure: 0.8273
# AGF: 0.6794
# Balanced Accuracy: 0.5065
# Matthew's Correlation Coefficient: 0.0459
# Cohen's Kappa: 0.0130
# Youden's Index: 0.0130
# Positive Likelihood Ratio: 1.0134
# Negative Likelihood Ratio: 0.5185
# Number of label 1 in the final training set:  5000
# Number of label 0 in the final training set (after downsampling):  100
# Number of label 1 in the final test set:  1000
# Number of label 0 in the final test set:  1000
# Total samples in final training set:  5100
# Total samples in final test set:  2000
# Number of batches in training set:  80
# Number of batches in test set:  32
# Images shape: torch.Size([64, 3, 32, 32])
# Labels shape: torch.Size([64])
# X_train.shape: (5100, 3072)
# y_train.shape: (5100,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# Resampled dataset shape Counter({np.int64(1): 5000, np.int64(0): 5000})
# ##############################################
# SMOTE done!
# X_train.shape: (10000, 3072)
# y_train.shape: (10000,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# y_pred.shape: (2000,)
# TP: 969
# FP: 891
# FN: 31
# TN: 109
# Accuracy: 0.5390
# Misclassification rate: 0.4610
# Sensitivity (Recall): 0.9690
# Specificity: 0.1090
# Precision: 0.5210
# Negative Predictive Value: 0.7786
# G-mean: 0.3250
# F-measure: 0.6776
# Discriminant Power: 0.7395
# F2-measure: 0.5741
# InvF0.5-measure: 0.8268
# AGF: 0.6889
# Balanced Accuracy: 0.5390
# Matthew's Correlation Coefficient: 0.1529
# Cohen's Kappa: 0.0780
# Youden's Index: 0.0780
# Positive Likelihood Ratio: 1.0875
# Negative Likelihood Ratio: 0.2844
# Number of label 1 in the final training set:  5000
# Number of label 0 in the final training set (after downsampling):  250
# Number of label 1 in the final test set:  1000
# Number of label 0 in the final test set:  1000
# Total samples in final training set:  5250
# Total samples in final test set:  2000
# Number of batches in training set:  83
# Number of batches in test set:  32
# Images shape: torch.Size([64, 3, 32, 32])
# Labels shape: torch.Size([64])
# X_train.shape: (5250, 3072)
# y_train.shape: (5250,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# Resampled dataset shape Counter({np.int64(1): 5000, np.int64(0): 5000})
# ##############################################
# SMOTE done!
# X_train.shape: (10000, 3072)
# y_train.shape: (10000,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# y_pred.shape: (2000,)
# TP: 924
# FP: 794
# FN: 76
# TN: 206
# Accuracy: 0.5650
# Misclassification rate: 0.4350
# Sensitivity (Recall): 0.9240
# Specificity: 0.2060
# Precision: 0.5378
# Negative Predictive Value: 0.7305
# G-mean: 0.4363
# F-measure: 0.6799
# Discriminant Power: 0.6334
# F2-measure: 0.5869
# InvF0.5-measure: 0.8080
# AGF: 0.6886
# Balanced Accuracy: 0.5650
# Matthew's Correlation Coefficient: 0.1868
# Cohen's Kappa: 0.1300
# Youden's Index: 0.1300
# Positive Likelihood Ratio: 1.1637
# Negative Likelihood Ratio: 0.3689
# Number of label 1 in the final training set:  5000
# Number of label 0 in the final training set (after downsampling):  500
# Number of label 1 in the final test set:  1000
# Number of label 0 in the final test set:  1000
# Total samples in final training set:  5500
# Total samples in final test set:  2000
# Number of batches in training set:  86
# Number of batches in test set:  32
# Images shape: torch.Size([64, 3, 32, 32])
# Labels shape: torch.Size([64])
# X_train.shape: (5500, 3072)
# y_train.shape: (5500,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# Resampled dataset shape Counter({np.int64(1): 5000, np.int64(0): 5000})
# ##############################################
# SMOTE done!
# X_train.shape: (10000, 3072)
# y_train.shape: (10000,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# y_pred.shape: (2000,)
# TP: 866
# FP: 667
# FN: 134
# TN: 333
# Accuracy: 0.5995
# Misclassification rate: 0.4005
# Sensitivity (Recall): 0.8660
# Specificity: 0.3330
# Precision: 0.5649
# Negative Predictive Value: 0.7131
# G-mean: 0.5370
# F-measure: 0.6838
# Discriminant Power: 0.6458
# F2-measure: 0.6071
# InvF0.5-measure: 0.7826
# AGF: 0.6893
# Balanced Accuracy: 0.5995
# Matthew's Correlation Coefficient: 0.2352
# Cohen's Kappa: 0.1990
# Youden's Index: 0.1990
# Positive Likelihood Ratio: 1.2984
# Negative Likelihood Ratio: 0.4024
# Number of label 1 in the final training set:  5000
# Number of label 0 in the final training set (after downsampling):  1000
# Number of label 1 in the final test set:  1000
# Number of label 0 in the final test set:  1000
# Total samples in final training set:  6000
# Total samples in final test set:  2000
# Number of batches in training set:  94
# Number of batches in test set:  32
# Images shape: torch.Size([64, 3, 32, 32])
# Labels shape: torch.Size([64])
# X_train.shape: (6000, 3072)
# y_train.shape: (6000,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# Resampled dataset shape Counter({np.int64(1): 5000, np.int64(0): 5000})
# ##############################################
# SMOTE done!
# X_train.shape: (10000, 3072)
# y_train.shape: (10000,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# y_pred.shape: (2000,)
# TP: 805
# FP: 560
# FN: 195
# TN: 440
# Accuracy: 0.6225
# Misclassification rate: 0.3775
# Sensitivity (Recall): 0.8050
# Specificity: 0.4400
# Precision: 0.5897
# Negative Predictive Value: 0.6929
# G-mean: 0.5951
# F-measure: 0.6808
# Discriminant Power: 0.6487
# F2-measure: 0.6231
# InvF0.5-measure: 0.7502
# AGF: 0.6837
# Balanced Accuracy: 0.6225
# Matthew's Correlation Coefficient: 0.2632
# Cohen's Kappa: 0.2450
# Youden's Index: 0.2450
# Positive Likelihood Ratio: 1.4375
# Negative Likelihood Ratio: 0.4432

# %%
from Swim_Maha import SwimMaha
fractions = [0.005, 0.01, 0.02, 0.05, 0.1, 0.2]
for frac in range(len(fractions)):
    import torch
    from torch.utils.data import DataLoader, Subset, ConcatDataset, TensorDataset
    from torchvision import datasets, transforms
    import numpy as np

    # CIFAR10 数据归一化参数
    # 数据预处理
    cifar10_transforms = transforms.Compose([
        transforms.ToTensor(), 
        transforms.Normalize((0.4914, 0.4822, 0.4465), (0.247, 0.243, 0.261))
    ])
    # 加载 CIFAR10 数据集
    full_train_dataset = datasets.CIFAR10(
        root="/Users/max/MasterThesisData/CIFAR10", train=True, transform=cifar10_transforms, download=True)
    full_test_dataset = datasets.CIFAR10(
        root="/Users/max/MasterThesisData/CIFAR10", train=False, transform=cifar10_transforms, download=True)

    # 筛选训练集中的标签 3 和 4，并映射标签（标签 3 -> 1，标签 4 -> 0）
    indices3_train = [i for i in range(len(full_train_dataset)) if full_train_dataset.targets[i] == 3]
    indices4_train = [i for i in range(len(full_train_dataset)) if full_train_dataset.targets[i] == 4]

    # 筛选测试集中的标签 3 和 4，并映射标签
    indices3_test = [i for i in range(len(full_test_dataset)) if full_test_dataset.targets[i] == 3]
    indices4_test = [i for i in range(len(full_test_dataset)) if full_test_dataset.targets[i] == 4]

    # 训练集：获取标签为 3 的数据（映射为 1）
    cifar3_train_data = full_train_dataset.data[indices3_train]  # numpy 数组，形状 (n, 32, 32, 3)
    cifar3_train_labels = torch.ones(len(indices3_train), dtype=torch.long)

    # 训练集：获取标签为 4 的数据（映射为 0）
    cifar4_train_data = full_train_dataset.data[indices4_train]
    cifar4_train_labels = torch.zeros(len(indices4_train), dtype=torch.long)

    # 测试集：获取标签为 3 的数据（映射为 1）
    cifar3_test_data = full_test_dataset.data[indices3_test]
    cifar3_test_labels = torch.ones(len(indices3_test), dtype=torch.long)

    # 测试集：获取标签为 4 的数据（映射为 0）
    cifar4_test_data = full_test_dataset.data[indices4_test]
    cifar4_test_labels = torch.zeros(len(indices4_test), dtype=torch.long)

    # 控制不平衡比例，比如这里设定为 0.005（即只选取标签 4 数据中的一小部分）
    fraction = int(fractions[frac] * len(cifar3_train_data))
    selected_indices_4 = np.random.choice(len(cifar4_train_data), fraction, replace=False)
    fraction_cifar4_train_data = cifar4_train_data[selected_indices_4]
    fraction_cifar4_train_labels = cifar4_train_labels[selected_indices_4]

    # 拼接最终的训练和测试数据集
    Final_train_data = np.concatenate([cifar3_train_data, fraction_cifar4_train_data], axis=0)
    Final_train_labels = torch.cat([cifar3_train_labels, fraction_cifar4_train_labels], dim=0)

    Final_test_data = np.concatenate([cifar3_test_data, cifar4_test_data], axis=0)
    Final_test_labels = torch.cat([cifar3_test_labels, cifar4_test_labels], dim=0)

    # 将 numpy 数组转换为 tensor，并调整维度为 (N, C, H, W)
    Final_train_data = torch.from_numpy(Final_train_data).permute(0, 3, 1, 2).float()
    Final_test_data = torch.from_numpy(Final_test_data).permute(0, 3, 1, 2).float()

    # 归一化图像数据：先除以 255，再进行标准化
    # # 创建 TensorDataset
    # Final_train_datasets = TensorDataset(Final_train_data.unsqueeze(3).float() / 255, Final_train_labels)
    # Final_test_datasets = TensorDataset(Final_test_data.unsqueeze(3).float() / 255, Final_test_labels)

    # 创建 TensorDataset
    Final_train_dataset = TensorDataset(Final_train_data.float() / 255, Final_train_labels)
    Final_test_dataset = TensorDataset(Final_test_data.float() / 255, Final_test_labels)

    # 数据加载器
    train_loader = DataLoader(Final_train_dataset, batch_size=64, shuffle=True)
    test_loader = DataLoader(Final_test_dataset, batch_size=64, shuffle=False)

    # 打印数据信息
    print("Number of label 1 in the final training set: ", len(cifar3_train_data))
    print("Number of label 0 in the final training set (after downsampling): ", len(fraction_cifar4_train_data))
    print("Number of label 1 in the final test set: ", len(cifar3_test_data))
    print("Number of label 0 in the final test set: ", len(cifar4_test_data))

    print("Total samples in final training set: ", len(Final_train_dataset))
    print("Total samples in final test set: ", len(Final_test_dataset))

    print("Number of batches in training set: ", len(train_loader))
    print("Number of batches in test set: ", len(test_loader))


    
    ## 获取一个 batch
    images, labels = next(iter(train_loader))

    # 打印张量信息
    print(f"Images shape: {images.shape}")  # (batch_size, 3, 32, 32)
    print(f"Labels shape: {labels.shape}")

    # 将第一张图像的维度转换为 (H, W, C) 并显示
    img = images[0].permute(1, 2, 0).numpy()  # (32, 32, 3)
    plt.imshow(img)  # 对于彩色图像，无需指定 cmap
    plt.title(f"Label: {labels[0].item()}")
    plt.show()

    plt.figure(figsize=(20, 5))
    for i, img_tensor in enumerate(images[:20]):
        # 将每张图像转换为 (H, W, C)
        npimg = img_tensor.permute(1, 2, 0).numpy()
        plt.subplot(2, 10, i+1)
        plt.imshow(npimg)  # 彩色图像，不指定 cmap
        plt.axis('off')
    plt.show()


    X_train = []
    y_train = []

    for batch in train_loader:
        images, labels = batch  # images: (batch_size, 1, 28, 28), labels: (batch_size,)
        if hasattr(images, 'numpy'): # images is tensor
            images = images.numpy()
        # batch_size = 64
        for img, label in zip(images, labels):
            #print(f"Original shape: {img.shape}")  #  
            flattened_img = img.flatten()           
            #print(f"Flattened shape: {flattened_img.shape}")
            X_train.append(flattened_img) # 
            y_train.append(label)


    X_test = [] # features
    y_test = [] # labels
    for batch in test_loader:
        images, labels = batch  # images: (batch_size, 1,28  ,28 ), labels: (batch_size,)
        if hasattr(images, 'numpy'): # images is tensor
            images = images.numpy()
        # batch_size = 64
        for img, label in zip(images, labels):
            flattened_img = img.flatten()           # flatten the image
            X_test.append(flattened_img)
            y_test.append(label)


    X_train = np.array(X_train)
    y_train = np.array(y_train)
    X_test = np.array(X_test)
    y_test = np.array(y_test)
    print("X_train.shape:", X_train.shape)
    print("y_train.shape:", y_train.shape)
    print("X_test.shape:", X_test.shape)
    print("y_test.shape:", y_test.shape)
    ### SMOTE

    from imblearn.over_sampling import SMOTE
    from collections import Counter

    sm = SMOTE(random_state=42)
    X_train, y_train = sm.fit_resample(X_train, y_train)
    print('Resampled dataset shape %s' % Counter(y_train))
    print("##############################################")
    print("SMOTE done!")
    print("X_train.shape:", X_train.shape)
    print("y_train.shape:", y_train.shape)
    print("X_test.shape:", X_test.shape)
    print("y_test.shape:", y_test.shape)
    # training model
    from sklearn import svm
    from sklearn.preprocessing import StandardScaler
    from sklearn.neighbors import KNeighborsClassifier

    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_test = scaler.transform(X_test)
    from sklearn.naive_bayes import GaussianNB

    # 创建一个Gaussian Naive Bayes分类器
    nb = GaussianNB()
    nb.fit(X_train, y_train)
    y_pred = nb.predict(X_test)
    print("y_pred.shape:", y_pred.shape)


    from self_metrics import Binary_got_metrics
    from self_metrics import Binary_got_cofusion_matrix
    from self_metrics import Binary_got_metrics
    TP, FP, FN, TN = Binary_got_cofusion_matrix(y_test, y_pred, labels = [1,0])


    Accuracy, misclassification_rate, Sensitivity, Specificity, Precision, Negative_Predictive_Value, Gmean, Fmean, DPower, F2measure, InvF_05, AGFmeasure, Balanced_Accuracy, MCCmeasure, Kappa, Youden_Index, LR_pos, LR_neg = Binary_got_metrics(TP, FP, FN, TN)
    import json

            # 构造一个包含所有指标数据的字典
    metrics_dict = {
                "Number of label 3 in the final training set": len(cifar3_train_data),
                "Number of label 4 in the final training set (after downsampling)": len(fraction_cifar4_train_data),
                "Number of label 3 in the final test set": len(cifar3_test_data),
                "Number of label 4 in the final test set": len(cifar4_test_data),
                "Total samples in final training set": len(Final_train_dataset),
                "Total samples in final test set": len(Final_test_dataset),
                "Number of batches in training set": len(train_loader),
                "Number of batches in test set": len(test_loader),
                "TP": TP,
                "FP": FP,
                "FN": FN,
                "TN": TN,
                "Accuracy": round(Accuracy, 4),
                "Misclassification rate": round(misclassification_rate, 4),
                "Sensitivity (Recall)": round(Sensitivity, 4),
                "Specificity": round(Specificity, 4),
                "Precision": round(Precision, 4),
                "Negative Predictive Value": round(Negative_Predictive_Value, 4),
                "G-mean": round(Gmean, 4),
                "F-measure": round(Fmean, 4),
                "Discriminant Power (DP)": round(DPower, 4),
                "F2-measure": round(F2measure, 4),
                "InvF0.5-measure": round(InvF_05, 4),
                "AGF": round(AGFmeasure, 4),
                "Balanced Accuracy": round(Balanced_Accuracy, 4),
                "Matthew's Correlation Coefficient (MCC)": round(MCCmeasure, 4),
                "Cohen's Kappa": round(Kappa, 4),
                "Youden's Index": round(Youden_Index, 4),
                "Positive Likelihood Ratio (LR+)": round(LR_pos, 4),
                "Negative Likelihood Ratio (LR-)": round(LR_neg, 4)
            }

            # 指定 JSON 文件保存路径
    metrics_results_path = f"SMOTE_NavieBayesBinaryCIFAR1034_{fraction}_metrics_results.json"
    # 将字典保存为 JSON 文件
    with open(metrics_results_path, "w") as f:
        json.dump(metrics_dict, f, indent=4)
# Out:
# Number of label 1 in the final training set:  5000
# Number of label 0 in the final training set (after downsampling):  25
# Number of label 1 in the final test set:  1000
# Number of label 0 in the final test set:  1000
# Total samples in final training set:  5025
# Total samples in final test set:  2000
# Number of batches in training set:  79
# Number of batches in test set:  32
# Images shape: torch.Size([64, 3, 32, 32])
# Labels shape: torch.Size([64])
# X_train.shape: (5025, 3072)
# y_train.shape: (5025,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# Resampled dataset shape Counter({np.int64(1): 5000, np.int64(0): 5000})
# ##############################################
# SMOTE done!
# X_train.shape: (10000, 3072)
# y_train.shape: (10000,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# y_pred.shape: (2000,)
# TP: 771
# FP: 436
# FN: 229
# TN: 564
# Accuracy: 0.6675
# Misclassification rate: 0.3325
# Sensitivity (Recall): 0.7710
# Specificity: 0.5640
# Precision: 0.6388
# Negative Predictive Value: 0.7112
# G-mean: 0.6594
# F-measure: 0.6987
# Discriminant Power: 0.8112
# F2-measure: 0.6615
# InvF0.5-measure: 0.7403
# AGF: 0.6998
# Balanced Accuracy: 0.6675
# Matthew's Correlation Coefficient: 0.3424
# Cohen's Kappa: 0.3350
# Youden's Index: 0.3350
# Positive Likelihood Ratio: 1.7683
# Negative Likelihood Ratio: 0.4060
# Number of label 1 in the final training set:  5000
# Number of label 0 in the final training set (after downsampling):  50
# Number of label 1 in the final test set:  1000
# Number of label 0 in the final test set:  1000
# Total samples in final training set:  5050
# Total samples in final test set:  2000
# Number of batches in training set:  79
# Number of batches in test set:  32
# Images shape: torch.Size([64, 3, 32, 32])
# Labels shape: torch.Size([64])
# X_train.shape: (5050, 3072)
# y_train.shape: (5050,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# Resampled dataset shape Counter({np.int64(1): 5000, np.int64(0): 5000})
# ##############################################
# SMOTE done!
# X_train.shape: (10000, 3072)
# y_train.shape: (10000,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# y_pred.shape: (2000,)
# TP: 825
# FP: 459
# FN: 175
# TN: 541
# Accuracy: 0.6830
# Misclassification rate: 0.3170
# Sensitivity (Recall): 0.8250
# Specificity: 0.5410
# Precision: 0.6425
# Negative Predictive Value: 0.7556
# G-mean: 0.6681
# F-measure: 0.7224
# Discriminant Power: 0.9455
# F2-measure: 0.6723
# InvF0.5-measure: 0.7807
# AGF: 0.7244
# Balanced Accuracy: 0.6830
# Matthew's Correlation Coefficient: 0.3817
# Cohen's Kappa: 0.3660
# Youden's Index: 0.3660
# Positive Likelihood Ratio: 1.7974
# Negative Likelihood Ratio: 0.3235
# Number of label 1 in the final training set:  5000
# Number of label 0 in the final training set (after downsampling):  100
# Number of label 1 in the final test set:  1000
# Number of label 0 in the final test set:  1000
# Total samples in final training set:  5100
# Total samples in final test set:  2000
# Number of batches in training set:  80
# Number of batches in test set:  32
# Images shape: torch.Size([64, 3, 32, 32])
# Labels shape: torch.Size([64])
# X_train.shape: (5100, 3072)
# y_train.shape: (5100,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# Resampled dataset shape Counter({np.int64(1): 5000, np.int64(0): 5000})
# ##############################################
# SMOTE done!
# X_train.shape: (10000, 3072)
# y_train.shape: (10000,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# y_pred.shape: (2000,)
# TP: 778
# FP: 415
# FN: 222
# TN: 585
# Accuracy: 0.6815
# Misclassification rate: 0.3185
# Sensitivity (Recall): 0.7780
# Specificity: 0.5850
# Precision: 0.6521
# Negative Predictive Value: 0.7249
# G-mean: 0.6746
# F-measure: 0.7095
# Discriminant Power: 0.8807
# F2-measure: 0.6739
# InvF0.5-measure: 0.7491
# AGF: 0.7105
# Balanced Accuracy: 0.6815
# Matthew's Correlation Coefficient: 0.3700
# Cohen's Kappa: 0.3630
# Youden's Index: 0.3630
# Positive Likelihood Ratio: 1.8747
# Negative Likelihood Ratio: 0.3795
# Number of label 1 in the final training set:  5000
# Number of label 0 in the final training set (after downsampling):  250
# Number of label 1 in the final test set:  1000
# Number of label 0 in the final test set:  1000
# Total samples in final training set:  5250
# Total samples in final test set:  2000
# Number of batches in training set:  83
# Number of batches in test set:  32
# Images shape: torch.Size([64, 3, 32, 32])
# Labels shape: torch.Size([64])
# X_train.shape: (5250, 3072)
# y_train.shape: (5250,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# Resampled dataset shape Counter({np.int64(1): 5000, np.int64(0): 5000})
# ##############################################
# SMOTE done!
# X_train.shape: (10000, 3072)
# y_train.shape: (10000,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# y_pred.shape: (2000,)
# TP: 733
# FP: 385
# FN: 267
# TN: 615
# Accuracy: 0.6740
# Misclassification rate: 0.3260
# Sensitivity (Recall): 0.7330
# Specificity: 0.6150
# Precision: 0.6556
# Negative Predictive Value: 0.6973
# G-mean: 0.6714
# F-measure: 0.6922
# Discriminant Power: 0.8150
# F2-measure: 0.6698
# InvF0.5-measure: 0.7161
# AGF: 0.6925
# Balanced Accuracy: 0.6740
# Matthew's Correlation Coefficient: 0.3504
# Cohen's Kappa: 0.3480
# Youden's Index: 0.3480
# Positive Likelihood Ratio: 1.9039
# Negative Likelihood Ratio: 0.4341
# Number of label 1 in the final training set:  5000
# Number of label 0 in the final training set (after downsampling):  500
# Number of label 1 in the final test set:  1000
# Number of label 0 in the final test set:  1000
# Total samples in final training set:  5500
# Total samples in final test set:  2000
# Number of batches in training set:  86
# Number of batches in test set:  32
# Images shape: torch.Size([64, 3, 32, 32])
# Labels shape: torch.Size([64])
# X_train.shape: (5500, 3072)
# y_train.shape: (5500,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# Resampled dataset shape Counter({np.int64(1): 5000, np.int64(0): 5000})
# ##############################################
# SMOTE done!
# X_train.shape: (10000, 3072)
# y_train.shape: (10000,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# y_pred.shape: (2000,)
# TP: 675
# FP: 305
# FN: 325
# TN: 695
# Accuracy: 0.6850
# Misclassification rate: 0.3150
# Sensitivity (Recall): 0.6750
# Specificity: 0.6950
# Precision: 0.6888
# Negative Predictive Value: 0.6814
# G-mean: 0.6849
# F-measure: 0.6818
# Discriminant Power: 0.8570
# F2-measure: 0.6860
# InvF0.5-measure: 0.6777
# AGF: 0.6818
# Balanced Accuracy: 0.6850
# Matthew's Correlation Coefficient: 0.3701
# Cohen's Kappa: 0.3700
# Youden's Index: 0.3700
# Positive Likelihood Ratio: 2.2131
# Negative Likelihood Ratio: 0.4676
# Number of label 1 in the final training set:  5000
# Number of label 0 in the final training set (after downsampling):  1000
# Number of label 1 in the final test set:  1000
# Number of label 0 in the final test set:  1000
# Total samples in final training set:  6000
# Total samples in final test set:  2000
# Number of batches in training set:  94
# Number of batches in test set:  32
# Images shape: torch.Size([64, 3, 32, 32])
# Labels shape: torch.Size([64])
# X_train.shape: (6000, 3072)
# y_train.shape: (6000,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# Resampled dataset shape Counter({np.int64(1): 5000, np.int64(0): 5000})
# ##############################################
# SMOTE done!
# X_train.shape: (10000, 3072)
# y_train.shape: (10000,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# y_pred.shape: (2000,)
# TP: 681
# FP: 313
# FN: 319
# TN: 687
# Accuracy: 0.6840
# Misclassification rate: 0.3160
# Sensitivity (Recall): 0.6810
# Specificity: 0.6870
# Precision: 0.6851
# Negative Predictive Value: 0.6829
# G-mean: 0.6840
# F-measure: 0.6830
# Discriminant Power: 0.8515
# F2-measure: 0.6843
# InvF0.5-measure: 0.6818
# AGF: 0.6831
# Balanced Accuracy: 0.6840
# Matthew's Correlation Coefficient: 0.3680
# Cohen's Kappa: 0.3680
# Youden's Index: 0.3680
# Positive Likelihood Ratio: 2.1757
# Negative Likelihood Ratio: 0.4643

# %%
from Swim_Maha import SwimMaha
fractions = [0.005, 0.01, 0.02, 0.05, 0.1, 0.2]
for frac in range(len(fractions)):
    import torch
    from torch.utils.data import DataLoader, Subset, ConcatDataset, TensorDataset
    from torchvision import datasets, transforms
    import numpy as np

    # CIFAR10 数据归一化参数
    # 数据预处理
    cifar10_transforms = transforms.Compose([
        transforms.ToTensor(), 
        transforms.Normalize((0.4914, 0.4822, 0.4465), (0.247, 0.243, 0.261))
    ])
    # 加载 CIFAR10 数据集
    full_train_dataset = datasets.CIFAR10(
        root="/Users/max/MasterThesisData/CIFAR10", train=True, transform=cifar10_transforms, download=True)
    full_test_dataset = datasets.CIFAR10(
        root="/Users/max/MasterThesisData/CIFAR10", train=False, transform=cifar10_transforms, download=True)

    # 筛选训练集中的标签 3 和 4，并映射标签（标签 3 -> 1，标签 4 -> 0）
    indices3_train = [i for i in range(len(full_train_dataset)) if full_train_dataset.targets[i] == 3]
    indices4_train = [i for i in range(len(full_train_dataset)) if full_train_dataset.targets[i] == 4]

    # 筛选测试集中的标签 3 和 4，并映射标签
    indices3_test = [i for i in range(len(full_test_dataset)) if full_test_dataset.targets[i] == 3]
    indices4_test = [i for i in range(len(full_test_dataset)) if full_test_dataset.targets[i] == 4]

    # 训练集：获取标签为 3 的数据（映射为 1）
    cifar3_train_data = full_train_dataset.data[indices3_train]  # numpy 数组，形状 (n, 32, 32, 3)
    cifar3_train_labels = torch.ones(len(indices3_train), dtype=torch.long)

    # 训练集：获取标签为 4 的数据（映射为 0）
    cifar4_train_data = full_train_dataset.data[indices4_train]
    cifar4_train_labels = torch.zeros(len(indices4_train), dtype=torch.long)

    # 测试集：获取标签为 3 的数据（映射为 1）
    cifar3_test_data = full_test_dataset.data[indices3_test]
    cifar3_test_labels = torch.ones(len(indices3_test), dtype=torch.long)

    # 测试集：获取标签为 4 的数据（映射为 0）
    cifar4_test_data = full_test_dataset.data[indices4_test]
    cifar4_test_labels = torch.zeros(len(indices4_test), dtype=torch.long)

    # 控制不平衡比例，比如这里设定为 0.005（即只选取标签 4 数据中的一小部分）
    fraction = int(fractions[frac] * len(cifar3_train_data))
    selected_indices_4 = np.random.choice(len(cifar4_train_data), fraction, replace=False)
    fraction_cifar4_train_data = cifar4_train_data[selected_indices_4]
    fraction_cifar4_train_labels = cifar4_train_labels[selected_indices_4]

    # 拼接最终的训练和测试数据集
    Final_train_data = np.concatenate([cifar3_train_data, fraction_cifar4_train_data], axis=0)
    Final_train_labels = torch.cat([cifar3_train_labels, fraction_cifar4_train_labels], dim=0)

    Final_test_data = np.concatenate([cifar3_test_data, cifar4_test_data], axis=0)
    Final_test_labels = torch.cat([cifar3_test_labels, cifar4_test_labels], dim=0)

    # 将 numpy 数组转换为 tensor，并调整维度为 (N, C, H, W)
    Final_train_data = torch.from_numpy(Final_train_data).permute(0, 3, 1, 2).float()
    Final_test_data = torch.from_numpy(Final_test_data).permute(0, 3, 1, 2).float()

    # 归一化图像数据：先除以 255，再进行标准化
    # # 创建 TensorDataset
    # Final_train_datasets = TensorDataset(Final_train_data.unsqueeze(3).float() / 255, Final_train_labels)
    # Final_test_datasets = TensorDataset(Final_test_data.unsqueeze(3).float() / 255, Final_test_labels)

    # 创建 TensorDataset
    Final_train_dataset = TensorDataset(Final_train_data.float() / 255, Final_train_labels)
    Final_test_dataset = TensorDataset(Final_test_data.float() / 255, Final_test_labels)

    # 数据加载器
    train_loader = DataLoader(Final_train_dataset, batch_size=64, shuffle=True)
    test_loader = DataLoader(Final_test_dataset, batch_size=64, shuffle=False)

    # 打印数据信息
    print("Number of label 1 in the final training set: ", len(cifar3_train_data))
    print("Number of label 0 in the final training set (after downsampling): ", len(fraction_cifar4_train_data))
    print("Number of label 1 in the final test set: ", len(cifar3_test_data))
    print("Number of label 0 in the final test set: ", len(cifar4_test_data))

    print("Total samples in final training set: ", len(Final_train_dataset))
    print("Total samples in final test set: ", len(Final_test_dataset))

    print("Number of batches in training set: ", len(train_loader))
    print("Number of batches in test set: ", len(test_loader))


    
    ## 获取一个 batch
    images, labels = next(iter(train_loader))

    # 打印张量信息
    print(f"Images shape: {images.shape}")  # (batch_size, 3, 32, 32)
    print(f"Labels shape: {labels.shape}")

    # 将第一张图像的维度转换为 (H, W, C) 并显示
    img = images[0].permute(1, 2, 0).numpy()  # (32, 32, 3)
    plt.imshow(img)  # 对于彩色图像，无需指定 cmap
    plt.title(f"Label: {labels[0].item()}")
    plt.show()

    plt.figure(figsize=(20, 5))
    for i, img_tensor in enumerate(images[:20]):
        # 将每张图像转换为 (H, W, C)
        npimg = img_tensor.permute(1, 2, 0).numpy()
        plt.subplot(2, 10, i+1)
        plt.imshow(npimg)  # 彩色图像，不指定 cmap
        plt.axis('off')
    plt.show()


    X_train = []
    y_train = []

    for batch in train_loader:
        images, labels = batch  # images: (batch_size, 1, 28, 28), labels: (batch_size,)
        if hasattr(images, 'numpy'): # images is tensor
            images = images.numpy()
        # batch_size = 64
        for img, label in zip(images, labels):
            #print(f"Original shape: {img.shape}")  #  
            flattened_img = img.flatten()           
            #print(f"Flattened shape: {flattened_img.shape}")
            X_train.append(flattened_img) # 
            y_train.append(label)


    X_test = [] # features
    y_test = [] # labels
    for batch in test_loader:
        images, labels = batch  # images: (batch_size, 1,28  ,28 ), labels: (batch_size,)
        if hasattr(images, 'numpy'): # images is tensor
            images = images.numpy()
        # batch_size = 64
        for img, label in zip(images, labels):
            flattened_img = img.flatten()           # flatten the image
            X_test.append(flattened_img)
            y_test.append(label)


    X_train = np.array(X_train)
    y_train = np.array(y_train)
    X_test = np.array(X_test)
    y_test = np.array(y_test)
    print("X_train.shape:", X_train.shape)
    print("y_train.shape:", y_train.shape)
    print("X_test.shape:", X_test.shape)
    print("y_test.shape:", y_test.shape)
    ### SMOTE

    from imblearn.over_sampling import SMOTE
    from collections import Counter

    sm = SMOTE(random_state=42)
    X_train, y_train = sm.fit_resample(X_train, y_train)
    print('Resampled dataset shape %s' % Counter(y_train))
    print("##############################################")
    print("SMOTE done!")
    print("X_train.shape:", X_train.shape)
    print("y_train.shape:", y_train.shape)
    print("X_test.shape:", X_test.shape)
    print("y_test.shape:", y_test.shape)
    # training model
    from sklearn import svm
    from sklearn.preprocessing import StandardScaler
    from sklearn.neighbors import KNeighborsClassifier

    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_test = scaler.transform(X_test)
    # 创建一个KNN分类器，设定邻居数为5（你可以根据需要调整n_neighbors的值）
    knn = KNeighborsClassifier(n_neighbors=5)
    knn.fit(X_train, y_train)
    y_pred = knn.predict(X_test)
    print("y_pred.shape:", y_pred.shape)



    from self_metrics import Binary_got_metrics
    from self_metrics import Binary_got_cofusion_matrix
    from self_metrics import Binary_got_metrics
    TP, FP, FN, TN = Binary_got_cofusion_matrix(y_test, y_pred, labels = [1,0])


    Accuracy, misclassification_rate, Sensitivity, Specificity, Precision, Negative_Predictive_Value, Gmean, Fmean, DPower, F2measure, InvF_05, AGFmeasure, Balanced_Accuracy, MCCmeasure, Kappa, Youden_Index, LR_pos, LR_neg = Binary_got_metrics(TP, FP, FN, TN)
    import json

            # 构造一个包含所有指标数据的字典
    metrics_dict = {
                "Number of label 3 in the final training set": len(cifar3_train_data),
                "Number of label 4 in the final training set (after downsampling)": len(fraction_cifar4_train_data),
                "Number of label 3 in the final test set": len(cifar3_test_data),
                "Number of label 4 in the final test set": len(cifar4_test_data),
                "Total samples in final training set": len(Final_train_dataset),
                "Total samples in final test set": len(Final_test_dataset),
                "Number of batches in training set": len(train_loader),
                "Number of batches in test set": len(test_loader),
                "TP": TP,
                "FP": FP,
                "FN": FN,
                "TN": TN,
                "Accuracy": round(Accuracy, 4),
                "Misclassification rate": round(misclassification_rate, 4),
                "Sensitivity (Recall)": round(Sensitivity, 4),
                "Specificity": round(Specificity, 4),
                "Precision": round(Precision, 4),
                "Negative Predictive Value": round(Negative_Predictive_Value, 4),
                "G-mean": round(Gmean, 4),
                "F-measure": round(Fmean, 4),
                "Discriminant Power (DP)": round(DPower, 4),
                "F2-measure": round(F2measure, 4),
                "InvF0.5-measure": round(InvF_05, 4),
                "AGF": round(AGFmeasure, 4),
                "Balanced Accuracy": round(Balanced_Accuracy, 4),
                "Matthew's Correlation Coefficient (MCC)": round(MCCmeasure, 4),
                "Cohen's Kappa": round(Kappa, 4),
                "Youden's Index": round(Youden_Index, 4),
                "Positive Likelihood Ratio (LR+)": round(LR_pos, 4),
                "Negative Likelihood Ratio (LR-)": round(LR_neg, 4)
            }

            # 指定 JSON 文件保存路径
    metrics_results_path = f"SMOTE_KNNBinaryCIFAR1034_{fraction}_metrics_results.json"
    # 将字典保存为 JSON 文件
    with open(metrics_results_path, "w") as f:
        json.dump(metrics_dict, f, indent=4)
# Out:
# Number of label 1 in the final training set:  5000
# Number of label 0 in the final training set (after downsampling):  25
# Number of label 1 in the final test set:  1000
# Number of label 0 in the final test set:  1000
# Total samples in final training set:  5025
# Total samples in final test set:  2000
# Number of batches in training set:  79
# Number of batches in test set:  32
# Images shape: torch.Size([64, 3, 32, 32])
# Labels shape: torch.Size([64])
# X_train.shape: (5025, 3072)
# y_train.shape: (5025,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# Resampled dataset shape Counter({np.int64(1): 5000, np.int64(0): 5000})
# ##############################################
# SMOTE done!
# X_train.shape: (10000, 3072)
# y_train.shape: (10000,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# y_pred.shape: (2000,)
# TP: 758
# FP: 439
# FN: 242
# TN: 561
# Accuracy: 0.6595
# Misclassification rate: 0.3405
# Sensitivity (Recall): 0.7580
# Specificity: 0.5610
# Precision: 0.6332
# Negative Predictive Value: 0.6986
# G-mean: 0.6521
# F-measure: 0.6900
# Discriminant Power: 0.7647
# F2-measure: 0.6548
# InvF0.5-measure: 0.7293
# AGF: 0.6910
# Balanced Accuracy: 0.6595
# Matthew's Correlation Coefficient: 0.3254
# Cohen's Kappa: 0.3190
# Youden's Index: 0.3190
# Positive Likelihood Ratio: 1.7267
# Negative Likelihood Ratio: 0.4314
# Number of label 1 in the final training set:  5000
# Number of label 0 in the final training set (after downsampling):  50
# Number of label 1 in the final test set:  1000
# Number of label 0 in the final test set:  1000
# Total samples in final training set:  5050
# Total samples in final test set:  2000
# Number of batches in training set:  79
# Number of batches in test set:  32
# Images shape: torch.Size([64, 3, 32, 32])
# Labels shape: torch.Size([64])
# X_train.shape: (5050, 3072)
# y_train.shape: (5050,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# Resampled dataset shape Counter({np.int64(1): 5000, np.int64(0): 5000})
# ##############################################
# SMOTE done!
# X_train.shape: (10000, 3072)
# y_train.shape: (10000,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# y_pred.shape: (2000,)
# TP: 692
# FP: 314
# FN: 308
# TN: 686
# Accuracy: 0.6890
# Misclassification rate: 0.3110
# Sensitivity (Recall): 0.6920
# Specificity: 0.6860
# Precision: 0.6879
# Negative Predictive Value: 0.6901
# G-mean: 0.6890
# F-measure: 0.6899
# Discriminant Power: 0.8771
# F2-measure: 0.6887
# InvF0.5-measure: 0.6912
# AGF: 0.6899
# Balanced Accuracy: 0.6890
# Matthew's Correlation Coefficient: 0.3780
# Cohen's Kappa: 0.3780
# Youden's Index: 0.3780
# Positive Likelihood Ratio: 2.2038
# Negative Likelihood Ratio: 0.4490
# Number of label 1 in the final training set:  5000
# Number of label 0 in the final training set (after downsampling):  100
# Number of label 1 in the final test set:  1000
# Number of label 0 in the final test set:  1000
# Total samples in final training set:  5100
# Total samples in final test set:  2000
# Number of batches in training set:  80
# Number of batches in test set:  32
# Images shape: torch.Size([64, 3, 32, 32])
# Labels shape: torch.Size([64])
# X_train.shape: (5100, 3072)
# y_train.shape: (5100,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# Resampled dataset shape Counter({np.int64(1): 5000, np.int64(0): 5000})
# ##############################################
# SMOTE done!
# X_train.shape: (10000, 3072)
# y_train.shape: (10000,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# y_pred.shape: (2000,)
# TP: 540
# FP: 212
# FN: 460
# TN: 788
# Accuracy: 0.6640
# Misclassification rate: 0.3360
# Sensitivity (Recall): 0.5400
# Specificity: 0.7880
# Precision: 0.7181
# Negative Predictive Value: 0.6314
# G-mean: 0.6523
# F-measure: 0.6164
# Discriminant Power: 0.8122
# F2-measure: 0.6737
# InvF0.5-measure: 0.5682
# AGF: 0.6187
# Balanced Accuracy: 0.6640
# Matthew's Correlation Coefficient: 0.3386
# Cohen's Kappa: 0.3280
# Youden's Index: 0.3280
# Positive Likelihood Ratio: 2.5472
# Negative Likelihood Ratio: 0.5838
# Number of label 1 in the final training set:  5000
# Number of label 0 in the final training set (after downsampling):  250
# Number of label 1 in the final test set:  1000
# Number of label 0 in the final test set:  1000
# Total samples in final training set:  5250
# Total samples in final test set:  2000
# Number of batches in training set:  83
# Number of batches in test set:  32
# Images shape: torch.Size([64, 3, 32, 32])
# Labels shape: torch.Size([64])
# X_train.shape: (5250, 3072)
# y_train.shape: (5250,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# Resampled dataset shape Counter({np.int64(1): 5000, np.int64(0): 5000})
# ##############################################
# SMOTE done!
# X_train.shape: (10000, 3072)
# y_train.shape: (10000,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# y_pred.shape: (2000,)
# TP: 448
# FP: 106
# FN: 552
# TN: 894
# Accuracy: 0.6710
# Misclassification rate: 0.3290
# Sensitivity (Recall): 0.4480
# Specificity: 0.8940
# Precision: 0.8087
# Negative Predictive Value: 0.6183
# G-mean: 0.6329
# F-measure: 0.5766
# Discriminant Power: 1.0605
# F2-measure: 0.6965
# InvF0.5-measure: 0.4919
# AGF: 0.5853
# Balanced Accuracy: 0.6710
# Matthew's Correlation Coefficient: 0.3821
# Cohen's Kappa: 0.3420
# Youden's Index: 0.3420
# Positive Likelihood Ratio: 4.2264
# Negative Likelihood Ratio: 0.6174
# Number of label 1 in the final training set:  5000
# Number of label 0 in the final training set (after downsampling):  500
# Number of label 1 in the final test set:  1000
# Number of label 0 in the final test set:  1000
# Total samples in final training set:  5500
# Total samples in final test set:  2000
# Number of batches in training set:  86
# Number of batches in test set:  32
# Images shape: torch.Size([64, 3, 32, 32])
# Labels shape: torch.Size([64])
# X_train.shape: (5500, 3072)
# y_train.shape: (5500,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# Resampled dataset shape Counter({np.int64(1): 5000, np.int64(0): 5000})
# ##############################################
# SMOTE done!
# X_train.shape: (10000, 3072)
# y_train.shape: (10000,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# y_pred.shape: (2000,)
# TP: 375
# FP: 56
# FN: 625
# TN: 944
# Accuracy: 0.6595
# Misclassification rate: 0.3405
# Sensitivity (Recall): 0.3750
# Specificity: 0.9440
# Precision: 0.8701
# Negative Predictive Value: 0.6017
# G-mean: 0.5950
# F-measure: 0.5241
# Discriminant Power: 1.2757
# F2-measure: 0.6883
# InvF0.5-measure: 0.4232
# AGF: 0.5397
# Balanced Accuracy: 0.6595
# Matthew's Correlation Coefficient: 0.3879
# Cohen's Kappa: 0.3190
# Youden's Index: 0.3190
# Positive Likelihood Ratio: 6.6964
# Negative Likelihood Ratio: 0.6621
# Number of label 1 in the final training set:  5000
# Number of label 0 in the final training set (after downsampling):  1000
# Number of label 1 in the final test set:  1000
# Number of label 0 in the final test set:  1000
# Total samples in final training set:  6000
# Total samples in final test set:  2000
# Number of batches in training set:  94
# Number of batches in test set:  32
# Images shape: torch.Size([64, 3, 32, 32])
# Labels shape: torch.Size([64])
# X_train.shape: (6000, 3072)
# y_train.shape: (6000,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# Resampled dataset shape Counter({np.int64(1): 5000, np.int64(0): 5000})
# ##############################################
# SMOTE done!
# X_train.shape: (10000, 3072)
# y_train.shape: (10000,)
# X_test.shape: (2000, 3072)
# y_test.shape: (2000,)
# /Users/max/anaconda3/envs/Thesis/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# y_pred.shape: (2000,)
# TP: 330
# FP: 37
# FN: 670
# TN: 963
# Accuracy: 0.6465
# Misclassification rate: 0.3535
# Sensitivity (Recall): 0.3300
# Specificity: 0.9630
# Precision: 0.8992
# Negative Predictive Value: 0.5897
# G-mean: 0.5637
# F-measure: 0.4828
# Discriminant Power: 1.4064
# F2-measure: 0.6686
# InvF0.5-measure: 0.3778
# AGF: 0.5026
# Balanced Accuracy: 0.6465
# Matthew's Correlation Coefficient: 0.3785
# Cohen's Kappa: 0.2930
# Youden's Index: 0.2930
# Positive Likelihood Ratio: 8.9189
# Negative Likelihood Ratio: 0.6957
